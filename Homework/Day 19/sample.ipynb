# %% [markdown]
# # 動態網頁爬蟲 - API Request
#
# * 了解 API Request 用於動態網頁爬蟲的原理
# * 能夠使用 API Request 撰寫動態網頁爬蟲

# %% [markdown]
# ## 觀察 API 請求資訊

# %% [markdown]
# ![](https://imgur.com/qBmCUxR.jpg)

# %% [markdown]
# ![](https://imgur.com/Xi5kYFX.jpg)

# %%
import requests
import json

r = requests.get('https://fhy.wra.gov.tw/fhy/api/ReservoirInfoApi/DryAreaGetAll')
d = json.loads(r.text)

d
# Out:
# [{'AREA_NO': 'A01',
#   'AREA_NAME': '北區',
#   'Warns': None,
#   'DryView': [{'AREA_NO': None,
#     'AREA_Name': None,
#     'DATE': '2020-06-12T04:00:00',
#     'NWL_MX': 245.0,
#     'Capacity': 14037.5775268754,
#     'CapacityRate': 71.11054698146147,
#     'Status': 5,
#     'Basin_Rain': 0.3,
#     'EffectiveCapacity': 19740.5,
#     'StationNo': '10201',
#     'StationName': '石門水庫',
#     'BasinNo': '1140',
#     'Basin': None},
#    {'AREA_NO': None,
#     'AREA_Name': None,
#     'DATE': '2020-06-11T08:00:00',
#     'NWL_MX': 86.0,
#     'Capacity': 966.5,
#     'CapacityRate': 96.45708582834331,
#     'Status': 5,
#     'Basin_Rain': 0.0,
#     'EffectiveCapacity': 1002.0,
#     'StationNo': '10204',
#     'StationName': '新山水庫',
#     'BasinNo': '1140',
#     'Basin': None},
#    {'AREA_NO': None,
#     'AREA_Name': None,
#     'DATE': '2020-06-12T04:00:00',
#     'NWL_MX': 170.0,
#     'Capacity': 24656.45,
#     'CapacityRate': 73.49055900806248,
#     'Status': 5,
#     'Basin_Rain': 0.0,
#     'EffectiveCapacity': 33550.5,
#     'StationNo': '10205',
#     'StationName': '翡翠水庫',
#     'BasinNo': '1140',
#     'Basin': None},
#    {'AREA_NO': None,
#     'AREA_Name': None,
#     'DATE': '2020-06-12T01:00:00',
#     'NWL_MX': 150.0,
#     'Capacity': 3172.12,
#     'CapacityRate': 100.0,
#     'Status': 5,
#     'Basin_Rain': 0.0,
#     'EffectiveCapacity': 3147.18,
#     'StationNo': '10405',
#     'StationName': '寶山第二水庫',
#     'BasinNo': '1300',
#     'Basin': None},
#    {'AREA_NO': None,
#     'AREA_Name': None,
#     'DATE': '2020-06-12T04:00:00',
#     'NWL_MX': 85.0,
#     'Capacity': 1969.08,
#     'CapacityRate': 65.65919958385295,
#     'Status': 5,
#     'Basin_Rain': 0.0,
#     'EffectiveCapacity': 2998.94,
#     'StationNo': '10501',
#     'StationName': '永和山水庫',
#     'BasinNo': '105',
#     'Basin': None},
#    {'AREA_NO': None,
#     'AREA_Name': None,
#     'DATE': '2020-06-11T07:00:00',
#     'NWL_MX': 61.0,
#     'Capacity': 1164.91,
#     'CapacityRate': 95.3245154481016,
#     'Status': 5,
#     'Basin_Rain': 0.0,
#     'EffectiveCapacity': 1276.0,
#     'StationNo': '10601',
#     'StationName': '明德水庫',
#     'BasinNo': '1350',
#     'Basin': None}]},
#  {'AREA_NO': 'A02',
#   'AREA_NAME': '中區',
#   'Warns': None,
#   'DryView': [{'AREA_NO': None,
#     'AREA_Name': None,
#     'DATE': '2020-06-12T04:00:00',
#     'NWL_MX': 300.0,
#     'Capacity': 8460.73,
#     'CapacityRate': 73.88315941143081,
#     'Status': 5,
#     'Basin_Rain': 0.0,
#     'EffectiveCapacity': 11448.69,
#     'StationNo': '20101',
#     'StationName': '鯉魚潭水庫',
#     'BasinNo': '1400',
#     'Basin': None},
#    {'AREA_NO': None,
#     'AREA_Name': None,
#     'DATE': '2020-06-11T07:00:00',
#     'NWL_MX': 1408.0,
#     'Capacity': 8919.21,
#     'CapacityRate': 59.768210145413114,
#     'Status': 5,
#     'Basin_Rain': 0.0,
#     'EffectiveCapacity': 15000.0,
#     'StationNo': '20201',
#     'StationName': '德基水庫',
#     'BasinNo': '1420',
#     'Basin': None},
#    {'AREA_NO': None,
#     'AREA_Name': None,
#     'DATE': '2020-06-12T03:00:00',
#     'NWL_MX': 274.5,
#     'Capacity': 100.08,
#     'CapacityRate': 68.98738540015165,
#     'Status': 5,
#     'Basin_Rain': 0.0,
#     'EffectiveCapacity': 142.17,
#     'StationNo': '20202',
#     'StationName': '石岡壩',
#     'BasinNo': '1420',
#     'Basin': None},
#    {'AREA_NO': None,
#     'AREA_Name': None,
#     'DATE': '2020-06-11T07:00:00',
#     'NWL_MX': 1005.0,
#     'Capacity': 3486.93,
#     'CapacityRate': 93.0883142053964,
#     'Status': 5,
#     'Basin_Rain': 0.0,
#     'EffectiveCapacity': 4505.57,
#     'StationNo': '20501',
#     'StationName': '霧社水庫',
#     'BasinNo': '1510',
#     'Basin': None},
#    {'AREA_NO': None,
#     'AREA_Name': None,
#     'DATE': '2020-06-11T07:00:00',
#     'NWL_MX': 748.48,
#     'Capacity': 12508.61,
#     'CapacityRate': 97.79235227296715,
#     'Status': 5,
#     'Basin_Rain': 0.0,
#     'EffectiveCapacity': 12857.64,
#     'StationNo': '20502',
#     'StationName': '日月潭水庫',
#     'BasinNo': '1510',
#     'Basin': None},
#    {'AREA_NO': None,
#     'AREA_Name': None,
#     'DATE': '2020-06-12T04:00:00',
#     'NWL_MX': 211.5,
#     'Capacity': 3508.1,
#     'CapacityRate': 68.9686763739081,
#     'Status': 5,
#     'Basin_Rain': 0.0,
#     'EffectiveCapacity': 5085.0,
#     'StationNo': '20509',
#     'StationName': '湖山水庫',
#     'BasinNo': '1510',
#     'Basin': None}]},
#  {'AREA_NO': 'A03',
#   'AREA_NAME': '南區',
#   'Warns': None,
#   'DryView': [{'AREA_NO': None,
#     'AREA_Name': None,
#     'DATE': '2020-06-11T07:00:00',
#     'NWL_MX': 105.0,
#     'Capacity': 1712.84,
#     'CapacityRate': 67.76922285614808,
#     'Status': 5,
#     'Basin_Rain': 0.0,
#     'EffectiveCapacity': 2531.9,
#     'StationNo': '30301',
#     'StationName': '仁義潭水庫',
#     'BasinNo': '1580',
#     'Basin': None},
#    {'AREA_NO': None,
#     'AREA_Name': None,
#     'DATE': '2020-06-11T08:00:00',
#     'NWL_MX': 109.0,
#     'Capacity': 103.0,
#     'CapacityRate': 14.905234544718887,
#     'Status': 5,
#     'Basin_Rain': 0.0,
#     'EffectiveCapacity': 691.0324,
#     'StationNo': '30401',
#     'StationName': '白河水庫',
#     'BasinNo': '1590',
#     'Basin': None},
#    {'AREA_NO': None,
#     'AREA_Name': None,
#     'DATE': '2020-06-11T07:00:00',
#     'NWL_MX': 58.18,
#     'Capacity': 6514.0,
#     'CapacityRate': 83.21410321921307,
#     'Status': 5,
#     'Basin_Rain': 0.0,
#     'EffectiveCapacity': 7828.0,
#     'StationNo': '30501',
#     'StationName': '烏山頭水庫',
#     'BasinNo': '1590',
#     'Basin': None},
#    {'AREA_NO': None,
#     'AREA_Name': None,
#     'DATE': '2020-06-12T04:00:00',
#     'NWL_MX': 230.0,
#     'Capacity': 17196.07,
#     'CapacityRate': 33.81791185667368,
#     'Status': 5,
#     'Basin_Rain': 0.0,
#     'EffectiveCapacity': 51002.0,
#     'StationNo': '30502',
#     'StationName': '曾文水庫',
#     'BasinNo': '1630',
#     'Basin': None},
#    {'AREA_NO': None,
#     'AREA_Name': None,
#     'DATE': '2020-06-11T07:00:00',
#     'NWL_MX': 180.0,
#     'Capacity': 7477.96,
#     'CapacityRate': 82.35548066651248,
#     'Status': 5,
#     'Basin_Rain': 5.1,
#     'EffectiveCapacity': 9145.4,
#     'StationNo': '30503',
#     'StationName': '南化水庫',
#     'BasinNo': '1630',
#     'Basin': None},
#    {'AREA_NO': None,
#     'AREA_Name': None,
#     'DATE': '2020-06-12T04:00:00',
#     'NWL_MX': 37.0,
#     'Capacity': 84.74,
#     'CapacityRate': 5.565699423332063,
#     'Status': 5,
#     'Basin_Rain': 0.0,
#     'EffectiveCapacity': 1612.8,
#     'StationNo': '30802',
#     'StationName': '阿公店水庫',
#     'BasinNo': '308',
#     'Basin': None},
#    {'AREA_NO': None,
#     'AREA_Name': None,
#     'DATE': '2020-06-12T04:00:00',
#     'NWL_MX': 142.0,
#     'Capacity': 1523.7,
#     'CapacityRate': 57.590932404641606,
#     'Status': 5,
#     'Basin_Rain': 0.0,
#     'EffectiveCapacity': 2641.212,
#     'StationNo': '31201',
#     'StationName': '牡丹水庫',
#     'BasinNo': '312',
#     'Basin': None}]}]

# %% [markdown]
# ## 作業目標
#
# * 根據範例的教學，去找出 Dcard 中呼叫的 API 當中，有一個跟「取得所有看板」是哪一個？並且利用 Requests 呼叫。
