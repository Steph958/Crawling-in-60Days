# %% [markdown]
# # 104人力銀行網站爬蟲練習
# ## 從104人力銀行網站爬取求職公司資訊。

# %%
import time
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

# %% [markdown]
# ### 首先進入104人力銀行網站：https://www.104.com.tw/cust/list/index/
# ### 在"地區"及"產業"下拉式選單中，選擇你希望的選項，然後按下"找公司"按鈕。

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 開啟新網頁後，觀察新的網址內容，把網址複製下來。

# %%
job_104_url = "https://www.104.com.tw/cust/list/index/?page=1&order=1&mode=s&jobsource=checkc&area=6001001000&indcat=1001002000"

# %% [markdown]
# # 先看看網頁內容

# %%
browser = webdriver.Chrome(executable_path='../chromedriver.exe')
browser.get(job_104_url)  # 打開瀏覽器並連到網頁

time.sleep(3)  # delay一段時間等待網頁更新完成

# %%
html = browser.page_source
soup = BeautifulSoup(html, 'lxml')

print(soup)
#print(soup.find_all('a', class_="info-job__text"))
# Out:
# <html class="" lang="zh-Hant-TW"><head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, user-scalable=no" name="viewport"/>
# <meta content="telephone=no, email=no, adress=no" name="format-detection"/>
# <link href="https://www.104.com.tw/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="https://www.104.com.tw/favicon.ico" rel="icon" type="image/x-icon"/>
# <link href="https://static.104.com.tw/logo/104logo_o_76x76_appletouchicon.png" rel="apple-touch-icon" sizes="76x76" type="image/png"/>
# <link href="https://static.104.com.tw/logo/104logo_o_120x120_appletouchicon.png" rel="apple-touch-icon" sizes="120x120" type="image/png"/>
# <link href="https://static.104.com.tw/logo/104logo_o_152x152_appletouchicon.png" rel="apple-touch-icon" sizes="152x152" type="image/png"/>
# <link href="https://static.104.com.tw" rel="dns-prefetch"/>
# ...

# %% [markdown]
# 先觀察得到的程式碼內容，找出第一家公司名稱出現在何處，找出規律
#
# >>
#
# <div class="row company-lists__wrap" data-v-5481f08a="" data-v-f25fc5d8=""><div class="col-12 d-flex flex-wrap justify-content-between" data-v-5481f08a="" data-v-f25fc5d8="">
#
# 第一家:德駏股份有限公司
# <div class="company-list-desktop w-100 bg-white py-4 container-fluid border-bottom company-lists__list" data-v-5481f08a="" data-v-ddf7892e="" data-v-f25fc5d8=""><div class="row align-items-start" data-v-ddf7892e=""><div class="col-auto d-flex align-items-center mt-6 pr-4 company-list-desktop__corporate-icon__wrap" data-v-ddf7892e=""><!-- --><!-- --></div><div class="col-auto pl-0 d-flex align-items-center" data-v-ddf7892e=""><div class="company-list-desktop__logo mt-2" data-v-ddf7892e=""><a data-v-ddf7892e="" href="//www.104.com.tw/company/15btev1s?jobsource=checkc" target="_blank"><div class="company-logo overflow-hidden text-center text-white font-weight-normal" data-v-0d2c8ddc="" data-v-ddf7892e="" style="width: 60px; height: 60px; line-height: 60px;"><div data-gtm-list="logo" data-v-0d2c8ddc="" style="background-color: rgb(255, 195, 27);" title="德駏股份有限公司"> 德 </div></div></a></div></div>
#
# 要蒐集的公司名稱在這
# <div class="col pl-2 company-list-desktop__cust-info-wrap" data-v-ddf7892e=""><div class="info company-list-desktop__cust-info" data-v-7a06bcd0="" data-v-ddf7892e=""><div class="info-container" data-v-7a06bcd0=""><div class="info-job text-break mb-2" data-v-7a06bcd0=""><a class="info-job__text h2 jb-link jb-link-blue jb-link-blue--visited text-truncate d-inline-block" data-gtm-list="公司名稱" data-v-7a06bcd0="" href="//www.104.com.tw/company/15btev1s?jobsource=checkc" rel="noopener" target="_blank" title="德駏股份有限公司">德駏股份有限公司</a></div><!-- -->
#
# <div class="info-tags mb-1 font-weight-bold gray-deep-dark" data-v-7a06bcd0=""><span class="info-tags__text" data-v-7a06bcd0="">台北市內湖區</span><span class="info-tags__text" data-v-7a06bcd0="">通訊機械器材相關業</span><span class="info-tags__text" data-v-7a06bcd0="">資本額5300萬元</span><span class="info-tags__text" data-v-7a06bcd0="">員工數25人</span><span class="info-tags__text" data-v-7a06bcd0="">暫無公司評論</span></div><div class="info-description text-gray-darker t4 text-break mb-2 position-relative" data-v-7a06bcd0=""> 人們對於媒體、資訊及通訊的需求快速地成長; 唯有互動式寬頻網路才能滿足多方的需求. 30年以來，德駏公司由初始的HFC的設備，逐步跟著產業與時精進，目前更精於頭端數位與寬頻訊號的建置與優化，在系統除錯和提高整體效能上有深厚的經驗... </div><!-- --></div></div></div><!-- --><div class="col-auto pl-1 company-list-desktop__icon" data-v-ddf7892e=""><!-- --></div><div class="col-auto pl-1" data-v-ddf7892e=""><div class="row d-block" data-v-ddf7892e=""><div class="col-12" data-v-ddf7892e=""><a class="btn btn-sm btn-outline-light company-list-desktop__btn-job-count disabled" data-gtm-list="工作機會" data-v-ddf7892e="" href="//www.104.com.tw/company/15btev1s?jobsource=checkc#info06" target="_blank" title="德駏股份有限公司的工作機會">工作機會(0)</a></div><!-- --><div class="col-12 mt-3" data-v-ddf7892e=""><button class="btn btn-sm btn-has-icon btn-outline-primary company-list-desktop__btn-alert btn-outline-light btn-outline-primary--track" data-gtm-list="新工作通知" data-v-362005a9="" data-v-ddf7892e=""><!-- --><span data-gtm-list="新工作通知" data-v-362005a9="">新工作通知</span></button></div></div></div></div></div>
#
# 第二家:台灣康普通信系統有限公司
# <div class="company-list-desktop w-100 bg-white py-4 container-fluid border-bottom company-lists__list" data-v-5481f08a="" data-v-ddf7892e="" data-v-f25fc5d8=""><div class="row align-items-start" data-v-ddf7892e=""><div class="col-auto d-flex align-items-center mt-6 pr-4 company-list-desktop__corporate-icon__wrap" data-v-ddf7892e=""><!-- --><!-- --></div><div class="col-auto pl-0 d-flex align-items-center" data-v-ddf7892e=""><div class="company-list-desktop__logo mt-2" data-v-ddf7892e=""><a data-v-ddf7892e="" href="//www.104.com.tw/company/1a2x6bk694?jobsource=checkc" target="_blank"><div class="company-logo overflow-hidden text-center text-white font-weight-normal" data-v-0d2c8ddc="" data-v-ddf7892e="" style="width: 60px; height: 60px; line-height: 60px;"><img alt="CommScope Ruckus_台灣康普通信系統有限公司 LOGO" class="w-100" data-gtm-list="logo" data-v-0d2c8ddc="" src="//static.104.com.tw/b_profile/cust_picture/2312/130000000102312/logo.png?v=20210422222439" title="CommScope Ruckus_台灣康普通信系統有限公司"/></div></a></div></div>
#
# 要蒐集的公司名稱在這
# <div class="col pl-2 company-list-desktop__cust-info-wrap" data-v-ddf7892e=""><div class="info company-list-desktop__cust-info" data-v-7a06bcd0="" data-v-ddf7892e=""><div class="info-container" data-v-7a06bcd0=""><div class="info-job text-break mb-2" data-v-7a06bcd0=""><a class="info-job__text h2 jb-link jb-link-blue jb-link-blue--visited text-truncate d-inline-block" data-gtm-list="公司名稱" data-v-7a06bcd0="" href="//www.104.com.tw/company/1a2x6bk694?jobsource=checkc" rel="noopener" target="_blank" title="CommScope Ruckus_台灣康普通信系統有限公司">CommScope Ruckus_台灣康普通信系統有限公司</a></div><!-- -->
#
#
#     <div class="info-tags mb-1 font-weight-bold gray-deep-dark" data-v-7a06bcd0=""><span class="info-tags__text" data-v-7a06bcd0="">台北市內湖區</span><span class="info-tags__text" data-v-7a06bcd0="">其他電信及通訊相關業</span><span class="info-tags__text" data-v-7a06bcd0="">資本額暫不提供</span><span class="info-tags__text" data-v-7a06bcd0="">員工數500人</span><span class="info-tags__text" data-v-7a06bcd0="">暫無公司評論</span></div><div class="info-description text-gray-darker t4 text-break mb-2 position-relative" data-v-7a06bcd0=""> === WHY COMMSCOPE AND RUCKUS ===
#
# CommScope is pushing the boundaries of communications technology. For more than ... </div><!-- --></div></div></div><!-- --><div class="col-auto pl-1 company-list-desktop__icon" data-v-ddf7892e=""><!-- --></div><div class="col-auto pl-1" data-v-ddf7892e=""><div class="row d-block" data-v-ddf7892e=""><div class="col-12" data-v-ddf7892e=""><a class="btn btn-sm btn-outline-light company-list-desktop__btn-job-count" data-gtm-list="工作機會" data-v-ddf7892e="" href="//www.104.com.tw/company/1a2x6bk694?jobsource=checkc#info06" target="_blank" title="CommScope Ruckus_台灣康普通信系統有限公司的工作機會">工作機會(11)</a></div><div class="col-12 mt-3" data-v-ddf7892e=""><button class="btn btn-sm btn-has-icon btn-outline-primary company-list-desktop__btn-save btn-outline-light btn-outline-primary--save" data-gtm-list="儲存公司" data-v-1d28795e="" data-v-ddf7892e=""><i class="mr-3 jb_icon_favor_line" data-v-1d28795e=""></i><span data-gtm-list="儲存公司" data-v-1d28795e="">儲存公司</span></button></div><!-- --></div></div></div></div>

# %%
#先從最外層的div下手
soup.find_all("div", class_='col pl-2 company-list-desktop__cust-info-wrap')
# Out:
# [<div class="col pl-2 company-list-desktop__cust-info-wrap" data-v-ddf7892e=""><div class="info company-list-desktop__cust-info" data-v-7a06bcd0="" data-v-ddf7892e=""><div class="info-container" data-v-7a06bcd0=""><div class="info-job text-break mb-2" data-v-7a06bcd0=""><a class="info-job__text h2 jb-link jb-link-blue jb-link-blue--visited text-truncate d-inline-block" data-gtm-list="公司名稱" data-v-7a06bcd0="" href="//www.104.com.tw/company/15btev1s?jobsource=checkc" rel="noopener" target="_blank" title="德駏股份有限公司">德駏股份有限公司</a></div><!-- --><div class="info-tags mb-1 font-weight-bold gray-deep-dark" data-v-7a06bcd0=""><span class="info-tags__text" data-v-7a06bcd0="">台北市內湖區</span><span class="info-tags__text" data-v-7a06bcd0="">通訊機械器材相關業</span><span class="info-tags__text" data-v-7a06bcd0="">資本額5300萬元</span><span class="info-tags__text" data-v-7a06bcd0="">員工數25人</span><span class="info-tags__text" data-v-7a06bcd0="">暫無公司評論</span></div><div class="info-description text-gray-darker t4 text
# ...

# %%
#接著往下找下一層的div
soup.find("div", class_='col pl-2 company-list-desktop__cust-info-wrap').find("div", class_='info-job text-break mb-2')
# Out:
# <div class="info-job text-break mb-2" data-v-7a06bcd0=""><a class="info-job__text h2 jb-link jb-link-blue jb-link-blue--visited text-truncate d-inline-block" data-gtm-list="公司名稱" data-v-7a06bcd0="" href="//www.104.com.tw/company/15btev1s?jobsource=checkc" rel="noopener" target="_blank" title="德駏股份有限公司">德駏股份有限公司</a></div>

# %%
#再往下找到a
soup.find("div", class_='col pl-2 company-list-desktop__cust-info-wrap').find("div", class_='info-job text-break mb-2').find('a', class_="info-job__text h2 jb-link jb-link-blue jb-link-blue--visited text-truncate d-inline-block")
# Out:
# <a class="info-job__text h2 jb-link jb-link-blue jb-link-blue--visited text-truncate d-inline-block" data-gtm-list="公司名稱" data-v-7a06bcd0="" href="//www.104.com.tw/company/15btev1s?jobsource=checkc" rel="noopener" target="_blank" title="德駏股份有限公司">德駏股份有限公司</a>

# %%
#再用.text擷取文字內容
soup.find("div", class_='col pl-2 company-list-desktop__cust-info-wrap').find("div", class_='info-job text-break mb-2').find('a', class_="info-job__text h2 jb-link jb-link-blue jb-link-blue--visited text-truncate d-inline-block").text
# Out:
# '德駏股份有限公司'

# %% [markdown]
# # 測試成功!接下來就來盤點所有的公司名稱了

# %%
all_mess_data = soup.find_all("div", class_='col pl-2 company-list-desktop__cust-info-wrap')
all_mess_data
# Out:
# [<div class="col pl-2 company-list-desktop__cust-info-wrap" data-v-ddf7892e=""><div class="info company-list-desktop__cust-info" data-v-7a06bcd0="" data-v-ddf7892e=""><div class="info-container" data-v-7a06bcd0=""><div class="info-job text-break mb-2" data-v-7a06bcd0=""><a class="info-job__text h2 jb-link jb-link-blue jb-link-blue--visited text-truncate d-inline-block" data-gtm-list="公司名稱" data-v-7a06bcd0="" href="//www.104.com.tw/company/15btev1s?jobsource=checkc" rel="noopener" target="_blank" title="德駏股份有限公司">德駏股份有限公司</a></div><!-- --><div class="info-tags mb-1 font-weight-bold gray-deep-dark" data-v-7a06bcd0=""><span class="info-tags__text" data-v-7a06bcd0="">台北市內湖區</span><span class="info-tags__text" data-v-7a06bcd0="">通訊機械器材相關業</span><span class="info-tags__text" data-v-7a06bcd0="">資本額5300萬元</span><span class="info-tags__text" data-v-7a06bcd0="">員工數25人</span><span class="info-tags__text" data-v-7a06bcd0="">暫無公司評論</span></div><div class="info-description text-gray-darker t4 text
# ...

# %%
companyList=[]

for i in all_mess_data:
    companyList.append(i)
    
print(companyList)
print(len(companyList))
# Out:
# [<div class="col pl-2 company-list-desktop__cust-info-wrap" data-v-ddf7892e=""><div class="info company-list-desktop__cust-info" data-v-7a06bcd0="" data-v-ddf7892e=""><div class="info-container" data-v-7a06bcd0=""><div class="info-job text-break mb-2" data-v-7a06bcd0=""><a class="info-job__text h2 jb-link jb-link-blue jb-link-blue--visited text-truncate d-inline-block" data-gtm-list="公司名稱" data-v-7a06bcd0="" href="//www.104.com.tw/company/15btev1s?jobsource=checkc" rel="noopener" target="_blank" title="德駏股份有限公司">德駏股份有限公司</a></div><!-- --><div class="info-tags mb-1 font-weight-bold gray-deep-dark" data-v-7a06bcd0=""><span class="info-tags__text" data-v-7a06bcd0="">台北市內湖區</span><span class="info-tags__text" data-v-7a06bcd0="">通訊機械器材相關業</span><span class="info-tags__text" data-v-7a06bcd0="">資本額5300萬元</span><span class="info-tags__text" data-v-7a06bcd0="">員工數25人</span><span class="info-tags__text" data-v-7a06bcd0="">暫無公司評論</span></div><div class="info-description text-gray-darker t4 text
# ...

# %%
for company in companyList:
    print(company.find("div", class_='info-job text-break mb-2').find('a').text)
# Out:
# 德駏股份有限公司
# CommScope Ruckus_台灣康普通信系統有限公司
# 祥勝安全科技股份有限公司
# 葳訊企業股份有限公司
# Migo_熱鬧點科技有限公司
# 天尚科技有限公司
# 駿捷通信有限公司
# 聯成國際有限公司
# 鄭民暉電機技師事務所
# 毅通網絡股份有限公司
# 信祥股份有限公司
# 橙恩科技國際有限公司
# TECH MAHINDRA LIMITED_印度商馬辛達國際科技有限公司台灣分公司
# 威潤科技股份有限公司
# 德瑪科技股份有限公司
# 皇輝科技股份有限公司
# 飛速移動有限公司
# 台灣吉立網路科技有限公司
# 香港商冠恒電訊有限公司台灣分公司
# 法商思瑪迪有限公司台灣分公司
# 新通環宇股份有限公司
# 愛訊電網科技股份有限公司
# 同步科技股份有限公司
# 彩富電子股份有限公司
# 美商野火設計股份有限公司
# 三佳成科技有限公司
# 皇邦系統有限公司
# 宗亞資訊工業股份有限公司
# 聯寶科技股份有限公司
# 是方電訊股份有限公司(中華電信關係企業)

# %%
for company in companyList:
    print(company.find("div", class_='info-job text-break mb-2').find('a').text)
    print(company.find("div", class_="info-description text-gray-darker t4 text-break mb-2 position-relative").text)
# Out:
# 德駏股份有限公司
#  人們對於媒體、資訊及通訊的需求快速地成長; 唯有互動式寬頻網路才能滿足多方的需求. 30年以來，德駏公司由初始的HFC的設備，逐步跟著產業與時精進，目前更精於頭端數位與寬頻訊號的建置與優化，在系統除錯和提高整體效能上有深厚的經驗...
# CommScope Ruckus_台灣康普通信系統有限公司
#  === WHY COMMSCOPE AND RUCKUS ===
#
# CommScope is pushing the boundaries of communications technology. For more than ...
# 祥勝安全科技股份有限公司
#  我們重視每一位員工，除了有良好工作環境、也提供學習及成長的空間，歡迎優秀的朋友一起加入祥勝安全科技股份有限公司的工作行列。
# 葳訊企業股份有限公司
#  成立於民國83年，民國102年12月改制為葳訊企業股份有限公司，從事行動電話和相關配件之銷售，年營業額約20 億台幣。
#
# 企業願景
# 一.     人才願景
# 我們要求同仁了解公司的經營理念，以及企業願景，在此學習成長，共榮共享，...
# Migo_熱鬧點科技有限公司
#  Migo 熱鬧點科技是一間外資新創企業，全球研發暨營運總部位於台北，打造專為全球新興市場的消費者數位內容平台，計畫從東南亞地區出發。
#
# 在Migo，你所設計開發的產品，將提供新興國家數百萬名使用者，娛樂以及教育資訊的全新體驗。透...
# 天尚科技有限公司
#  零食不定時供應!!!
# 邊做邊聽音樂?可以!只要不妨礙他人你開心就好..
# ​​​​​​​吃吃零食?可以!別吃到滿地又不清潔就好...
# 我們是小公司，但我們重視每一位員工，除了有良好工作環境、也提供學習及成長的空間，歡迎優秀及...
# 駿捷通信有限公司
#  駿捷通信有限公司於提供親切、關懷的高品質服務，以滿足客戶對行動通訊生活的需求。旗下連鎖體系有數家行動電話通訊門市，多年來經營團隊秉持專業的服務品質及優質的營運績效，屢創佳績!!
#
# 誠摯歡迎您的加入~~
#
# 聯成國際有限公司
# ...

# %% [markdown]
# ### 開始爬取搜尋結果

# %%
soup
# Out:
# <html class="" lang="zh-Hant-TW"><head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, user-scalable=no" name="viewport"/>
# <meta content="telephone=no, email=no, adress=no" name="format-detection"/>
# <link href="https://www.104.com.tw/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="https://www.104.com.tw/favicon.ico" rel="icon" type="image/x-icon"/>
# <link href="https://static.104.com.tw/logo/104logo_o_76x76_appletouchicon.png" rel="apple-touch-icon" sizes="76x76" type="image/png"/>
# <link href="https://static.104.com.tw/logo/104logo_o_120x120_appletouchicon.png" rel="apple-touch-icon" sizes="120x120" type="image/png"/>
# <link href="https://static.104.com.tw/logo/104logo_o_152x152_appletouchicon.png" rel="apple-touch-icon" sizes="152x152" type="image/png"/>
# <link href="https://static.104.com.tw" rel="dns-prefetch"/>
# ...

# %% [markdown]
# <div class="pagination mx-auto my-4 text-center" data-v-0580e86a="" data-v-5481f08a="" data-v-f25fc5d8=""><div class="pagination__count d-inline-block" data-v-0580e86a=""> 共 9 頁 </div><ul class="paging d-inline-block p-0 my-0 mx-4" data-v-0580e86a=""><li class="paging__item d-inline-block position-relative text-center mr-2 disable" data-v-0580e86a=""><a class="paging__link d-block position-relative" data-v-0580e86a="" href="?page=1"><i class="jb_icon_left" data-gtm-list="上一頁" data-v-0580e86a=""></i></a></li><li class="paging__item d-inline-block position-relative text-center mx-2" data-v-0580e86a=""><a class="paging__link d-block position-relative active" data-gtm-list="頁碼" data-v-0580e86a="" href="?page=1"> 1 </a></li><li class="paging__item d-inline-block position-relative text-center mx-2" data-v-0580e86a=""><a class="paging__link d-block position-relative" data-gtm-list="頁碼" data-v-0580e86a="" href="?page=2"> 2 </a></li><li class="paging__item d-inline-block position-relative text-center mx-2" data-v-0580e86a=""><a class="paging__link d-block position-relative" data-gtm-list="頁碼" data-v-0580e86a="" href="?page=3"> 3 </a></li><li class="paging__item d-inline-block position-relative text-center mx-2" data-v-0580e86a=""><a class="paging__link d-block position-relative" data-gtm-list="頁碼" data-v-0580e86a="" href="?page=4"> 4 </a></li><li class="paging__item d-inline-block position-relative text-center mx-2" data-v-0580e86a=""><a class="paging__link d-block position-relative" data-gtm-list="頁碼" data-v-0580e86a="" href="?page=5"> 5 </a></li><li class="paging__item d-inline-block position-relative text-center ml-2" data-v-0580e86a=""><a class="paging__link d-block position-relative" data-v-0580e86a="" href="?page=2"><i class="jb_icon_right" data-gtm-list="下一頁" data-v-0580e86a=""></i></a></li></ul><!-- --></div></div><!-- --></div><!-- --></div></div></div>

# %%
soup.find("div", class_='pagination mx-auto my-4 text-center').find_all('a',class_='paging__link d-block position-relative')
# Out:
# [<a class="paging__link d-block position-relative" data-v-0580e86a="" href="?page=1"><i class="jb_icon_left" data-gtm-list="上一頁" data-v-0580e86a=""></i></a>,
#  <a class="paging__link d-block position-relative" data-gtm-list="頁碼" data-v-0580e86a="" href="?page=2"> 2 </a>,
#  <a class="paging__link d-block position-relative" data-gtm-list="頁碼" data-v-0580e86a="" href="?page=3"> 3 </a>,
#  <a class="paging__link d-block position-relative" data-gtm-list="頁碼" data-v-0580e86a="" href="?page=4"> 4 </a>,
#  <a class="paging__link d-block position-relative" data-gtm-list="頁碼" data-v-0580e86a="" href="?page=5"> 5 </a>,
#  <a class="paging__link d-block position-relative" data-v-0580e86a="" href="?page=2"><i class="jb_icon_right" data-gtm-list="下一頁" data-v-0580e86a=""></i></a>]

# %%
soup.find("div", class_='pagination mx-auto my-4 text-center').find_all('a',class_='paging__link d-block position-relative')[-1]
# Out:
# <a class="paging__link d-block position-relative" data-v-0580e86a="" href="?page=2"><i class="jb_icon_right" data-gtm-list="下一頁" data-v-0580e86a=""></i></a>

# %%
soup.find("div", class_='pagination mx-auto my-4 text-center').find_all('a',class_='paging__link d-block position-relative')[-1]['href']
# Out:
# '?page=2'

# %%
browser = webdriver.Chrome(executable_path='../chromedriver.exe')
browser.get(job_104_url)  # 打開瀏覽器並連到網頁
time.sleep(2)  # delay一段時間等待網頁更新完成

while True:
    time.sleep(3)  # delay一段時間等待網頁更新完成
    html = browser.page_source
    soup = BeautifulSoup(html, 'lxml')
    company_list = soup.find_all("div", class_='col pl-2 company-list-desktop__cust-info-wrap')
    
    companyList=[]

    for i in company_list:
        companyList.append(i)
    
    # 擷取公司名稱及簡介內容
    for company in companyList:
        # 因為內容太多，我們把爬取到的結果，寫入"company_list.txt"檔案中，稍後再來檢視
        company_name = company.find("div", class_='info-job text-break mb-2').find('a').text
        f = open("company_list.txt", "a+", encoding='utf-8')
        f.write(company_name + "\n" )  # 寫入公司名稱
        
        company_desc = company.find("div", class_="info-description text-gray-darker t4 text-break mb-2 position-relative").text
        f.write(company_desc + "\n" )  # 寫入公司簡介
        f.write( "--------------------------------------------------------------------------------" + "\n" )
        f.close()

    try:
        next_disable = soup.find("div", class_='pagination mx-auto my-4 text-center').find_all('a',class_='paging__link d-block position-relative')[-1]['href']
        print(next_disable)
    
        if next_disable != None:
            job_104_url2=job_104_url.replace('?page=1',next_disable+'&order=1&mode=s&jobsource=checkc&area=6001001000&indcat=1001002000')
            browser.get(job_104_url2)
        else:
            print('==========沒有下一頁了==========')
            break
    except:
            print('==========沒有下一頁了==========')
            break
# Out:
# ?page=2
# ?page=3
# ?page=4
# ?page=5
# ?page=6
# ?page=7
# ?page=8
# ?page=9
# ?page=10
# ==========沒有下一頁了==========
