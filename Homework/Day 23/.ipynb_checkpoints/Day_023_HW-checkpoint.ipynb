# %% [markdown]
# # 東森新聞雲爬蟲練習
# ## 練習從東森新聞雲網站中，爬取新聞摘要及詳細內容。
# ## 學習利用Selenium模擬人為操作，更新動態網頁後爬取新聞內容。

# %%
import requests
import time
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

# %% [markdown]
# ### 以財經新聞為例，先連結到財經新聞網頁，複製其URL。

# %%
ETtoday_url = "https://www.ettoday.net/news/focus/%E8%B2%A1%E7%B6%93/"  #財經新聞

# %% [markdown]
# ### 用Selenium打開一個瀏覽器，連結到網站。然後模擬下拉網頁的動作，讓網頁完成更新，再處理後續動作。

# %%
browser = webdriver.Chrome(executable_path='../chromedriver.exe')
browser.get(ETtoday_url)  # 打開瀏覽器並連到東森新聞雲網頁

SCROLL_PAUSE_TIME = 1

# 以下是用Selenium模擬下拉網頁動作，讓網頁更新

last_height = browser.execute_script("window.scrollTo(0, document.body.scrollHeight);")  #先設定初始網頁底端

while True:
    '''
    Your code here
    
    提示：可參考以下的Stack Overflow: 
    https://stackoverflow.com/questions/48850974/selenium-scroll-to-end-of-page-indynamically-loading-webpage/48851166
    '''
    # 模擬網頁下拉
    browser.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    
    # 等待一段時間讓網頁更新
    time.sleep(SCROLL_PAUSE_TIME)

    # 檢視目前網頁底端
    new_height = browser.execute_script("return document.body.scrollHeight")
    
    if new_height == last_height:
        print("到達頁面底端")
        break
    last_height = new_height
    print("網頁更新中...")
# Out:
# 網頁更新中...
# 網頁更新中...
# 網頁更新中...
# 網頁更新中...
# 網頁更新中...
# 網頁更新中...
# 網頁更新中...
# 網頁更新中...
# 網頁更新中...
# 到達頁面底端

# %% [markdown]
# ### 到這裡網頁已經更新完畢，所有的新聞都已經出現在網頁上。接下來做爬取收集新聞的動作。

# %% [markdown]
# ### 先看看目前頁面的內容:

# %%
resp = requests.get(ETtoday_url)
resp.encoding = 'utf-8'
#print(resp.text)

soup = BeautifulSoup(resp.text, 'lxml')
#print(soup)
#print(soup.find("div", attrs={'class':'block block_1 infinite_scroll'}))
print(soup.find_all('div', attrs={'class':'piece clearfix'}))
#print(soup.find("div", attrs={'class':'block block_1 infinite_scroll'}).find_all('div', attrs={'class':'piece clearfix'}))
# Out:
# [<div class="piece clearfix">
# <a class="pic" href="/news/20210609/2003253.htm" title="連螞蟻都拍得一清二楚！雙主鏡頭超強大　OPPO Find X3 Pro開箱全實測"><img alt="連螞蟻都拍得一清二楚！雙主鏡頭超強大　OPPO Find X3 Pro開箱全實測" data-original="//cdn2.ettoday.net/images/5678/c5678572.jpg" src="//cdn2.ettoday.net/style/ettoday2017/images/loading_200x150.gif"/></a>
# <h3><a href="/news/20210609/2003253.htm" title="連螞蟻都拍得一清二楚！雙主鏡頭超強大　OPPO Find X3 Pro開箱全實測">連螞蟻都拍得一清二楚！雙主鏡頭超強大　OPPO Find X3 Pro開箱全實測</a></h3>
# <p class="summary">OPPO新機Find X3 Pro於6月5日正式登台，此次新機強調拍攝的強大能力，搭載雙主鏡頭，加上超廣角與極具特色的顯微鏡頭，集成獨具創新的拍攝風格，《ETtoday新聞雲》也取得實機搶先開箱實測。</p>
# <span class="date">3小時前</span>
# </div>, <div class="piece clearfix">
# <a class="pic" href="/news/20210609/2003264.htm" title="快訊／高端新冠疫苗將解盲！股票明天停牌　收盤後開記者會"><img alt="快訊／高端新冠疫苗將解盲！股票明天停牌　收盤後開記者會" data-original="//cdn2.ettoday.net/images/5677/c5677874.jpg" src="//cdn2.ettoday.net/style/ettoday2017/images/loading_200x150.gif"/></a>
# ...

# %% [markdown]
# ### 再看看內頁中連結頁面的內容:

# %%
#Extenal_link = ETtoday_url+"/news/20210609/2003289.htm"
Extenal_link = 'https://www.ettoday.net/news/20210609/2003253.htm'
#print(Extenal_link)

resp = requests.get(Extenal_link)
resp.encoding = 'utf-8'
#print(resp.text)

soup = BeautifulSoup(resp.text, 'lxml')
#print(soup)
#print(soup.find("div", attrs={'class':'story'}))
print(soup.find("div", attrs={'class':'story'}).find_all("p"))
# Out:
# [<p><img alt="▲OPPO Find X3實測。（圖／記者陳俐穎攝）" height="450" src="//cdn2.ettoday.net/images/5678/d5678570.jpg" title="▲OPPO Find X3實測。（圖／記者陳俐穎攝）" width="600"/></p>, <p><strong>▲OPPO Find X3採取霧面設計。（圖／記者陳俐穎攝）</strong></p>, <p>記者陳俐穎／台北報導</p>, <p>OPPO新機Find X3 Pro於6月5日正式登台，此次新機強調拍攝的強大能力，搭載雙主鏡頭，加上超廣角與極具特色的顯微鏡頭，集成獨具創新的拍攝風格，《ETtoday新聞雲》也取得實機搶先開箱實測。</p>, <p><span style="color: rgb(0, 0, 255);"><span style="font-size: larger;"><strong>外觀配備</strong></span></span></p>, <p>盒裝配備充電器、TypeC-C的連接線、耳機與同色系的手機殼。先從外表來說，這次推出2個顏色，分別為鏡黑與霧藍，此次拿到的測試機是霧藍版本，可以看到曲面螢幕與邊框過度柔和，且背板採取霧面的磨砂質感，很難得的是，許多機種就算採取霧面質感還是容易留下指紋，而Find X3上這種情況卻顯著的減少。</p>, <p><img alt="▲OPPO Find X3實測。（圖／記者陳俐穎攝）" height="373" src="//cdn2.ettoday.net/images/5678/d5678571.jpg" title="▲OPPO Find X3實測。（圖／記者陳俐穎攝）" width="600"/></p>, <p><strong>▲OPPO Find X3採取螢幕下指紋解鎖技術。（圖／記者陳俐穎攝）</strong></p>, <p><img alt="▲OPPO Find X3實測。（圖／記者陳俐穎攝）" height="450" src="//cdn2.ettoday.net/images/5678/d5678572.jpg" title="▲OPPO Find X3實測。（圖／記者陳俐穎攝）" width="600"/></p>, <p><stron
# ...

# %%
# 這裡先建立一個函數，其功能是連到外部連結，並爬取新聞內容。

def getNewsDetailContent(link_url):
    resp = requests.get(link_url)
    resp.encoding = 'utf-8'
    #print(resp.text)

    soup = BeautifulSoup(resp.text, 'lxml')
    news_content = soup.find("div", attrs={'class':'story'}).find_all("p") #抓取連結頁面中內容的div標籤
    
    for p in news_content:
        """
        .string屬性說明：
        (1) 若當前tag節點底下沒有其他tag子節點，會直接抓取內容(返回"NavigableString")
        (2) 若當前tag節點底下只有唯一的一個tag子節點，也會直接抓取tag子節點的內容(返回"NavigableString")
        (3) 但若當前tag節點底下還有很多個tag子節點，.string就無法判斷，(返回"None")
        """
        if ((p.string) is not None):
            print(p.string)

# %% [markdown]
# ### 解析HTML並萃取新聞摘要，若有外部的連結，再連到外部連結並把詳細新聞內容抓取下來。

# %%
# 爬取網頁內容，解析後萃取新聞摘要
html = browser.page_source
soup = BeautifulSoup(html, "lxml")
all_news = soup.find("div", attrs={'class':'block block_1 infinite_scroll'})

news_block = all_news.find_all('div', attrs={'class':'piece clearfix'})

for i, news_item in enumerate(news_block):
    print("----------------------------------------------------------------------")
    news_body = news_item.find('h3')
    print("\n[%d] %s\n" % (i, news_body.a.string))
    
    # 
    # 連到外部連結，擷取詳細新聞內容
    #
    externalLink = "https://www.ettoday.net" + news_body.a["href"]
    print( externalLink)
    getNewsDetailContent(externalLink)
# Out:
# ----------------------------------------------------------------------
#
# [0] 連螞蟻都拍得一清二楚！雙主鏡頭超強大　OPPO Find X3 Pro開箱全實測
#
# https://www.ettoday.net/news/20210609/2003253.htm
# ▲OPPO Find X3採取霧面設計。（圖／記者陳俐穎攝）
# 記者陳俐穎／台北報導
# OPPO新機Find X3 Pro於6月5日正式登台，此次新機強調拍攝的強大能力，搭載雙主鏡頭，加上超廣角與極具特色的顯微鏡頭，集成獨具創新的拍攝風格，《ETtoday新聞雲》也取得實機搶先開箱實測。
# 外觀配備
# 盒裝配備充電器、TypeC-C的連接線、耳機與同色系的手機殼。先從外表來說，這次推出2個顏色，分別為鏡黑與霧藍，此次拿到的測試機是霧藍版本，可以看到曲面螢幕與邊框過度柔和，且背板採取霧面的磨砂質感，很難得的是，許多機種就算採取霧面質感還是容易留下指紋，而Find X3上這種情況卻顯著的減少。
# ▲OPPO Find X3採取螢幕下指紋解鎖技術。（圖／記者陳俐穎攝）
# ▲左上挖孔自拍鏡頭最大化螢幕的使用範圍。（圖／記者陳俐穎攝）
# 相機表現
# 先從官方強調的拍攝能力開始看起，實測當天是下雨天，但手機相機中的演算法卻有辦法把陰雨天拍得十分明亮，而在變焦上，最大可放大到20X，且不同於一般數位變焦，放大後的畫面呈現仍十分清晰，顆粒感較小，這點讓人驚豔。
# ▲陰雨天仍能拍攝出細節。（圖／記者陳俐穎攝）
# ▲放大20X仍能看清楚招牌上的字跡。（圖／記者陳俐穎攝）
# 在夜拍方面，在畫面上具有強烈的對比感，可以把夜晚低光源的細節拍攝清楚，強大的地方則是在螢幕上點選暗部，暗部會立刻提亮，就像是自備打光儀一樣，用手機就能有這種效果實屬不易。
# 而自拍前鏡頭也延續OPPO品牌的優勢，特別細節化的美顏運算方式，且改進了過去的缺點，人物磨皮變得自然，而3200萬畫素加上大光圈，也就像是自帶了打光燈。
# ▲OPPO Find X3前鏡頭人像效果。（圖／記者陳俐穎攝）
# ...
