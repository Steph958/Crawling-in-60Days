# %% [markdown]
# # 反爬：登入授權模擬
#
# * 了解「登入權限機制」的反爬蟲機制
# * 「登入權限機制」反爬蟲的因應策略

# %% [markdown]
# ## 未授權前存取

# %%
import requests
from bs4 import BeautifulSoup

# %%
res = requests.get('https://www.ptt.cc/bbs/Gossiping/index.html', verify = False)
soup = BeautifulSoup(res.text, 'html.parser')
print(soup.text)
# Out:
# C:\Users\vincentLee1231995\Anaconda3\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.ptt.cc'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# C:\Users\vincentLee1231995\Anaconda3\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.ptt.cc'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# 批踢踢實業坊
#
#
#
#
#
#
#
#
#
# 本網站已依網站內容分級規定處理
# 警告︰您即將進入之看板內容需滿十八歲方可瀏覽。
# 若您尚未年滿十八歲，請點選離開。若您已滿十八歲，亦不可將本區之內容派發、傳閱、出售、出租、交給或借予年齡未滿18歲的人士瀏覽，或將本網站內容向該人士出示、播放或放映。
#
#
#
#
#
#
# 我同意，我已年滿十八歲進入
#
#
# 未滿十八歲或不同意本條款離開

# %% [markdown]
# ## 模仿授權機制

# %% [markdown]
# ### 方法一：先送登入，再送請求

# %%
rs = requests.session()

payload={
    'from':'/bbs/Gossiping/index.html',
    'yes': 'yes'
}
res = rs.post('https://www.ptt.cc/ask/over18',verify = False, data = payload)
res = rs.get('https://www.ptt.cc/bbs/Gossiping/index.html',verify = False)
soup = BeautifulSoup(res.text,'html.parser')
print(soup.text)
# Out:
# C:\Users\vincentLee1231995\Anaconda3\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.ptt.cc'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# C:\Users\vincentLee1231995\Anaconda3\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.ptt.cc'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# 看板 Gossiping 文章列表 - 批踢踢實業坊
#
#
#
#
#
#
#
#
#
# 批踢踢實業坊
# ›
# 看板 Gossiping
# 關於我們
# 聯絡資訊
#
#
#
#
#
#
# 看板
# 精華區
#
#
# 最舊
# ‹ 上頁
# 下頁 ›
# 最新
#
#
#
#
#
#
#
#
#
#
# 1
#
# [問卦] 台女為了防疫對變得很冷漠，怎辦？
#
#
# WaWa3
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 WaWa3 的文章
#
#
#  8/09
#
#
#
#
# 23
#
# [新聞] 小五童心疼爸中風癱　掉淚盼望爸病快好
#
#
# iXXXXGAY5566
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 iXXXXGAY5566 的文章
#
#
#  8/09
#
#
#
#
# 2
#
# Re: [問卦] 不銹鋼吸管製作者給我進來！
#
#
# jingthreept
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 jingthreept 的文章
#
#
#  8/09
#
#
#
#
# 9
#
# [問卦] 還沒打第一劑的人是不是很可憐
#
#
# ACERACER99
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 ACERACER99 的文章
#
#
#  8/09
#
#
#
#
# 1
#
# [問卦] 離別這種事情要怎麼樣去面對？
#
#
# QAQ0731
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 QAQ0731 的文章
#
#
#  8/09
#
#
#
#
# 1
#
# Re: [新聞] 住民宿遺失30萬現金 遊客、業者撕破臉鬧
#
#
# tps6115
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 tps6115 的文章
#
#
#  8/09
#
#
#
#
# 12
#
# [問卦] 庭院深深深幾許?
#
#
# Keira1990
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 Keira1990 的文章
#
#
#  8/09
#
#
#
#
#
#
# [新聞] 小島秀夫喜愛收藏CD
#
#
# Roshan
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 Roshan 的文章
#
#
#  8/09
#
#
#
#
#
#
# [問卦] 矮小亞洲人能去歐洲嗎
#
#
# aertina
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 aertina 的文章
#
#
#  8/09
#
#
#
#
# 1
#
# [問卦] 現在去中國投資好嗎？
#
#
# delphi5566
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 delphi5566 的文章
#
#
#  8/09
#
#
#
#
# 6
#
# [新聞] 凱基證券慘被「韭菜負評」洗版！疑大戶
#
#
# pat7681
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 pat7681 的文章
#
#
#  8/09
#
#
#
#
# 1
#
# Re: [新聞] 同志開毒趴 業者憂引爆傳播鏈
#
#
# sunbear928
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 sunbear928 的文章
#
#
#  8/09
#
#
#
#
# 4
#
# [問卦] 急！那裡有潮汕火鍋吃到飽？
#
#
# Qpera
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 Qpera 的文章
#
#
#  8/09
#
#
#
#
# 10
#
# Re: [新聞] 疫苗庫存荒 徐巧芯：赫然發現第二類不斷
#
#
# SkyIsMyLimit
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 SkyIsMyLimit 的文章
#
#
#  8/09
#
#
#
#
# 1
#
# [問卦] 為啥要公車上書,而不在火車上書呢?
#
#
# andrewkuo
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 andrewkuo 的文章
#
#
#  8/09
#
#
#
#
#
#
# [問卦] 請問西遊記這部作品是否涉及辱華？
#
#
# Assyla
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 Assyla 的文章
#
#
#  8/09
#
#
#
#
#
#
# [問卦] 如果時間可以重來 我會...
#
#
# Ninja650r
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 Ninja650r 的文章
#
#
#  8/09
#
#
#
#
# 7
#
# [問卦] 膝蓋都怎麼念
#
#
# h63882
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 h63882 的文章
#
#
#  8/09
#
#
#
#
# 1
#
# [新聞] 系統錯誤非接種對象也能預約莫德納 指揮
#
#
# Celesite
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 Celesite 的文章
#
#
#  8/09
#
#
#
#
# 1
#
# Re: [問卦] 美國正面臨嚴重通貨膨脹
#
#
# aa384756
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 aa384756 的文章
#
#
#  8/09
#
#
#
#
#
#
#
# [公告] 八卦板板規(2021.05.11)
#
#
# arsonlolita
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 arsonlolita 的文章
#
#
#  5/11
# !
#
#
#
# 42
#
# [協尋] 07/29 台北南京東路三段275號行車紀錄器畫面
#
#
# heidi47
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 heidi47 的文章
#
#
#  8/04
#
#
#
#
# 30
#
# [協尋] 8/6新竹縣湖口鄉中平路一段&信昌街交叉口
#
#
# j50829j
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 j50829j 的文章
#
#
#  8/07
#
#
#
#
# 30
#
# [協尋] 8/4 縣道164號水林路行車紀錄器畫面
#
#
# kobe00148
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 kobe00148 的文章
#
#
#  8/07
#
#
#
#
# 5
#
# [公告] 二級警戒八月也要好好生活下去！置底閒聊區
#
#
# wuyiulin
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 wuyiulin 的文章
#
#
#  8/02
# M
#
#
#
# 本網站已依台灣網站內容分級規定處理。此區域為限制級，未滿十八歲者不得瀏覽。
# C:\Users\vincentLee1231995\Anaconda3\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.ptt.cc'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(

# %% [markdown]
# ### 方法二：在請求中帶入 cookie

# %%
res = requests.get('https://www.ptt.cc/bbs/Gossiping/index.html',verify = False, cookies={'over18': '1'})
soup = BeautifulSoup(res.text,'html.parser')
print(soup.text)
# Out:
# 看板 Gossiping 文章列表 - 批踢踢實業坊
#
#
#
#
#
#
#
#
#
# 批踢踢實業坊
# ›
# 看板 Gossiping
# 關於我們
# 聯絡資訊
#
#
#
#
#
#
# 看板
# 精華區
#
#
# 最舊
# ‹ 上頁
# 下頁 ›
# 最新
#
#
#
#
#
#
#
#
#
#
# 2
#
# Re: [新聞]「台灣野人」恆春半島吃不停 林管處盼吸收
#
#
# hltinokuo
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 hltinokuo 的文章
#
#
#  7/29
#
#
#
#
# 3
#
# [問卦] 香港運輸物資居然用大隊接力！
#
#
# charco
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 charco 的文章
#
#
#  7/29
#
#
#
#
# 7
#
# [問卦] 有人會直接吃鮪魚罐頭嗎
#
#
# Antihuman
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 Antihuman 的文章
#
#
#  7/29
#
#
#
#
#
#
# [問卦] 海底撈點這樣算摳嗎？
#
#
# danmitsu
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 danmitsu 的文章
#
#
#  7/29
#
#
#
#
#
#
# [問卦] 為什麼台灣找不到混血黑人球員??
#
#
# kerkerson
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 kerkerson 的文章
#
#
#  7/29
#
#
#
#
# 1
#
# [問卦] 不會念書的人有女友嗎？
#
#
# Francise
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 Francise 的文章
#
#
#  7/29
#
#
#
#
#
#
# [新聞] IZ*ONE熱潮狂掃《TGC 富山 2019》 八千人
#
#
# ATCTaiwan
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 ATCTaiwan 的文章
#
#
#  7/29
#
#
#
#
# 2
#
# Re: [新聞] 回應韓國瑜 蔡英文：守護中華民國我說到
#
#
# cowardlyman
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 cowardlyman 的文章
#
#
#  7/29
#
#
#
#
# 2
#
# [問卦] 農藥店真的很賺嗎？
#
#
# brucielu95
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 brucielu95 的文章
#
#
#  7/29
#
#
#
#
# 1
#
# [問卦] STU瀧野由美子終究只是個第三者嗎?
#
#
# emperor
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 emperor 的文章
#
#
#  7/29
#
#
#
#
#
#
# Re: [問卦] 買私菸的官員會不會變成世紀罪人？
#
#
# fuxdk
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 fuxdk 的文章
#
#
#  7/29
#
#
#
#
# 6
#
# Re: [問卦] 俄羅斯小蘿莉在跳什麼舞？
#
#
# violinlife
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 violinlife 的文章
#
#
#  7/29
#
#
#
#
#
#
# [問卦] 洗完雞雞容易激起性慾嗎
#
#
# dinex
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 dinex 的文章
#
#
#  7/29
#
#
#
#
# 4
#
# [問卦] 為什麼教科書都要寫「偽」滿洲國？
#
#
# leopika
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 leopika 的文章
#
#
#  7/29
#
#
#
#
#
#
# [問卦] 假日時光倒流，想回去什麼時候
#
#
# blackzero1
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 blackzero1 的文章
#
#
#  7/29
#
#
#
#
#
#
# [問卦] 台鐵補票事件是不是顯露部分台灣人醜陋?
#
#
# MizunaRei
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 MizunaRei 的文章
#
#
#  7/29
#
#
#
#
#
#
#
# [公告] 八卦板板規(2019.07.21)
#
#
# Bignana
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 Bignana 的文章
#
#
#  7/21
# !
#
#
#
# 63
#
# [問卦]懇求7/19大溪往三峽路段死亡車禍行車紀錄
#
#
# nekosandy
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 nekosandy 的文章
#
#
#  7/21
# M
#
#
#
# 19
#
# [公告] 版規4-16修正草案
#
#
# arsonlolita
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 arsonlolita 的文章
#
#
#  7/23
# M
#
#
#
# 87
#
# [尋人]尋人啟事 懇請幫忙
#
#
# skysea0940
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 skysea0940 的文章
#
#
#  7/26
#
#
#
#
# 39
#
# [公告] 七月份置底閒聊文
#
#
# Bignana
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 Bignana 的文章
#
#
#  7/01
# M
#
#
#
# 本網站已依台灣網站內容分級規定處理。此區域為限制級，未滿十八歲者不得瀏覽。
#
#
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-32365737-1', {
#     cookieDomain: 'ptt.cc',
#     legacyCookieDomain: 'ptt.cc'
#   });
#   ga('send', 'pageview');
# /Users/wei/.virtualenvs/py3/lib/python3.6/site-packages/urllib3/connectionpool.py:857: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)

# %% [markdown]
# ## 作業目標
#
# * 找一個需要登入的網站試試看，並說明思考流程
# （如果不知道要用哪個網站的話，可以試試看 https://github.com/new 網址，未登入時會被導向登入頁）
