# %% [markdown]
# # 反爬：登入授權模擬
#
# * 了解「登入權限機制」的反爬蟲機制
# * 「登入權限機制」反爬蟲的因應策略

# %% [markdown]
# ## 未授權前存取

# %%
import requests
from bs4 import BeautifulSoup

# %%
res = requests.get('https://www.ptt.cc/bbs/Gossiping/index.html', verify = False)
soup = BeautifulSoup(res.text, 'html.parser')
print(soup.text)
# Out:
# C:\Users\vincentLee1231995\Anaconda3\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.ptt.cc'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# C:\Users\vincentLee1231995\Anaconda3\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.ptt.cc'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# 批踢踢實業坊
#
#
#
#
#
#
#
#
#
# 本網站已依網站內容分級規定處理
# 警告︰您即將進入之看板內容需滿十八歲方可瀏覽。
# 若您尚未年滿十八歲，請點選離開。若您已滿十八歲，亦不可將本區之內容派發、傳閱、出售、出租、交給或借予年齡未滿18歲的人士瀏覽，或將本網站內容向該人士出示、播放或放映。
#
#
#
#
#
#
# 我同意，我已年滿十八歲進入
#
#
# 未滿十八歲或不同意本條款離開

# %% [markdown]
# ## 模仿授權機制

# %% [markdown]
# ### 方法一：先送登入，再送請求

# %%
rs = requests.session()

payload={
    'from':'/bbs/Gossiping/index.html',
    'yes': 'yes'
}
res = rs.post('https://www.ptt.cc/ask/over18',verify = False, data = payload)
res = rs.get('https://www.ptt.cc/bbs/Gossiping/index.html',verify = False)
soup = BeautifulSoup(res.text,'html.parser')
print(soup.text)
# Out:
# C:\Users\vincentLee1231995\Anaconda3\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.ptt.cc'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# C:\Users\vincentLee1231995\Anaconda3\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.ptt.cc'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# 看板 Gossiping 文章列表 - 批踢踢實業坊
#
#
#
#
#
#
#
#
#
# 批踢踢實業坊
# ›
# 看板 Gossiping
# 關於我們
# 聯絡資訊
#
#
#
#
#
#
# 看板
# 精華區
#
#
# 最舊
# ‹ 上頁
# 下頁 ›
# 最新
#
#
#
#
#
#
#
#
#
#
# 20
#
# [問卦] 南韓總統現在是不是瑟瑟發抖啊？
#
#
# Taiwan007
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 Taiwan007 的文章
#
#
#  8/16
#
#
#
#
# 5
#
# Re: [新聞] 俄媒:阿富汗總統攜現金出逃 過多帶不走
#
#
# ricky525
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 ricky525 的文章
#
#
#  8/16
#
#
#
#
# 19
#
# [新聞] 竹北驚傳鱷魚「逃家」！ 里長緊急公告協
#
#
# gto59674
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 gto59674 的文章
#
#
#  8/16
#
#
#
#
# 3
#
# Re: [問卦] 純欲系是什麼神奇形容詞？
#
#
# parrot11
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 parrot11 的文章
#
#
#  8/16
#
#
#
#
# 1
#
# [問卦] 玉挑主人 恐怖傳說
#
#
# chamge7788
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 chamge7788 的文章
#
#
#  8/16
#
#
#
#
# 1
#
# [問卦] 哪裡有可以抽菸的租屋阿？
#
#
# wiwi212
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 wiwi212 的文章
#
#
#  8/16
#
#
#
#
# 1
#
# [問卦] 南美洲的毒梟為啥不搶執政權？
#
#
# QQBB
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 QQBB 的文章
#
#
#  8/16
#
#
#
#
# 3
#
# [問卦] 欸欸 成大畢業去當設備會被笑嗎
#
#
# david0426
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 david0426 的文章
#
#
#  8/16
#
#
#
#
#
#
# Re: [問卦] 塔利班不會殺到自己人嗎？
#
#
# BleedWang
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 BleedWang 的文章
#
#
#  8/16
#
#
#
#
# 14
#
# [問卦] 為什麼台灣強姦案那麼少？
#
#
# Aloee
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 Aloee 的文章
#
#
#  8/16
#
#
#
#
# 5
#
# Re: [新聞] 俄媒:阿富汗總統攜現金出逃 過多帶不走
#
#
# potabaw
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 potabaw 的文章
#
#
#  8/16
#
#
#
#
# 2
#
# Re: [新聞] 俄媒:阿富汗總統攜現金出逃 過多帶不走
#
#
# lucifa38
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 lucifa38 的文章
#
#
#  8/16
#
#
#
#
# 2
#
# [問卦] 食衣住行育樂 挑一個終身免費？
#
#
# makinoyui
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 makinoyui 的文章
#
#
#  8/16
#
#
#
#
#
#
# [問卦] 老婆被搶走了，急！
#
#
# au4g3wk4k
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 au4g3wk4k 的文章
#
#
#  8/16
#
#
#
#
# 1
#
# [新聞] 卡神爆北市府只給麟洋抽1成悠遊卡 市府發
#
#
# com2
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 com2 的文章
#
#
#  8/16
#
#
#
#
# 4
#
# [問卦] 韓劇是不是拍不出青春感阿？
#
#
# trylin
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 trylin 的文章
#
#
#  8/16
#
#
#
#
#
#
# [問卦] 今天的乃木坂配信中是神回嗎?
#
#
# circus763
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 circus763 的文章
#
#
#  8/16
#
#
#
#
#
#
#
# [公告] 八卦板板規(2021.05.11)
#
#
# arsonlolita
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 arsonlolita 的文章
#
#
#  5/11
# !
#
#
#
# 52
#
# [協尋] 8/10(二)16:25新莊新五路與新北大道交叉路口
#
#
# jqqlas
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 jqqlas 的文章
#
#
#  8/12
#
#
#
#
# 51
#
# [協尋] 7/29早上7:55內湖路往堤頂大道行車紀錄器
#
#
# yang46cf
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 yang46cf 的文章
#
#
#  8/13
#
#
#
#
# 4
#
# [公告] 二級警戒八月也要好好生活下去！置底閒聊區
#
#
# wuyiulin
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 wuyiulin 的文章
#
#
#  8/02
# M
#
#
#
# 20
#
# [協尋] 8/5興隆路四段與木柵路二段路口監視器
#
#
# bom10306
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 bom10306 的文章
#
#
#  8/16
#
#
#
#
# 本網站已依台灣網站內容分級規定處理。此區域為限制級，未滿十八歲者不得瀏覽。
# C:\Users\vincentLee1231995\Anaconda3\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.ptt.cc'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(

# %% [markdown]
# ### 方法二：在請求中帶入 cookie

# %%
res = requests.get('https://www.ptt.cc/bbs/Gossiping/index.html',verify = False, cookies={'over18': '1'})
soup = BeautifulSoup(res.text,'html.parser')
print(soup.text)
# Out:
# 看板 Gossiping 文章列表 - 批踢踢實業坊
#
#
#
#
#
#
#
#
#
# 批踢踢實業坊
# ›
# 看板 Gossiping
# 關於我們
# 聯絡資訊
#
#
#
#
#
#
# 看板
# 精華區
#
#
# 最舊
# ‹ 上頁
# 下頁 ›
# 最新
#
#
#
#
#
#
#
#
#
#
# 2
#
# Re: [新聞]「台灣野人」恆春半島吃不停 林管處盼吸收
#
#
# hltinokuo
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 hltinokuo 的文章
#
#
#  7/29
#
#
#
#
# 3
#
# [問卦] 香港運輸物資居然用大隊接力！
#
#
# charco
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 charco 的文章
#
#
#  7/29
#
#
#
#
# 7
#
# [問卦] 有人會直接吃鮪魚罐頭嗎
#
#
# Antihuman
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 Antihuman 的文章
#
#
#  7/29
#
#
#
#
#
#
# [問卦] 海底撈點這樣算摳嗎？
#
#
# danmitsu
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 danmitsu 的文章
#
#
#  7/29
#
#
#
#
#
#
# [問卦] 為什麼台灣找不到混血黑人球員??
#
#
# kerkerson
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 kerkerson 的文章
#
#
#  7/29
#
#
#
#
# 1
#
# [問卦] 不會念書的人有女友嗎？
#
#
# Francise
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 Francise 的文章
#
#
#  7/29
#
#
#
#
#
#
# [新聞] IZ*ONE熱潮狂掃《TGC 富山 2019》 八千人
#
#
# ATCTaiwan
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 ATCTaiwan 的文章
#
#
#  7/29
#
#
#
#
# 2
#
# Re: [新聞] 回應韓國瑜 蔡英文：守護中華民國我說到
#
#
# cowardlyman
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 cowardlyman 的文章
#
#
#  7/29
#
#
#
#
# 2
#
# [問卦] 農藥店真的很賺嗎？
#
#
# brucielu95
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 brucielu95 的文章
#
#
#  7/29
#
#
#
#
# 1
#
# [問卦] STU瀧野由美子終究只是個第三者嗎?
#
#
# emperor
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 emperor 的文章
#
#
#  7/29
#
#
#
#
#
#
# Re: [問卦] 買私菸的官員會不會變成世紀罪人？
#
#
# fuxdk
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 fuxdk 的文章
#
#
#  7/29
#
#
#
#
# 6
#
# Re: [問卦] 俄羅斯小蘿莉在跳什麼舞？
#
#
# violinlife
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 violinlife 的文章
#
#
#  7/29
#
#
#
#
#
#
# [問卦] 洗完雞雞容易激起性慾嗎
#
#
# dinex
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 dinex 的文章
#
#
#  7/29
#
#
#
#
# 4
#
# [問卦] 為什麼教科書都要寫「偽」滿洲國？
#
#
# leopika
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 leopika 的文章
#
#
#  7/29
#
#
#
#
#
#
# [問卦] 假日時光倒流，想回去什麼時候
#
#
# blackzero1
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 blackzero1 的文章
#
#
#  7/29
#
#
#
#
#
#
# [問卦] 台鐵補票事件是不是顯露部分台灣人醜陋?
#
#
# MizunaRei
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 MizunaRei 的文章
#
#
#  7/29
#
#
#
#
#
#
#
# [公告] 八卦板板規(2019.07.21)
#
#
# Bignana
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 Bignana 的文章
#
#
#  7/21
# !
#
#
#
# 63
#
# [問卦]懇求7/19大溪往三峽路段死亡車禍行車紀錄
#
#
# nekosandy
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 nekosandy 的文章
#
#
#  7/21
# M
#
#
#
# 19
#
# [公告] 版規4-16修正草案
#
#
# arsonlolita
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 arsonlolita 的文章
#
#
#  7/23
# M
#
#
#
# 87
#
# [尋人]尋人啟事 懇請幫忙
#
#
# skysea0940
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 skysea0940 的文章
#
#
#  7/26
#
#
#
#
# 39
#
# [公告] 七月份置底閒聊文
#
#
# Bignana
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 Bignana 的文章
#
#
#  7/01
# M
#
#
#
# 本網站已依台灣網站內容分級規定處理。此區域為限制級，未滿十八歲者不得瀏覽。
#
#
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-32365737-1', {
#     cookieDomain: 'ptt.cc',
#     legacyCookieDomain: 'ptt.cc'
#   });
#   ga('send', 'pageview');
# /Users/wei/.virtualenvs/py3/lib/python3.6/site-packages/urllib3/connectionpool.py:857: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)

# %% [markdown]
# ## 作業目標
#
# * 找一個需要登入的網站試試看，並說明思考流程
# （如果不知道要用哪個網站的話，可以試試看 https://github.com/new 網址，未登入時會被導向登入頁）
