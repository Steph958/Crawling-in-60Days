# %% [markdown]
# # 網路爬蟲馬拉松-期末專題
#
# ## 專題目標:期末主題 1 - Cupoy
#
# 任選 Cupoy 新聞服務之某一種分類 (如熱門新聞、科技、商業....)，使用你學習過的爬蟲程式，爬取前 500 篇的文章

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import time
import pandas as pd

# %% [markdown]
# 遇到chromedriver版本相容問題:
#
# selenium报错Message: This version of ChromeDriver only supports Chrome version xx:
# https://blog.csdn.net/qq_41605934/article/details/116330227
#
# http://npm.taobao.org/mirrors/chromedriver/

# %% [markdown]
# ## 爬取文章

# %%
N = 500  # 設定要爬取文章數

# %%
# 打開瀏覽器, 進入欲爬取網頁
browser = webdriver.Chrome(executable_path='../chromedriver')
browser.get("https://www.cupoy.com/newsfeed/topicgrp/tech_tw")

# %%
start_time=time.time()

# 每隔兩秒鐘自動往下滑, 擷取 500 篇新聞的 url
count = 0
articles_info = []

print('目前文章數: ', end='')

while count<N:
    html_source = browser.page_source
    soup = BeautifulSoup(html_source, 'html5lib')
    target = soup.find_all('a', class_='sc-jxGEyO')           
    
    dummy = 0    #重複、需扣掉的文章數量                     
    
    for d in target:
        article = {}
        article['title']= d['title']
        article['url'] = d['href']
        article['origin'] = '/'.join(d['href'].split('/', 3)[:-1])  # 新聞來源的網站主頁
        
        if article not in articles_info:                  # 如果有因為往下滑的時間延遲造成爬取到重複的新聞
            articles_info.append(article)               
        else:
            dummy += 1   #重複、需扣掉的文章數量
    
    count = count + len(target) - dummy  #修正後的文章數量
    
    print(count, end=' ')
    
    browser.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(5)

browser.quit()

if len(articles_info) > N:    # 取前 500 筆
    articles_info = articles_info[:N]
    
    
end_time = time.time()
print('take time:', end_time-start_time, 's')
# Out:
# 目前文章數: 15 15 15 15 15 15 15 15 15 15 15 15 15 15 15 15 15 15 15 15 15 15 29 40 55 55 55 55 55 55 55 55 55 55 55 55 55 55 55 55 55 55 55 55 55 55 55 55 55 55 55 55 55 55 55 55 55 55 55 55 55 55 55 55 55 55 55 55 55 55 55 55 55 55 55 55 55 55 55 55 55 55 55 55 55 55 55 55 55 55 55 55 55 55 55 55 55 55 55 55 55 55 55 55 55 55 55 55 55 55 55 55 55 55 55 55 55 55 55 55 55 55 55 55 55 55 55 55 55 55 55 55 55 55 55 55 55 59 59 59 59 72 86 87 99 114 126 141 147 159 174 186 201 213 229 242 258 271 287 300 316 329 346 359 375 385 401 412 424 439 451 466 472 484 498 501 take time: 956.4498989582062 s

# %%
for i, a in enumerate(articles_info, start=1):    # 確認 500 筆新聞的標題
    print(i, ' ', a['title'])
# Out:
# 1   想開咖啡廳，不是只要沖咖啡而已！專家曝8大開店地雷，經營美店絕對比你想的還要累-風傳媒
# 2   指揮中心公佈配戴口罩放寬規定，爬山、海邊活動可不用戴口罩 | T客邦
# 3   中國東北限電限到只有 2G 訊號，紅綠燈罷工、行動支付不能用連買飯都困難 | T客邦
# 4   NETSCOUT威脅情報報告：DDoS攻擊達540萬次較去年同期增11% | T客邦
# 5   休旅車華麗變身「音樂戰車」，紐約街頭「惡名昭彰」的多明尼加汽車音響文化 - The News Lens 關鍵評論網
# 6   如何在手機上壓縮影片檔案？ | T客邦
# 7   相關道路車輛系統網路安全的最新 ISO 21434 - Soft & Share 線上課程資訊分享
# 8   【中信兄弟象 vs 味全龍】中華職棒直播、10/3 免費直播線上看、兄弟象Twitch直播-2021 - 蘋果仁 - 果仁 iPhone/iOS/好物推薦科技媒體
# 9   【味全龍 vs 中信兄弟象】中華職棒直播 LINE Today 線上看、10/3 CPBL下半季線上轉播-2021 - 蘋果仁 - 果仁 iPhone/iOS/好物推薦科技媒體
# 10   【富邦悍將 vs 統一獅】中華職棒直播、LINE Today Live 直播線上看、10/3 CPBL下半季線上轉播-202 - 蘋果仁 - 果仁 iPhone/iOS/好物推薦科技媒體
# 11   Apple Watch Series 7 據傳最快下週可預訂，10 月中旬出貨 - 蘋果仁 - 果仁 iPhone/iOS/好物推薦科技媒體
# 12   pycaret：一個開源、少量程式碼(low-code)的 Python 機器學習庫 - Soft & Share 線上課程資訊分享
# 13   [免費教學影片]- 使用 PyCaret 在 12 行程式碼中建立一個機器學習分類模型 - Soft & Share 線上課程資訊分享
# 14   特斯拉 2021 第二季安全報告：自動輔助駕駛更穩定，事故更少 - 蘋果仁 - 果仁 iPhone/iOS/好物推薦科技媒體
# 15   火幣正式公告中國「12月清退行程表」 : 月中終止入金、幣幣交易，10/31禁人民幣 | 動區動趨-最具影響力的區塊鏈媒體 (比特幣, 加密貨幣)
# 16   Cardano 資方砸 1 億美元發展「DeFi、NFT生態系」；將與英國 DJ 界傳奇合作 | 動區動趨-最具影響力的區塊鏈媒體 (比特幣, 加密貨幣)
# 17   eNaira｜「奈及利亞央行數位貨幣」遭告侵犯商標，法院批准上路：對全國經濟有益 | 動區動趨-最具影響力的區塊鏈媒體 (比特幣, 加密貨幣)
# 18   SUMo 5.14.1.508 免安裝中文版 - 軟體更新檢查工具        -         阿榮福利味 - 免費軟體下載
# 19   科普｜跨鏈橋：「多鏈時代」的重要參與者，與不同跨鏈橋的權衡 | 動區動趨-最具影響力的區塊鏈媒體 (比特幣, 加密貨幣)
# 20   史上首次！灰度以太坊信託 9月日交易量超越比特幣；Grayscale基金將納 SOL UNI | 動區動趨-最具影響力的區塊鏈媒體 (比特幣, 加密貨幣)
# 21   iOS 15 的 Safari 瀏覽器隱藏應用小技巧教學 - 電腦王阿達
# 22   有內線？柴犬幣巨鯨 10/1 狂買 6.1兆 SHIB、昨再買2,760億，與Robinhood有關？ | 動區動趨-最具影響力的區塊鏈媒體 (比特幣, 加密貨幣)
# 23   iOS 15 的第一個小更新解決了 iPhone 13 無法利用 Apple Watch 解鎖的問題
# 24   中國下達加密幣禁令，其他國家會跟進嗎？長期投資人：不會，但流通量太小的幣種要注意了！-風傳媒
# 25   微軟、Google、Amazon等雲端業者發表保護客戶資料原則 | iThome
# 26   Chrome 正在實驗將你去過的網頁依主題進行歸類的新功能
# 27   「臺北創新論壇」聚焦金融、物流，暢談北市數位轉型的前景與機會 | T客邦
# 28   【2021電視金鐘獎】Darren拿下戲劇節目男配角獎、簡嫚書獲得女配角獎 - The News Lens 關鍵評論網
# 29   vivo V70 系列全通路開賣，平價 Y21 手機一起登場 | T客邦
# 30   買不起 Leica 相機沒關係，不妨看看這款徠卡推出的麻將禮盒 | T客邦
# 31   今日本土零確診、10例境外移入，高鐵員工南下打疫苗，陳時中坦承預約系統漏洞 - The News Lens 關鍵評論網
# 32   歐盟Android反壟斷上訴案開庭，Google律師稱歐盟根本把蘋果當空氣 | T客邦
# 33   撐起「空拋之城」的移動重砲，洛杉磯快艇隊史最強射手J.J. Redick - The News Lens 關鍵評論網
# 34   LINE Bank 攜手 LINE Pay，不限通路筆筆享 LINE POINTS 3.5% 回饋 | T客邦
# 35   使用 LINE Bot 查詢商品在電商平臺的價格變化曲線圖
# 36   iPhone、三星指定機型換電池，神腦推 990 元限時優惠 | T客邦
# 37   Corsair 的首款電競螢幕是 32 吋、1440p 的 Xeneon
# 38   亞馬遜家用機器人，你會買嗎？員工爆料：這東西連走樓梯也不行，哪有可能顧家！-風傳媒
# 39   Fintech周報第197期：臺灣金融業去年共投入182億元發展金融科技，銀行業投入金額最高 | iThome
# 40   Google緊急修補兩個己被開採的Chrome零時差漏洞 | iThome
# 41   研究：Apple Pay含有Visa信用卡可被盜刷的安全漏洞 | iThome
# 42   用AI點亮“華夏之光” 優必選機器人正式亮相迪拜世博會中國館 | 機器之心
# 43   7納米工藝，Intel 4首款芯片Loihi 2出爐，速度提升10倍 | 機器之心
# 44   人類首次拍攝到電子固體畫面，伯克利華人團隊研究登上Nature | 機器之心
# 45   提前90分鐘、一塊GPU一秒預測降雨概率，DeepMind ML天氣預報登Nature | 機器之心
# 46   iPhone電池舊換新活動來了！神腦換原廠電池只要990元 - 蘋果仁 - 果仁 iPhone/iOS/好物推薦科技媒體
# 47   HTC Vive Focus 3 及 Vive Pro 2 在香港開賣，後者期間限定贈送《Superhot VR》
# 48   Sony 五倍券加碼回饋，購機再送超商禮券、藍牙耳機、風格大禮包 | T客邦
# 49   Sony ZV-E10評測：Youtuber神器再進化，錄影特化的輕便隨身機 | T客邦
# 50   天有多大？古埃及人用「駱駝」推算地球周長——天文學中的距離（一） - PanSci 泛科學
# 51   Nokia G50 新機登臺，買再送軍規防摔殼、抽 007 雙人電影票 | T客邦
# 52   淘寶推出「家居一條龍」物流組裝服務！天天有九折券、搭配 VISA 享指定回饋 | T客邦
# 53   今天回收舊手機抽iPhone 12 mini，三星回收舊手機更加碼 | T客邦
# 54   Lenovo 消費券活動買多折多，X1 Titanium Yoga 激減五千
# 55   空間音訊版《地表最強》周杰倫演唱會 Apple Music 獨家推出，用「聲」臨其境音效親臨現場吧 - 電腦王阿達
# 56   國語小幫手 – 不帶課本、詞典也能查國字、課本生字 | 就是教不落 - 給你最豐富的 3C 資訊、教學網站
# 57   Axie Infinity受質押計畫激勵「漲75%創新高」，已湧入11億美元AXS | 動區動趨-最具影響力的區塊鏈媒體 (比特幣, 加密貨幣)
# 58   iPhone 原廠 App 終於開放評價　評分普遍不高 - 香港 unwire.hk
# 59   WSJ：拜登政府正考慮穩定幣發行商「適用銀行等級」監管；Circle表態支持 | 動區動趨-最具影響力的區塊鏈媒體 (比特幣, 加密貨幣)
# 60   OPPO 螢幕可凹折手機或卷軸手機 預計明年才有機會開賣 #捲軸手機產品 (166436) - Cool3c
# 61   微軟、Google 及 AWS 共同承諾雲端服務存放數據隱私安全 僅在合理範圍或國安因素下提供政府數據內容 (166438) - Cool3c
# 62   吳忌寒評 924 監管：中國幣圈散戶將在短時間內消失、只餘大戶存留 | 動區動趨-最具影響力的區塊鏈媒體 (比特幣, 加密貨幣)
# 63   首挖！薩爾瓦多總統：已從「火山節點」 開採出 0.0059 BTC | 動區動趨-最具影響力的區塊鏈媒體 (比特幣, 加密貨幣)
# 64   Microsoft Surface Pro 8 4G 版  Microsoft 確認發售延期 - 香港 unwire.hk
# 65   【味全龍 vs 中信兄弟象】中華職棒直播 LINE Today 線上看、10/2 CPBL下半季線上轉播-2021 - 蘋果仁 - 果仁 iPhone/iOS/好物推薦科技媒體
# 66   【中信兄弟象 vs 味全龍】中華職棒直播、10/2 免費直播線上看、兄弟象Twitch直播-2021 - 蘋果仁 - 果仁 iPhone/iOS/好物推薦科技媒體
# 67   【樂天桃猿 vs 統一獅】中華職棒直播、LINE Today Live 直播線上看、10/2 CPBL下半季線上轉播-202 - 蘋果仁 - 果仁 iPhone/iOS/好物推薦科技媒體
# 68   2FA夠安全？今年春季 Coinbase 6000 名用戶資金被盜，官方承諾補償 | 動區動趨-最具影響力的區塊鏈媒體 (比特幣, 加密貨幣)
# 69   AMA精華》臺灣獨立樂團進入音樂元宇宙！與「美秀集團」談全息演唱會創新體驗 | 動區動趨-最具影響力的區塊鏈媒體 (比特幣, 加密貨幣)
# 70   傳下週開始預售  Apple Watch Series 7 有望月中上市 - 香港 unwire.hk
# 71   玩交友軟體總是被發無聲卡，讓女生告訴你問題出在哪！ | manfashion這樣變型男
# 72   新冠口服藥激勵美股大振、BTC衝破4.8萬！布林通道發明人:下一關是50000美元 | 動區動趨-最具影響力的區塊鏈媒體 (比特幣, 加密貨幣)
# 73   LINE 應用小技巧：LINE 貼圖整理小祕技，貼圖大戶看這篇！ - 電腦王阿達
# 74   蘋果 Trade in 不想換購商品，也能換成 Apple Store 禮品卡當購物金使用 - 蘋果仁 - 果仁 iPhone/iOS/好物推薦科技媒體
# 75   【紙本五倍券優惠整理】Sony五倍券優惠整理，BRAVIA、影音、耳機都有五倍券優惠！ - 蘋果仁 - 果仁 iPhone/iOS/好物推薦科技媒體
# 76   刪除舊 iPhone 照片，新 iPhone 裡的也不見了？因為你使用 iCloud 同步功能 - 蘋果仁 - 果仁 iPhone/iOS/好物推薦科技媒體
# 77   推特宣佈支持比特幣閃電網路，支援小費「聰支付」，聰 (Satoshi) 計價的優勢為何？ | 動區動趨-最具影響力的區塊鏈媒體 (比特幣, 加密貨幣)
# 78   Mubert Render 用 AI 技術，即時產生免費音樂素材，各式曲風要什麼有什麼 :: 哇哇3C日誌
# 79   iPhone 13 使用者快更新 iOS 15.0.1，2 個重大 Bug 都被修好了 - 蘋果仁 - 果仁 iPhone/iOS/好物推薦科技媒體
# 80   臺灣兩原因留不住獨角獸　Gogoro寧赴美「借殼上市」-風傳媒
# 81   攻擊SolarWinds的駭客再涉入2起後門程式感染行動 | iThome
# 82   Zimperium：GriftHorse木馬感染全球1千萬臺Android裝置，擅自幫受害者訂閱高價簡訊服務 | iThome
# 83   資安業者Group IB執行長因涉嫌叛國遭俄羅斯逮捕 | iThome
# 84   「掃鼻子，找狗子」是怎麼做到的？答案在這篇CVPR論文裏 | 機器之心
# 85   法拉利首款電動車，蘋果前首席設計師Jony Ive打造 | 機器之心
# 86   深度學習作弊，用單個參數 fit 任何數據集，這篇 19 年的論文重新「火」了 | 機器之心
# 87   牆壁和柱子供電，任意角落50W傳輸功率，東京大學建了個無線充電屋 | 機器之心
# 88   百億參數、中文NLU能力首次超越人類，QQ瀏覽器大模型「神舟」登頂CLUE | 機器之心
# 89   協助北韓閃避美國制裁，區塊鏈專家Virgil Griffith認罪了 | iThome
# 90   臉書開源Android、Java App漏洞檢查工具 | iThome
# 91   2021年9月10大資安新聞 | iThome
# 92   摩爾定律逐漸失效，新思科技：芯片產業要具備「奧林匹克」精神 | 機器之心
# 93   站在巨人肩膀鑄造雲端中臺，國泰醫院攻新世代微服務HIS | iThome
# 94   甲骨文推出新版整合OLTP/分析負載的Exadata X9M系統，叫陣挑戰AWS及微軟Azure | iThome
# 95   IBM與Linux基金會共同發表AI構件儲存庫MLX | iThome
# 96   間諜組織FamousSparrow利用ProxyLogon漏洞入侵受害組織，植入後門程式 | iThome
# 97   資安一週第165期：國內中小電商遭網釣攻擊鎖定。中國鎖定臺灣資安公司製造假新聞 | iThome
# 98   明年的長城車將升級全新電氣架構，工程師：GEEP 4.0只有三個智能區域 | 機器之心
# 99   微軟Microsoft Store開放Amazon、Epic第三方應用市集 | iThome
# 100   TKDE21 | 網絡社團發現新綜述：從統計建模到深度學習 | 機器之心
# 101   國防科技大學提出ROSEFusion，實現快速相機移動下的高精度在線RGB-D重建 | 機器之心
# 102   百倍訓練效率提升，微軟通用語言表示模型T-ULRv5登頂XTREME | 機器之心
# 103   研究人員公開揭露蘋果Airtag遺失模式的安全漏洞 | iThome
# 104   雲+端自動選型訓練、Swin-Transformer、最高4卡ICU3.0平臺，毫末智行的自動駕駛野心曝光！ | 機器之心
# 105   NeurIPS 2021揭榜，接收率創九年新高，速速報名北京這場官方授權線下學術交流活動 | 機器之心
# 106   單體模型參數量達2457億，浪潮發佈全球最大規模人工智能巨量模型「源」 | 機器之心
# 107   海內外71支勁旅角逐青光眼AI，視杯盤分割任務體素科技團隊斬獲第一 | 機器之心
# 108   阿里數據中臺底座的12年建設實踐 | 機器之心
# 109   提出聯邦學習可信驗證框架，星雲 Clustar 論文獲 FTL-IJCAI 21 最佳應用論文獎 | 機器之心
# 110   PyFlink 開發環境利器：Zeppelin Notebook | 機器之心
# 111   DataWorks賦能企業一站式數據開發治理能力 | 機器之心
# 112   「生髮」那些事兒：媽媽再也不用擔心我禿頭了！ | 機器之心
# 113   學術頂會再突破！計算平臺MaxCompute論文入選國際頂會VLDB 2021 | 機器之心
# 114   高端DSP芯片提供商中科本原完成億元A輪融資 | 機器之心
# 115   百分點大數據技術團隊：BI嵌入式分析實踐 | 機器之心
# 116   百分點感知智能實驗室：語音識別技術發展階段探究 | 機器之心
# 117   百分點認知智能實驗室：智能校對的技術原理和實踐 | 機器之心
# 118   百分點數據科學實驗室：白酒零售行業商品搭售方案 | 機器之心
# 119   百度研究院曬出年度成績單，九大實驗室碩果累累 | 機器之心
# 120   Amazon的Ring Always Home Cam家用無人機監視器即將登場 | iThome
# 121   中國的AI創業公司有多卷？Gartner：野蠻生長的時代要結束了 | 機器之心
# 122   自動化所IEEE-TNNLS發文提出類腦獎賞傳播調控用於脈衝卷積網絡學習 | 機器之心
# 123   機器學習函式庫Scikit-learn 1.0，加入關鍵字參數和線上OneClass SVM演算法 | iThome
# 124   Dell發表混合量子模擬平臺，降低量子演算法開發門檻 | iThome
# 125   Firefox惡意擴充程式Safepal Wallet清空了使用者的加密貨幣錢包 | iThome
# 126   WWW-2021最佳論文亞軍花落天津大學：基於屬性補全的異質圖神經網絡新架構 | 機器之心
# 127   美商務部要求臺積電、三星45天內提交芯片庫存訂單信息 | 機器之心
# 128   與AI俱進，化時光爲翎：「AI中國」機器之心2021年度評選暨特別策劃正式啓動 | 機器之心
# 129   把大腦「複製-粘貼」到芯片上，三星、哈佛的大膽設想登上Nature子刊 | 機器之心
# 130   百度AI可識別70餘種詐騙套路，領先AI技術守護財產和信息安全 | 機器之心
# 131   百度飛槳PaddleRobotics新升級！一套強化學習算法解決四足機器人多地形行走難題 | 機器之心
# 132   惡意程式使用新的簽章手法躲避Windows檢查 | iThome
# 133   讓聽障人士“看到”聲音，亮亮視野正式發售消費級AR助聽眼鏡 | 機器之心
# 134   GitLab 14.3專注強化安全性加入新一代SAST引擎 | iThome
# 135   工業環境中對機器學習的行業視角 | 機器之心
# 136   Eclypsium發現微軟的WPBT含有漏洞，允許駭客植入Rookit | iThome
# 137   阿里無人車配送快遞突破100萬單，達摩院王剛首次對外解讀阿里自動駕駛佈局 | 機器之心
# 138   歐盟正式指控俄羅斯政府參與駭客攻擊 | iThome
# 139   雲端用戶莫名被警告帳號逾期將停權，Google坦言是技術問題引發烏龍 | iThome
# 140   中國央行：所有的加密貨幣交易都是違法的 | iThome
# 141   Cloud周報第121期：富國銀行宣佈採跨Azure和GCP多雲架構，藉助雲端服務加速實現數位優先目標 | iThome
# 142   相信AI的力量——「AI中國」機器之心 2021年度評選獎項設置及參選說明
# 143   不滿蘋果漏洞處理態度，研究人員公佈iOS 15等4漏洞資訊 | iThome
# 144   時隔3個月再獲戰略投資，追一科技獲得中金資本基礎設施基金投資 | 機器之心
# 145   IoT雙周報第100期：臺北市自駕公車沙盒實驗展示新成果，不僅建立車聯網輔助自駕車行駛，還結合邊緣AI影像辨識，能偵測站牌上候車乘客自動停靠 | iThome
# 146   Hinton團隊CV新作：用語言建模做目標檢測，性能媲美DETR | 機器之心
# 147   AI，讓增長變簡單：匯量科技官宣朱小強加盟，發佈全域營銷雲產品矩陣「熱力引擎」 | 機器之心
# 148   爲科學創新插上模型的翅膀，MindSpore 「昇思」正在探索框架的未來 | 機器之心
# 149   5G趨勢月報第23期：2021年全球5G行動網路體驗報告出爐！臺灣兩家電信商進榜，遠傳5G下載網速全球居冠，中華電緊追在後 | iThome
# 150   “兩化融合”新技術成果在商業領域規模化應用，影譜科技全棧數字方案亮相科博會  | 機器之心
# 151   騰訊天籟行動公佈三大進展，以科技創新推動無障礙社會建設 | 機器之心
# 152   全球各大藥企與AI公司建立合作，推動藥物開發創新變革 | 機器之心
# 153   哈弗大狗上市一週年，發佈「大狗+」計劃 | 機器之心
# 154   冬奧手語播報數字人、語音助手問答體驗升級，1.75萬億參數的大模型「悟道」開始落地了 | 機器之心
# 155   Google量子計算AI實驗室大公開，並分享了未來十年的路線圖 | 機器之心
# 156   近期四項研究，人工智能又搞出了哪些新材料？ | 機器之心
# 157   騰訊OAV1賦能騰訊雲數據萬象，提供最前沿AVIF圖片壓縮技術 | 機器之心
# 158   刷新4項文檔智能任務紀錄，百度TextMind打造ERNIE-Layout登頂文檔智能權威榜單 | 機器之心
# 159   北大獲獎人數最多，王東皞蟬聯金牌，2021阿里全球數學競賽獲獎名單出爐 | 機器之心
# 160   二氧化碳直接合成澱粉，中國科學家顛覆性突破：1立方米反應器頂5畝地 | 機器之心
# 161   求解億級規模約束條件和變量，全球權威榜單斬獲第一，華爲雲發佈首個商用AI求解器 | 機器之心
# 162   谷歌2021博士獎研金完整名單公佈，13方向共75人獲獎 | 機器之心
# 163   創維旗艦新品震撼面世：以“真實”科技力拓展行業全新價值空間 | 機器之心
# 164   ICCV2021 | 南洋理工大學、港中大提出Talk-to-Edit，對話實現高細粒度人臉編輯 | 機器之心
# 165   算法改進有多快？是否比迭代硬件收益更大？這是MIT的結論 | 機器之心
# 166   AI求解器、百萬級節點協同管理：華爲雲重磅發佈十大新服務 | 機器之心
# 167   儲備池計算新突破：神經元更少，計算速度最高提升百萬倍 | 機器之心
# 168   蘇姿豐、陶哲軒在列，拜登政府公佈30位總統科技顧問委員 | 機器之心
# 169   在原神裏釣魚，有人竟然用上了深度強化學習，還把它開源了 | 機器之心
# 170   覆蓋10億設備的小冰，發佈了下一代社交網絡：給你發語音、朋友圈點贊的都是AI | 機器之心
# 171   半導體封裝設備先進製造商凌波微步完成數千萬A輪融資 | 機器之心
# 172   穗騰OS2.0來了！爲智慧地鐵提供靈活、可生長的數字底座 | 機器之心
# 173   超越Facebook、谷歌、微軟，百度發佈全球首個百億參數對話預訓練生成模型PLATO-XL | 機器之心
# 174   2021入坑機器學習，有這份指南就夠了 | 機器之心
# 175   查詢非結構化數據庫、克服Transformer模型局限性，Facebook提出神經數據庫架構 | 機器之心
# 176   華人團隊用Transformer做風格遷移，速度快、可試玩，網友卻不買賬 | 機器之心
# 177   晚上就應該睡覺？新的機器學習技術探索晝夜節律 | 機器之心
# 178   千字提煉：把RNN、LTSM、Seq2Seq、Attention機制聊透一點 | 機器之心
# 179   直播時各種背景是怎麼實現的？聊一聊虛擬背景背後的技術 | 機器之心
# 180   Spark 大數據處理最佳實踐 | 機器之心
# 181   融合趨勢下基於 Flink Kylin Hudi 湖倉一體的大數據生態體系 | 機器之心
# 182   物理學家教機器學習物理知識，用來預測電子設備故障 | 機器之心
# 183   科學家使用人工智慧迅速偵測重力波 | iThome
# 184   基於人臉圖像復原和人臉轉正聯合模型的人臉識別方法 | 機器之心
# 185   NLP任務非Transformer不可？谷歌大規模研究發現預訓練卷積模型往往更優 | 機器之心
# 186   有人拿當今最強GPU A6000和3090做了性能對比，網友：都買不起 | 機器之心
# 187   浙大校友李旻辰獲SIGGRAPH 2021最佳博士論文獎，連續四年華人學者包攬此獎項 | 機器之心
# 188   NeurIPS 2021「科學中的AI：理想與現實」(AI4ScienceWorkshop) | 機器之心
# 189   公開課 | MindSpore–SPONGE 人工智能分子模擬暑期線上課程開啓 | 機器之心
# 190   Cloudera數據平臺Spark工作開始支援GPU運算，讓ML資料前處理提高5倍執行效率 | iThome
# 191   影譜科技與海爾達成戰略合作，加速數字經濟與實體經濟融合 | 機器之心
# 192   經典教材《統計學習導論》第二版來了，新增深度學習等內容，免費下載 | 機器之心
# 193   用一張草圖創建GAN模型，新手也能玩轉，朱儁彥團隊新研究入選ICCV 2021 | 機器之心
# 194   華人科學家團隊再獲ACL最佳論文：以數學方法生成最優詞表 | 機器之心
# 195   Google應用機器學習來偵測難以發現的大腸息肉 | iThome
# 196   AI賦能遊戲工業化，網易互娛AI Lab動捕去噪新方法入選SIGGRAPH 2021 | 機器之心
# 197   蘋果計畫偵測裝置用戶的訊息與iCloud上有關兒童色情的內容，遭EFF抨擊入侵民眾隱私 | iThome
# 198   蘋果掃描iPhone所有照片，發現問題還要報警：全新「保護」計劃惹衆怒 | 機器之心
# 199   國內AI研究「頂不了天、落不了地」，李國傑院士文章刷屏，到底什麼是基礎研究？ | 機器之心
# 200   ACL2021 | 多粒度輸入信息不降低推理速度，騰訊看點等提出高效預訓練方法LICHEE | 機器之心
# 201   同態加密算力開銷如何彌補？港科大等提出基於FPGA實現的同態加密算法硬件加速方案 | 機器之心
# 202   ACL 2021 | 騰訊AI Lab、港中文傑出論文：用單語記憶實現高性能NMT | 機器之心
# 203   B站粉絲超130萬，最火最直觀數學網站3b1b終於有了文字版！網友：點燃對數學的愛 | 機器之心
# 204   廣東省打造「大灣區的麻省理工」，加速粵港澳製造業升級 | 機器之心
# 205   美國NSF在AI領域再投2.2億美元，教育和基礎設施將成未來AI研究重點 | 機器之心
# 206   「Tier2」地平線：先上大餐，再烹小菜 | 機器之心
# 207   清華大學朱軍：發展安全可靠的AI，爲什麼依舊任重道遠？ | 青年科學家50²論壇 | 機器之心
# 208   WAIC 2021隱私計算學術交流會 | 翼方健數張霖濤：隱私安全計算如何助力形成數據和計算互聯網 | 機器之心
# 209   NLP領域國際頂會ACL 2021收錄結果公佈 百度14篇論文上榜 | 機器之心
# 210   悲劇 or 春天？AlphaFold究竟給結構生物學家帶來了什麼？ | 機器之心
# 211   CV十年發展之觀察：1.5萬篇論文透視「業界」與「學界」，到底誰更勝一籌？ | 機器之心
# 212   下個軟件包可能泄露信用卡信息，Python包存儲庫PyPI又爆惡意代碼，下載達3萬次，你中招了嗎？ | 機器之心
# 213   Google Cloud加入SAP RISE軟體訂閱方案 | iThome
# 214   扎克伯格：Facebook將投入至少10億美元向「元宇宙」邁進 | 機器之心
# 215   寧德時代發佈第一代鈉離子電池，與鋰電混用互補短板，高寒場景優勢明顯 | 機器之心
# 216   「AI×科研」每日要聞｜7月30日 ​ | 機器之心
# 217   生物計算專家超細緻解讀AlphaFold2 論文：模型架構及應用 | 機器之心
# 218   重磅 | 美國AI再加碼：投資2.2億美元新增11個國家AI研究中心，覆蓋7大研究領域 | 機器之心
# 219   DeepMind開源的AlphaFold怎麼用？打開Colab就能在線用 | 機器之心
# 220   Google使用AI技術精準偵測非洲建築物分佈 | iThome
# 221   「新瓶裝新酒」的百度智能雲，未來將從這八個方向決勝AI時代 | 機器之心
# 222   華爲「盡全力」發佈了P50系列：原生搭載鴻蒙，5G改4G | 機器之心
# 223   AI一眼識別這是什麼鳥，「我們來找茬」十級選手誕生 | 機器之心
# 224   《語音識別基礎：（一）語音是什麼》 | 機器之心
# 225   英特爾攜手百度全方位深化合作，共築智能生態 | 機器之心
# 226   Nature社論：AlphaFold爲生命科學帶來了什麼？開源的技術和未來的方向 | 機器之心
# 227   在美上市的中國公司必須向投資者披露任何政府干預風險 | 機器之心
# 228   抖音的AI速度：平均每天上線超過100個新特效 | 機器之心
# 229   北大謝濤獲ASE 2021最有影響力論文獎，成爲首位華人獲獎學者 | 機器之心
# 230   ACL 2021論文分享會現場招聘，榮耀專場 | 機器之心
# 231   在CUDA的天下，OpenAI開源GPU編程語言Triton，將同時支持N卡和A卡 | 機器之心
# 232   揭祕Hologres如何支持超高QPS在線服務（點查）場景 | 機器之心
# 233   KDD 2021 | 小紅書推薦多樣性解決方案：SSD在質量、多樣性之間獲得較好權衡 | 機器之心
# 234   爲了讓16歲的兒子從輪椅上站起來，這位機器人工程師父親打造了一套外骨骼裝置 | 機器之心
# 235   針對資料科學團隊日常工作需求，紅帽推出AI作業環境代管服務 | iThome
# 236   AI車道級預警，可視化調度：高德地圖助力上海高速路網“軟實力”升級 | 機器之心
# 237   鋼鐵之軀，人工大腦，中國機器人的十年故事 | 機器之心
# 238   百度入選ICML、IJCAI、ISIT等機器學習頂會的論文都在關注什麼？ | 機器之心
# 239   案例 | 二手車智能質檢：以雙流分組殘差網絡爲核心，結合計算機視覺構建智能車輛檢測系統
# 240   母公司X副總裁親自掛帥，谷歌新公司押注AI軟件變革工業機器人
# 241   世界上最薄的磁鐵：僅有一個原子厚度，可在室溫工作
# 242   解疑 | 專家稱碰撞測試須換冷卻液，可比亞迪仍被自家售後打臉
# 243   給一個詞就能模仿你的筆跡，Facebook這個AI強大到不敢開源代碼 | 機器之心
# 244   復旦校友、微軟傑出首席科學家周禮棟博士升任微軟亞研院長，洪小文不再兼任 | 機器之心
# 245   Intel 20A：1nm不夠用了，英特爾將製程節點提升了一個計量單位 | 機器之心
# 246   英特爾晶圓代工打算要在2025年趕上臺積電與三星 | iThome
# 247   WAIC 2021 | 百度量子計算段潤堯：從理論到實踐談量子人工智能 | 機器之心
# 248   超越硅元素：Arm發佈塑料芯片，研究登上Nature | 機器之心
# 249   中國隊喜提六枚金牌，實現IMO團隊三連冠：王一川拿下全場唯一滿分 | 機器之心
# 250   電氣化大趨勢下，長城爲啥還在執着於內燃機？ | 機器之心
# 251   中國商業航天該如何？近千項專利爲我們指引航天商業化之路 | 機器之心
# 252   當代最偉大物理學家之一、諾獎得主史蒂文·溫伯格教授逝世 | 機器之心
# 253   Google研究在加護病房使用機器學習技術，綜合預測病人2天內的不良事件 | iThome
# 254   AlphaFold 再登 Nature！預測確定98.5%所有人類蛋白結構 | 機器之心
# 255   AI加持的WPS來了：金山開源全球首個辦公DL框架KSAI-Lite | 機器之心
# 256   達摩院創新高性能網絡輕量化方法，以5.9%精度優勢實現1.62倍實際加速 | 機器之心
# 257   WAIC 2021 | RIOS實驗室執行主任譚章熹：RISC-V——從開源芯片製造、EDA到處理器 | 機器之心
# 258   接收率25.9%，ICCV 2021接收論文列表放出，你中了嗎？ | 機器之心
# 259   前瞻打造超級「怪獸」，商湯想要馴服AI長尾 | 機器之心
# 260   雲從科技IPO首發過會，「AI四小龍」第一股之爭終於有了眉目 | 機器之心
# 261   首款採用大功率「雙極性鎳氫電池」的豐田AQUA上市 | 機器之心
# 262   「AI×科研」每日要聞彙總｜7月21日 | 機器之心
# 263   人類細胞中的基因調控？人工智能來揭示！ | 機器之心
# 264   用量子重新定義AI，千億量子計算賽道先鋒——玻色量子持續完成新一輪融資 | 機器之心
# 265   八卦一下快手Bagua：突破TensorFlow、PyTorch並行瓶頸的分佈式訓練框架 | 機器之心
# 266   鋰離子帶給動力電池的「愛與恨」 | 機器之心
# 267   美國加大科技資金投入，試圖複製美國國防高級研究計劃局的成功 | 機器之心
# 268   37頁pdf，埃默裏大學最新「大數據時代事件預測」綜述，ACM頂級期刊上發表 | 機器之心
# 269   WAIC 2021 | 思謀科技劉樞：賦能製造業需要什麼樣的算法平臺？ | 機器之心
# 270   字節跳動多篇論文入選 CVPR 2021，精選乾貨都在這裏了 | 機器之心
# 271   圖模型句法分析第一講：隨機遊走之拒絕採樣 | 機器之心
# 272   數據隱私與推薦系統的二者兼得——聯邦推薦系統 | 機器之心
# 273   Triton推理服務器在阿里雲機器學習PAI-EAS公測啦！！！ | 機器之心
# 274   只需1臺CPU跑600多秒，GNN快速有效優化蛋白質模型 | 機器之心
# 275   Transformer也能生成圖像，新型ViTGAN性能比肩基於CNN的GAN | 機器之心
# 276   WAIC 2021 | 雲天勵飛副總裁肖嶸：創「芯」時代 打造自進化城市智能體 | 機器之心
# 277   機器人頂會RSS各獎項出爐，CMU華人博士生摘得最佳論文 | 機器之心
# 278   AI生成的代碼你敢用嗎？有人給最近走紅的Copilot做了個「風險評估」 | 機器之心
# 279   領跑機器人手眼協調賽道，星猿哲科技完成3500萬美元B輪融資 | 機器之心
# 280   WAIC 2021 | 阿里副總裁司羅：大規模語言模型如何賦能行業、創造價值 | 機器之心
# 281   圖靈獎得主Judea Pearl談機器學習：不能只靠數據 | 機器之心
# 282   對話《AI 3.0》作者：除非AI能夠進行類比，否則永遠不會真正像人類 | 機器之心
# 283   Android 12使用機器學習技術，加速螢幕自動旋轉功能 | iThome
# 284   一天之內，兩大AI預測蛋白結構算法開源，分別登上Nature、Science | 機器之心
# 285   無限接近海森堡極限，控制小玻璃球量子運動研究登上Nature封面 | 機器之心
# 286   能效提升3倍，登臨科技展示國內唯一量產GPU實力 | 機器之心
# 287   11支隊伍獲勝，聚焦 AI 技術與應用：2021 WAIC 黑客鬆圓滿落幕 | 機器之心
# 288   科大訊飛AI學習機新品重磅發佈，開啓AI學習新時代 | 機器之心
# 289   騰訊優圖榮獲CVPR2021 Image Matching Workshop雙賽道冠亞軍 | 機器之心
# 290   雙核+GPU加持，華米科技黃山2S來了：智能可穿戴芯片進入全新時代 | 機器之心
# 291   國家災研院與千尋位置達成戰略合作：防災減災北斗來幫忙 | 機器之心
# 292   arXiv 論文的 idea 被人抄襲，又發表在了頂級 CV 期刊上，這時該怎麼辦？ | 機器之心
# 293   訓練Rainbow算法需要1425個GPU Day？谷歌說強化學習可以降低計算成本 | 機器之心
# 294   99行代碼實現冰雪奇緣特效的「太極」再進化，胡淵鳴團隊、快手等聯合打造 | 機器之心
# 295   Google推出Android ML平臺，可減少機器學習App大小 | iThome
# 296   WAIC 2021 | 中國惠普周信宏：AI基礎設施——邊緣計算演進及趨勢 | 機器之心
# 297   是什麼導致美國製造業生產率持續下滑？ | 機器之心
# 298   蔚來NIO Power三週年，只給自己打了29分（百分制） | 機器之心
# 299   圖神經網絡的驚人應用 | 機器之心
# 300   兼具CNN和Transformer優勢，靈活使用歸納偏置，Facebook提出ConViT | 機器之心
# 301   輕量型模型比肩千億大模型，周明團隊提出中文語言模型孟子，刷新CLUE紀錄 | 機器之心
# 302   WAIC 2021 | 好未來集團技術副總裁吳中勤：多模態機器學習及大規模自動生成技術算法框架與行業實踐 | 機器之心
# 303   並行生成奇點臨近！字節跳動GLAT斬獲WMT2021大語種德英自動評估第一 | 機器之心
# 304   ACL 2021論文分享會重磅嘉賓揭曉：李航、劉羣Keynote分享，大會主席宗成慶致辭 | 機器之心
# 305   AI 改進半導體分層技術，賦能計算機芯片、電池製造 | 機器之心
# 306   WAIC | Annotator 5.0標註平臺盛大發佈暨AI數據生態聯盟成立 | 機器之心
# 307   超越德國，中國成爲2020全球最大機械制造出口國 | 機器之心
# 308   Faster& Cooler：GPU+創新架構成就卓越能效 | 機器之心
# 309   WAIC2021：優必選AMR智能物流機器人解決方案首次國內亮相 | 機器之心
# 310   阿里雲視頻雲全景創新峯會落幕：多維探索，開啓想象 | 機器之心
# 311   Hologres揭祕：高性能原生加速MaxCompute核心原理 | 機器之心
# 312   紐約市生物辨識隱私法生效了 | iThome
# 313   以人工智能爲火種，點燃下一代工業革命！2021年WAIC雲帆獎獲得者名單公佈 | 機器之心
# 314   精準識別！精確定位！AI助力幹細胞培養 | 機器之心
# 315   WAIC2021「A班」朋友圈擴容：那些在中國的廣闊天地上大有作爲的青年 | 機器之心
# 316   影譜科技受邀亮相2021WAIC，智能數字化新品開闢消費體驗新藍海 | 機器之心
# 317   數行代碼訓練視頻模型，PyTorch視頻理解利器出爐 | 機器之心
# 318   逃犯爭相購買的安全手機，其實是FBI出售的：自帶後門，現已逮捕800餘人 | 機器之心
# 319   跨石灘、過草地、負重12kg，UC伯克利等研發新型機器人運動算法，實時快速適應變化環境 | 機器之心
# 320   用AI搜尋「宇宙燈塔」，這家公司爲何執着於星辰大海？
# 321   手機上用AI實時、流暢解碼視頻，超精細畫質提升：高通研發出首個神經視頻解碼器 | 機器之心
# 322   節省顯存新思路，在 PyTorch 裏使用 2 bit 激活壓縮訓練神經網絡 | 機器之心
# 323   自動化所研發全球首個圖文音三模態預訓練模型，讓AI更接近人類想象力 | 機器之心
# 324   斑馬智行發佈天瀑AI平臺，核心技術首款落地榮威鯨 | 機器之心
# 325   「AI×科研」每日要聞彙總｜7月9日 | 機器之心
# 326   這個枯燥、費時的植物表型分類問題，AI幫植物學家幹了 | 機器之心
# 327   2500萬升級用戶、69款支持機型，鴻蒙生態建設前路幾何？ | 機器之心
# 328   長城：合作固然重要，可要活下去還得靠自研能力 | 機器之心
# 329   Netflix如何打造AI工廠 | iThome
# 330   IBM開源機器學習應用程式框架CodeFlare，大幅簡化混合雲AI部署工作 | iThome
# 331   首屆世界先進製造業大會將於8月23日-26日在濟南舉辦 | 機器之心
# 332   標貝科技精彩亮相WAIC2021世界人工智能大會 | 機器之心
# 333   容聯雲亮相世界人工智能大會 發佈容犀機器人助力產業數字化轉型 | 機器之心
# 334   華爲達成汽車業最大專利許可協議/ 市監局處罰7起滴滴相關違法合營案件/ 理想「水銀門」事件發酵 | 機器之心
# 335   CVPR 2021 | 視覺目標檢測大模型GAIA：面向行業的視覺物體檢測一站式解決方案 | 機器之心
# 336   沒有車企願意只作華爲的「肉體」 | 機器之心
# 337   AI都會寫靈魂Rap了？Transformer跨界說唱，節奏、流暢度都不在話下 | 機器之心
# 338   IJCAI-21三大獎項公佈，強化學習之父、CMU助理教授方飛、德撲AI之父獲獎 | 機器之心
# 339   AI預測百萬化合物的生物活性信息，這裏有個高效開源工具 | 機器之心
# 340   千尋位置亮相世界人工智能大會，時空智能成爲城市數字化轉型必備要素 | 機器之心
# 341   Nvidia斥資1億美元打造英國最快的AI超級電腦 | iThome
# 342   比利時藝術家在Twitter上線AI，督促政客開會時不要玩手機 | 機器之心
# 343   中資企業收購英國最大半導體製造商 | 機器之心
# 344   「AI×科研」每日要聞彙總｜7月7日 | 機器之心
# 345   X光片能顯示分子構成？杜克大學研發混合X射線掃描儀加速癌症診斷 | 機器之心
# 346   全新榮威RX5 PLUS借《最強大腦》上市，指導價10.38-13.98萬元 | 機器之心
# 347   Swin Transformer爲主幹，清華等提出MoBY自監督學習方法，代碼已開源 | 機器之心
# 348   0語料下，如何通過「貼標籤」獲得更好的多語言翻譯效果 | 機器之心
# 349   誰是「反向傳播之父」？Hinton曾親口否認，真正的提出者或許是這個剛獲 IEEE 認證的大佬 | 機器之心
# 350   Yann LeCun：我是卷積神經網絡之父，但也被它的專利卡過脖子 | 機器之心
# 351   百場演講的萬人峯會，AI開發者最應該看什麼？（千元禮包現場抽） | 機器之心
# 352   KDD CUP 2021首屆圖神經網絡大賽放榜，百度飛槳PGL獲得2金1銀 | 機器之心
# 353   iFixit 拆解 iPad mini 6，分析「啫喱效果」形成原因！ | Qooah
# 354   喜歡二次元已經不滿足，42%人接受與 AI 機械人「發生浪漫關係」 | Qooah
# 355   《SLAM DUNK》AI 真人化 16個角色，最靚彩子最型三井 | Qooah
# 356   iPad mini（第六代）評測：缺陷藏於細節，卻又小得可以忽視？
# 357   Sony 推出了一款超便宜的真・無線耳機
# 358   小米 11 Lite 5G NE 手機和小米平板 5 登陸臺灣，香港更會加推小米 11T 系列
# 359   Apple：新 iPad mini 上的「果凍捲動」屬於 LCD 面板的「正常現象」
# 360   Amazon 發表 Halo View 手環，想靠生態來挑戰 Fitbit 和 Apple
# 361   Dyson 產品最低 69 折，網店優惠碼照價再減
# 362   Google Stadia 現在讓你用手機當作串流到電視上時的控制器
# 363   5G邁入2.0+ iPhone 13銷售靚  法人：助攻5G ETF長線走多！ -風傳媒
# 364   網店自帶分期付款，彈性購買 iPhone 13
# 365   誰說iPhone會改用Type-C？分析師：iPhone將無孔化、直上無線充電-風傳媒
# 366   成為全場焦點！Case-Mate iPhone 13 專用手機殼
# 367   ［下午 5 點直播］Engadget Update EP116：iPhone 13 系列你問我答、用後感、bug 回報
# 368   iPhone 13 不能被 Apple Watch 解鎖的 bug 將會被修復
# 369   Google Map是最好用的地圖導航？內行人揭它最大優勢，其他專業導航都辦不到-風傳媒
# 370   iPhone 14 據報將會是個「完全重新設計」的產品
# 371   沒有「他」也不會有現在的PayPal和特斯拉？！看矽谷天王彼得．提爾如何用超常思維開創科技界新藍海 | 大大學院 職場趨勢新觀點
# 372   收集你的面部特徵，將成為面試門檻？你的政府正在透過AI追蹤你！ | CitiOrange 公民報橘
# 373   Tesla 正在開發 AI 驅動的人形機器人 Tesla Bot
# 374   Intel 將放棄 RealSense AI 相機的業務
# 375   OnePlus Nord 2 5G 確認搭載聯發科天璣 1200-AI 晶片
# 376   SocialBook Background Remover 最強大 AI 全自動線上人物去背工具
# 377   AI 助陣醫學、防疫，個人隱私難兩全？ - PanSci 泛科學
# 378   GIBXChange 入圍 Forex Awards！角逐「全球最佳數位資產交易所」榮耀 - 區塊客
# 379   TikTok 進軍 NFT 新戰場！攜創作者在以太坊發行 NFT - 區塊客
# 380   美國 FED 主席鮑爾：不會效法中國「全面禁止」加密貨幣 - 區塊客
# 381   【犢叔扭扭】報紙暢讀上線、mooInk 系列進駐誠品新板店 - Readmoo閱讀最前線Readmoo閱讀最前線
# 382   區塊鏈社會學 | 永續空投： LikeCoin 化讚為賞 - 區塊客
# 383   AI涉足刑事鑑定 智財權與憲法權益的兩難 | CASE報科學
# 384   【線上直播】是擒兇警察，也是肉身凡人──他們與犯罪的距離 - Readmoo閱讀最前線Readmoo閱讀最前線
# 385   使用 Pandas 的 Python 資料科學：掌握 12 個進階專案 - Soft & Share 線上課程資訊分享
# 386   Taiwan’s AI Ecosystem Map 21H1: Deepening Synergies between Startups and Corporates - AppWorks 之初創投
# 387   ‧ 智慧零售，AI 技術不斷被導入  - 3S Market「全球智慧科技應用」市場資訊網
# 388   限時免費 DVDFab Enlarger AI 影片放大不失真，影片畫質修復 App 現省 2700 元 :: 哇哇3C日誌
# 389   AI 配合手機一拍即知健康狀況  相機測心跳 + 氧飽和度 + 呼吸頻率 - 香港 unwire.hk
# 390   香港私隱專員發表 AI 指引  確保人為監督＋三項基本數據管理 - 香港 unwire.hk
# 391   AI 再現社羣網路上情緒用語的男女差異，卻能助人理解字裡行間的真實情緒——清大資工陳宜欣專訪 | DQ 地球圖輯隊 帶你看透全世界
# 392   生產的機器學習工程(MLOps)專業課程 - Soft & Share 線上課程資訊分享
# 393   韓國奧運射箭隊高命中率拆解  精心設計訓練場 + AI 分析輔助 - 香港 unwire.hk
# 394   ．人臉辨識技術的優勢淺析 - 3S Market「全球智慧科技應用」市場資訊網
# 395   使用 SAP 的資料科學–企業資料的機器學習 - Soft & Share 線上課程資訊分享
# 396   Pixelhunter 自動 AI 圖片裁切工具，一秒裁出各大社羣平臺圖片尺寸！ :: 哇哇3C日誌
# 397   ．人工智慧可以取代同步翻譯嗎？ - 3S Market「全球智慧科技應用」市場資訊網
# 398   ‧ BA 系統如何進行建築能耗分析及監測管理？ - 3S Market「全球智慧科技應用」市場資訊網
# 399   ‧ 電腦到底是怎麼辨識人臉的？ - 3S Market「全球智慧科技應用」市場資訊網
# 400   ．工業人工智慧：解鎖未來五年的機會 - 3S Market「全球智慧科技應用」市場資訊網
# 401   鄰近詞查詢工具 – 輸入一個詞彙或成語，讓 AI 找出相關的還有哪些 | 就是教不落 - 給你最豐富的 3C 資訊、教學網站
# 402   比特幣為什麼這麼耗電？有其他省電一點的辦法嗎？ | T客邦
# 403   機器學習將會如何徹底改變電玩中的物理模擬 | T客邦
# 404   下載一位「心理醫生」？AI ＋心理療法的聊天機器人 | T客邦
# 405   未來20年的4大預測：人工智慧、生物技術、遠端工作和去中心化 | T客邦
# 406   如果奧運會全部改用 AI 裁判，結果會更公平嗎？ | T客邦
# 407   NVIDIA協助阿貢國家實驗室的超級電腦發展超大規模人工智慧 | T客邦
# 408   NVIDIA於Interspeech大會分語音合成研究成果，帶來富有表現力的AI語音 | T客邦
# 409   NVIDIA AI Enterprise全面上市，簡化在VMware vSphere執行AI程式 | T客邦
# 410   亞馬遜家用機器人，你會買嗎？員工爆料：這東西連走樓梯也不行，哪有可能顧家！-風傳媒
# 411   《追尋寧靜》：也許耳機的問題不僅在於實質音量，更在於聲音持續氾濫 - The News Lens 關鍵評論網
# 412   保時捷在臺佈建高速充電站，拓建全臺充電網路 | T客邦
# 413   數位五倍券綁了嗎？橘子支付推筆筆回饋10%零用金，消費ACG更划算 | T客邦
# 414   金魚腦救星！Apple ID 忘記密碼靠「4Mekey」讓你免於 iPhone 重置之苦！ | T客邦
# 415   社區住戶買了停車位卻當倉庫用，大樓管委會該怎麼處理？ - The News Lens 關鍵評論網
# 416   肚子大被讓座好尷尬！酵素王解決百萬女性小腹婆困擾，內含綜合蔬果萃取物及多種益生菌，代謝順暢變年輕 - The News Lens 關鍵評論網
# 417   iPad mini 6用戶抱怨螢幕出現「果凍現象」Bug，但蘋果說這很正常 | T客邦
# 418   掌握三大LINE廣告操作心法，Cookieless時代將新舊客一把抓 | T客邦
# 419   科技戰已成常態，運動員背後的「神隊友們」 - The News Lens 關鍵評論網
# 420   【智慧科技左右看】運動科技智慧未來！創造貼心的健康生活 - The News Lens 關鍵評論網
# 421   vivo X70 Pro 開箱評測：不只是蔡司攝影旗艦，效能、續航力也超好的輕薄手機 | T客邦
# 422   為熱愛的音樂人鼓掌！StreetVoice新功能「拍拍手」即日開始Beta公測 | T客邦
# 423   是否有密碼之盾能夠擋住量子電腦之矛？後量子密碼學的前世今生——匯智安全科技陳君明董事長專訪 - PanSci 泛科學
# 424   Moto edge 20 pro 與 edge 20 fusion 旗艦、中階雙機搶攻 5G 市場 | T客邦
# 425   阿里巴巴「小蠻驢」完成逾100萬配送訂單，三年後車隊將增至10000輛 | T客邦
# 426   「能耗雙控」不是問題？中媒爆廣西公司推出不需原料的發電技術、宣稱完全突破能量守恆定律 | T客邦
# 427   最新研究：憂鬱症可能是自我概念失調的精神疾病，「過度反芻性思考」與嚴重度有關 - The News Lens 關鍵評論網
# 428   士林分署10月拍賣公告成礦工拍賣會：包含44臺挖礦機、7620枚泰達幣、以太幣都上架 | T客邦
# 429   小米 10 月振興季，五倍券加碼、實體店面再增二家 | T客邦
# 430   小米 11 Lite 5G NE 登臺，紅米 10 也一起來了 | T客邦
# 431   三星Galaxy Z系列大摺學家線上演唱會，張震嶽、告五人CHILL開唱 | T客邦
# 432   遠傳漫遊驚爆價，新加坡上網吃到飽一天不到60元 | T客邦
# 433   小米平板 5 開箱評測！大尺寸的 Android 平板搭配觸控筆一起來了 | T客邦
# 434   LG收購汽車資安公司CYBELLUM，以研發更安全的車用軟體 | T客邦
# 435   《打造韌性》：虛實整合的數位轉型這件「事」，關鍵仍在於處理與「人」有關的課題 - The News Lens 關鍵評論網
# 436   MacBook傳明年大幅砍單15%，衝擊臺灣供應鏈，中國限電使蘋果缺料再加劇 - The News Lens 關鍵評論網
# 437   小米集團回應針對立陶宛資訊安全主管部門（NCSC）發佈之「具有 5G 功能手機的資訊安全評估」報告 | T客邦
# 438   蘋果 iPhone 13 不允許第三方更換螢幕，強拆將導致 Face ID 功能失效 | T客邦
# 439   從「產品思維」看美國疫苗預約流程，臺灣能學到什麼？ - The News Lens 關鍵評論網
# 440   除了You’re welcome，一次學會九種「不客氣」的英文說法 - The News Lens 關鍵評論網
# 441   加密貨幣市場中國團滅、礦工末日：價值約臺幣253億元比特幣緊急轉出、虛擬交易平臺全數關閉 | T客邦
# 442   揭祕 iPhone 13 電影級模式，蘋果竟然是這樣把它打造出來的 | T客邦
# 443   Omi推新功能「戀愛人格測驗」，上線3天突破20萬人瘋玩 | T客邦
# 444   中國監管措施不斷出臺，老百姓擔心受怕、還得閃躲眼睛比雷達敏銳的「西城大媽」 - The News Lens 關鍵評論網
# 445   疑似iPhone 14工程機曝光：挖孔螢幕設計、保留前鏡頭+Face ID | T客邦
# 446   五倍券發放辦法規定禁止轉售，經濟部呼籲民眾及店家遵守規定、勿違法 | T客邦
# 447   華爾街日報》習近平在拯救童年？還是想全面幹預社會？中國嚴控未成年人打網遊時間，美國大學生這樣看-風傳媒
# 448   1More 子品牌 omthing 推出 AirFree 2 降噪真無線耳機，限量超早鳥價 1,690 元 | T客邦
# 449   趨勢科技偵測到近1300萬次針對Linux的惡意程式事件 | T客邦
# 450   《假病真演》：後SARS時代醫學教育第一項變革，就是畢業後一般醫學訓練—— PGY的成立 - The News Lens 關鍵評論網
# 451   《資訊科技犯罪》：據說美國國安局的座右銘，就是「取得不可取得的」 - The News Lens 關鍵評論網
# 452   中國「能耗雙控」力拚2060碳中和：多省突襲限電勒令停工，臺商、外資企業受創 - The News Lens 關鍵評論網
# 453   緬甸平行政府與軍方持續武裝與外交對抗，緬甸未在聯合國大會發言 - The News Lens 關鍵評論網
# 454   iPhone13紙膜公佈之後，網友調侃蘋果包裝再省下去、未來iPhone連盒子都可省下來 | T客邦
# 455   未卜先知？一名神祕礦工在中國宣佈加密貨幣交易非法前，急領1366枚比特幣安全下莊 | T客邦
# 456   中國限電衝擊！蘋果和特斯拉多家重要供應商宣佈中國廠區停產 | T客邦
# 457   iPad mini 6與iPhone13 Pro Max性能對比，不考慮通話功能的話誰的性價比較高？ | T客邦
# 458   Sony Xperia 5 III 開箱評測：尺寸變小但功能不妥協，最合手的 Android 小旗艦 | T客邦
# 459   部分iPhone 13用戶發現無法用Apple Watch解鎖的Bug，蘋果表示將會修復 | T客邦
# 460   Fortinet最新報告：遠距使用者成重點目標，勒索軟體攻擊激增10倍 | T客邦
# 461   騎著自行車在洪水中掙扎，紐約市通過「外送員有權選擇送貨地點」等六項權益法案 - The News Lens 關鍵評論網
# 462   曾與乾旱共存 200 年——印度古城 Dholavira 的衰亡給當代社會的啟示 - PanSci 泛科學
# 463   今年上半年網路資安攻擊量暴增，趨勢科技攔截近410億次威脅 | T客邦
# 464   一個打匈奴、一個打領主：為何英美「民主代議制」在中國幾乎不可能發生？ - The News Lens 關鍵評論網
# 465   TravelDX正式推出線上VR環球旅遊服務 | T客邦
# 466   歐盟提議將 USB-C 作為通用充電口，蘋果表示會給 iPhone 使用者帶來「不便」 | T客邦
# 467   「新太空 2.0」時代來臨！盤點新創太空產業的衛星部署手段 - PanSci 泛科學
# 468   iPhone13全系列與前代電池續航對比測試，iPhone 13 Pro Max電池續航力到底強多少？
# 469   教育部就2.5萬筆學習歷程檔案遺失道歉，宣佈補救措施並將究責 | T客邦
# 470   【圖表分析】國民黨主席朱立倫「慘勝」，亡黨感、棄保奏效與黃復興黨部的裂解 - The News Lens 關鍵評論網
# 471   【小說】黃怡〈今朝有酒〉：飲啦！反正我們都已經變成了彼此的密切接觸者 - The News Lens 關鍵評論網
# 472   【圖輯】頭痛全攻略：大多數頭痛都是良性的？什麼症狀一定要看醫生？ - The News Lens 關鍵評論網
# 473   iPhone 13 原廠保護殼開箱，具備尋找功能的皮革卡套也一起來了 | T客邦
# 474   Tim Cook表示：那些爆料蘋果產品消息的人，不配當蘋果的員工 | T客邦
# 475   德誼數位iPhone 13購新機再加碼，舊換新iPhone 11系列最高折抵18,000元 | T客邦
# 476   在紓緩病房交流學習過後 - The News Lens 關鍵評論網
# 477   相機史上最強？iPhone 13 Pro Max 實拍評測！微距制霸、電影級模式超厲害！ | T客邦
# 478   《＋2的強效微鍛鍊》：走樓梯代替搭電梯，真的有運動效果嗎？ - The News Lens 關鍵評論網
# 479   AWS Dev Day開發者大會10月線上登場，即刻報名、取得最強大的技術補血 - The News Lens 關鍵評論網
# 480   2021金穗獎學生劇情片解析：臺灣短片創作悄悄蛻了一層皮，某些成長變化正在發生 - The News Lens 關鍵評論網
# 481   開箱要小心！iPhone13首摔案例已經在中國出現，還不止一個 | T客邦
# 482   【影評】《沙丘》：感官體驗實屬上乘，難以想像這一趟史詩旅途還會迎來什麼光景 - The News Lens 關鍵評論網
# 483   亞太地區最佳創投基金Kejora Capital看好臺灣機會 | T客邦
# 484   歐洲天然氣價格飆漲，北溪二號管將德國陷入「被勒索」境地？ - The News Lens 關鍵評論網
# 485   五倍券數位綁定浮現資安問題，國內 6 成金融業者 App 有遭駭隱憂 | T客邦
# 486   iPhone 13 全色系動眼看，開賣首週末蘋果直營店只提供取貨無法現場購買 | T客邦
# 487   iPhone 13 今天開賣，信義區一級戰場不見排隊盛況 | T客邦
# 488   【國民黨主席 X 青年】幕僚看朱立倫：他將是馬英九後最有實權的黨主席，改造國民黨貫徹到底 - The News Lens 關鍵評論網
# 489   《影響力投資》：一個專為女性設計的共同工作空間及社羣，算不算是「影響力企業」？ - The News Lens 關鍵評論網
# 490   《獨角獸創業勝經》：YouTube原本是約會網站？這些創辦人「打掉重練」造就的關鍵轉折 - The News Lens 關鍵評論網
# 491   牙醫師圖文解析「植牙」：什麼是牙橋？缺牙不處理會有什麼問題嗎？ - The News Lens 關鍵評論網
# 492   狂丟上百封履歷都石沈大海？誤踩這三大地雷，投再多也等不到面試通知 - The News Lens 關鍵評論網
# 493   iPhone 13來了，但Apple口袋破了：加州法院歷史性判決，會翻轉網路巨頭的賺錢規則？-風傳媒
# 494   振興五倍券蝦皮購物也適用，攜手多家銀行數位綁定 | T客邦
# 495   烏龍爆料讓衛星股暴漲暴跌：iPhone13支援衛星通訊為什麼這麼難？-風傳媒
# 496   iPhone 13 全系列開箱四款機種一次看完！天峯藍沒那麼藍、螢幕變亮超有感 | T客邦
# 497   Appier、Gogoro分別赴日、美掛牌，臺灣創新板與戰略新板為何留不住自家培育的獨角獸？ - The News Lens 關鍵評論網
# 498   中共「以經圍政」只會得到反效果，但更令人匪夷所思的恐怕是國民黨的反應 - The News Lens 關鍵評論網
# 499   避免青年人成為巨嬰，「18歲投票權」誰曰不宜？ - The News Lens 關鍵評論網
# 500   Mac mini？iMac？我該怎麼選？－ 蘋果生態系桌機差異徹底分析！ | T客邦

# %%
# 轉成 dataframe 並存檔

import os
os.getcwd()
# Out:
# 'C:\\Users\\vincentLee1231995\\OneDrive\\Documents\\Personal\\Crawling-in-60Days\\Homework\\final project'

# %%
df = pd.DataFrame(articles_info)
df.to_csv('C:/Users/vincentLee1231995/OneDrive/Documents/Personal/Crawling-in-60Days/Homework/final project/news_info.csv', index=False)

# %%
# 讀取 csv
import pandas as pd
news_info = pd.read_csv('news_info.csv')
news_info.head()
# Out:
#                                                title  \
# 0        想開咖啡廳，不是只要沖咖啡而已！專家曝8大開店地雷，經營美店絕對比你想的還要累-風傳媒
# 1                 指揮中心公佈配戴口罩放寬規定，爬山、海邊活動可不用戴口罩 | T客邦
# 2         中國東北限電限到只有 2G 訊號，紅綠燈罷工、行動支付不能用連買飯都困難 | T客邦
# 3         NETSCOUT威脅情報報告：DDoS攻擊達540萬次較去年同期增11% | T客邦
# 4  休旅車華麗變身「音樂戰車」，紐約街頭「惡名昭彰」的多明尼加汽車音響文化 - The News...
#
#                                                  url  \
# 0      https://www.storm.mg/lifestyle/3689600?page=1
# 1  https://www.techbang.com/posts/90420-the-comma...
# 2  https://www.techbang.com/posts/90380-there-are...
# 3  https://www.techbang.com/posts/90274-netscout-...
# 4         https://www.thenewslens.com/article/157149
#
#                         origin
# 0         https://www.storm.mg
# 1     https://www.techbang.com
# 2     https://www.techbang.com
# 3     https://www.techbang.com
# 4  https://www.thenewslens.com

# %% [markdown]
# ## 爬取每篇新聞內容

# %%
#test

import requests
from bs4 import BeautifulSoup
import time
import re
    
url=news_info['url'][1]
headers={'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/94.0.4606.71 Safari/537.36 Edg/94.0.992.38'}

response = requests.get(url, headers=headers)   
response.encoding='utf-8'
soup = BeautifulSoup(response.text, 'html.parser')

single_content=[]
paragraphs = []
        
if soup.find('p'):                                         
    paragraphs.append(soup.find_all('p'))   
            
if soup.find('section'):
    paragraphs.append(soup.find_all('section'))

for pars in paragraphs:                                    # pars 是 <p>集合 和 <section>集合
    for par in pars:
        text = re.sub('[\W]+', ' ', par.text)              # 找出特殊字元 (\n,\t,...等) 替換成空白  
        single_content.append(text)

single_content
# Out:
# [' janus 發表於 2021年10月03日 15 28 收藏此文 ',
#  '指揮中心今天宣布放寬戶外戴口罩的規定 指揮官陳時中表示由於疫情相對穩定 再加上先前中秋節過後 在人口流動的情況下 疫情依然維持穩定 因此指揮中心將陸續放寬口罩政策 ',
#  '第一波10 5日開始 將開放起農林漁牧工作於空曠處 如 田間 魚 山林工作無須戴口罩 但仍應隨身攜帶口罩 並與他人均保持社交距離 在山林包含森林遊樂區 海濱活動 無須戴口罩 也應隨身攜帶口罩 並應與他人均保持社交距離 但只要有人潮聚集或與他人共同工作 活動等無法保持社交距離就應戴上口罩 ',
#  '',
#  '不過陳時中強調 外出要戴口罩依然維持基本要求 就是如果在空曠沒有人的地方可以不用戴上口罩 但還是要隨身攜帶 萬一有人來互相有接觸時 還是要把口罩戴起來 ',
#  '先前本來就有免戴口罩例外規定 像是外出時有飲食需求 能與不特定對象保持社交距離或有適當阻隔設備 得免戴口罩 於開放餐飲內用之場所 台鐵高鐵用餐區 潛水 衝浪等符合指揮中心或主管機關指定之場所或活動 如符合相關防疫措施 得暫時脫下口罩 這些規定依然延續 ',
#  '對於脫口罩時機如何拿捏 陳時中表示這是基本性原則 沒有說一定要開罰 但這關係到民眾的自身安全 除了特別空曠的地方可以不用戴口罩外 一旦有人潮聚集 距離無法維持的時候 口罩還是要隨身攜帶 例如溫泉區域人潮聚集相對比較多 因此還是要戴口罩 ',
#  '此外 針對宗教等其他場所的防疫政策調整 指揮中心表示明天將會宣布 ',
#  ' ',
#  ' ',
#  ' 標籤 趨勢 ',
#  '請注意 留言要自負法律責任 相關案例層出不窮 請慎重發文 ',
#  ' 指揮中心今天宣布放寬戶外戴口罩的規定 指揮官陳時中表示由於疫情相對穩定 再加上先前中秋節過後 在人口流動的情況下 疫情依然維持穩定 因此指揮中心將陸續放寬口罩政策 第一波10 5日開始 將開放起農林漁牧工作於空曠處 如 田間 魚 山林工作無須戴口罩 但仍應隨身攜帶口罩 並與他人均保持社交距離 在山林包含森林遊樂區 海濱活動 無須戴口罩 也應隨身攜帶口罩 並應與他人均保持社交距離 但只要有人潮聚集或與他人共同工作 活動等無法保持社交距離就應戴上口罩 不過陳時中強調 外出要戴口罩依然維持基本要求 就是如果在空曠沒有人的地方可以不用戴上口罩 但還是要隨身攜帶 萬一有人來互相有接觸時 還是要把口罩戴起來 先前本來就有免戴口罩例外規定 像是外出時有飲食需求 能與不特定對象保持社交距離或有適當阻隔設備 得免戴口罩 於開放餐飲內用之場所 台鐵高鐵用餐區 潛水 衝浪等符合指揮中心或主管機關指定之場所或活動 如符合相關防疫措施 得暫時脫下口罩 這些規定依然延續 對於脫口罩時機如何拿捏 陳時中表示這是基本性原則 沒有說一定要開罰 但這關係到民眾的自身安全 除了特別空曠的地方可以不用戴口罩外 一旦有人潮聚集 距離無法維持的時候 口罩還是要隨身攜帶 例如溫泉區域人潮聚集相對比較多 因此還是要戴口罩 此外 針對宗教等其他場所的防疫政策調整 指揮中心表示明天將會宣布 Facebook LINE ',
#  ' 使用 Facebook 留言 ',
#  ' 發表回應 請先登入會員方可留言 謹慎發言 尊重彼此 按此展開留言規則 留言板發文規則 請注意 留言要自負法律責任 相關案例層出不窮 請慎重發文 請勿一文多貼灌水洗板或發表無意義字串 違者直接刪除留言 請勿張貼廣告 不允許任何形式的商業廣告行為 包含頭像 簽名檔等 禁止發表非官方所舉辦的團購性質活動 違者直接刪除留言 發言時請勿涉及人身攻擊 侮辱 色情或其他有違社會善良風俗之內容 違者直接刪除留言 嚴禁發表討論破解軟體 註冊碼 音樂 影片 軟體複製等違反智慧財產權之留言 請尊重他人之文章著作權 轉載者請標明來源 ',
#  ' 最愛排行榜 1 他冒充 少年神童 被校友爆料是AI神棍 大學碩士博士學歷全造假 2 士林分署10月拍賣公告成礦工拍賣會 包含44台挖礦機 7620枚泰達幣 以太幣都上架 3 iPhone 13 全系列 4 大機型有何不同 開箱一次看 規格 售價 機型 顏色總整理 4 網民問歐菲光iPhone 13哪款用他們的鏡頭模組 歐菲光尷尬回應 我們已被蘋果終止採購了 5 三款神還原 魷魚遊戲 玩法Roblox遊戲推薦 手機 桌機都可玩 輸了就下地獄 6 米其林Uptis無氣乘用車輪胎首次公開亮相 7 iPhone 13紙膠條包裝被華強北破解 一套封條只賣18元 8 悠遊卡也會過期 第一代悠遊卡將滿效期 從序號來查你的悠遊卡是否快到期 9 暗黑破壞神II 獄火重生 Bug 不斷 玩家狂炸負評 10 小米平板 5 開箱評測 大尺寸的 Android 平板搭配觸控筆一起來了 ',
#  '',
#  '']

# %%
#把解析爬回的Html的程式封裝起來

content=[]

def analysis(url_list, content):
    
    import requests
    from bs4 import BeautifulSoup
    import time
    import re

    headers={'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/94.0.4606.71 Safari/537.36 Edg/94.0.992.38'}
    
    for url in url_list:
        response = requests.get(url, headers=headers)   
        response.encoding='utf-8'
        soup = BeautifulSoup(response.text, 'html.parser')

        single_content=[]
        paragraphs = []
        
        if soup.find('p'):                                         
            paragraphs.append(soup.find_all('p'))   
            
        if soup.find('section'):
            paragraphs.append(soup.find_all('section'))

        for pars in paragraphs:                                    # pars 是 <p>集合 和 <section>集合
            for par in pars:
                text = re.sub('[\W]+', ' ', par.text)              # 找出特殊字元 (\n,\t,...等) 替換成空白  
                single_content.append(text)

        content.append(single_content)

# %%
target = news_info['url']
print(len(target))
# Out:
# 500

# %%
import time

start=time.time()

analysis(target,content) #呼叫函式

end=time.time()

print('Done!', end-start, 's')
# Out:
# Done! 356.9401741027832 s

# %%
print(len(content))
# Out:
# 500

# %%
news = []

for i in content:   
        news.append(i)

# %% [markdown]
# 以上為單線程爬蟲的做法，有空，在試試用多線程的方法，看能夠節省多少時間

# %%
news_info['content'] = news # 把新聞內容加進 dataframe
news_info.to_csv('C:/Users/vincentLee1231995/OneDrive/Documents/Personal/Crawling-in-60Days/Homework/final project/news_contents.csv', index=False)  # 重新存檔

# %% [markdown]
# # 整理爬取到的資料，統計

# %%
import pandas as pd

data = pd.read_csv('./news_contents.csv')
data.head()
# Out:
#                                                title  \
# 0        想開咖啡廳，不是只要沖咖啡而已！專家曝8大開店地雷，經營美店絕對比你想的還要累-風傳媒
# 1                 指揮中心公佈配戴口罩放寬規定，爬山、海邊活動可不用戴口罩 | T客邦
# 2         中國東北限電限到只有 2G 訊號，紅綠燈罷工、行動支付不能用連買飯都困難 | T客邦
# 3         NETSCOUT威脅情報報告：DDoS攻擊達540萬次較去年同期增11% | T客邦
# 4  休旅車華麗變身「音樂戰車」，紐約街頭「惡名昭彰」的多明尼加汽車音響文化 - The News...
#
#                                                  url  \
# 0      https://www.storm.mg/lifestyle/3689600?page=1
# 1  https://www.techbang.com/posts/90420-the-comma...
# 2  https://www.techbang.com/posts/90380-there-are...
# 3  https://www.techbang.com/posts/90274-netscout-...
# 4         https://www.thenewslens.com/article/157149
#
#                         origin  \
# 0         https://www.storm.mg
# 1     https://www.techbang.com
# 2     https://www.techbang.com
# 3     https://www.techbang.com
# 4  https://www.thenewslens.com
#
#                                              content
# 0  [' 人氣 ', '現正熱映中', '熱門文章', '熱門分享', ' 許多人夢想開咖啡廳創...
# 1  [' janus 發表於 2021年10月03日 15 28 收藏此文 ', '指揮中心今天...
# 2  [' 鳯凰網 發表於 2021年10月03日 15 00 收藏此文 ', '中國東北多地傳出...
# 3  [' Hsuann 發表於 2021年10月03日 11 00 收藏此文 ', '友訊代理品...
# 4  [' TNL編輯部國際編譯專用帳號 發表國際新聞的分析與整理 ', ' 這個文化源於對聲音和...

# %%
origin_state = data['origin'].value_counts().reset_index()  
origin_state.columns=['origin', 'count']
origin_state
# Out:
#                                origin  count
# 0          https://www.jiqizhixin.com    234
# 1            https://www.techbang.com     73
# 2           https://www.ithome.com.tw     46
# 3         https://www.thenewslens.com     38
# 4        https://chinese.engadget.com     20
# 5          https://www.blocktempo.com     14
# 6             https://applealmond.com     13
# 7                https://www.storm.mg     11
# 8                   https://unwire.hk      6
# 9   http://3smarket-info.blogspot.com      6
# 10             https://softnshare.com      6
# 11                https://pansci.asia      5
# 12               https://blockcast.it      4
# 13           https://www.kocpc.com.tw      3
# 14                    https://ez3c.tw      3
# 15                  https://qooah.com      3
# 16                https://free.com.tw      2
# 17                https://steachs.com      2
# 18           https://news.readmoo.com      2
# 19             https://www.cool3c.com      2
# 20                https://appworks.tw      1
# 21                 https://dq.yam.com      1
# 22          https://www.smartm.com.tw      1
# 23            https://mf.techbang.com      1
# 24            https://case.ntu.edu.tw      1
# 25        https://www.azofreeware.com      1
# 26             https://buzzorange.com      1

# %%
def mapping_new_origin(origin, count):                              # 把太少的部分歸納成 Others
    if count >= 5:
        return origin
    else:
        return 'Others'

new_origin = []

for i in range(len(origin_state)):
    new_origin.append(mapping_new_origin(origin_state.iloc[i, 0], origin_state.iloc[i, 1]))

origin_state['new_origin'] = new_origin
origin_state
# Out:
#                                origin  count  \
# 0          https://www.jiqizhixin.com    234
# 1            https://www.techbang.com     73
# 2           https://www.ithome.com.tw     46
# 3         https://www.thenewslens.com     38
# 4        https://chinese.engadget.com     20
# 5          https://www.blocktempo.com     14
# 6             https://applealmond.com     13
# 7                https://www.storm.mg     11
# 8                   https://unwire.hk      6
# 9   http://3smarket-info.blogspot.com      6
# 10             https://softnshare.com      6
# 11                https://pansci.asia      5
# 12               https://blockcast.it      4
# 13           https://www.kocpc.com.tw      3
# 14                    https://ez3c.tw      3
# 15                  https://qooah.com      3
# 16                https://free.com.tw      2
# 17                https://steachs.com      2
# 18           https://news.readmoo.com      2
# 19             https://www.cool3c.com      2
# 20                https://appworks.tw      1
# 21                 https://dq.yam.com      1
# 22          https://www.smartm.com.tw      1
# 23            https://mf.techbang.com      1
# 24            https://case.ntu.edu.tw      1
# 25        https://www.azofreeware.com      1
# 26             https://buzzorange.com      1
#
#                            new_origin
# 0          https://www.jiqizhixin.com
# 1            https://www.techbang.com
# 2           https://www.ithome.com.tw
# 3         https://www.thenewslens.com
# 4        https://chinese.engadget.com
# 5          https://www.blocktempo.com
# 6             https://applealmond.com
# 7                https://www.storm.mg
# 8                   https://unwire.hk
# 9   http://3smarket-info.blogspot.com
# 10             https://softnshare.com
# 11                https://pansci.asia
# 12                             Others
# 13                             Others
# 14                             Others
# 15                             Others
# 16                             Others
# 17                             Others
# 18                             Others
# 19                             Others
# 20                             Others
# 21                             Others
# 22                             Others
# 23                             Others
# 24                             Others
# 25                             Others
# 26                             Others

# %%
new_origin_state = origin_state.groupby(by='new_origin').sum().reset_index().sort_values(by='count', ascending=False).reset_index(drop=True)
new_origin_state
# Out:
#                            new_origin  count
# 0          https://www.jiqizhixin.com    234
# 1            https://www.techbang.com     73
# 2           https://www.ithome.com.tw     46
# 3         https://www.thenewslens.com     38
# 4                              Others     28
# 5        https://chinese.engadget.com     20
# 6          https://www.blocktempo.com     14
# 7             https://applealmond.com     13
# 8                https://www.storm.mg     11
# 9   http://3smarket-info.blogspot.com      6
# 10             https://softnshare.com      6
# 11                  https://unwire.hk      6
# 12                https://pansci.asia      5

# %%
new_origin_state.to_csv('C:/Users/vincentLee1231995/OneDrive/Documents/Personal/Crawling-in-60Days/Homework/final project/new_origin_state.csv', index=False)  # 重新存檔

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(figsize=(25,10))
plt.pie(new_origin_state['count'],
        labels=new_origin_state['new_origin'],
        autopct='%0.1f%%')

#plt.rcParams['font.sans-serif']=['FangSong']

plt.legend()
plt.title('新聞來源網站分布')
plt.show()

# %% [markdown]
# ## 接著將新聞內容斷詞，根據關鍵詞繪製文字雲

# %%
import pandas as pd 

data = pd.read_csv('./news_contents.csv')
data.head()
# Out:
#                                                title  \
# 0        想開咖啡廳，不是只要沖咖啡而已！專家曝8大開店地雷，經營美店絕對比你想的還要累-風傳媒
# 1                 指揮中心公佈配戴口罩放寬規定，爬山、海邊活動可不用戴口罩 | T客邦
# 2         中國東北限電限到只有 2G 訊號，紅綠燈罷工、行動支付不能用連買飯都困難 | T客邦
# 3         NETSCOUT威脅情報報告：DDoS攻擊達540萬次較去年同期增11% | T客邦
# 4  休旅車華麗變身「音樂戰車」，紐約街頭「惡名昭彰」的多明尼加汽車音響文化 - The News...
#
#                                                  url  \
# 0      https://www.storm.mg/lifestyle/3689600?page=1
# 1  https://www.techbang.com/posts/90420-the-comma...
# 2  https://www.techbang.com/posts/90380-there-are...
# 3  https://www.techbang.com/posts/90274-netscout-...
# 4         https://www.thenewslens.com/article/157149
#
#                         origin  \
# 0         https://www.storm.mg
# 1     https://www.techbang.com
# 2     https://www.techbang.com
# 3     https://www.techbang.com
# 4  https://www.thenewslens.com
#
#                                              content
# 0  [' 人氣 ', '現正熱映中', '熱門文章', '熱門分享', ' 許多人夢想開咖啡廳創...
# 1  [' janus 發表於 2021年10月03日 15 28 收藏此文 ', '指揮中心今天...
# 2  [' 鳯凰網 發表於 2021年10月03日 15 00 收藏此文 ', '中國東北多地傳出...
# 3  [' Hsuann 發表於 2021年10月03日 11 00 收藏此文 ', '友訊代理品...
# 4  [' TNL編輯部國際編譯專用帳號 發表國際新聞的分析與整理 ', ' 這個文化源於對聲音和...

# %%
news = list(data['content'].values)                                 
print(len(news), type(news))
# Out:
# 500 <class 'list'>

# %%
pip install jieba
# Out:
# Collecting jiebaNote: you may need to restart the kernel to use updated packages.
#
#   Downloading jieba-0.42.1.tar.gz (19.2 MB)
# Building wheels for collected packages: jieba
#   Building wheel for jieba (setup.py): started
#   Building wheel for jieba (setup.py): finished with status 'done'
#   Created wheel for jieba: filename=jieba-0.42.1-py3-none-any.whl size=19314481 sha256=2b833f25e8aa0045b41c6093da40f66c1f1639482d691ccb7cdc3b8ede87cf7d
#   Stored in directory: c:\users\vincentlee1231995\appdata\local\pip\cache\wheels\ca\38\d8\dfdfe73bec1d12026b30cb7ce8da650f3f0ea2cf155ea018ae
# Successfully built jieba
# Installing collected packages: jieba
# Successfully installed jieba-0.42.1

# %%
import jieba
import jieba.analyse

# 移除停用詞
stopwords=[]

with open('cn_stopwords.txt', 'r', encoding='utf-8') as f:             # 使用從網路上抓來的停用詞表
    for data in f.readlines():
        data = data.strip()
        stopwords.append(data)
        
len(stopwords)
# Out:
# 746

# %%
# jieba 分詞

import time

print('Jobs just begin!')

remained_news = []

startTime=time.time()

for n in news:
    
    seg = jieba.cut(n, cut_all=False)               # 分詞後去除停用詞, 然後再重組回文章
   
    try:
        remained_news.append(''.join(list(filter(lambda a: a not in stopwords and a != '\n', seg))))
    
    except Exception as e:                         
        print(e)                                    # 若有 'nan' 的項目會引發錯誤  
        print(news.index(n))                        # 取得序號再次確認新聞內容是否有問題

endTime=time.time()

print('Take time: ', endTime-startTime, 's')
print('All jobs Done!')
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache C:\Users\VINCEN~1\AppData\Local\Temp\jieba.cache
# Jobs just begin!
# Loading model cost 0.955 seconds.
# Prefix dict has been built successfully.
# Take time:  39.3056480884552 s
# All jobs Done!

# %%
print(len(remained_news))
# Out:
# 500

# %%
# 關鍵字 tfidf
keywords = []

startTime=time.time()

for n in remained_news:
    keywords.append(jieba.analyse.extract_tags(n, topK=20, withWeight=False))

for j in keywords:
    print(j,'\n')
    
    
endTime=time.time()

print('Take time: ', endTime-startTime, 's')
print('All jobs Done!')
# Out:
# ['10', '2021', '07', '咖啡', '06', '16', '09', '市場', '台灣', '咖啡店', '中央社', '新聞', '20', '創業', '星巴克', '通路', '熱門', '許多', '食力', '超商']
#
# ['口罩', '指揮', '距離', '隨身', '攜帶', '還是', '活動', '留言', '社交', '規定', '維持', '10', '相對', '穩定', '無須', '無法', '空曠', '之場', '相關', '聚集']
#
# ['停電', '手機', '包一倩', '沒有', '社區', '時間', '電影', '留言', '不見', '出門', '用電', '情況', '一個', '發電機', '因為', '發現', '煤氣', '居民', '不斷', '他們']
#
# ['攻擊', 'DDoS', '駭客', '網路', '威脅', '組織', 'DNS', '屍網', '勒索', '留言', '增加', '報告', '機構', '攻擊鏈', '2020', 'TCP', '放大', '反射', '三重', '伺服器']
#
# ['運動', '我們', '音響', '多明尼加', '一個', '汽車', '科技', '透過', '國家', '改變', '埃塔', '曼蘇', '音樂', '智慧', '這個', '一樣', '沙龍', '科學', '選手', '美國']
#
# ['檔案', '步驟', '壓縮', '留言', '影片', '手機', '壓片', '熊貓', 'App', '解析度', '發表', '10', '軟體', '發文', '廣告', '違者', '刪除', 'iPhone', '13', '直接']
#
# ['網路', 'ISO', '車輛', '標準', 'SAE', '電子', '安全', '系統', '技術', '郵件', '我們', '風險', '21434', 'International', '開發', '委員會', '網站', '留言', '合作', '它將']
#
# ['直播', '10', '中華職', '2021', 'CPBL', '味全', '線上', '兄弟', '職棒', '中信', 'vs', '比賽', '轉播', 'Live', '05', '11', 'iPhone', '17', 'Twitch', '賽程']
#
# ['直播', '中華職', 'CPBL', '10', '2021', '味全', 'LINE', 'Today', '線上', 'vs', 'Live', '兄弟', '中信', '比賽', '轉播', '11', 'iPhone', '賽程', '推薦', '下半季']
#
# ['直播', '中華職', 'CPBL', '10', '2021', '統一獅', 'LINE', 'Today', '線上', '富邦', 'vs', '悍將', '中職', '比賽', 'Live', '轉播', '11', 'iPhone', '賽程', '收看']
#
# ['Apple', 'Watch', 'Series', '10', '販售', '2021', '蘋果', '開始', '下週', '預訂', '出貨', 'iPhone', '資訊', '確定', '價格', '充電', '推薦', '發表會', '不過', '售價']
#
# ['學習', '機器', '資料', '程式', 'PyCaret', '一個', '科學家', '電子', '郵件', '開源', 'low', 'code', '任務', '公民', 'Soft', 'Share', 'Python', '幾個', 'scikit', 'learn']
#
# ['學習', '電子', '郵件', '機器', '一個', '將學習', '模型', '預測', '這個', '訂閱', '位址', '文章', '程式', '建立', '接收', '使用', '通知', 'Soft', 'Share', '告訴']
#
# ['特斯拉', '發生', '2021', '事故', '英里', '10', 'Autopilot', '啟用', '自動', '輔助', '安全', 'NTSB', '美國國家', '美國', '問題', '一次', '報告', '顯示', '情況', '則是']
#
# ['火幣', '用戶', '提現', '時間', '清退', '10', '中國', '加密', '日間', '一至', '法幣', '帳號', '中國用', '12', '14', '15', '31', '現貨', '26', 'your']
#
# ['Cardano', 'EMURGO', '投資', '區塊', 'NFT', 'DeFi', '項目', '解決', '專輯', 'Emurgo', '生態系', '霍斯金森', '歐肯', '佛德', 'Africa', 'Ventures', '音樂', '發展', '創辦', '鏈上']
#
# ['eNaira', 'CBN', '上路', '奈及', '利亞', '貨幣', '10', '試點', 'CBDC', '該國', '高等法院', '上線', '聯邦', '數位', 'Payment', 'Solutions', '報導', 'eNaria', 'your', '央行']
#
# ['解壓', '檔案', '軟體', '問題', '轉貼', '什麼', '本站', '縮密碼', 'azo', '阿榮', '福利', '常見', '連結', '載點', '歡迎', '隨意', '盜連', '無須', '反盜', '版聲明']
#
# ['資產', '鏈橋', '用戶', '公鏈', 'L2', '模式', '跨鏈', '驗證', '不同', '安全性', '以太', '鏈之間', '目標', '代幣', '進行', '實現', '費用', '他們', '這種', '這些']
#
# ['BTC', '灰度', '美元', 'GDLC', '加密', 'Grayscale', 'SOL', '機構', 'GBTC', '17', '表現', 'UNI', '納入', '顯見', '同時', 'ETHE', 'Solana', 'ETH', '10', 'AUM']
#
# ['Safari', 'iOS', '15', '瀏覽器', '顯示', '畫面', '分頁', '調整', '設定', '網頁', '開啟', '群組', '功能', '預設', '瀏覽', '按鈕', '切換', '圖片', '使用者', 'iPhone']
#
# ['SHIB', '億枚', '買進', '這位', 'Robinhood', '富豪', '30', '10', '柴犬', '上架', '成長', '美元', '巨鯨', '760', '單日', '大戶', 'Coinbase', '柴犬幣', '閱讀', 'WhaleStats']
#
# ['Apple', 'Watch', '解鎖', 'iPhone', 'iOS', '13', '問題', '蘋果', '15', '設定', '出來', '14', 'ios', 'iphone', '急修', '更新', '透過', '然後升級', '用戶', '發現']
#
# ['10', '2021', '中國', '加密', '07', '06', '比特', '交易所', '虛擬', '貨幣', '09', '新聞', '火幣', '16', '中央社', '20', '認為', '市場', '活動', '詐騙']
#
# ['資料', '10', '2021', '用戶', '索取', '保護', '微軟', '臉書', '04', '各國', '05', '政府', '原則', '雲端業者', '法令', 'Google', '隱私', '業者', '這些', '新聞']
#
# ['Journey', 'Google', '一個', '歷史', '相關', '網頁', '進行', 'chrome', '搜尋結果', 'google', 'Chrome', '這個', '記錄', '主題', 'history', '未來', '測試', '側邊', '連結', '圖示']
#
# ['發展', '科技', '物流', '10', '留言', '區塊', '鏈技術', '應用', '台灣', '創辦', '新創', '機會', '技術', '電商', '金融', '台北', '創業', '執行長', '未來', 'FinTech']
#
# ['企業', '戲劇', '社創', '女配角', '節目', '數位', '金鐘獎', '服務', '社會', '電視', '商家', '疫情', '2021', '資源', '消費者', '購物', '我們', '轉型', '男配角', '沙龍']
#
# ['vivo', '鏡頭', '萬畫素', 'X70', '手機', '10', '售價', '留言', '旗艦', '990', '電信', '資費', '元起', '優惠', '200', '體驗店', 'Y21s', 'Y21', '搭配', '自拍']
#
# ['禮盒', '設計', '2021', '留言', '愛好者', '傳統', '金秋', '相機', '限定', '麻將', '攝影', '經典', '標誌', 'logo', '內部', '牌面', '材質', '限量', '發表', '10']
#
# ['營養', '桂冠', '美味', '疫苗', '接種', '健力餐', '指揮', '研究室', '10', '我們', '消費者', '健康', '預約', '醫療', '沙龍', '影響', '醫院', '照顧', '預購', '花椰菜']
#
# ['Google', 'Android', '蘋果', '市場', '競爭', '系統', '手機', '盟委', '應用', '尼古拉斯', '留言', '程式', '反壟斷', '歐盟', '員會', '壟斷', '皮克福德', '行動', '領域', '一個']
#
# ['Lexus', 'Redick', '快艇', '我們', '射手', '品牌', '概念', 'Electrified', '油電', 'LEXUS', 'ELECTRIFIED', '15', '沙龍', 'LC', '創造', 'TNL', 'Hybrid', '500h', '運動', '討論']
#
# ['LINE', '回饋', 'Bank', 'POINTS', '加碼', 'Pay', '新戶', '10', '活動', '屈臣氏', '優惠', '快點', '綁定', '日起', '兌換', '消費', '通路', '付款', '31', '點數']
#
# ['免費', '下載', '價格', '教學', '網站', 'WordPress', 'LINE', '查詢', '電商', '歷史', 'Google', '網路', 'info', '電子', '購物', '變化', 'TWBuyer', '應用', '資料', '郵件']
#
# ['iPhone', '神腦', '原廠', '電池', '優惠', '10', 'Plus', 'Pro', '12', 'Note', '手機', '留言', '990', '85', '採線', '時間', 'Max', '11', '換修', 'S20']
#
# ['並且', '螢幕', '開始', 'Xeneon', '32QHD165', '100', 'USB', '軟體', '插孔', '解析度', '機殼', '組件', '近幾年', '各種', '週邊', '擴張', 'Corsair', '將觸', '角伸', '進電']
#
# ['10', '2021', '07', 'Astro', '06', '亞馬遜', '機器', '新聞', '09', '16', '中央社', '這款', '樓梯', '20', '熱門', 'Alexa', '時間', '報導', '30', '專家']
#
# ['貨幣', '10', '2021', '加密', '支付', '金融', '金管會', '美國', '電子', '機構', '億元', '銀行', 'Suex', '科技', '中國', '區塊', '資料', '服務', '相關', '上線']
#
# ['2021', '10', 'CVE', '04', 'Google', '漏洞', 'Chrome', '臉書', '05', 'iThome', '釋放', '程式', '37976', '執行', '新聞', '微軟', '卡巴斯基', '94', '4606', '兩個']
#
# ['10', '2021', 'Visa', '蘋果', '人員', '04', 'Apple', 'Pay', '模擬器', '臉書', '支付', '使用者', '05', 'Express', 'Transit', '透過', 'iThome', '卡片', '機制', '進行']
#
# ['中国馆', '机器人', '熊猫', '必选', '优悠', '世博会', '人工智能', '科技', 'Walker', '迪拜', '智能', '服务', '全球', '中国', 'AI', '2020', '助力', '共同体', '上岗', '新冠']
#
# ['Loihi', '芯片', '神经', '英特尔', '形态', 'Lava', 'Intel', '神经元', '制程', '学习', '架构', '框架', '使用', '可编程', '计算', '软件', '应用', 'EUV', '算法', '研究']
#
# ['维格纳', '电子', '晶体', '显微镜', '王枫', '石墨', '扫描', '隧道', '原子', '蜂窝状', '物理学家', '半导体', '固体', '排列', 'A100', '微信', 'Wigner', 'https', 'www', 'nature']
#
# ['DGMR', '降雨', '预测', '雷达', '即时', '预报', '模型', 'DeepMind', '方法', '生成', '研究者', '天气', '天气预报', '准确性', '强降雨', '2019', 'PySTEPS', 'UNet', '研究', '能够']
#
# ['電池', 'iPhone', '更換', '10', '優惠', '原廠', '2021', '舊換', '神腦', '990', '活動', '這次', '送修', '同樣', '預約', '型號', '保養', '教學', '需要', '推薦']
#
# ['Vive', 'Focus', 'HTC', 'Pro', 'VR', '控制器', '兩個', '不過', '電池', '充電', '解析度', 'PC', '系統', 'HK', '999', '企業', '服務', 'Sync', 'Viveport', 'Infinity']
#
# ['Xperia', 'Sony', 'III', 'Mobile', '手機', '10', '優惠', '行動', '通訊', '專賣店', '旗艦', '留言', 'Android', '活動', '機種', '購買', '銷售', '回饋', '維修', 'XZ']
#
# ['ZV', '錄影', 'E10', '規格', 'Sony', '相機', '影音', '功能', 'a6400', '裁切', '機頂', '4K', '電池', '具備', '感光', '鏡頭', '同時', '螢幕', '機種', '搭載']
#
# ['太空', '距離', '地球', '我們', '這個', '飛行', '月球', '公里', '天文', '運動', '2021', '25', '一個', '怎麼', '大約', '重量', '量測', '因為', '小時', '太陽']
#
# ['Nokia', 'G50', '10', '手機', '留言', '採用', '萬畫素', '30', '鏡頭', '007', '交戰', '螢幕', '790', '6GB', '128GB', '系統', '穩定', '自動', '購物', '全台']
#
# ['台灣', '家具', '消費者', '家居', '天貓', '成長', '採購', '服務', '商品', '組裝', '留言', '品類', '10', '集運', '物流', '12', '合單', '必賠', '各項', 'VISA']
#
# ['手機', '台灣', '回收', '三星', '10', '活動', '協會', '民眾', '廢棄', '環境', '留言', '資源', '企業', '維修', '服務', '保護', '全台', '保育', 'iPhone', '荒野']
#
# ['HK', 'Yoga', 'Lenovo', '電腦', 'ThinkPad', '購買', 'X1', 'Titanium', '螢幕', '採用', 'Flex', 'P15v', '15', '按此', '10', '金額', 'Intel', '理器', 'Dolby', 'Chromebook']
#
# ['杜比', '啟動', '全景', 'Apple', 'AirPods', '空間', '音訊', '演唱', '周杰倫', 'Music', 'Live', '設定', '支援', '現場', '獨家', '音樂', '頭部', '體聲', '音量', '音源']
#
# ['國語', '阿湯', '生字', '幫手', '查詢', 'LINE', '查國字', '雖然', '手機', '國字', '筆順', '造詞', '相關', '成語', '課本', '加入', '詞典', '點擊', '內容', '興趣']
#
# ['AXS', 'Axie', '萬枚', 'Infinity', '質押', '美元', '30', '玩家', '80', '漲幅', '75', '歷史', '120', '663', '區塊', 'your', '社群', '200', 'APR', '創下']
#
# ['App', 'Store', 'Apple', '評分', '評價', '不過', '終於開', '變化', '這些', '留言', '上用', '各個', '進行', '以來', '內置', '並沒有', '選項', '結果', '負評', 'iOS']
#
# ['穩定幣', '監管', '銀行', 'Circle', '拜登', '等級', '機構', 'FSOC', 'USDC', '執行', '透過', '準備', '報導', '當局', '監管者', '聯盟', '現金', 'your', '此事', '主席']
#
# ['產業', 'OPPO', '天前', '螢幕', '遊戲', '凹折', '手機', '消息', '2022', '應用', '什麼', '英文', '情況', '機產品', '裝置', '設計', '發展', '市場', 'Windows', '11']
#
# ['應用', '天前', '機構', '數據', '服務', '遊戲', '協議', '內容', '微軟', '雲端', '用戶', '隱私', '什麼', '英文', '科技', '情況', '服務數', '購物', '特務', '未來']
#
# ['監管', '中國', '加密', '比特', '貨幣', '大陸', '吳忌寒', '924', '吳忌', '創辦', '機構', '產業', '預言', '散戶', '服務', 'your', '做出', '28', '趨勢', '發展']
#
# ['地熱', '火山', '比特', '挖礦', '薩爾瓦多', 'BTC', '總統', '該國', '薩爾瓦', '能源', '節點', 'volcanode', 'Nayib', 'Bukele', '發電', '設施', '閱讀', '成為', 'your', '再生能源']
#
# ['Surface', 'Pro', '配備', 'Core', '4G', '企業', '市場', 'Microsoft', '官網', '同樣', 'i3', '平板', '上市', '吸引', '發表', '筆電', '13', '120Hz', 'PixelSense', 'Flow']
#
# ['直播', '中華職', '2021', 'CPBL', '10', '味全', '線上', 'LINE', 'Today', 'Live', 'vs', '兄弟', '中信', '比賽', '轉播', '11', '例行', 'iPhone', '賽程', '推薦']
#
# ['直播', '10', '中華職', '2021', 'CPBL', '味全', '線上', '兄弟', '職棒', '中信', 'vs', '轉播', 'Live', '比賽', '05', '11', 'iPhone', '17', 'Twitch', '賽程']
#
# ['直播', '中華職', '2021', 'CPBL', '10', '統一獅', '線上', 'LINE', 'Today', 'vs', '樂天桃', '中職', '比賽', 'Live', '11', 'iPhone', '轉播', '賽程', '收看', '推薦']
#
# ['用戶', 'Coinbase', '驗證', '2FA', 'Email', '帳號', '駭客', 'App', '攻擊', '加密', '透過', '補償', '資產', '釣魚', '發生', '執法', 'your', '警告', '官方', '受害者']
#
# ['我們', '美秀', '一個', '集團', '這個', 'NFT', 'TK', 'Chen', '演唱', '全息', '音樂', '什麼', '修齊', '時候', '因為', 'Beatday', '他們', '這次', '結合', '狗柏']
#
# ['Apple', 'Watch', 'Series', 'Jon', 'Prosser', '將會', '10', '發售', '上市', '夥伴', '預訂', '並且', '舉行', 'California', 'Streaming', '雖然', '發表', '並沒有', '細節', '當時']
#
# ['照片', '軟體', '感覺', '哪裡', '電影', '交友', '聊天', '獨照', '因為', '時候', '什麼', '開始', '風景', '興趣', '約會', '地點', '細節', '關鍵', '一定', '女生']
#
# ['BTC', '美元', '比特', '美股', '指數', 'Q4', '激勵', '成長', 'Bollinger', '目標', '新冠', '43', '包寧傑', 'John', '開盤', '500', '已經', '52', 'below', 'your']
#
# ['貼圖', 'LINE', '用戶', '擁有', '圖鍵盤', '刪除', '開啟', '聊天室', '超值', '情境', '這時', '分類', '顯示', '設定', '建議', '方案', '使用', '我們', '免費', '總是']
#
# ['Trade', '蘋果', '禮品', 'Apple', '換出', '換購', 'iPad', 'Store', '換成', '現場', '購物金', '估價', '10', '金額', 'iPhone', '裝置', '2021', '流程', '螢幕', '接著']
#
# ['優惠', '五倍', '900', '綁定', '領取', '紙本', 'Sony', '10', '原價', '影音', '預約', 'BRAVIA', '2021', '000', 'iPhone', '超商', '紙本券', 'XRM', '懶人包', 'XRW']
#
# ['iPhone', 'iCloud', '照片', '同步', '資料', 'App', '開啟', '10', '檔案', '刪掉', '不見', '這個', '設備', '2021', '什麼', '推薦', 'iOS', '蘋果', '這樣', '備份']
#
# ['比特', '網路', '閃電', '支付', '用戶', '貨幣', '單位', 'SAT', 'BTC', '轉帳', '計價', '閱讀', '屬性', '加密', '推特', '小費', '優勢', '標價', '投資者', '成為']
#
# ['音樂', '免費', '素材', 'Mubert', 'Render', '下載', '曲風', '網站', '按下', '情境', '一樣', 'AI', '我們', '主題', '樂器', '推薦', '這個', '背景', '點擊', '預覽']
#
# ['iPhone', 'iOS', '15', '13', 'Bug', '10', '2021', '更新', '網友', '討論', '蘋果', '建議', '出現', '問題', '使用者', '推薦', '教學', '盡快', '點和', 'Apple']
#
# ['10', '2021', '07', '06', 'Gogoro', '台灣', '09', '上市', '16', '中央社', '新聞', '陸學森', 'SPAC', '獨角獸', '億元', '20', '熱門', '市場', '傳出', '開始']
#
# ['2021', '10', '微軟', '伺服器', '卡巴斯基', '程式', '發現', 'Tomiris', '04', 'Nobelium', '後門', '臉書', '攻擊', '駭客', '組織', '05', '植入', 'FoggyWeb', 'iThome', 'Orion']
#
# ['2021', '10', 'Zimperium', '程式', '使用者', '04', '超過', '臉書', '惡意', '05', 'GriftHorse', 'Android', '歐元', 'iThome', '活動', '服務', '發現', '11', '駭客', 'Google']
#
# ['2021', '10', 'Sachkov', 'Group', '俄羅斯', 'IB', '04', '臉書', '05', '斯政府', '服務', '俄羅', '創辦', '新聞', '卡巴斯基', '羈押', '調查', '當地', '駭客', '報導']
#
# ['特征', '元素', '支付宝', '身份', '判别', '研究者', '狗子', '学习', '论文', '宠物', '鼻子', '细粒度', '分类器', '功能', '最近', '记得', '样本', '公布', '擦除', '方法']
#
# ['法拉利', '首款', '电动车', '艾维', '里程碑', '品牌', '乔纳森', '苹果', 'LoveFrom', '历史', '乔布斯', '表示', '设计', '2021', '纽森', 'Exor', 'https', 'www', 'com', '马克']
#
# ['参数', '大象', '画出', '论文', '神经网络', '学习', '一个', '数据', 'DeepMind', '机器', '算法', '诺依曼', '可微', '实值', '图像', '研究者', '单个', '模态', '拟合', '模型']
#
# ['充电', '无线', '房间', '角落', '实现', '期待', '传输', '研究者', 'Sasatani', '磁场', '方法', '无线电', '系统', '导电', '模态', '电子设备', '下图', '这项', 'Takuya', 'QSCR']
#
# ['模型', '训练', '自然语言', '神舟', '腾讯', '理解', 'QQ', '中文', '浏览器', '评测', '榜单', 'CLUE', '蒸馏', '登顶', '19', '语义', '任务', 'Shenzhou', '知识', '学习']
#
# ['2021', '10', 'Griffith', '貨幣', '美國', '加密', '北韓', '04', '臉書', '服務', '05', 'iThome', '2019', '當地', '以太', '制裁', '20', '新聞', '微軟', '卡巴斯基']
#
# ['2021', '10', '臉書', 'Mariana', 'Trench', '04', '程式', '分析', 'App', '05', '漏洞', '資料', 'iThome', 'AndroidJava', '工具', '新聞', '微軟', '卡巴斯基', '藉由', '專案']
#
# ['2021', '10', '漏洞', '04', '攻擊', '05', '臉書', 'iThome', '微軟', '駭客', '使用者', 'MSHTML', '網路', '資料', 'CVE', '相當', '網站', '攻擊者', '新聞', '卡巴斯基']
#
# ['芯片', '新思', '开发者', '科技', '数字', '人工智能', '系统', '5G', 'Sassine', 'Ghazi', '摩尔定律', '设计', '技术', '产业', 'EDA', '2021', '陈志', '葛群', '创新', '层面']
#
# ['醫院', '系統', '國泰', '開發', '10', 'HIS', '2021', '醫生', '架構', '電子', '醫療', 'App', '曾景平', '團隊', '技術', '他們', '專案', '微服', '分院', '資訊']
#
# ['X9M', '資料', 'Exadata', '2021', '10', '甲骨文', 'Oracle', '執行', 'Appliance', '04', 'Database', 'Cloud', '服務', 'OLTP', 'SQL', '軟體', '儲存', 'Recovery', '臉書', 'Customer']
#
# ['2021', '10', '資料', 'MLX', '人工智慧', '04', '臉書', '管線', '05', '模型', '執行', '這些', '作為', '儲存庫', '資產', 'Jupyter', '筆記本', '新聞', '微軟', '卡巴斯基']
#
# ['2021', '10', '程式', 'ESET', '組織', '檔案', '04', '攻擊', 'SparrowDoor', '臉書', 'FamousSparrow', '飯店', '微軟', '05', '受害', '網路', '駭客', 'iThome', '漏洞', '應用']
#
# ['2021', '10', '漏洞', '內容', '資料', 'Epik', '全文', 'Windows', '駭客', '04', '攻擊', '微軟', '5G', '臉書', '人員', '網路', '05', '郵件', '詐騙', '外洩']
#
# ['架构', '智能', 'ECU', 'GEEP', '长城汽车', '驾驶', '座舱', '计算', '中央', '功能', '升级', '第四代', '长城', '整合', '电气', 'SOA', '底盘', '车身', '平台', '汽车']
#
# ['10', '2021', 'Microsoft', 'Store', '微軟', '應用', 'Windows', 'App', '04', '程式', '市集', '臉書', '05', '搜尋', '瀏覽器', '11', 'Android', '上架', '新聞', '卡巴斯基']
#
# ['社团', '网络', '模型', '检测', '结点', '学习', '方法', '统计', '复杂', '结构', '神经网络', '数据', '生成', '特性', '研究', '泛化', 'Girvan', 'Newman', '深度', '通常']
#
# ['RGB', '相机', '优化', '粒子', '在线', '位姿', '三维重建', 'ROSEFusion', '重建', '移动', '深度图', 'PST', '采样', '方法', '函数', '滤波', '3D', '迭代', '序列', '10']
#
# ['模型', 'ULRv5', '语言', 'XTREME', '微软', '训练', 'Google', 'SOTA', '排行榜', '图灵', 'XLM', '榜首', 'token', '位列', '神经网络', '打造', '通用', '公共', '最新', '语料库']
#
# ['2021', '10', '蘋果', 'AirTag', '04', 'Rauch', '臉書', '05', '人員', 'iThome', '遺失', 'Security', '漏洞', '資訊', '新聞', '微軟', '卡巴斯基', '使用者', '裝置', '發表']
#
# ['毫末', '智行', '模型', '数据', 'Transformer', '顾维灝', '自动', '聚类', '驾驶', '场景', '训练', '芯片', '车端', 'Swin', '感知', '100', '安全', '仿真', '量产', '云端']
#
# ['NeurIPS', '论文', '2021', 'AAAI', '人工智能', '顶会', '接收', '29', '22', '审稿人', '提交', '列表', '21', '学习', '机器', '凌晨', '放出', '今年', 'AI', '作者']
#
# ['模型', '样本', 'AI', '巨量', '学习', '人工智能', '李飞飞', '训练', '图灵', '中文', '斯坦福大学', '语言', '2457', '10', '智能', '测试', '参数', '应用', '人类', '数据']
#
# ['青光眼', '分割', '视盘', '杯盘', '团队', 'AI', 'et', 'al', 'medical', 'arXiv', '定位', '医学影像', 'Medical', 'Image', '视杯', '体素', 'segmentation', '2021', '任务', '进行']
#
# ['数据', '阿里巴巴', '平台', '业务', 'AI', '云梯', '治理', '建设', '智能', '技术', '架构', '质量', '成本', '资产', '阿里', '计算', '存储', '方法论', '核心', '规则']
#
# ['联邦', '学习', 'Clustar', '参与方', '星云', '纵向', 'IJCAI', '数据', '技术', '应用', '21', '模型', '隐私', '范式', '建模', '人工智能', 'Aegis', '恶意', '安全', '训练']
#
# ['PyFlink', 'Zeppelin', 'Conda', 'Python', '集群', 'Flink', 'Yarn', '环境', '使用', 'notebook', 'env', '创建', '需要', '版本', '接下来', '安装', '注意', '打包', '下面', '第三方']
#
# ['数据', 'DataWorks', '企业', '治理', '平台', '蜕变', '阿里巴巴', '链路', '建模', 'AI', '数据服务', '阿里', '能力', '一站式', '开发', '2021', '建设', '敏捷', '完成', '计算']
#
# ['生成', '图像', '配对', 'image', 'StyleGAN', '数据', '属性', '头发', '向量', '发际', 'Lab', 'CVPR', '编辑', 'MT', '2020', '高清', '区域', '迭代', '插值', '获得']
#
# ['Fangorn', '计算', 'VLDB', 'Cost', 'Framework', '论文', '布道', '增量', 'Data', '2021', 'MaxCompute', 'Tempura', 'Paper', '批处理', '执行', '学术会议', '平台', '作业', '框架', '优化']
#
# ['芯片', 'DSP', '中科', '本原', '领域', '团队', '高性能', '中科院', '数字', '高创', '20', '智能', '解决方案', '国产', '信号处理', '科技', '发展', '人工智能', '量产', '技术']
#
# ['SDK', 'BI', '18', '组件', '图表', '嵌入', '点击', '嵌入式', '系统', '报告', '分析', '输入', '描述', 'web', '图片', 'script', '技术', '最多', '所示', '百分点']
#
# ['模型', 'CTC', 'HMM', '语音', '识别', 'RNN', 'DNN', 'GMM', '谷歌', 'LAS', '所示', '算法', '建模', 'model', '性能', 'LSTM', '端到', '如图', '结构', 'latency']
#
# ['AI', 'A100', '微信', '智能', '数据', '一扫', '获取', '资讯', '前沿技术', '企业级', 'Data', 'Intelligence', 'Auto', 'Byte', 'Science', '2021', 'ICP', '2021005318', '战疫', '科技']
#
# ['AI', 'A100', '微信', '智能', '数据', '一扫', '获取', '资讯', '前沿技术', '企业级', 'Data', 'Intelligence', 'Auto', 'Byte', 'Science', '2021', 'ICP', '2021005318', '战疫', '科技']
#
# ['百度', '算法', 'AI', '学习', '研究院', '模型', '人工智能', '量子', '技术', '深度', '计算', '智能', '领域', '数据', '自然语言', '视频', '同传', '机器', '图谱', '自动']
#
# ['2021', '10', 'Ring', '04', '臉書', '05', 'Always', 'Home', 'Cam', '使用者', '路徑', '起飛', '設定', '新聞', '微軟', '卡巴斯基', 'Amazon', '發表', '無人機', '警報']
#
# ['AI', '创业', '自然语言', 'Gartner', '公司', '人工智能', '技术', '蔡惠芬', '国内', '企业', '初创', '大中华区', '模型', '处理', '能力', '应用', '计算机', '领域', '市场', '机器']
#
# ['卷积', '奖赏', 'SNN', '脉冲', '学习', '编码', '算法', '传播', 'Neural', '类脑', 'BRP', '局部', '张铁林', '反向', '结构', 'A100', '微信', 'Spiking', 'Network', 'BP']
#
# ['2021', '10', '參數', '04', 'learn', '臉書', 'SVM', '05', 'Class', '官方', '版本', '用戶', 'scikit', 'SGDOneClassSVM', 'Scikit', '關鍵', '新聞', '微軟', '卡巴斯基', '函式']
#
# ['量子', '2021', '運算', '10', 'Dell', '傳統', '執行', '04', '演算法', '臉書', '模擬平', '用戶', '05', '資源', '能夠', '混合', 'Qiskit', 'Runtime', '使用', '人員']
#
# ['2021', '10', 'Safepal', 'Wallet', '程式', '04', '臉書', '擴充', 'Firefox', '05', '加密', 'iThome', '使用者', 'Mozilla', '貨幣', 'Cali', '錢包', '圖片', '新聞', '微軟']
#
# ['属性', '节点', '补全', '异质', '神经网络', '模型', '本文', '网络', '向量', '缺失', '学习', '先验', '拓扑', 'subject', '重构', '框架', 'author', '信息网络', '任务', '机制']
#
# ['半导体', '产品', '芯片', '台积', '美国政府', '供应链', '2021', '厂商', '设厂', '美国商务部', '瓶颈', '公司', '是否', '生产', '订单', '客户', '要求', '每个', '购买', '英特尔']
#
# ['AI', '之心', '机器', '2021', '科技', '年度', '技术', 'TOP', '评选', '人工智能', '产业', '10', '俱进', '策划', '创新', '年会', '时光', '中国', '年度报告', '最具']
#
# ['神经元', '神经', '连接', '映射', '三星', '大脑', '复制', '粘贴', '线路图', '芯片', '一个', '电极', '研究', '存储', '逆向', 'Ham', 'Park', 'CNEA', '纳米', '记录']
#
# ['AI', '百度', '诈骗', '拦截', '技术', '安全', '网络', 'APP', '换脸', '反诈', '公民', '黑灰产', '平台', '滥用', '信息安全', '恶意', '源头', '阻断', '网站', '搜索']
#
# ['学习', '机器人', '强化', '步态', '四足', '算法', '生成器', '百度', '控制算法', '神经网络', '控制', '场景', '训练', '框架', '开源', 'AI', '飞桨', 'https', '智能', '环境']
#
# ['2021', '10', 'Google', '簽章', 'Windows', '04', '偵測', '程式', '人員', '編碼', '臉書', '產品', '微軟', '05', 'OpenSUpdater', 'iThome', '發現', '軟體', '安全', '已經']
#
# ['AR', '助听', '听障', '眼镜', '亮亮', '视野', '吴斐', '官网', '人士', '听力', 'XR', '沟通', '科技', '智能', '残疾', '文字', '语音', '损失', 'A100', '微信']
#
# ['2021', '10', 'GitLab', '環境', '14', '專案', '04', 'SAST', '引擎', '開發', '臉書', '掃描', '05', '層級', '執行', 'Kubernetes', '群組', '這些', '能夠', '測試']
#
# ['机器', '学习', 'https', 'Google', '领域', '模型', '算法', '工作', 'Science', 'www', 'com', '研究', '一个', '问题', '科学家', '系统', '组件', 'Applied', 'nature', 'articles']
#
# ['10', '2021', 'WPBT', 'Windows', '微軟', '一個', '04', '臉書', '05', '韌體', 'Eclypsium', 'ACPI', '攻擊', 'iThome', '執行', '系統', '硬體', '檔案', '程式', '表格']
#
# ['小蛮', '驾驶', '自动', '达摩院', '王刚', '技术', '快递', '100', '配送', '阿里', 'L4', '机器人', '巡检', '无人', '研发', '卡车', '场景', 'A100', '微信', '万单']
#
# ['2021', '10', '歐盟', '04', '行動', '臉書', '新聞', '05', 'Ghostwriter', '國家', '攻擊', 'iThome', '帳號', '理事', '企圖', '媒體', '資料', '網路', '微軟', '卡巴斯基']
#
# ['2021', '10', 'Google', '帳號', '用戶', '資訊', '04', '臉書', '問題', '服務', '05', '訊息', '技術', '導致', '支付', '付款', 'Cloud', '美國', '發出', '新聞']
#
# ['貨幣', '2021', '加密', '10', '中國', '服務', '04', '臉書', '05', '交易', '火幣網', '市場', '新用', '用戶', '新聞', '微軟', '卡巴斯基', '提供', '通知', '自中國']
#
# ['執行', '2021', '資料', 'AWS', 'EKS', '10', '預留', '服務', '企業', 'GKE', '雲端', '備份', '基礎', '應用', '微軟', 'Google', '負載', 'K8s', 'Amazon', '實例']
#
# ['AI', '之心', '机器', '2021', '年度', '科技', '技术', '产业', '俱进', '评选', '时光', '策划', '2022', '年会', '一年', '落地', '年度报告', '创新', '特别', '人工智能']
#
# ['蘋果', '10', '漏洞', '2021', 'iOS', '15', 'App', '人員', '資訊', '04', '修補', '臉書', '存取', '05', '研究', 'IllusionOfChaos', '時間', '嚴重', '這些', '14']
#
# ['追一', 'AI', '资本', '基础设施', '基金', '科技', '投资', '领先', '基建', '产业', '行业', '智能', '人工智能', '助力', '获得', '电信', 'A100', '微信', '2021', '中移']
#
# ['IoT', '2021', '自駕', '10', '公車', '臉書', '眼鏡', '智慧', '裝置', 'Amazon', 'SMB', '04', 'App', 'Whole', 'Foods', 'DevOps', '北市', 'Apple', 'Watch', '機械']
#
# ['目标', 'token', '序列', '图像', '检测', '标签', '模型', '边界', '研究者', '先验', '函数', '架构', '识别', '视觉', '神经网络', '任务', '描述', '类别', '一组', '使用']
#
# ['AI', '汇量', '数据', '企业', '小强', '智能', '技术', '科技', '决策', '引擎', '营销', '热力', '增长', '人工智能', 'EnginePlus', '阿里巴巴', '一家', '业务', '核心', '行业']
#
# ['MindSpore', '模型', '训练', '并行', '代码', '学习', '张量', '小伙伴', '开源', '算法', '优化', '计算', '可读性', 'AI', '深度', '微分', '自动', '全自动', 'MoE', '科学计算']
#
# ['5G', '2021', '網路', '10', '下載', '邊緣', '應用', '服務', 'Mbps', '速度', '行動', 'Advanced', '企業', '實驗室', 'Verizon', '解決', '04', '全球', '方案', '電信商']
#
# ['数字', '科技', '创新', '影谱', '技术', '智能', '产业', '数字化', '影像', '碳中', '科博会', '融合', '孪生', '助力', '商业', '展示', '全栈', '碳达峰', '双碳', '赋能']
#
# ['天籁', '腾讯', '听障', '听力', '公益', '耳蜗', 'AI', '科技', '行动', '康复', '聋人', '实验室', '社会', '服务', '人士', '人工', '技术', '基金会', '助力', '无障碍']
#
# ['AI', '药物', '神经网络', '公司', '学习', '辉瑞', '图谱', '阿斯利康', 'Exscientia', '疾病', '数据', '人工智能', '合作', '靶点', '新药', '知识', '识别', '强生', '机器', '发现']
#
# ['哈弗大狗', '智能', '互动', '生态圈', '哈弗智家', '狗哥', '大狗', '哈弗', '福利', '直播', '平台', '品牌', 'A100', '微信', 'SUV', '邓小七', 'V3', 'FOTA', '30', '四驱']
#
# ['模型', '悟道', '智源', '问答', 'OPPO', '助手', '人工智能', '清华大学', 'AI', 'EVA', '智能', '手语', '图谱', '应用', '唐杰', '训练', '知识', '系统', '冬奥', '图像']
#
# ['量子', 'Google', '计算机', '纠错', '计算', '张量', '逻辑', '园区', 'Erik', '学习', '里程碑', '经典', '开源', 'AI', '子位', '实现', '人工智能', '超导', '机器', 'TPU']
#
# ['材料', 'DRNets', '高通量', '组合', '2021', '特性', '映射', '发现', 'https', '识别', '研究', '晶体结构', '人工智能', '元素', '挑战', '学习', '知识', '热电', '太阳能', '方法']
#
# ['AV1', 'AVIF', '腾讯', '图片', '压缩', '编码', '格式', '开源', '支持', 'AOM', 'OAV1', '性能', '技术', '万象', '编码器', '编码标准', '视频', '多媒体', '数据处理', '版权']
#
# ['文档', 'ERNIE', 'Layout', 'TextMind', '布局', '模型', '智能', '百度', '理解', '抽取', '模态', 'DocVQA', '知识', '语义', '信息', '理解能力', '视觉', '数字化', '增强', '技术']
#
# ['数学', '选手', '竞赛', '王东', '金牌', '阿里巴巴', 'MIT', '决赛', '2021', '周康杰', '全球', '获得', '北京大学', '本科毕业', '70', '麻省理工学院', '博士学位', '科学', '理论', '铜奖']
#
# ['淀粉', '合成', '二氧化碳', '生物', '马延', '途径', '研究', '人工合成', '工业', 'https', '天津', '转化', '研究所', '团队', '中科院', '11', '蔡韬', '人工', '技术', '速率']
#
# ['AI', '求解', '华为', '模型', '天筹', '药物', '问题', '分子', '研发', '云盘', '场景', '建模', '智能', '永利', '商用', '最优', '运筹学', '新药', '盘古', '优化']
#
# ['博士生', 'Li', 'https', '个人主页', '新加坡国立大学', '学习', '计算机', '大学', '视觉', '王鑫龙', '机器', '李昀', 'Qinbin', 'github', 'io', '计算机科学', '获奖', '研究', '自然语言', '谷歌']
#
# ['创维', 'OLED', 'MiniLED', '120Hz', 'S82', '电视', 'AI', '电竞', 'A20', 'Pro', '画质', '体验', 'Q72', '4K', '技术', '2021', 'G90', '原彩', '智能', '影音']
#
# ['Talk', '编辑', 'Edit', '细粒度', '人脸', '20', '想换个', '搞定', '发型', 'CelebA', 'Semantic', 'Field', '发愁', '试试', '特征', 'Dialog', '神经网络', '研究', '想要', '用户']
#
# ['算法', '改进', '复杂度', '摩尔定律', '问题', 'step', '研究', '研究者', '性能', '硬件', '展示', '渐进', '学习', '输入', '数据', '计算机', '时间', '论文', '益处', '代码']
#
# ['华为', 'AI', '服务', '数字化', '求解', '创新', '数字', '徐直军', '技术', '2021', '云盘', 'aPaaS', '药物', '区块', '场景', '开发者', '原生', '应用', '网络', '全球']
#
# ['神经元', '研究者', '储备', '州立大学', '俄亥俄', '100', '系统', '要少', '预测', '计算速度', '万倍', '神经网络', '通讯', '一期', 'Gauthier', '要用', '给出', '否定', '复杂', '方法']
#
# ['首席', 'Dally', 'PCAST', '陶哲轩', 'AMD', '苏姿丰', 'Bill', '伟达', 'Eric', '总统', '拜登', 'Horvitz', '30', '科技', '科学家', '其任', '华裔', '微软', '科学', '成员']
#
# ['学习', '原神', '钓鱼', '还愁', '瓦特', '迟到', '指南', '训练', '模型', '这有', '一份', '不到', '机器', '迁移', '算法', '安装', 'DQN', '下载', '标记', 'YOLOX']
#
# ['小冰', 'AI', '10', '2021', '22', '岛上', '冰岛', '天气晴朗', '闲逛', 'Beings', '图谱', '内容', '李笛', '下午', '智能', '聊天', '人工智能', '社交', '知识', '学习']
#
# ['凌波微', '封装', '半导体', 'IC', '设备', '球焊', '芯片', '焕然', '制造', '核心', '技术', '引线键合', 'ASM', '企业', '行业', '厂商', '国产', '人工智能', '自主', '隐形']
#
# ['穗腾', 'OS', '轨道交通', 'OS2', '地铁', '广州', '智慧', '腾讯', '大湾', '合作伙伴', '生态', '迭代', '运营', '升级', '设备', '车站', '平台', '应用', '实现', '产业']
#
# ['PLATO', '对话', '模型', 'XL', '百度', '训练', '参数', '开放', '效果', '生成', '中英文', '110', 'Blender', '进行', '规模', '多轮', '发布', '提升', '回复', '大规模']
#
# ['学习', '机器', '指南', '于小白', 'Bouchard', '资源', 'AI', '一份', '适用', '线性代数', '吴恩达', '丰富', '人工智能', '这是', '理论', '课程', '数学', '领域', '整理', 'https']
#
# ['数据库', '查询', '神经', '方法', '文本', '结构化', 'Facebook', '对非', '架构', '模式', '数据量', '数据库系统', '数据分析', '数据', '实例', '研究者', '扩展', '预定', '图像', '可用']
#
# ['笔画', 'Transformer', '神经网络', '研究者', '方法', '迁移', 'RL', '百度', '图像', '学习', 'Paint', 'VIS', '预测器', '风格', '生成', '基线', '优化', '绘画', '训练', '卷积']
#
# ['昼夜节律', '转录', '拟南芥', 'IBM', 'ML', 'DNA', '使用', '方法', '学习', '预测', '时间', '生物钟', '先验', '序列', '人工智能', '机器', '调节', '算法', '研究', '图示']
#
# ['RNN', '输出', '序列', '隐藏', '状态', 'context', 'attention', '输入', '信息', 'nn', 'lstm', 'vector', '遗忘', '单元', '向量', '一个', '相关性', 'rnn', 'output', 'cdot']
#
# ['分割', '人像', '图片', '语义', '如上图', '网络', '预测', '所示', '算法', '模型', '数据', '边缘', 'trimap', '训练', '标注', '场景', '进行', '标签', '特征', '背景']
#
# ['spark', 'Spark', 'https', 'aliyun', 'com', '回放', 'A100', '微信', 'AI', 'developer', 'live', '247072', 'driver', 'memory', 'cores', 'executor', 'html', 'Notebook', '参考', '懂得']
#
# ['Hudi', '数据', 'Flink', '架构', '存储', 'Kylin', '湖仓', '更新', 'T3', '查询', 'Spark', '一体', 'Snowflake', '一个', '融合', '引擎', '介绍', 'Hive', '出行', 'AWS']
#
# ['异质', '学习', '机器', '特性', '电子', '原子', '预测', '结构', '研究', '物理', '第一性', 'https', '算法', '信息学', '积木', '数十亿', '理论', '物理学家', '半导体', '理解']
#
# ['2021', '10', '人工智慧', '重力', '資料', '這個', '04', '實驗室', '臉書', '研究', '天文', '05', '貢國家', '漣漪', 'LIGO', 'GPU', '時候', '運算', '學習', '64']
#
# ['人脸', '图像', '人脸识别', '姿态', '归一化', '低质量', 'MDFR', 'FFN', '作者', '判别', '训练', 'FRN', '转正', '损失', '模型', '网络', '方法', '生成', '高质量', '3D']
#
# ['卷积', 'Transformer', '训练', '模型', '序列', '研究者', '架构', '使用', '注意力', '任务', 'NLP', '机器翻译', '助益', '实验', '研究', 'FLOPs', '语言', '建模', '学习', '是否']
#
# ['RTX', 'A6000', '3090', '显卡', '模型', 'PyTorch', 'GPU', '使用', '训练', '显存', '深度', '32', '学习', 'bit', '八块', '语言', '精确度', '速度', '伟达', '卷积']
#
# ['SIGGRAPH', '计算机', '图形学', '2021', 'ACM', '动画', '李旻辰', '领域', '杰出', '研究', '计算机科学', '图像', '模拟', '博士论文', 'Steven', 'Anson', 'Coons', 'Doug', '奖项', '图形']
#
# ['人工智能', 'AI', '科学', '研究', '学习', '2021', 'DeepMind', '领域', '方向', '机器', '算法', 'Workshop', '学科', '提交', '神经科学', '交叉', '生物学', '教授', '药物', '假设']
#
# ['分子', '模拟', 'MindSpore', 'SPONGE', '北京大学', '人工智能', '动力学', '深度', '学习', '2021', '算法', '华为', '深圳湾', 'Workshop', '高毅勤', '课题组', '研究', '软件', '微信', 'MindSponge']
#
# ['資料', 'GPU', '執行', 'Spark', '2021', '10', 'CPU', 'Cloudera', 'Nvidia', 'CDP', '運算', 'RAPIDS', '04', '數據平', '臉書', '開源', '處理', '05', '這個', '時間']
#
# ['影谱', '数字化', '人工智能', '数字', '智能', 'AI', '海尔', '科技', '制造', '智护', '体验', '技术', '合作', '智能化', '搭建', '经济', 'A100', '微信', '数智', '2021']
#
# ['学习', '模型', '算法', '神经网络', '方法', '回归', '分类器', '线性', '机器', '统计', '实例', '深度', '介绍', 'Hastie', '贝叶斯', '非线性', '分析', 'Trevor', '训练', '选择']
#
# ['模型', '草图', '图像', '训练', '研究者', '生成', 'GAN', '数据', '方法', '正则', '所示', '匹配', '用户', '自定义', '使用', '概率分布', '研究', '一个', '拟合', '潜在']
#
# ['词表', '最优', '标记', 'VOLT', '信息熵', '论文', 'MUV', 'ACL', '作者', '大小', '运输', 'AI', '子词', '问题', '搬运', '稀疏', '边际', '字节', '学习', '步骤']
#
# ['息肉', '檢查', '2021', '10', '人員', '系統', '大腸鏡', '醫療', '研究', '04', '偵測', '遺漏', '這個', '檢測', '臉書', '05', '野中', '問題', '結果', '因為']
#
# ['marker', '动捕', 'markers', '动画', '骨骼', '参考', '演员', '数据', '算法', 'raw', 'motion', 'AI', '清洗', '动作', '光学', '互娱', 'Lab', 'MoCap', '解算', '训练']
#
# ['蘋果', '2021', '10', '內容', '兒童', '使用者', '裝置', '04', 'Messages', 'iCloud', 'iOS', 'CSAM', '資料', '臉書', '照片', '色情', 'EFF', '05', '將會', '用戶']
#
# ['苹果', '扫描', '图像', '照片', '儿童', '系统', '通知', 'iPhone', 'neuralMatch', '用户', '发送', '手机', 'iCloud', '13', '隐私', '父母', '内容', '功能', '接收', '色情图片']
#
# ['研究', '象限', 'AI', '基础', 'AlphaFold', 'CPU', '巴斯德', '底层', '搞清楚', '原理', '云岗', '类脑', '问题', '蛋白质', '机器', '技术', '定义', '李国杰', '架构设计', '需要']
#
# ['token', '粒度', '粗粒度', '细粒度', 'LICHEE', '嵌入', '模型', 'BERT', '研究者', '荔枝', 'CLUE', 'AMBERT', '腾讯', '训练', '推理', '任务', '信息', '向量', '编码器', 'PLM']
#
# ['FPGA', '加密', '同态', '隐私', '运算', '学习', '联邦', '计算技术', '算法', '乘法', '时钟', '数据安全', '模乘', '计算', '蒙哥马利', '机器', '安全', 'Paillier', '逻辑', '乘法器']
#
# ['TM', '模型', '单语', 'NMT', '双语', '基线', '检索', '2021', 'ACL', 'augmented', '训练', '翻译', '使用', '论文', '数据模型', '性能', '语句', '研究者', '编码器', '腾讯']
#
# ['学习', '视频', '3b1b', '神经网络', '优雅', '知识', '3blue1brown', 'Grant', '线性代数', '方法', '数学', '比特', '文字版', '网站', '可视化', '深度', '微积分', '向量', 'AI', 'Sanderson']
#
# ['大湾', '大学', '办学', '应该', '研究型', '广东省政府', '2020', '邓江年', 'MIT', '理工科', '麻省理工学院', '理工', '社科院', '常务会议', '副所长', '松山湖', '广东省', '起步', '新型', '国际化']
#
# ['AI', '人工智能', 'NSF', '研究', '资助', '技术', '美国', '领域', '教育', '农业', '2030', '重大项目', '分布式', '11', '40', '个州', '应用', '新一代', '再度', '新一期']
#
# ['地平线', '芯片', '智能', 'Tier2', '征程', 'Matrix', 'TogetherOS', '场景', '算法', 'AI', '算力', 'Horizon', '驾驶', '神经网络', '李星宇', 'Tier1', '鸿蒙', '车载', '合作伙伴', '能够']
#
# ['贝叶斯', '人工智能', '朱军', '探索', '深度', 'AI', '珠算', '学习', '模型', '科学', '科学家', '方法', '青年', '机器', '算法', '50', '数据', '论坛', '概率', '安全可靠']
#
# ['数据', '平台', '隐私', '计算', '安全', '应用', '传染病', '很多', '价值', '城市', '一个', 'XDP', '模型', '实现', '需要', '翼方', '健数', 'IoDC', '计算技术', '技术']
#
# ['模型', '文本', '事件', '知识', '因果关系', '语义', '训练', '对话', '建模', '学习', '数据', '因果', '语音', '识别', '链接', '推理', 'https', '生成', '关系', 'PLATO']
#
# ['蛋白质', 'AlphaFold', '结构', '脯氨酸', '预测', '学习', '药物', '机器', '问题', '研究', '计算', '功能', '生物学家', 'AI', '折叠', '算法', '生物学', '不同', '很多', '统计学']
#
# ['业界', '论文', '学界', '2019', '视觉', '作者', '计算机', '研究者', '2010', '研究', '引用', '领域', '学习', 'top', '机器', '主题', '所示', '数据', '发表', '算法']
#
# ['恶意软件', 'PyPI', '软件包', '恶意代码', '窃取', 'token', '负载', 'Python', '信用卡', '存储', 'Discord', '信息', '密码', '身份验证', '感染', '机器', 'noblesse', '软件', '有效', '代码']
#
# ['SAP', '2021', '10', 'Cloud', '服務', '04', '臉書', 'Google', '05', '訂閱', '技術', 'RISE', '新聞', '微軟', '卡巴斯基', '方案', '軟體', '這項', '計畫', '用戶']
#
# ['Facebook', '亿美元', '2021', '超出', '290', '财报', '营收', '278', '2020', '186', '50', '61', '季度初', '本季度', '社交', '预期', '第二季度', '这家', '同期', '每股']
#
# ['电池', '钠离子', '宁德', '材料', '时代', '锂离子', '密度', '低温', '产业链', '概念图', '能量', '方面', '第一代', '系统', '集成', '场景', 'A100', '微信', '黄起森', 'kg']
#
# ['https', 'org', '论文', '学习', '机器', 'doi', '10', 'news', 'AI', '2021', '化学', '模型', '链接', 'www', 'http', 'dx', '1038', '021', '07', '报道']
#
# ['AF2', 'IPA', '蛋白质', 'MSA', '残基', '推理', 'AlphaFold2', '3D', '结构', 'DeepMind', 'evoformer', '迭代', '论文', '表示', '回收', '序列', 'ij', '编码', '模型', '一个']
#
# ['人工智能', '研究', 'AI', '中心', '网络', '学习', 'STEM', '智能', '优化', '教育', '劳动力', '系统', '农业', '领域', '芯片', '技术', 'NSF', '资助', '挑战', '领导']
#
# ['AlphaFold', '蛋白质', 'Colab', '结构', '序列', 'DeepMind', 'https', 'alphafold', '生物学', '研究者', 'com', 'notebook', 'colab', 'notebooks', '开源', '使用', '模型', '数据库', '链接', '研究']
#
# ['建築物', '2021', '10', '資料', '04', 'Google', '臉書', '非洲', '05', 'Open', 'Buildings', '這些', '人工智慧', '地圖', '過去', '發現', '服務', '新聞', '微軟', '卡巴斯基']
#
# ['AI', '百度', '智能', '智能化', '神经网络', '机器翻译', '人工智能', '云智', '海峰', '李彦宏', '产业', '数字化', '技术', '学习', '升级', '一体', '自动', '深度', '驾驶', '领域']
#
# ['P50', '华为', 'Pro', '系列', '手机', '4G', '影像', '视频', '10', '实现', '图像', 'AI', '余承东', '图标', '鸿蒙', '模组', '搭载', '提升', '技术', '原色']
#
# ['注意力', '图像', '鹦鹉', '学习', '细粒度', 'AI', '算法', '阿里巴巴', '图像识别', '卷积', '牡丹', '识别', '研究者', '阿里', 'patch', '网路', '浙江大学', '领域', '区域', '数据']
#
# ['语音', '声音', '语言', '表征', '声波', '意义', '音量', '傅里叶', '时域', '保存', '不同', '一种', '学习', '大音希声', '变换', '发音器官', '分辨率', '产生', 'AI', 'Wave']
#
# ['AI', '英特尔', '百度', '智能', '人工智能', '边缘', '深度', '学习', '解决方案', '计算', '算力', 'EdgeX', '助力', '数据', '技术', '平台', '至强', '处理器', '节点', '架构']
#
# ['蛋白质', 'DeepMind', '结构', '人工智能', '预测', 'AlphaFold', 'AI', '数据', '研究', '准确', '生物学', 'Nature', '人类', '基因组', '杰米', '领域', '数据库', '哈萨', '折叠', '方法']
#
# ['美国', '中国', '高级官员', '无视', '决策者', '系统地', '披露', '监管', '周一', '证监会', '风险', '规则', '一名', '担心', '上市', '必须', '环境', '相关', '表示', '企业']
#
# ['特效', '抖音', '投稿', '视频', '表达方式', '学习', '漫画', '使用', '深受', '喜爱', '五个', '算法', '引擎', '技术', '字节', '平均', '机器', '成为', '深度', '用户']
#
# ['ASE', '论文', '谢涛', 'Suresh', 'Thummalapenta', '2021', '2007', '北京大学', '影响力', '教授', '博士生', '最有', '奖项', '微软', 'PARSEWeb', 'IBM', '经典', '一篇', '发表', '代码']
#
# ['学习', '算法', 'Android', '识别', '技术', '机器', '负责', '熟悉', '语音', '开发', '优先', '隐私', '自然语言', '安全', '图像', 'AI', 'NLP', '岗位职责', '平台', '领域']
#
# ['Triton', 'GPU', 'CUDA', '神经网络', '张量', 'OpenAI', '编程语言', '学习', '开源', '替代品', '内核', '算法', '编程', '规范化', '自然语言', '全新', '并行', '矩阵', '深度', '编译器']
#
# ['Hologres', '点查', 'Query', '实时', 'IO', '吞吐', 'HBase', 'Plan', '服务', '场景', '数据', '进行', '分析', '在线', 'SQL', 'Optimizer', 'Fixed', 'LSM', 'cache', '延时']
#
# ['多样性', '用户', '张量', '推荐', '分解', '笔记', '过滤', '矩阵', '向量', '奇异', '序列', '内容', '协同', '系统', '窗口', '方法', '小红书', 'SSD', 'Tensor', '信息']
#
# ['外骨骼', '机器人', 'Jean', 'Louis', 'Constanza', '行走', 'Oscar', 'Wandercraft', 'Atalante', '装置', 'exoskeleton', '帮助', '医疗', '大学', '清华大学', '领域', '下肢', '外卖', '16', '10']
#
# ['2021', '10', 'OpenShift', '服務', 'Red', 'Hat', '機器', '學習', '資料', 'Data', '紅帽', '應用', '04', '工具', '模型', '系統', '臉書', '提供', '代管', 'Hub']
#
# ['作业', '车辆', '高德', '道路', '预警', '车道', '系统', '实时', 'AI', '高速公路', '提醒', '追尾', '地图', '护卫', '事故', '视频', '信息', '试点', '智能', '安全']
#
# ['机器人', 'AI', '人工智能', '中国', '人形', '智能', 'Walker', '服务', '必选', '应用', '技术', '领域', '全球', '市场', '场景', '5G', '日本', '未来', '公司', '科技']
#
# ['模型', '模态', '方法', '算法', '学习', '量子', '本文', '标签', '论文', '矩阵', '数据', '训练', '百度', '特征', '提出', '神经网络', '文本', '视频', '序列', '2021']
#
# ['检测', 'AI', '搜车', '代替', '网络', '残差', '双流', '车辆', '交互', '智能', '毫秒', '视觉', '分组', '解决方案', '数据分析', '架构', '汽车产业', '人眼', '识别', '主干']
#
# ['机器人', '谷歌', 'Intrinsic', '机器', '来教', '学习', '心仪', '人形', '工业', '操控', '廉价', '可能', '物体', '克服', '不像', '吸引力', '印象', '涌入', '深刻', '前进']
#
# ['二维', '磁体', '室温', '磁性', '原子', 'Co', '磁铁', '研究', 'gZnO', '氧化锌', '量子', '材料', '磁性材料', '人员', '石墨', '自由电子', '单层', '自旋', '姚杰', '2D']
#
# ['冷却液', 'EV', '比亚迪', '起火', '测试', '碰撞', '电池', '更换', '媒体', '回应', '电瓶', '引发', '液体', '油液', 'Auto', 'Byte', '致燃', '导致', '火灾', '冷却']
#
# ['AI', '文本', '图像', 'TextStyleBrush', '风格', '生成器', '生成', 'Facebook', '准确率', '识别', 'TSB', '样式', '替换', '模仿', '训练', '输入', '字体', '手写', '场景', '文字']
#
# ['微软', '研究院', '亚洲', '院长', '周礼', '洪小文', '人工智能', '博士', 'AI', '计算机', '研究', '升任', '研发', '分布式系统', '计算机科学', '工程院', '计算机系统', '1998', 'Microsoft', 'ACM']
#
# ['英特尔', '芯片', 'Intel', '泛化', '制程', '10', '技术', '纳米', '7nm', 'Foveros', '晶体管', '节点', '路线图', '推出', '堆叠', '使用', '架构', 'Pat', 'Gelsinger', '2025']
#
# ['10', '2021', 'Intel', '英特', '04', '晶片', '臉書', '客戶', '05', '高通', '奈米', '藍圖', 'IFS', '技術', '服務', '20A', '每瓦', '效能', 'Amazon', '兩大']
#
# ['量子', '人工智能', '计算', '百度', '算法', '学习', '机器', '平台', '经典', '开发者', '量易伏', '逻辑', 'AI', 'Quantum', '领域', '理论', '智能', '计算机', '研究', '自然语言']
#
# ['处理器', '柔性', '芯片', 'TFT', 'Arm', '基板', 'PlasticARM', 'CPU', '氧化物', '学习', '技术', '制造', '金属', '机器', 'Cortex', 'M0', '32', '联网', '计算', '晶体管']
#
# ['IMO', '竞赛', '一川', '数学', '成绩', '2021', '金牌', '冯晨旭', '36', '选手', '获得', '入选', '满分', '夏语', 'CMO', '陈锐', '比赛', '本届', '附属中学', '清华大学']
#
# ['发动机', '长城', '动力', '自研', '蜂巢', '扭矩', '电机', '燃油', '动力系统', '内燃机', '0T', '采埃孚', '研发', '经济性', '越野', '变速器', '高程', '搭载', '能源', 'A100']
#
# ['太空', '火箭', '航天', '发射', '遥感', '主题', 'LDA', '专利', '商业', '系统', '卫星', '数据', '文档', '发展', '商业化', '星座', 'CASC', '文本', '模型', '航天工业']
#
# ['温伯格', '史蒂文', '量子场论', '理论', '物理学', '1979', '相互作用', '引力', '宇宙学', '研究', '科学', '提出', '玻色子', '之梦', '物理学家', '粒子', '出版', '三分钟', '美国', '终极']
#
# ['2021', '10', '預測', '資料', '人員', '加護', '病患', 'SeqSNR', '04', '學習', '研究', '病房', '任務', '臉書', '05', '情況', '臨床', '模型', '機器', '任務學習']
#
# ['AlphaFold', '蛋白质', '预测', '结构', 'DeepMind', '置信度', '残基', '研究', 'pLDDT', '实验', '人类', 'PAE', '蛋白', '结构域', 'CASP14', '人工智能', '机器', '度量', '人员', '解析']
#
# ['AI', 'WPS', '办公', '金山', 'PPT', 'KSAI', 'lite', '智能', '自动', '生成', '美化', '文字', '姚冬', 'OCR', '识别', '排版', '文档', '训练', '功能', '适配']
#
# ['达摩院', '轻量化', '网络', '动态', '模型', '算法', '嵌入式', '可变', '硬件', '滤波器', '小蛮', '算力', '宽度', '方法', '驾驶', '加速', '无人', '自动', '剪枝', '62']
#
# ['开源', 'RISC', '处理器', '芯片', 'RIOS', 'EDA', '架构', '非常', '包括', 'Foundry', 'PicoRio', '指令集', '整个', '实验室', '软件', 'Google', '基金会', '项目', '流片', 'AI']
#
# ['论文', 'ICCV', '2021', '接收', '投稿', '审稿', '列表', '6236', '25', '审稿人', 'rebuttal', '收到', '评审', '反馈', '视觉', 'A100', '微信', 'AI', 'ID', '1617']
#
# ['AI', '商汤', '人工智能', '模型', '算力', '行业', '计算中心', '通用性', '基建', '智能', '场景', '成本', '高通量', '超算', '2020', '50', 'IDC', '赋能', '降低', '炫技']
#
# ['IPO', '科技', 'AI', '过会', '12', '科创板', '四小龙', '招股书', '上交所', '今天下午', '排队', '审核', '多月', '受理', '三家', '最快', '亿元', '批准', '相比', '经历']
#
# ['泛化', '镍氢电池', 'AQUA', '电池', '堆叠', '极性', '传统型', '新款', 'A100', '微信', '集电体', '涂为', '交叉', '单元', '学习', '相比', '推导', '一扫', '紧凑', '电能']
#
# ['https', 'org', '2021', 'www', '量子', '07', '深度', '模型', '学习', 'news', 'com', '逻辑', '测序', '神经网络', '链接', 'AI', 'NGS', 'Sycamore', 'nature', 'articles']
#
# ['转录', '因子', 'BITFAM', '聚类', '细胞', 'seq', '基因', '活性', 'scRNA', '数据', '推断', '亚群', '生物学', '研究', '学习', 'ChIP', '模型', '图示', '识别', '算法']
#
# ['量子', '玻色', '计算', '光量子', 'AI', '路线', '人工智能', '天使', '科技', '应用', '商业化', '算力', '2021', '方案', '技术', '计算技术', '获得', '融资', '资本', '经典']
#
# ['Bagua', '算法', '训练', '优化', '系统', '分布式', '学习', '快手', '语音', 'Zhang', '使用', '中心化', '模型', 'International', '自然语言', '识别', '性能', '开源', '效率', '梯度']
#
# ['电池', '锂离子', 'SEI', '枝晶', '金属', '短路', '负极', '金属锂', '电动汽车', '实验室', '隔膜', '研究', '桑迪亚', '锂电池', '无法', '充电', '电解质', '良性', '研发', '刺穿']
#
# ['ARPA', 'DARPA', 'NIH', '人工智能', '拜登', '机构', '美国', '研究', '技术', '能源', '汽车', '部门', 'AI', 'Covid', '19', 'PM', '浪潮', '领域', '使命', '需要']
#
# ['事件', '预测', '方法', '数据', '学习', '模型', '时间', '未来', '空间', '分类', '张量', '语义', '聚类', '序列', '领域', '技术', '地点', '问题', '卷积', '匹配']
#
# ['算法', '模型', '检测', '非常', '代码', '不同', '学习', '模块', '平台', '客户', 'AI', '交付', '东西', '训练', '思谋', '工程师', '技术', '抽象', '一套', '项目']
#
# ['https', '字节', '分割', '链接', '跳动', '论文', '视觉', '像素', '本文', '模块', 'com', 'github', 'arxiv', 'org', '模态', '卷积', '图像', '视频', '学习', '方法']
#
# ['采样', '分布', '拒绝', 'tilde', '随机', '正方形', 'Monte', 'Carlo', 'pi', '均匀分布', '高斯分布', '接受', '一个', '方法', 'A100', '微信', 'AI', 'Zp', 'kg', '圆形']
#
# ['推荐', '联邦', '系统', '参与方', '隐私', '用户', '模型', '数据', '服务器', '召回', '效果', '影视', '设计', 'Yang', '排序', '算法', '保护', '纵向', '学习', '之间']
#
# ['Triton', 'EAS', '服务', '模型', '部署', 'Avg', 'rt', 'ms', 'PAI', 'name', '支持', 'model', '推理', 'output', 'time', '用户', '299', 'OK', '提供', 'GPU']
#
# ['模型', '蛋白质', '优化', '方法', '团队', 'GNNRefine', '预测', 'CASP13', 'CASP14', '结构', '深度', '学习', 'Baker', '许锦波', 'GNN', '3D', 'DeepMind', 'Feig', 'https', '研究']
#
# ['ViT', '生成器', '判别', 'GAN', 'Transformer', '研究者', 'Lipschitz', '归一化', 'CNN', 'patch', '训练', '使用', '架构', '范数', '图像', 'ViTGAN', '研究', '卷积', '提出', '矩阵']
#
# ['智能', '励飞', '端侧', '云天', '问题', 'AI', '模型', '学习', '应用', '为例', '样本', '芯片', '算法', '云端', '城市', '人工智能', '当中', '标注', '视频', '场景']
#
# ['机器人', '论文', 'https', 'org', '运动', 'RSS', 'roboticsconference', 'program', '算法', '学习', '最佳', '研究者', 'papers', 'SOTA', '规划', '方法', '探索', '主页', '研究', '模拟器']
#
# ['Copilot', '代码', 'var', '生成', '计算器', 'GitHub', '月相', 'Math', 'floor', '密钥', '一个', '模型', '函数', '正确', '复活节', '解析器', 'PHP', '安全漏洞', '使用', '注释']
#
# ['XYZ', 'Robotics', '机器人', '技术', '资本', '手眼', '感知', '领先', '团队', '操作', '创始', '产品', '五源', '愿景', 'Pick', 'Anything', 'Place', 'Anywhere', '赋能', '周佳骥']
#
# ['自然语言', '语言', '模型', '智能', '场景', '技术', '阿里巴巴', '能力', 'AliceMind', '相应', '取得', '更好', '结构化', '翻译', '阿里', '平台', '人工智能', '知识', '非常', '不同']
#
# ['数据', '机器', '学习', '知识', '经验主义', '因果', '拟合', '科学', '模型', '进化', '编译', '解释', '过程', '解释性', '人工智能', '感官', '统计学', '表征', '算法', '研究']
#
# ['类比', '人工智能', '米切尔', '学习', '映射', '抽象', '人类', 'AI', '一种', '理解', '能够', '知识', '认为', '侯世达', '机器', '问题', '字符串', '神经网络', '系统', '一个']
#
# ['2021', '10', '螢幕', '應用', '程式', '旋轉', '功能', '自動', '裝置', '截圖', '04', 'Android', '偵測', '測試', 'Google', 'UI', '臉書', '05', '指示器', 'API']
#
# ['蛋白质', 'AlphaFold', 'RoseTTAFold', '结构', '预测', 'AlphaFold2', 'DeepMind', '开源', '序列', 'https', '原子', '华盛顿大学', '研究', 'Science', 'com', '3D', 'Nres', '方法', '论文', '网络']
#
# ['量子', '研究者', '纳米', '控制', '粒子', '玻璃球', '反馈', '实验', '基态', '实现', '测量', '实时', '卡尔曼滤波', '状态', '海森堡', '最优', '球体', '原子', '估计', '10']
#
# ['GPU', '登临', 'AI', '算力', 'Goldwasser', '计算', '科技', '建文', '引擎', '服务器', '芯片', '功耗', '模型', '异构', '人工智能', '异构计算', 'CUDA', '架构', '应用', '开发者']
#
# ['MindSpore', '赛题', '算法', '开源', '团队', '黑客', '赛道', 'WAIC', 'LeNet', 'openLooKeng', '开发者', '社区', 'AI', '机器', '乡村', 'Waston', 'Build', '人工智能', '挑战赛', '训练']
#
# ['AI', '科大', '学习机', '学习', '个性化', '新品', 'T10', '批改', '教育', '减负', '家长', '提升', '五育', '技术', '孩子', '辅导', '因材施教', '并举', '学生', '人工智能']
#
# ['匹配', '关键点', '位姿', '比赛', '特征', '赛道', '描述', '融合', '图像匹配', '对应', '限制性', '图像', '检索', '腾讯', '优图', '配准', 'SuperGlue', 'fine', '差异', '相似']
#
# ['华米', '芯片', '智能', '手表', '黄山', '穿戴', '2S', 'RISC', '设备', '算法', '监测', '健康', 'Zepp', 'OS', '科技', '黄汪', '操作系统', '手环', '血压', '自研']
#
# ['北斗', '千寻', '监测', '灾研院', '应急', '电离层', '高精度', '位置', '对流层', '时空', '预警', '自然灾害', '智能', '防治', '天气', '站网', '极端', '卫星', '实时', '数据']
#
# ['论文', 'arXiv', '卷积', 'IJCV', '神经网络', '3D', '网路', '期刊', '架构', 'idea', '2D', '深度', '模型', '期刊论文', '训练', '神经', '网络', '2019', '2017', 'https']
#
# ['算法', 'Rainbow', '学习', '研究者', 'DQN', '优化', '游戏', '组件', '强化', '环境', 'Atari', '智能', '实验', '损失', '训练', '2600', '函数', '论文', '研究', '经典']
#
# ['模拟', '量化', '浮点数', '存储', '自定义', '32', '类型', '研究者', 'QuanTaichi', 'GPU', '细胞', '网格', '用户', '使用', '太极', '整数', '粒子', '物理', '线程', '一个']
#
# ['Android', '裝置', '2021', '機器', '10', '學習', 'Google', '應用', '程式', '04', 'API', '臉書', '推理', 'TensorFlow', 'Lite', '05', '效能', '學習平', '開發', '硬體']
#
# ['工作站', '惠普', '计算', '边缘', '数据', '人工智能', 'AI', '智能', '场景', '科学', '算力', '医疗', '应用', '2021', '监控', '行业', '部署', '落地', '领域', '需求']
#
# ['BLS', '制造业', '美国', '2010', '增长', '2019', '10', '劳动生产率', '1988', '第一次', '生产力', '劳工', '统计局', '生产率', '下降', '测量', '下滑', '年内', '总体', '有所']
#
# ['蔚来', '电站', '电池', '用户', '加电', '沈斐', 'NIO', 'Power', '29', '服务', '秦力', '电区', 'Athena', '规划', '人工智能', '开放', '平台', '智能', '充电', '换电']
#
# ['神经网络', '学习', 'Aasman', '机器', '节点', '实体', '数据', '关系', '预测', '图像', '高维', '事件', '场景', '之间', '矢量化', '识别', '客户', '理解', '分类', '人工智能']
#
# ['卷积', '偏置', 'ConViT', '模型', '学习', '归纳', '注意力', '参数', '训练', 'CNN', '数据', '图像', 'DeiT', 'soft', '算法', 'Transformer', '门控', '机器', '深度', '视觉']
#
# ['模型', '语言', '自然语言', '孟子', '训练', '知识', '腾讯', '领域', '微软', '机器翻译', '图谱', '语义', '互联网', '数字', '理解', '周明', '文本', '公益', '词性', '搜狗']
#
# ['模态', '老师', '学习', 'AI', '生成', '识别', '自动', '模型', '人工智能', '语音', '学生', '课堂', '机器', '算法', '文本', '授课', '训练', '系统', '输入', '作文']
#
# ['GLAT', '翻译', '并行', '生成', '解码', '机器翻译', '模型', '训练', '系统', '语句', '回归', '采样', '解码器', 'Transformer', 'WMT', '目标', '火山', '团队', '技术', 'Glancing']
#
# ['自然语言', 'ACL', '论文', '对话', '2021', 'NLP', '分享', '处理', '诺亚方舟', '机器翻译', '报名', '实验室', '李航', 'Keynote', '人工智能', '研究员', '机器', '学术交流', 'AI', 'Poster']
#
# ['ALD', '优化', '专家系统', '策略', '薄膜', '方法', '工艺', '时序', '研究', 'AI', '200', '使用', '贝叶斯', '反应器', '前驱', '随机', 'Al2O3', '噪声', '时间', '生长']
#
# ['标注', '平台', 'Annotator', 'AI', '开源', '智能化', '爱数', '数据', '联盟', '智慧', '功能', '人工智能', '生态', '核心', '可视化', '模态', 'CEO', '张晴晴', '现场', '北京']
#
# ['2035', '机器人', '工业', '领域', '出口商', '中国', '机械设备', '制造商', '挑战', '德国', '机遇', '机械', '主导', '落后', '欧洲', '工程', '技术', '首次', '去年', '目标']
#
# ['GPU', '登临', 'AI', 'Goldwasser', '人工智能', '科技', '系列产品', '计算', '创新', '架构', '自主', '异构', '多个', 'CUDA', 'GPGPU', '软件', '云端', '平台', '通用性', '首款']
#
# ['移动机器人', '场景', '必选', '物流', 'AI', 'AMR', '自主', '工厂', '柔性', '人工智能', '智慧', '机器人', '调度', '科技', '智能', '物料', '灵活', '算法', '解决方案', '展出']
#
# ['视频', '场景', '技术', '阿里', '赛道', '创新', '交互', '时代', 'AI', '峰会', '音视频', '优酷', '想象力', '体验', '平台', '算法', '数据', '智能', '全景', '内容']
#
# ['Hologres', 'MaxCompute', '查询', '数据', '性能', 'SQE', '外表', '引擎', '场景', 'IO', 'ms', '异步', '实时', '内表', '支持', '加速', '提升', '存储', '访问', '索引']
#
# ['2021', '10', '04', '臉書', '辨識', '相關', '05', '資訊', '技術', '商家', '法令', '隱私', '張貼', '新聞', '微軟', '卡巴斯基', '生物', '紐約州', '規定', '不過']
#
# ['AI', '人工智能', '论文', '博士', '学习', '研究', '2020', '机器', '2021', 'NeurIPS', '本科毕业', '博士学位', '在读', '教授', 'ACM', '顶级', '计算机', '斯坦福大学', '计算机系', '机器人']
#
# ['干细胞', '细胞', '角质', '识别', '培养', 'DeepACT', '学习', '深度', '跟踪', '形成', '集落', '2021', 'stem', '菌落', '皮肤', '健康', '控制', '算法', '研究', '自动']
#
# ['AI', '青年', '联盟', '人工智能', '人才', '科技', '科学家', '博士', '智能', '科技人才', '朱明杰', '班生', '世界', '发展', '技术', '之心', '学术', '论文', '卢策', '2019']
#
# ['人工智能', 'AI', '影谱', '影像', '科技', '智能', '2021', '数字', '引擎', '仿真', '技术', '领域', '孪生', '大会', '创新', '商业化', '生产链', '数字化', '三维', '世界']
#
# ['PyTorchVideo', '视频', 'video', '模型', 'Facebook', '开源', 'networks', 'recognition', '人工智能', '代码', 'PySlowFast', 'https', 'pytorchvideo', 'Vision', 'Lightning', 'Flash', 'learning', '前沿', '理解', '实验室']
#
# ['Anom', '手机', '设备', 'FBI', 'Motherboard', '应用程序', '擦除', 'GrapheneOS', '操作系统', '屏幕', '设置', '一个', 'Android', 'ArcaneOS', '使用', '用户', '计算器', '联系人', '加密', '功能']
#
# ['机器人', 'RMA', '适应', '学习', '模块', '现实', '环境', '模拟', '四足', '研究者', '腿式', '世界', '策略', '部署', '训练', '算法', '不同', '使用', '能够', '智能']
#
# ['腾讯', '脉冲星', 'FAST', '公益', 'AI', '学习', '优图', '数字', '人类', '星际', '一个', '信号', '互联网', '人工智能', '科技', '机器', '天文', '算法', '遮挡', '射电']
#
# ['视频', 'AI', '解码', '高通', '骁龙', '编解码器', '神经网络', '解码器', '888', '编码', 'CPU', '神经', '引擎', '编解码', '实时', '算力', '智能手机', '处理', '实现', '并行']
#
# ['ActNN', '内存', '训练', '压缩', 'bit', '模型', 'PyTorch', '节省', '使用', '梯度', '激活', '有损压缩', '量化', 'batch', '压缩算法', 'size', 'fp32', '方差', '引入', 'GPU']
#
# ['模态', '模型', '文本', '语音', '训练', 'level', '图像', '学习', '数据', '图文', '生成', '任务', '级别', '人工智能', '视觉', 'Modality', '性能', '掩盖', '词条', '监督']
#
# ['AI', '斑马', '智能', '智行', '天瀑', '天猫', '达摩院', '精灵', '技术', '打造', '融合', '交互', '汽车', '沉淀', '平台', '王恺', '场景', 'A100', '微信', '荣威']
#
# ['https', 'org', '2021', '10', '论文', 'doi', 'news', '学习', '链接', '07', '算法', '人工智能', '机器', 'html', '参数', '模型', '北京大学', '报道', '相关', '统计学']
#
# ['植物', 'ARADEEPOPSIS', '图像', '表型', 'ther', '研究', 'https', 'Schandry', '识别', '拟南芥', 'org', 'learning', '学习', '分析', '人员', 'jstor', 'botanists', 'use', 'machine', 'accelerate']
#
# ['华为', '鸿蒙', '用户数量', '系统', '发布', '升级', 'OS', 'HarmonyOS', '2500', '69', '格力', '外媒', '用户数', '董明珠', '机型', '热度', '上线', '不减', '国产', '智能']
#
# ['线控', '长城汽车', '架构', '底盘', '长城', '电池', '众创', '冗余', '驾驶', '智能', '汽车', '系统', '自研', '宋东先', '自动', '使用', '出行', '控制', '生态', '技术']
#
# ['資料', '我們', '2021', '10', '人工智慧', '網飛', '工廠', '擁有', '推薦', '系統', '演算法', '活動', '04', '這些', '時間', '創造', '臉書', '影片', '會員', '05']
#
# ['2021', '10', 'CodeFlare', '管線', '資料', '學習', 'IBM', '工作', '機器', '04', '臉書', '應用', '05', '最佳化', '時間', '框架', '流程', '簡化', '模型', '開源']
#
# ['制造业', '先进', '大会', '发展', '制造', '高质量', '山东', '信息化', '强省', '邀请', '战略', '强国', '山东省', '动能', '工业', '济南市', '加快', '创新', '智能', '举办']
#
# ['语音', 'AI', '标贝', '智能', '数据服务', '场景', '科技', '人工智能', '交互', '赋能', '客服', '应用', '数据', '大屏', '领域', '技术', '识别', '数字', '打造', '合成']
#
# ['AI', '智能', '容联云', '机器人', '场景', '智能化', '语音', '赋能', '客服', '2021', '陪练', '人工智能', '联络', '坐席', '应用', '容犀', '外呼', '企业', '中心', '客户']
#
# ['合营企业', '华为', '汽车', '惠迪', '持股', '协议', '理想', '水银', '2018', '天津', '智能', '专利', '出行', '设立', '许可', '小桔', '奥通', '有限公司', '投毒', '签署']
#
# ['GAIA', '模型', '数据', '检测', '训练', '视觉', '学习', '目标', '神经网络', '类别', '自然语言', '参数', '领域', '映射', '人脸识别', '不同', '深度', '算法', '网络', '任务']
#
# ['主机厂', '智能', '跨界者', '华为', '汽车', '供应商', '软件', '合作', '上汽', '主导权', '车企', '驾驶', '汽车行业', '5G', '自动', '时代', '迭代', '模式', '滴滴', '关系']
#
# ['Rap', '研究者', 'AI', '节拍', '模型', '生成', '数据', '歌词', '对齐', 'DeepRapper', '唱歌曲', '建模', '数据挖掘', '韵律', 'rap', 'BEAT', '押韵', '看出', 'pipeline', '节奏']
#
# ['IJCAI', '学习', '人工智能', '智能', 'AI', 'Sandholm', 'Tuomas', '吴恩达', 'Julia', '2021', '麦卡锡', '计算机', '奖项', '研究', '强化', '大学', '博弈论', '教授', '21', '2017']
#
# ['活性', '分子生物', '化学', 'Chemical', 'Checker', 'signaturizers', '分子', '预测', '生物', '描述符', 'CDD', '研究', '化合物', '信息', '人员', '集合', '工具', 'descriptors', '2021', 'SigAR']
#
# ['智能', '时空', '千寻', '城市', '位置', '人工智能', '执法', '数字化', '监测', '昆仑镜', '定位', '应用', '实时', '德清', '上虞', '操作系统', '精准', '感知', '遂昌', '联动']
#
# ['2021', '10', '人工智慧', 'Cambridge', '訓練', '04', '臉書', '超級', '電腦', '藥物', '05', 'Nvidia', '運算', 'Nanopore', '模型', '領域', '數位', '研究', '技術', 'AstraZeneca']
#
# ['立法会', '黑镜', '分神', '人工智能', '立法机关', '沉闷', '工作', '纳税人', '身为', '手机', '人人', '日常', '监督', '一名', '会议', '人员', '正在', '接受', '参加', '准备']
#
# ['Nexperia', '收购', 'Newport', 'NWF', 'Wafer', 'Fab', '外媒', '闻泰', '安世', '6300', '62', '芯片', '万英镑', '半导体', '生产商', '约合', '本周一', '全资', '这项', '荷兰']
#
# ['https', 'com', '2021', '电路', '阿斯利康', 'org', 'news', 'html', '论文', '链接', '几秒钟', '模拟', '示意图', 'AI', '2D', '粒体', 'GAN', 'www', 'nature', 'articles']
#
# ['射线', '扫描仪', '成像', '杜克大学', '扫描', '透射', '孔径', 'Kapadia', 'Greenberg', '图像', '分辨率', '系统', '不同', '用于', '物体', 'https', 'XRD', '衍射', '编码', '诊断']
#
# ['荣威', 'RX5', 'PLUS', '全新', '智能', '元增', '330TGI', '国潮', '终身', '免费', '换购', '维纳斯', '13', '双十佳', '静音', '系统', '补贴', '互联网', '礼遇', '汽车']
#
# ['MoCo', 'MoBY', 'Transformer', '学习', '准确率', 'ImageNet', '1K', '主干', '架构', '线性', 'v2', 'BYOL', '研究者', '方法', '训练', '监督', 'v3', 'DINO', '微软', '评估']
#
# ['语言', '标签', 'shot', 'Zero', '翻译', 'ENC', '不同', '集上', '数据', '巨大', '目标语言', '影响', '研究者', '相差', '验证', '句子', '实验', '优于', '火山', '模型']
#
# ...
#
# ['貨幣', '區塊', '鮑爾', '穩定幣', '我們', '加密', '數位', '監管', 'Fed', '中國', '並沒有', '雖然', '認為', '應該', '市場', '鮑爾說', '大眾', '發行', 'email', 'protected']
#
# ['Readmoo', '讀墨', 'mooInk', '閱讀', '電子', '暢讀', '報紙', '讀者', '我們', 'App', '功能', '系列', '分享', '上線', '訂閱', '展售', '誠品', '新板', '體驗', '線上']
#
# ['空投', '區塊', 'LikeCoin', 'LIKE', '專案', '用戶', '通證', '條件', '社群', '作者', '目標', '介紹', '機制', '我們', '永續', '沒有', 'Ramp', '公民', '使用', '分散式']
#
# ['DNA', '鑑定', '軟體', 'Cybergenetics', 'Views', '技術', 'TrueAllele', '結果', '因為', '搶匪', 'Total', '程式', '沒有', 'Watson', 'Online', 'Visitors', '19', 'PGS', '犯罪', '被告']
#
# ['懸疑', '警察', '這個', '他們', '調查', '文房', '推理', '活動', '對話', '緩緩', '展開', '辦案', '選擇', '距離', '30', '閱讀', '犯罪', '夜晚', '肉身', '凡人']
#
# ['課程', '資料', 'Alexander', '電子', '金融', 'Pandas', '專案', '郵件', '真實', '機器', '學習', '專業', '科學家', '講師', '技能', 'Soft', 'Share', '歡迎', '科學', 'Hagmann']
#
# ['AI', 'AppWorks', 'Taiwan', '2021', 'Accelerator', 'companies', 'data', 'first', 'ecosystem', 'startup', 'their', 'marketing', 'startups', 'more', 'teams', 'new', 'organizations', 'Wistron', 'will', 'appworks']
#
# ['人工智慧', '客戶', '零售', '數據', '系統', '預測', 'AI', '應用', '我們', '技術', '一個', '他們', '處理', '市場', '能夠', '智慧', '零售商', '公司', '機器', '交付']
#
# ['AI', '畫質', 'DVDFab', 'Enlarger', '影片', 'Email', '序號', '技術', '提升', '輸入', '工具', '免費', '選擇', '授權', '能夠', '圖片', '小編', '透過', '89', '99']
#
# ['AI', '技術', 'Binah', '狀況', 'App', '發展', '研發出', '透過', '偵測員工', '分鐘', '應用', '裝置', '鏡頭', '偵測', '員工', '毋須', '電腦', '照片', '程式', '健康']
#
# ['人工智能', '私隱', '機構', '開發及', '相關', '帶來', '專員', '標準', '資料', '指引', '公署', '道德', '日漸', '同時', '風險', '條例', '規定', '來源', '發展', '大灣區']
#
# ['情緒', '老師', '我們', '發現', '悲傷', '他們', '認為', 'AI', '宜欣', '能夠', '學習', '表達', '憤怒', '過程', '結果', '圖輯隊', '怎麼', '帶著', '社會', '人類']
#
# ['學習', '生產', '機器', '專業', '資料', 'AI', '開發', '工程', '軟體', '電子', '模型', '至關', '職涯', '技術', '將機器', '現代', '知識', '相結合', '郵件', '助您']
#
# ['選手', '射箭', '南韓', '東京', '成績', '現代', '汽車', '項目', '訓練', '變化', '大數據', '金牌', '分析', '隊成績', '單是', '今屆', '奧運', '已經', '實力', '而輝煌']
#
# ['辨識', '人臉', '技術', '應用', '領域', '優勢', '指紋', '資訊', '臉辨識', '採集', '市場', '系統', '自然性', '透過', '設備', '接觸', '人員', '身份', '3S', 'Market']
#
# ['資料', '課程', '我們', 'SAP', '學習', '科學', '科學家', '電子', '機器', '專業', '郵件', '一個', '問題', '主題', '這個', '成為', '網站', 'Soft', 'Share', '應用']
#
# ['圖片', '裁切', '網站', '社群', 'Pixelhunter', '工具', '尺寸', '自動', '這款', 'Facebook', '線上', '平台', '選擇', 'Google', '就會', '顯示', '下載', '一個', '打包', '整成']
#
# ['應用', '3S', 'Market', '市場', '資訊', '領域', '產業', '智慧', '資訊網', '台灣物', '聯網', '監控', '雲端', '解決', '人氣布', '落格', '網站', '三大應', '產品', '行業']
#
# ['應用', '3S', 'Market', '市場', '資訊', '領域', '產業', '智慧', '資訊網', '台灣物', '聯網', '監控', '雲端', '解決', '人氣布', '落格', '網站', '三大應', '產品', '行業']
#
# ['應用', '3S', 'Market', '市場', '資訊', '領域', '產業', '智慧', '資訊網', '台灣物', '聯網', '監控', '雲端', '解決', '人氣布', '落格', '網站', '三大應', '產品', '行業']
#
# ['數據', '工業', '設備', '平台', '人工智慧', '應用', '大數', '發展', 'WitSight', '聯網', '問題', '機器', '技術', '處理', '行業', '進行', '工業物', '產品', '未來', '重工']
#
# ['不過', '阿湯', '鄰近', '雖然', '工具', '一個', '詞查詢', '輸入', '成語', '自動', '顯示', '網站', '這個', '發現', '線上', '相關', 'AI', '還有', '興趣', '服務']
#
# ['比特', '貨幣', '一個', '幣的', '這個', '挖礦', '遊戲', '這樣', '已經', '因為', '加密', '系統', '這種', '他們', '骰子', '10', '電量', '我們', '網路', '資料']
#
# ['模擬', '模型', '物理', '網路', '遊戲', '學習', '變形', '進行', '算器', '方法', 'MPM', '數據', '透過', '計算', '材料', '我們', '一種', '神經', '訓練', '預測']
#
# ['Woebot', '治療', '一個', '情緒', '心理', '臨床', '問題', '對話', '時候', 'Darcy', '療法', 'AI', '使用者', '能夠', '人們', 'CBT', '認知', '聊天', '回應', '希柯']
#
# ['我們', '未來', '他們', '因為', '技術', '一個', '這些', '人工智慧', '貨幣', '已經', '這種', '系統', '機器', '中心化', 'AI', '什麼', '預測', '發生', '社會', '數位']
#
# ['裁判', '人工智慧', 'Lucey', 'Stats', '進行', '比賽', '他們', 'Perform', '來源', '資料', '系統', '自動', '項目', '技術', '圖片', 'courtesy', '網球', '留言', '評分', '運動員']
#
# ['超級', '電腦', 'Polaris', 'NVIDIA', 'AI', 'GPU', '運算', '科學', 'ALCF', 'exascale', '等級', '留言', '發表', '貢國家', '實驗室', 'Argonne', '推動', 'A100', '業負載', '搭載']
#
# ['AI', '語音', 'NVIDIA', '技術', '2021', '應用', '合成', '留言', '發表', '電子', '相關', 'Interspeech', '影片', '旁白', '虛擬', 'Power', '語言', '多場', '主題', '演說']
#
# ['AI', 'NVIDIA', 'Enterprise', '軟體', 'vSphere', 'VMware', '硬體', '支援', '伺服器', '企業', '虛擬化', '套件', '留言', '搭配', '運作', '執行', '未來', '授權', '相容性', '系統']
#
# ['10', '2021', '07', 'Astro', '06', '亞馬遜', '機器', '新聞', '09', '16', '中央社', '這款', '樓梯', '20', '熱門', 'Alexa', '時間', '報導', '30', '專家']
#
# ['我們', '聲音', '隨身', 'iPod', '運動', '噪音', 'Walkman', '音量', 'Audiac', '他們', '音樂', '裝置', '什麼', '這個', '科技', '環境', '透過', '問題', '智慧', '寧靜']
#
# ['台灣', '保時捷', '充電站', 'Taycan', '充電', '酒店', 'Charging', '全台', '留言', '網路', '車主', '持續', '充電據點', '目的地', '純電', '體驗', '保時', '時捷', 'Turbo', '充電樁']
#
# ['綁定', '橘子', '五倍', '零用金', '消費', '支付', '000', '優惠券', '10', '回饋', '留言', '數位', 'ACG', '家電', '乙張', '遊戲', '熱門', '振興', '消費者', '加碼']
#
# ['Apple', 'ID', '密碼', '4MeKey', '設定', 'iPhone', '接下', '忘記', '設備', 'iOS', '裝置', '解鎖', '狀態', '手機', '登入', '輸入', '連結', '授權', '使用', '需要']
#
# ['住戶', '醬油', '大廈', '條例', '公寓', '我們', '擠壓', '容器', '車位', '包裝', '條第項', '管委', '使用', '規定', '沙龍', '時代', '環保', 'PET', '包材', '管理']
#
# ['運動', '我們', '酵素', '科技', '智慧', '協助', '台灣', '保濟堂', '沙龍', '國家', '網路', '討論', '訓練', '超過', '專業', '資訊', '益生菌', '多種', '觀點', '節目']
#
# ['iPad', '現象', '螢幕', '畫面', 'LCD', '出現', '蘋果', 'mini', '留言', '根據', 'frame', '問題', '進行', '軟體', '60Hz', '更新', '發表', 'Dieter', 'Bohn', '他們']
#
# ['LINE', '廣告', '好友', '廣告主', '消費者', '帳號', 'LAP', '用戶', '王宣', '台灣', '數據', '留言', '系統', '名單', '潛力', '互動', '新客', '官方', '投放', '13']
#
# ['運動', '我們', '科技', '改變', '科學', '透過', '選手', '智慧', '成為', '訓練', '環境', '國家', '東京', '台灣', '細節', '這樣', '大數據', '這些', '討論', '落地']
#
# ['運動', '我們', '智慧', '國家', '科技', '台灣', '觀測', '報告', '重訓', '協助', '專業', '吳誠文', '極地', '超馬', '09', '訓練', '運動員', '彥博', '休閒', '討論']
#
# ['vivo', '螢幕', 'X70', 'Pro', '蔡司', '手機', '留言', '更新', '機身', '起來', '時間', 'Type', '體驗', '認證', '發表', '我們', '理器', '測試', '支援', '超薄']
#
# ['樂迷', '創作', '留言', '街聲', '拍拍手', '歌曲', '拍拍', '功能', '音樂', '一個', '商業', 'StreetVoice', '鼓勵', '實質', '持續', '成為', '音樂人', '給予', '掌聲', '感謝']
#
# ['PQC', '量子', '尿酸', '電腦', '演算法', '我們', '加密', '痛風', '發作', '關節', '2021', '腎臟', '吳建興', '系統', '開始', '密碼學', '小時', '治療', '出現', '數學']
#
# ['edge', '20', 'Motorola', 'pro', '手機', '螢幕', '相機', 'fusion', '萬畫素', '鏡頭', '留言', '10', '理器', '主鏡頭', '800', '具備', '售價', 'moto', '搭配', '使用者']
#
# ['小蠻', '自動', '達摩院', '駕駛', '000', '機器', '100', '校園', '10', '留言', '配送', '研發', '已經', '超過', '中國', '社區', '服務', '物流', '包裹', '阿里巴巴']
#
# ['守恆', '官網', '發電機', '能量', '他們', '定律', '中國', '已經', '研發', '根據', '轉動', '留言', '槓桿', '一種', '企業', '不斷', '做功', '發表', '電子', '補償']
#
# ['憂鬱症', '我們', '思考', 'AWS', '反芻性', '相關', '開發者', '研究', '大腦', '技術', 'Dev', 'Day', '這個', '2021', '憂鬱', '自我概念', '腦波', '影響', '沙龍', '科學']
#
# ['貨幣', '虛擬', 'MaiCoin', '之虛擬', '分署', '泰達幣', '留言', '拍定', '收取', '10', '礦機', '7620', '以太', '不過', '因為', 'USDT', 'ETH', '清單', 'ERC20', '大隊']
#
# ['小米', '10', '三重', '權店', '消費滿', '手機', '留言', 'mi', 'com', '獲贈', '店家', '五千元', '新店', '加碼', '活動', '開幕', '回收', '商城', '日起', '14']
#
# ['小米', '10', '11', 'Lite', '5G', 'NE', '像素', '購物', '台灣', '日起', '實體', '門市', '鏡頭', '支援', '8GB', '開賣', 'AI', '售價', '相機', '搭載']
#
# ['Galaxy', '手機', '創作', '5G', '三星', '留言', '張震', 'Facebook', '告五人', 'Fold3', 'Flip3', '雙方', '不僅', '相當', 'Pen', '直呼', '有感', '系列', '歌手', '發表']
#
# ['上網', '遠傳', '網路', '漫遊', '留言', '新加坡', '出國', '門市', '用戶', '每日', '優惠', '60', '遠遊卡', '選購', '東南亞', '網卡', '199', '消費者', '隨時', '數據']
#
# ['平板', '小米', '螢幕', '控筆', '表現', '追劇', '顯示', '10', '11', '靈感觸', '版本', '6GB', '整體', '搭配', '256GB', 'app', '使用', '發表', '售價', '留言']
#
# ['LG', 'Cybellum', '汽車', '收購', '車載', '軟體', '我們', '留言', '資安', '成長', '解決', '夥伴', '合作', '電子', '股權', '成為', '未來', '投資', '資安威脅', '產業']
#
# ['手術', '顧客', '企業', '過程', '脊椎', '轉型', '機器', '經營', '數位', '神經', '腦部', 'SO', 'NICE', '接觸點', '服務', '關鍵', '價值', '減少', '各種', '透過']
#
# ['蘋果', '醬油', '影響', '我們', 'ABF', '擠壓', '容器', '缺料', '供應', '包裝', '零組件', '時代', '台灣', '沙龍', '環保', 'PET', '包材', 'MacBook', '問題', '中國']
#
# ['小米', '報告', '資訊', '用戶', '資料', '軟體', '隱私', '使用者', '手機', '留言', '廣告', '安全', '我們', '第三方', 'NCSC', '評估', '機構', '回應', '不會', '處理']
#
# ['螢幕', 'iPhone', '蘋果', '維修', 'Face', 'ID', '13', '留言', '顯示', '第三方', '他們', '使用者', '使用', '感器', '更換', 'iPhone13', '一個', '提示', '發表', '發文']
#
# ['疫苗', '我們', '治療', '憂鬱症', '用戶', '醫療', '預約', '資訊', '系統', 'Shandy', 'Tsai', '影響', '藥物', '台灣', '施打', '美國', 'Photo', 'Credit', '問題', '流程']
#
# ['飢餓', '我們', '客氣', '問題', '說法', 'No', '街友', 'me', '因為', '營養', '英文', '協助', '回應', '這個', '低收入', '什麼', '環境', '這句', '幫助', '同時']
#
# ['貨幣', '虛擬', '使用者', '相關', '服務', '中國', '監管', '中國大陸', '2021', '24', '地區', '終止', '交易平台', '火幣', '注冊', '關閉', '留言', '清退', '發布', '數據']
#
# ['電影級', 'iPhone', '焦點', '模式', '13', '蘋果', '電影', '一個', '我們', '透過', '移動', '人像', '焦員', 'A15', '並非', '進而', '出現', '設計', '瞭解', '影片']
#
# ['人格', '測驗', '戀愛', '留言', 'Omi', '20', '結果', '類型', '對象', '萬用戶', '用戶', '性格', '發表', 'AI', '軟體', '發文', '違者', '刪除', 'iPhone', '13']
#
# ['SSD', 'Western', 'Digital', '儲存', 'James', '監管', '我們', 'WDBLACK', 'NVMe', '選擇', '中國', '解決', '玩家', '培訓', '沙龍', 'SanDisk', 'WD', '小吳', '一個', '技術']
#
# ['iPhone', '14', '螢幕', '爆料', '蘋果', '留言', '設計', '13', '雖然', '時間', '改進', '不過', '這張', '圖片', 'Face', 'ID', '方案', '系列', '發表', '10']
#
# ['五倍', '10', '振興', '規定', '綁定', '社群', '媒體', '轉售', '下架', '留言', '收購', '經濟部', '辦法', '業者', '紙本', '數位', '萬人', '發文', '店家', '平台']
#
# ['10', '2021', '07', '中國', '06', '新聞', '遊戲', '日報', '這種', '我們', '電子', '觀點', '09', '30', '00', '熱門', '網遊', '熱議', '美國', '他們']
#
# ['小時', '真無線', '藍牙耳機', '降噪', 'omthing', 'AirFree', '留言', '擁有', '規格', 'ANC', '主動', '快充', '分鐘', '690', '早鳥', '單耳', '環境音', '保護', '充電盒', '專屬']
#
# ['Linux', '雲端', '程式', '攻擊', '環境', '惡意', '留言', '這份', '報告', '企業', '2021', '趨勢', '系統', '我們', '伺服器', '數位', '作業', '未來', '虛擬化', '基礎']
#
# ['病人', '標準化', '醫師', '訓練', '醫學', '醫院', '臨床', '醬油', '考試', 'OSCE', '慈濟', '時代', '準化', '台灣', 'SARS', '畢業', '高聖博', '我們', '擠壓', '容器']
#
# ['網路', '我們', '駭客', 'NSA', '華為', '美國', '醬油', '英國', '關鍵', '擠壓', '容器', '行動', '委員會', '這個', '5G', '資訊', '包裝', '記者', '通訊', '科技']
#
# ['中國', '飢餓', '問題', '我們', '限電', '台灣', '企業', '街友', '目標', '營養', '低收入', '停工', '雙控', '影響', '大廠', '地區', '許多', '沙龍', '關鍵', '貧窮']
#
# ['緬甸', '太陽能', '微電', '軍方', '聯合國', '我們', '能源', '政府', '發言', '他們', '因為', '一個', '報導', '網路', 'Cindy', '消費', '永續', '大會', '創造', '沙龍']
#
# ['蘋果', 'iPhone', '包裝', '13', '手機', '採用', '塑膠', '留言', '環保', '封膜', '100', '再生', '不斷', '取消', '網友', '這樣', '這個', '發表', '內容', '鏡頭']
#
# ['貨幣', '虛擬', '比特', '中國', '加密', '活動', '留言', '銀行', '根據', '提領', '時間', '以太', '交易', '發表', '16', '相關', '新聞', 'Coin', 'Rivet', '幾乎']
#
# ['供應', '蘋果', '週日', 'iPhone', '留言', '停工', '生產', '影響', '工廠', '蘇州', '電子', '中國', '電力', '限電', '幾家', '期間', '工業', '運營', '滿足', '客戶']
#
# ['iPad', 'mini', 'Pro', '13', 'iPhone', 'Max', 'GPU', 'iPhone13', 'CPU', '時脈', '差異', '性能', 'A15', '理器', '留言', '兩者', '運行', '單核', '多核', '效能']
#
# ['Xperia', 'III', 'Sony', '手機', '螢幕', '鏡頭', '設計', '拍攝', '模式', '畫面', '24mm', '介面', '不過', '顯示', '主鏡頭', '測試', '旗艦', '機身', '採用', '表現']
#
# ['iPhone', 'Apple', 'Watch', '解鎖', '蘋果', '13', '他們', '無法', '軟體', '留言', '一個', '發表', 'iOS', '使用者', '更新', '功能', '針對', '這個', '發現', '受影響']
#
# ['攻擊', '軟體', '網路', '企業', '組織', '偵測', '勒索', '2021', '惡意', '屍網路', 'FortiGuard', 'Labs', '回應', '不斷', '廣告', '留言', '顯示', '進行', '超過', '恐嚇']
#
# ['送員', '外送', '運動', '餐廳', '我們', '紐約', '他們', '紐約市', '外送員', '平台', '法案', '疫情', '科技', '權益', '通過', '智慧', '美國', '工資', '這些', '期間']
#
# ['知識', '原作者', '泛科', '沒有', 'PanSci', '事務', '我們', '泛科學', '法律', '台灣', '媒體', '一個', '新學習', '生態', '難學', '由泛', '科知識', '營運', '內容', '圖像']
#
# ['趨勢', '攻擊', '威脅', '資料', '企業', '勒索', '惡意', '網路', '2021', '留言', '科技', '病毒', '數量', '偵測', '駭客', '機構', '詐騙', '上半年', '他們', '程式']
#
# ['大憲章', '國王', '英國', '企業', '我們', '約翰王', '社創', '他們', '貴族', '中國', '數位', '約翰', '服務', '社會', '一個', '商家', '疫情', '資源', '消費者', '購物']
#
# ['服務', '導遊', '旅遊', '留言', 'VR', '影片', '環球', '超過', '體驗', '價格', '幣約', '旅行', '發表', '發文', '違者', '刪除', 'iPhone', '13', '日元', '世界各地']
#
# ['蘋果', 'iPhone', 'USB', '連接', 'Lightning', '連接埠', '認證', '接埠', '系統', '相容', 'MFi', '盟委', '生態', '客戶', 'iPad', '通過', '充電', '使用者', '員會', '充電連']
#
# ['太空', '衛星', '地球', '軌道', '飛行', '發射', '2021', '我們', '火箭', '新創', '一個', '市場', '運動', '公里', '重量', '公司', '系統', '因為', '小時', '沒有']
#
# ['iPhone', '13', '小時', '分鐘', 'Pro', '留言', 'Max', '10', '機型', '電池續', '全系', '12', '11', '2020', 'SE', '電池', '情況', '測試', '52', '17']
#
# ['學生', '資料', '檔案', '學校', '遺失', '國教署', '教育部', '版模', '留言', '暨南', '發表', '歷程', '記者', '受影響', '認證', '搬移到', '新機', '大學', '2021', '13']
#
# ['營養', '朱立倫', '國民黨', '桂冠', '黨員', '美味', '選舉', '張亞中', '健力餐', '江啟', '研究室', '得票率', '我們', '什麼', '興黨部', '地方', '投票', '主席', '10', '消費者']
#
# ['我們', '電磁波', '5G', '輻射', '什麼', '居酒', '那麼', '手機', '清酒', '已經', '通訊', '其實', '沙龍', '頻率', '酒精', '影響', '戀愛', '因為', '怎麼', '不會']
#
# ['AWS', '醫師', '開發者', '技術', 'Dev', 'Day', '林嘉俊', '頭痛', '我們', '沙龍', '討論', '網路', '2021', 'Photo', 'Credit', '多元', '觀點', '發者', '大會', '台灣']
#
# ['MagSafe', '卡套', '保護殼', 'iPhone', '皮革', '13', '尋找', '矽膠', '採用', '開箱', '通知', '蘋果', '我們', '手機', '留言', '功能', '保護', '螢幕', '發出', '午夜']
#
# ['我們', '產品', 'Cook', '蘋果', '爆料', 'iPhone', '留言', 'Tim', '媒體', '洩密者', '洩露', '機密', '洩露給', '13', '內容', '電子', '郵件', '進行', '沒有', '會議']
#
# ['iPhone', '13', '數位', '新機', '德誼', '折抵', '留言', '開賣', '消費者', '進行', '手機', '系列', '現省', '即通', '排隊', '小時', 'Pro', '加購', '服務', 'APP']
#
# ['運動', '我們', '科技', '智慧', '沙龍', '國家', '網路', '台灣', '協助', '討論', '訓練', '環境', '資訊', '大佬', '交流', '觀點', '節目', '提醒', '結合', '困難']
#
# ['iPhone', '13', '留言', '10', '09', '開箱', 'Pro', '00', '影片', '發表', '我們', '電影級', '微距', '發文', '18', '44', '違者', '刪除', '模式', '平板']
#
# ['運動', '電磁波', '開始', '我們', '身體', '5G', '這樣', '分鐘', '輻射', '筋膜', '建議', '通訊', '運動時', '還是', '手機', '肌肉', '不過', '30', '教練', '沙龍']
#
# ['AWS', '開發者', '技術', 'Dev', 'Day', '2021', '發者', '大會', '舉行', '議程', '10', '領域', '設計', '線上', '報名', '開發', '學習', '大會將', '日線', '豐富']
#
# ['手術', '脊椎', '機器', '我們', '神經', '腦部', '短片', '減少', '台灣', '傳統', '過程', '發生', '精準', '手臂', '網路', '電影', '母親', '透過', '這是', '沙龍']
#
# ['iPhone', '13', '留言', '一個', '同時', '中國', '開箱', '這位', '應該', '明顯', '發表', '封條', '手機', '蘋果', '發文', '違者', '刪除', '案例', '直接', '17']
#
# ['運動', '我們', '科技', '預知', '智慧', '電影', '沙丘', '未來', '沙龍', '國家', '創造', '網路', '台灣', '協助', '原作', '方格子', '能夠', '難以', '討論', '訓練']
#
# ['東南亞', 'Kejora', 'Capital', '投資', '新創', '留言', '創投', '地區', '超過', '台灣', '資金', '協助', '發展', '成為', 'Charles', 'Pan', '聯盟', '開始', '網路', '規模']
#
# ['運動', '德國', '我們', '之聲', '科技', '天然', '智慧', '價格', '國家', '歐洲', '沙龍', '設施', '網路', '台灣', '協助', '北溪', '討論', '訓練', '一個', '新聞']
#
# ['App', '數位', '果核', '綁定', '消費者', '留言', '下載', '網頁', '保護', '銀行', '駭客', '詐騙', '安全', '五倍', '資訊', '單位', '網路', '進行', '相當', '三要']
#
# ['iPhone', '13', 'Pro', 'Apple', '天峰', '藍色', '信義', 'A13', '那麼', '色系', '金色', '石墨', '我們', '蘋果', '留言', '實體', '讀者', '101', '感覺', '分別']
#
# ['iPhone', '13', '開賣', '果粉', '5G', '活動', '排隊', '24', '現場', '遠傳', '留言', '新機', '申辦', '蘋果', '不過', '中華電信', '台灣', '首賣', '已經', '網路']
#
# ['國民黨', '朱立倫', '我們', '輕人', '電磁波', '青年', '5G', '他們', '輻射', '通訊', '現在', '一個', '兩岸', '手機', '主席', '這些', '林家', '台灣', '沙龍', '頻率']
#
# ['運動', '影響力', '投資', '我們', '問題', '社會', '婦女', '企業', '環境', '改變', '奇德', '一個', '女性', 'Wing', '正義', '國家', '解決', '發展', '科技', '美國']
#
# ['關鍵', '創辦', 'EasyStore', '市場', '產品', '轉折', '企業', '網路', '我們', '他們', '獨角獸', '服務', '消費者', '巴特菲', '銷售', '賣家', '創業', 'YouTube', '電商', '影片']
#
# ['醫師', '郭光', '牙齒', '哲牙', 'AWS', '開發者', '缺牙', '問題', '技術', '我們', 'Dev', 'Day', '因為', '處理', '關節', '狀況', '討論', '植牙', '傾倒', '影響']
#
# ['太陽能', '微電', '履歷', '我們', '面試', '能源', '投履歷', '職缺', '因為', '產業', 'Cindy', '消費', '回應', '永續', '機會', '一個', '其實', '企業', '創造', '沙龍']
#
# ['10', '2021', '06', '蘋果', '07', 'Epic', 'Games', '30', '新聞', 'Google', '付費', 'App', '觀點', '05', '40', 'iOS', '費用', '專欄', '09', '華爾街']
#
# ['購物', '綁定', '消費', '留言', '五倍', '全站', '蝦皮', '店家', '信用卡', '22', '數位', '攜手', '台灣', '相關', '消費者', '國泰世華', '蝦幣', '回饋', '即日起', '發表']
#
# ['10', '2021', '07', '06', '衛星', 'iPhone', '通訊', '蘋果', '09', '20', '16', '中央社', '新聞', '這個', '15', '螢幕', '爆料', '低軌', '什麼', '我們']
#
# ['13', 'iPhone', 'Pro', 'Max', '我們', '手機', '天峰', 'mini', '留言', '金色', '分享', '那麼', '12', '明顯', '四款', '全系列', '發表', '蘋果', '開箱', '封條']
#
# ['EasyStore', '台灣', '網路', '市場', '服務', '賣家', 'Gogoro', '企業', '銷售', '電商', '購物', '開店', '新創', '資金', '創業者', '我們', 'SPAC', '選擇', '投資人', '消費者']
#
# ['企業', '台南', '經濟', '永續', '台灣', '制裁', '循環', '我們', '合作', '關鍵', '目標', '跨域', '市場', '國民黨', '沙龍', '中國', '創造', '歌謠', '透過', '產業']
#
# ['日照', '麥子', '照顧', '社會', '18', '多功能', '一粒', '服務', '中心', '台灣', '偏鄉', '我們', '同時', '年齡', '權利', '無法', '社區', '關鍵', '他們', '一個']
#
# ['Mac', 'mini', 'iMac', '蘋果', 'M1', '新款', '消費者', 'Apple', 'USB', '產品', '規格', '電腦', '連接', '升級', '記憶體', '24', '效能', '螢幕', 'Type', '周邊']
#
# Take time:  15.852669715881348 s
# All jobs Done!

# %%
# 把這 500 篇新聞內容做成文字雲

def plt_wordcloud(content, maskpath): # 把文章內容轉文字雲
    
    from wordcloud import WordCloud
    import jieba
    import matplotlib.pyplot as plt
    from PIL import Image 
    import numpy as np
    # %matplotlib inline
    
    words = jieba.cut(content, cut_all=False)
    
    all_words = ''
    for word in words:
        all_words += ' '+word
    
    mask = np.array(Image.open(maskpath))
    
    wcloud = WordCloud(width=500, height=500, background_color='white', mask=mask, 
                       min_font_size=8, font_path='simhei.ttf').generate(all_words)
    plt.figure(figsize=(20, 10), facecolor=None)
    plt.imshow(wcloud)
    plt.axis('off')
    plt.tight_layout(pad=0)
    
    plt.show()

# %%
# 把這 500 篇新聞內容做成文字雲

def plt_wordcloud(content): # 把文章內容轉文字雲
    
    from wordcloud import WordCloud
    import jieba
    import matplotlib.pyplot as plt
    from PIL import Image 
    import numpy as np
    # %matplotlib inline
    
    words = jieba.cut(content, cut_all=False)
    
    all_words = ''
    for word in words:
        all_words += ' '+word
    
    
    wcloud = WordCloud(width=500, height=500, background_color='white', mask=None, 
                       min_font_size=8, font_path='C:/Windows/Fonts/kaiu.ttf').generate(all_words)
    
    plt.figure(figsize=(20, 10), facecolor=None)
    plt.imshow(wcloud)
    plt.axis('off')
    plt.tight_layout(pad=0)
    
    plt.show()

# %%
allnews = ''

for n in remained_news:  # 這500篇新聞的總和
    allnews += n

# %%
plt_wordcloud(allnews)

# %%
print(len(keywords))
# Out:
# 500

# %%
keywords[0:2]
# Out:
# [['10',
#   '2021',
#   '07',
#   '咖啡',
#   '06',
#   '16',
#   '09',
#   '市場',
#   '台灣',
#   '咖啡店',
#   '中央社',
#   '新聞',
#   '20',
#   '創業',
#   '星巴克',
#   '通路',
#   '熱門',
#   '許多',
#   '食力',
#   '超商'],
#  ['口罩',
#   '指揮',
#   '距離',
#   '隨身',
#   '攜帶',
#   '還是',
#   '活動',
#   '留言',
#   '社交',
#   '規定',
#   '維持',
#   '10',
#   '相對',
#   '穩定',
#   '無須',
#   '無法',
#   '空曠',
#   '之場',
#   '相關',
#   '聚集']]

# %%
#keywords

keyword_text='' #要製作文字雲，來源文本不能是list形式

for lst in keywords:
    for item in lst:
        keyword_text+=' '+item
        
print(len(keyword_text))
# Out:
# 36694

# %%
print(keyword_text[0:200])
# Out:
#  10 2021 07 咖啡 06 16 09 市場 台灣 咖啡店 中央社 新聞 20 創業 星巴克 通路 熱門 許多 食力 超商 口罩 指揮 距離 隨身 攜帶 還是 活動 留言 社交 規定 維持 10 相對 穩定 無須 無法 空曠 之場 相關 聚集 停電 手機 包一倩 沒有 社區 時間 電影 留言 不見 出門 用電 情況 一個 發電機 因為 發現 煤氣 居民 不斷 他們 攻擊 DDoS 駭客 網

# %%
def wordCloud(text):   
    wcloud = WordCloud(width=500, height=500, background_color='white', mask=None, 
                       min_font_size=8, font_path='C:/Windows/Fonts/msjh.ttc').generate(text)
    
    plt.figure(figsize=(20, 10), facecolor=None)
    plt.imshow(wcloud)
    plt.axis('off')
    plt.tight_layout(pad=0)
    
    plt.show()

# %%
wordCloud(keyword_text)
