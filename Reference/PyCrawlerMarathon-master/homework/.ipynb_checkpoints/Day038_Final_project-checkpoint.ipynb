# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import time
import pandas as pd

N = 500  # 設定要爬取文章數

# %%
# 透過開發者工具發現也可以利用 API
# api = 'https://www.cupoy.com/MixNewsMongoAction.do?op=getTopMixNewsByBucketGroup&groupid=tech_tw&len=500'
# 回傳是 json 文件格式

# %%
# 打開瀏覽器, 進入欲爬取網頁
browser = webdriver.Chrome(executable_path='chromedriver')
browser.get("https://www.cupoy.com/newsfeed/topicgrp/tech_tw")

# 每隔兩秒鐘自動往下滑, 擷取 500 篇新聞的 url
count = 0
articles_info = []

print('目前文章數: ', end='')

while count<N:
    html_source = browser.page_source
    soup = BeautifulSoup(html_source, 'html5lib')
    
    target = soup.find_all('a', class_='sc-jxGEyO')                 # class name 曾經改過, 導致抓不到, 所以要再次確認
    dummy = 0
    
    for d in target:
        article = {}
        article['title']= d['title']
        article['url'] = d['href']
        article['origin'] = '/'.join(d['href'].split('/', 3)[:-1])           # 新聞來源的網站主頁
        
        if article not in articles_info:                  # 如果有因為往下滑的時間延遲造成爬取到重複的新聞
            articles_info.append(article)                 # 設置 dummy 扣除計算數
        else:
            dummy += 1
    
    count = count + len(target) - dummy
    print(count, end=' ')
    
    browser.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(5)

browser.quit()

if len(articles_info) > N:                               # 取前 500 筆
    articles_info = articles_info[:N]
# Out:
# 目前文章數: 0 15 29 40 54 65 80 92 108 121 137 150 166 179 195 208 224 237 253 266 283 296 313 326 343 356 372 385 402 415 432 445 462 475 492 505

# %%
print(len(articles_info))
print()

for i, a in enumerate(articles_info, start=1):                  # 確認 500 筆新聞的標題
    print(i, ' ', a['title'])
# Out:
# 500
#
# 1   顛覆知產保護傳統模式，阿里AI模特首度現身國內頂尖AI安全會議 | 機器之心
# 2   阿里AI“一對多”挑戰人類律師，不到10秒審近百行合同文書，準確率96% | 機器之心
# 3   快手聯手英特爾提升 KGNN 平臺大規模實時動態圖訓練效率 | 機器之心
# 4   因應後疫新常態數位爆量新挑戰，Line發布2021技術新戰略 | iThome
# 5   LG 計劃外包更多低階和中階手機
# 6   Apple 的 2021 年 Mac 晶片中可能包含 32 核心的產品
# 7   apple one營收比重估達85%！分析師：可能推出軟硬體結合的訂閱服務｜數位時代
# 8   Google Authenticator 新增匯出帳戶功能，可將資料移轉到新手機
# 9   您與孩子使用的Apps正被祕密監控中！國際版「360兒童手錶」後門偷窺事件 - The News Lens 關鍵評論網
# 10   Bose 新型真無線運動耳機通過 FCC 認證，無耳塞式外觀構造曝光 | T客邦
# 11   傳三星 Galaxy S21+ 將提前到一月發表，外型可能長這樣 | T客邦
# 12   人口1.5億的電商市場，該怎麼打？阿里巴巴善用4大策略，讓戰鬥民族買到剁手-風傳媒
# 13   你的iPhone 11觸控螢幕也卡卡？趕快送去蘋果，可以免費修理！-風傳媒
# 14   遠傳助攻桃園下水道智慧監測系統，獲雲端物聯網創新獎 | T客邦
# 15   聯電漲價，10檔受惠股出線！年底半導體大搶貨，輪到8吋晶圓產能吃緊-風傳媒
# 16   蘋果、三星、華為都發表自製晶片，5nm之爭還要比「跑分」嗎？｜數位時代
# 17   瀏覽網頁覺得無聊、煩悶嗎？讓「Laser Cat」幫你把網頁內容全都清空！ （Google Chrome 擴充套件） – 重灌狂人
# 18   斥資千萬深耕區塊鏈！新加坡政府：望促進應用商業化 - 區塊客
# 19   渣打銀行 CEO：數位貨幣普及化是「必然趨勢」 - 區塊客
# 20   GU網路商店特別企劃12月7日正式開跑，話題聯名哈利波特、PlayStation再次回歸 | 哈利波特、GU、網路商店 | 品牌新聞 | 妞新聞 niusnews
# 21   傳 AirPods 3 將於 2021 三月發表，外觀將有較大的改變 - 蘋果仁 - iPhone/iOS/好物推薦科技媒體
# 22   卯起來套現｜瑞波共同創辦人 Jed McCaleb 單日再拋售近 3,000 萬 XRP | 動區動趨-最具影響力的區塊鏈媒體 (比特幣, 虛擬貨幣)
# 23   Google Home / Nest 智慧喇叭開始支援 Apple Music - 電腦王阿達
# 24   臺積電ADR覈算市值已經超過巴菲特的波克夏 5517億美元全球第九企業 #超越波克夏 (158490) - 癮科技 Cool3c
# 25   蘋果未來可能推出結合軟硬體產品的訂閱方案 iPhone、Mac、Apple Watch 都能每年舊換新 #Google (158486) - 癮科技 Cool3c
# 26   Uber 自動駕駛技術發展業務以低於市值的 40 億美金賣給新創Aurora Innovation #自駕車 (158487) - 癮科技 Cool3c
# 27   傳蘋果將在 2021 年推出 20 核心 Apple Silicon 、 2022 年推出 32 核心版本 #CPU (158488) - 癮科技 Cool3c
# 28   Bobii Box 開箱動手玩：臺灣最強 OTT 影音播放盒，超強大 AI 語音搜尋功能，想看什麼影片？想唱KTV？動口就搞定！ - 電腦王阿達
# 29   LG 將只專注開發高階手機 中階、入門手機將授權外部廠商貼牌推出 (158482) - 癮科技 Cool3c
# 30   Google、三星合作的自製處理器命名「Whitechapel」 最快 2021 年推出 #Pixel (158483) - 癮科技 Cool3c
# 31   Google 公佈 12 月更新內容，多個 Pixel 5 特色功能都下放到 Pixel 3 以上的舊機種 - 電腦王阿達
# 32   現金花完還不夠！MicroStrategy 將出售 4 億美元「可轉換公司債」，用來購買比特幣 | 動區動趨-最具影響力的區塊鏈媒體 (比特幣, 虛擬貨幣)
# 33   鏈上觀鯨｜a16z 、Alameda、Vitalik 等大戶都買了哪些幣？ | 動區動趨-最具影響力的區塊鏈媒體 (比特幣, 虛擬貨幣)
# 34   史上第一次！蘋果頒發實體獎牌給年度最佳 App 得主 - 蘋果仁 - iPhone/iOS/好物推薦科技媒體
# 35   Surface Pro X 要緊張了！M1 版 Mac 執行 Windows 作業系統跑分贏很多 - 蘋果仁 - iPhone/iOS/好物推薦科技媒體
# 36   Moyashi：家與辦公室的距離 - *CUP
# 37   DeepMind 又贏：AlphaFold 深度學習 AI 預測蛋白質結構 - *CUP
# 38   德國｜私人銀行 H&A 獲監管首肯，下月發行面向機構的「加密貨幣基金」 | 動區動趨-最具影響力的區塊鏈媒體 (比特幣, 虛擬貨幣)
# 39   Memoji 聖誕裝扮操作教學，聖誕帽、紅色口罩這樣玩！ - 電腦王阿達
# 40   北京市政府批准  百度自動駕駛車輛路面實測 - 香港 unwire.hk
# 41   慶祝創辦 85 週年  潮牌 Porter 推 Casio G-Shock 別注版 - 香港 unwire.hk
# 42   鐵人三項》彰化順澤宮神帽再發威 艾登職業鐵人冠軍賽掄元 - 最新體育新聞，即時比分，賽程和戰績 | FOX體育臺
# 43   寶可夢訓練家集合！全家門市開賣 3 款皮卡丘手機周邊　AirPods 絨毛收納包超搶手
# 44   [Soft & Share 會員服務] 文章選讀 022 創業公司中的線粒體/ 科學研究說 10 分鐘點心式運動就足夠了 - Soft & Share 線上課程資訊分享
# 45   iPhone 11 螢幕觸控不良如何查詢與更換？蘋果提供免費換修服務，你有符合資格嗎？ :: 哇哇3C日誌
# 46   上啊神奇寶貝！Anker 寶可夢皮卡丘聯名 30W 充電器套裝開箱分享！ @3C 達人廖阿輝
# 47   背景神祕的 Ravn X 是一架能發射衛星的無人機
# 48   iPhone 11 屏幕維修計劃：觸控有問題？Apple 免費換！ | Qooah
# 49   Nokia C1 Plus 已經曝光，工信部+ Network.it 齊齊爆料 | Qooah
# 50   AI倫理研究者Timnit Gebru因論文爭議被迫離開Google，員工與學術界串連數千人討公道 | iThome
# 51   勒索軟體歹徒找客服打電話給不想付錢的受害企業 | iThome
# 52   安全研究人員：採用T2晶片的Mac無法在離線狀態下重置，危害用戶安全及隱私 | iThome
# 53   5份精選報告：274家樣本刻畫中國企業數字化羣像，近三分之一傳統企業困於路徑依賴 | 機器之心
# 54   Nature：AI的瓶頸突破在於「實體人工智能（PAI）」 | 機器之心
# 55   集成光電，機器編程：英特爾一次放出五大新技術 | 機器之心
# 56   標題：安謀中國首款ISP處理器“玲瓏”面世，IP產品線逐漸完善 | 機器之心
# 57   蘋果開放iOS程式內購買分享給家人 | iThome
# 58   Chrome 86安全性提升，造成Google字型顯示問題 | iThome
# 59   Google Play函式庫漏洞可使Android App遭惡意程式注入 | iThome
# 60   造車行業百年未有變局之下，一個「老玩家」開始了自己的趕超 | 機器之心
# 61   性能提升30%以上，實時實例分割算法SOLOv2實現產業SOTA | 機器之心
# 62   狂攬2500星，開源十六進制編輯器登頂GitHub熱榜 | 機器之心
# 63   Adam真的是最好的優化器嗎？有人認爲不過是神經網絡進化的結果 | 機器之心
# 64   BEC電子郵件詐騙攻擊事件出現新手法，駭客竄改網頁信箱自動轉寄政策來收集情資，企業偵測機制可能難以察覺 | iThome
# 65   京東成為首個開始測試數位人民幣的線上購物平臺
# 66   Oppo 申請了一項可拆式手機相機的專利
# 67   中國 AutoX 全自動駕駛車隊開始運作　未知何時可以載客服務 - 香港 unwire.hk
# 68   中國蘇州派 2,000 萬數碼人民幣  京東成首個數碼人民幣網購平臺 - 香港 unwire.hk
# 69   市區自動輔助駕駛入列？特斯拉年末升級新方案登場 | 車壇速報 | 國內車訊 | 發燒車訊
# 70   iOS 14.2 傳出耗電災情：半小時就下滑近 50% 電力 - 蘋果仁 - iPhone/iOS/好物推薦科技媒體
# 71   【狂人日記】高位震盪何時了，等待月線均線上。12 月 7 日行情分析 - 區塊客
# 72   社羣廣告不夠看！揭開球鞋品牌業績成長280%的祕密｜數位時代
# 73   Uber落地成境內公司，即日起免海外刷卡手續費！還要靠什麼找回消費者？｜數位時代
# 74   天成醫療首度導入微軟HoloLens2，突破遠距醫療障礙、真的能「隔空抓藥」？｜數位時代
# 75   丹麥風電商CIP曝6處新離岸風場計畫，CEO為何倡議推浮動式風機？｜數位時代
# 76   LINE MUSIC登臺逾一年，成績不如預期⋯ 結盟中華電卻只做「來電答鈴」？｜數位時代
# 77   Steam 電子發票載具歸戶教學，買電腦遊戲也可自動對獎
# 78   《創客創業導師程天縱的職場力》：「我今天賺到自己的薪水了沒？」從職涯第一天到最後一天的自省 - The News Lens 關鍵評論網
# 79   中國電商推「著西裝、戴白手套捧盒子」高級送貨服務，網友笑稱「葬禮級的隆重」 | T客邦
# 80   野生保育、盜獵者、動物保護區⋯⋯這些「動保」相關詞彙的英文怎麼說？ - The News Lens 關鍵評論網
# 81   參考新加坡經驗，國民住宅在臺灣的發展歷經四個階段 - The News Lens 關鍵評論網
# 82   曾是山寨手機代名詞的「深圳華強北」，現在正在轉型賣美妝 | T客邦
# 83   Razer 新一代真無線耳機Hammerhead True Wireless Pro發表，支援主動降噪與遊戲低延遲 | T客邦
# 84   iPhone XS、iPhone 7等舊手機更新iOS 14.2傳災情，半小時電池消耗50% | T客邦
# 85   「英國脫歐獸」出現示警：脫歐緩衝期剩1個月，貿易談判仍卡關 - The News Lens 關鍵評論網
# 86   臺鐵瑞芳猴硐段未搶通，林佳龍：東部幹線預估13日恢復雙向通車 - The News Lens 關鍵評論網
# 87   微軟將透過 Windows Feature Experience Pack 提供更多實驗性功能 | T客邦
# 88   存股族注意，銀行股明年可能不配現金股利！金管會主委：「有考量，但還沒決定」-風傳媒
# 89   開會摸魚？微軟新專利透過臉部辨識，評判開會時的注意力和感到無聊的程度 | T客邦
# 90   分析師爆料，全新外型設計且搭載 Mini LED 螢幕的 MacBook Pro 將在明年登場 | T客邦
# 91   華爾街日報》美國緊縮審計法規，趕中概股回家？阿里巴巴早就揭開中概股回歸大幕-風傳媒
# 92   第三階段開發風電商各顯神通　CIP拋浮動式風機國產化當「誘餌」？-風傳媒
# 93   替「劊子手」劉銘傳拍攝紀錄片統戰臺灣，凸顯了中共破綻百出的大一統史觀 - The News Lens 關鍵評論網
# 94   防止硬體路上被掉包、植入間諜軟體，Dell提供伺服器、PC安全防護工具 | iThome
# 95   AWS推出工業用機器學習解決方案Amazon Monitron，可監控設備狀態預測故障 | iThome
# 96   全球Top 40的人工智能英文媒體「Synced」，瞭解一下 | 機器之心
# 97   第六代高通AI引擎、跨平臺統一API人人可用，驍龍888不止於芯片 | 機器之心
# 98   大幅提升訓練性能，字節跳動與清華提出新型分佈式DNN訓練架構 | 機器之心
# 99   NLP攜手Transformer跨界計算機視覺！DETR：目標檢測新範式 | 機器之心
# 100   不用綠幕也能實時摳圖，商湯等提出只需單張圖像、單個模型的新方法MODNet | 機器之心
# 101   一週大事：樂天純網銀App介面首度曝光。中鋼AI應用落地靠三大祕訣 | iThome
# 102   近 4 年全靠比特幣過活！一家 5 口竟還能暢遊 40 國  - 區塊客
# 103   「數位人民幣」最新進展：蘇州大撒紅包、首支援網購、香港開測跨境支付 - 區塊客
# 104   [ZKP 讀書會] Zkopru. Zkopru | by NIC Lin | Taipei Ethereum Meetup | Dec, 2020 | Medium
# 105   穩定幣在牛市中大放異彩！USDT 今年市值增長近 4 倍 - 區塊客
# 106   史丹佛金融專家：比特幣是目前最佳投資機會 - 區塊客
# 107   首款5k Retina iMac 列入老舊設備，包含部分過時產品仍可享延長服務 - 蘋果仁 - iPhone/iOS/好物推薦科技媒體
# 108   比特幣普及不如預期？分析：全球人口僅 1.7% 持有 - 區塊客
# 0 個專案 – HTML, CSS & JavaScript - Soft & Share 線上課程資訊分享
# 110   Samsung 正研發 6億像素 CMOS，超越人眼極限 | Qooah
# 111   專家教你保／投保失智險 減輕照護負擔 | 銀行保險 | 理財 | 經濟日報
# 112   Nokia 5.4 現身 FCC，整體設計已經曝光 | Qooah
# 113   Fitbit 將免費更換部分有潛在心電圖問題的 Sense 手錶
# 114   小米擊敗蘋果登全球手機三哥、2021年目標賣破3億支！它憑什麼如此樂觀？｜數位時代
# 115   【漫畫】未審先「囚」 - The News Lens 關鍵評論網
# 116   投資比特幣、P2P網路借貸等新興金融商品，務必知道背後的風險 - The News Lens 關鍵評論網
# 117   新藥歐洲銷售旺 藥華藥11月營收較上月成長四倍，再創新高-風傳媒
# 118   善用Windows內建「自黏便箋」，追蹤或提醒待辦事項 | T客邦
# 119   金融科技創新論壇：疫情推快了金融科技創新進程-風傳媒
# 120   小資男女的紅酒筆記本 APP 推薦，以介紹臺灣賣場可入手葡萄酒為主
# 121   Epson投影科技與AR智慧眼鏡，為未來教育環境超部署 | T客邦
# 122   三星或將為 Galaxy Z Flip 5G 帶來「神祕白」新色 - SayDigi | 點子生活
# 123   WeMo Scooter 推 2020 年度回顧 – 12 星座 “機車” 排行榜! - SayDigi | 點子生活
# 124   中國 AutoX 全自動駕駛車隊開始運作　未知何時可以載客服務 - 香港 unwire.hk
# 125   NVIDIA 發表自我調整判別器增強技術，使 AI 以較少影像數量訓練可產生越級成果 #GaN (158476) - 癮科技 Cool3c
# 126   XDown 2.0.0.8 免安裝中文版 - 檔案及BT下載工具 百度網盤下載器        -         阿榮福利味 - 免費軟體下載
# 127   中國數位人民幣將可在京東商城線上購物 與支付寶、微信支付競爭市場 #wechat pay (158480) - 癮科技 Cool3c
# 128   《創智贏家》投資實境秀｜裁判奧利裏：我願意配置5%投資組合給「加密貨幣ETF」 | 動區動趨-最具影響力的區塊鏈媒體 (比特幣, 虛擬貨幣)
# 129   Google 被控不當解僱人工智慧部門主管 多元包容性再受質疑 #性騷擾 (158479) - 癮科技 Cool3c
# 130   臉書、推特用力打川普卻幫中國..郭文貴揭兩大社羣媒體助攻北京的真正目的 | 信傳媒
# 131   「Instagram Academy」落戶香港　　目標培育 300 名年青企業家 - UNWIRE.PRO
# 132   密碼學專家 Adam Back：「bits」更好！應把比特幣現行最小面額「聰」取代掉 | 動區動趨-最具影響力的區塊鏈媒體 (比特幣, 虛擬貨幣)
# 133   Google Play 商店應用也不安全，許多 Android 應用程式還在用過時版本核心庫 - 電腦王阿達
# 134   效法《玩命關頭》演出，英國飛車搶案劫走 PS5 主機、智慧型手機等高價貨物 :: 遊戲基地 gamebase
# 135   知名動漫歌手 May'n 擔任 QoA 新耳機 Adonis 代言，採混合三單體通用耳機 #超時空要塞 (158474) - 癮科技 Cool3c
# 136   iPhone 12 mini、iPhone 12 / 12 Pro 與 iPhone 12 Pro Max 該買多少瓦數的 PD 充電器？這篇實測為你解答 - 電腦王阿達
# 137   DeFi市場回顧｜11月因「BTC吸血行情」跌宕起伏；4 個新項目值得關注 | 動區動趨-最具影響力的區塊鏈媒體 (比特幣, 虛擬貨幣)
# 138   DCEP｜香港金管局總裁：正在和中國央行商討數位人民幣「跨境支付測試」 | 動區動趨-最具影響力的區塊鏈媒體 (比特幣, 虛擬貨幣)
# 139   小米米家螢幕掛燈通過 NCC 認證，近期有望在臺開賣 - 電腦王阿達
# 140   新款 Pixel 手機現身？國外大神爆料一款名叫 Google Pixel XE 的間諜照 - 電腦王阿達
# 141   博韻音響即日起代理荷蘭品牌Mola Mola – MY-HiEND
# 142   Tesla 發狠對 EAP 自動駕駛用戶祭出升級 FSD 降價，直降 1,000 美元（臺灣價格公佈） - 電腦王阿達
# 143   中國蘇州以「2000萬數位人民幣紅包」迎接雙12！首次開放「京東商城」線上消費 | 動區動趨-最具影響力的區塊鏈媒體 (比特幣, 虛擬貨幣)
# 144   Wiily Woo：比特幣明年將站上 20 萬美元！他給出兩個關鍵看漲理由 | 動區動趨-最具影響力的區塊鏈媒體 (比特幣, 虛擬貨幣)
# 145   Grayscale高管: 今年看到大批「以太坊優先」投資者；ETH信託11月日均交易量創新高 | 動區動趨-最具影響力的區塊鏈媒體 (比特幣, 虛擬貨幣)
# 146   「iMood」手繪塗鴉風表情符號心情日記（iPhone, iPad） – 重灌狂人
# 147   世界新局｜拜登下月欲再推「新紓困案」、歐洲央行擴大寬鬆，比特幣成新避險資產？ | 動區動趨-最具影響力的區塊鏈媒體 (比特幣, 虛擬貨幣)
# 148   你絕對做得到的待辦清單！The Least Dangerous To-Do List（iPhone, iPad） – 重灌狂人
# 149   未來的暗殺都不靠人 伊朗核子科學家被AI透過衛星遙控的機槍殺害 #人工智慧 (158469) - 癮科技 Cool3c
# 150   國外傳多款 iPhone 型號升級到 iOS 14.2 後，電池很快就沒電 - 電腦王阿達
# 151   YFI 托拉斯宇宙？Andre Cronje 主導的「合併」項目均大幅上漲 | 動區動趨-最具影響力的區塊鏈媒體 (比特幣, 虛擬貨幣)
# 152   【MICA RESEARCH】金融與投資機構正在加速擁抱加密貨幣 - 區塊客
# 153   一張圖告訴你，平均工作幾天才買得起 iPhone - 蘋果仁 - iPhone/iOS/好物推薦科技媒體
# 154   加密巨頭搶攻大宗經紀業務，Genesis執行長：明年將有250家上市公司追隨MicroStrategy | 動區動趨-最具影響力的區塊鏈媒體 (比特幣, 虛擬貨幣)
# 155   臺南翻轉1》從古都到全臺產經重鎮 臺積電撐起南科 照亮府城經濟半邊天 | 信傳媒
# 156   十分鐘知天下 2020/12/6-7 | 民報 Taiwan People News
# 157   網購非年輕人專利  淘寶中國推省心版吸長者客 - 香港 unwire.hk
# 158   傳明年 1 月發表  Galaxy Buds Pro 再有新色流出 - 香港 unwire.hk
# 159   免費的 Auto Office L1 系統單機版，提高公司運作效率以達到降低成本 - 電腦王阿達
# 160   2020成長駭客年會告一段落，臺灣行銷科技、工具應用與發展才正要百花齊放 – 看見數據
# 161   Chrome 擴充快速鍵與實用快捷鍵，學會了就是比其他人快上一步 :: 哇哇3C日誌
# 162   Google Chrome 87 教你如何開啟「自動創建分頁羣組標籤」功能！ :: 哇哇3C日誌
# 163   ．藉助 5G 技術應對 COVID-19 大流行 - 3S Market「全球智慧科技應用」市場資訊網
# 164   ．四大環節保駕護航，物聯網安全問題能否被擊破？ - 3S Market「全球智慧科技應用」市場資訊網
# 165   【狂人日記】鯨魚持續出貨，下週機構接得住嗎？12 月 6 日行情分析 - 區塊客
# 166   安心出行？表列比較各地的健康追蹤程式 - *CUP
# 167   經典與未來的完美結合！Moto razr 5G 摺疊機開箱實測（開箱/性能/電力/拍照實測） @3C 達人廖阿輝
# 168   我從高級開發者身上學到的19條編碼原則 | 機器之心
# 169   2020啓智開發者大會聚焦深度學習，百度飛槳多措並舉助力全球開發者 | 機器之心
# 170   娛樂內容+5G! Line與中華電信聯手推Line Music鈴聲答鈴服務 | iThome
# 171   百分點認知智能實驗室：基於知識圖譜的問答技術和實踐 | 機器之心
# 172   當勒索軟體與資料外洩合流 | iThome
# 173   駭客正針對包括臺灣在內的全球疫苗冷鏈供應鏈展開網釣攻擊 | iThome
# 174   潘建偉、陸朝陽團隊實現量子優越性：原型機「九章」登上Science，速度超谷歌百億倍 | 機器之心
# 175   收購Arm，推出80G超級A100：2020年，英偉達還有一招沒出 | 機器之心
# 176   新型輸電線巡檢路徑決定算法，助力無人機巡檢，明略等獲ASEM最佳論文 | 機器之心
# 177   不懼噪音環境、提升樣本效率，華爲雲等最新強化學習成果入選NeurIPS 2020 | 機器之心
# 178   亞太地區學術頂會AACL2020如期而至，百度頻頻「現身」發揮重要助力 | 機器之心
# 179   2萬字深度調查：2020年美國50座城市的數字化樣本 | 機器之心
# 180   【VSA】One-shot video-based person re-identification with | 機器之心
# 181   輕舟智航與華礪智行合作打造的5G+V2X無人公交方案首次在廣州亮相 | 機器之心
# 182   破解數據安全和信任難題！索信達控股正式推出自研區塊鏈+聯邦學習平臺方案 | 機器之心
# 183   【PSMA】Progressive Sample Mining and Representation Learning for | 機器之心
# 184   Google即將關閉3D物件市集Poly | iThome
# 185   ACLU要求國土安全部提供購買手機位置資訊以追蹤移民的紀錄 | iThome
# 186   Mac用戶當心！APT駭客組織鎖定macOS用戶植入後門，多數防毒軟體尚無法偵測相關行為 | iThome
# 187   2020 NeurIPS MeetUp全日程公佈，這是一場充實的學術之旅 | 機器之心
# 188   2020 AWS re:Invent大會開幕，新一代機器學習定製訓練芯片Trainium面世 | 機器之心
# 189   俄羅斯駭客以全新Crutch木馬來滲透歐盟國家 | iThome
# 190   Oracle WebLogic已知RCE漏洞遭殭屍網路病毒積極鎖定 | iThome
# 191   Fintech周報第165期：臺壽保產險年底將推碎片化保險，車體險1天也能保 | iThome
# 192   可微圖學習&弱監督，中山大學提出新型行人重識別方法和史上最大最新評測基準 | 機器之心
# 193   被開源綁架的開源項目開發者 | 機器之心
# 194   開發者數量2025年預計破億，TypeScript受歡迎度飆升：GitHub最新年度報告 | 機器之心
# 195   預訓練圖像處理Transformer：華爲諾亞、北大等提出IPT模型，刷榜多項底層視覺任務 | 機器之心
# 196   Visa將與Circle合作發行USDC加密貨幣信用卡 | iThome
# 197   工程機械無人化需求凸顯，百度盤古助力工業生產智能化升級 | 機器之心
# 198   Google新作：注意力機制是否真的能夠提供模型的可解釋性？ | 機器之心
# 199   NeurIPS 2020 | 微軟亞洲研究院論文摘錄之目標檢測篇 | 機器之心
# 200   【防止未授權存取與資料外洩】公有雲檔案儲存的存取管制與加密功能 | iThome
# 201   【新興的公有雲平臺NAS檔案儲存服務】公有雲檔案儲存服務的型態與類型 | iThome
# 202   中央大學展示無人機居家照護應用，可協助遠端照護跌倒親人 | iThome
# 203   資安一週第122期：研華科技表明攻擊事件可能有資料外洩情事。Sophos因系統組態不當導致用戶資料曝險 | iThome
# 204   Project Zero安全研究人員展示如何攻陷iOS裝置，執行任意程式並存取裝置資料 | iThome
# 205   Libra協會更名為Diem協會，可望於明年發行加密貨幣 | iThome
# 206   阿里AI慧眼識廢鋼，95%準確率堪比老師傅 | 機器之心
# 207   告別渣畫質，視頻會議帶寬降90%，英偉達公開Maxine服務背後重要技術 | 機器之心
# 208   十行代碼就能搞定深度學習？飛槳框架高層API，一起輕鬆玩轉AI | 機器之心
# 209   驍龍888，高通新一代旗艦芯片正式出爐：小米11將全球首發 | 機器之心
# 210   Google Maps新增社羣回饋功能 | iThome
# 211   遭到勒索軟體攻擊，巴爾的摩學區被迫關閉 | iThome
# 212   使用機器學習加速對非結構化數據的查詢-第1部分（使用BlazeIt加速聚合和限制查詢） | 機器之心
# 213   事件間因果關係方向數據調研 | 機器之心
# 214   誠品朝全通路再進一步，推出新電商串連實體店，要成為明年新社區店型的虛擬2樓 | iThome
# 215   比特幣價格創下19,900美元的新高紀錄 | iThome
# 216   疫情重構經濟，傳統企業「數字化」的通關密碼是什麼？ | 機器之心
# 217   一場屬於蓉城的“鮮香”盛宴，DevRun開發者沙龍邀您開啓“麻辣”開發之旅 | 機器之心
# 218   模型聽人講幾句就能學得更好？斯坦福提出用語言解釋輔助學習 | 機器之心
# 219   頂會paper越來越多，我該怎麼看？ | 機器之心
# 220   GNN、RL強勢崛起，CNN初現疲態？這是ICLR 2021最全論文主題分析 | 機器之心
# 221   「它將改變一切」，DeepMind AI解決生物學50年來重大挑戰，破解蛋白質分子摺疊問題 | 機器之心
# 222   讓AI再次升級：更快、更精確、更節能光驅納米芯片問世！助力無人機、可穿戴設備和仿生植入物等領域 | 機器之心
# 223   性能與輕薄的完美結合，拯救者9000X 2021今日震撼發佈 | 機器之心
# 224   人工智能中國專利技術分析報告發佈，百度三年蟬聯榜首 | 機器之心
# 225   單模型史上最佳成績，騰訊微視BLENDer模型登頂權威榜單VCR | 機器之心
# 226   除了雲計算和5G，未來之城還缺哪個「基礎設施」？ | 機器之心
# 227   官宣！邢波出任全球首個AI大學校長，MBZUAI明年1月迎來首批新生 | 機器之心
# 228   AWS偏愛Rust，已將Rust編譯器團隊負責人收入囊中 | 機器之心
# 229   百度研究院EMNLP 2020精選論文解讀 | 機器之心
# 230   CAAI理事長戴瓊海院士《人工智能幾點思考——算力、算法、測試》 | 機器之心
# 231   重提大一統？微軟被曝開發原生運行安卓App的Win10系統，最早明年見 | 機器之心
# 232   六項任務、多種數據類型，谷歌、DeepMind提出高效Transformer評估基準 | 機器之心
# 233   王者榮耀AI絕悟完全體對戰開啓：英雄隨便選，論文已被NeurIPS收錄 | 機器之心
# 234   家裏沒有王位繼承？沒關係，有人用AI打造了一個童話魔法世界 | 機器之心
# 235   二分類、多分類、迴歸任務，一個項目get競賽必備模型 | 機器之心
# 236   人工智能和自然智能能否交匯？李飛飛對話斯坦福神經生物學教授Bill Newsome | 機器之心
# 237   要不要讀博？機器學習博五學生和強化學習博士展開了一場battle | 機器之心
# 238   誰卡住了工業AI的脖子？ | 機器之心
# 239   第四範式NeurIPS 2020：知識圖譜嵌入的自動化 | 機器之心
# 240   3D視覺：一張圖像如何看出3D效果？ | 機器之心
# 241   124頁哈佛數學系本科論文，帶你瞭解流形學習的數學基礎 | 機器之心
# 242   下一代機器學習的應走之路 | 機器之心
# 243   AI生成中國山水畫！普林斯頓姑娘本科畢業作品，線條筆觸騙過半數人類觀察者 | 機器之心
# 244   又一次！AI「擊敗了」人類，自學習AI算法發現高性能材料，未來遠程科研或成現實 | 機器之心
# 245   萬家民企、每年4億「嫁妝」：蘇南製造「騰雲」換鳥 | 機器之心
# 246   魁北克大學教授痛批雙盲評審制度：這不是個好主意 | 機器之心
# 247   3D視覺CV界的終極體現形式，計算機如何「看」這個三維世界 | 機器之心
# 248   Python3.10第二個alpha版本來了！最新特性值得關注 | 機器之心
# 249   不到1000行代碼，GitHub 1400星，天才黑客開源深度學習框架tinygrad | 機器之心
# 250   交大資工研究團隊發表AIoT溫控生產預測技術，以AI取代人工量溫調整，改善PCB的SMT生產品質 | iThome
# 251   NeurIPS 2020 | 百裏挑一：如何加速超網訓練的收斂和搜索速度 | 機器之心
# 252   這可能會引領通用AI的下一個重大突破 | 機器之心
# 253   一篇文章7.4萬，Nature 33種期刊開放獲取新政引爭議，社區斥其「寄生蟲」 | 機器之心
# 254   精選報告：五份報告、雙重視角把脈企業數字轉型指數、路徑與方向 | 機器之心
# 255   突破AI和機器理解的界限，牛津CS博士143頁畢業論文學習重建和分割3D物體 | 機器之心
# 256   微分方程VS機器學習，實例講解二者異同 | 機器之心
# 257   李宏毅強化學習完整筆記！開源項目《LeeDeepRL-Notes》發佈 | 機器之心
# 258   基於數值數據理解和重要信息驗證的數據到文本生成模型 | 機器之心
# 259   清華大學智能產業研究院張亞勤：我們已經進入數字化3.0階段 | 機器之心
# 260   這顆模擬AI芯片將開啓新紀元？ | 機器之心
# 261   圖像分類：來自13個Kaggle項目的經驗總結 | 機器之心
# 262   文遠知行Robotaxi全對外開放運營一週年，聯手清華大學交通研究所發佈中國首份Robotaxi乘客調研報告 | 機器之心
# 263   烏鎮世界互聯網大會百度CTO王海峯談創新發展：人工智能是新動能 | 機器之心
# 264   小冰宣佈與微軟達成戰略合作：Pre A輪融資結束，三大行業解決方案上線 | 機器之心
# 265   華爲搶佔5G先機背後：一位科學家和他的二十年「冷板凳」 | 機器之心
# 266   瀏覽器中實現深度學習？有人分析了7個基於JS語言的DL框架，發現還有很長的路要走 | 機器之心
# 267   撥開「短視頻第一股」的外表，我們看見了一家強悍的「科技公司」 | 機器之心
# 268   谷歌搜索：幾乎所有的英文搜索都用上BERT了 | 機器之心
# 269   1.8M超輕量目標檢測模型NanoDet，比YOLO跑得快，上線兩天Star量超500 | 機器之心
# 270   NeurIPS 2020 | AWS Auto-Aug: 利用權重共享思想的新型自動數據增強方法解讀 | 機器之心
# 271   用歸納偏置來增強你的模型性能 | 機器之心
# 272   COLING 2020 | 字符感知預訓練模型CharBERT | 機器之心
# 273   智能製造企業還在受困數字化轉型？不妨試試生態系統打法 | 報告解讀 | 機器之心
# 274   皺眉細節完美復刻，阿爾伯塔大學團隊標星1.7K的項目生成超逼真的肖像畫 | 機器之心
# 275   7天8卡訓練32種語言，字節跳動推出多語言預訓練新範式mRASP | 機器之心
# 276   提高方面級情感分析的性能：一種結合詞彙圖和句法圖的方法 | 機器之心
# 277   每天調用達80億次的小米MiNLP平臺，近期又開源了中文分詞功能 | 機器之心
# 278   「無落地，不科技」，聯想創投成員企業探討To B科技賽道的商業化落地 | 機器之心
# 279   深度學習“壟斷”！分析17萬篇AI頂會論文，他們首次揭示了計算資源貧富分化的證據 | 機器之心
# 280   影譜科技完成新一輪增資，國資委基金再加碼 | 機器之心
# 281   利用CodeBERT，這個VS Code擴展可以自動生成Python文檔字符串 | 機器之心
# 282   熱門的模型跨界，Transformer、GPT做CV任務一文大盤點 | 機器之心
# 283   入冬後的第一場技術盛宴！DevRun開發者沙龍華爲雲武漢專場成功舉辦 | 機器之心
# 284   Cloud周報第88期：臺灣行動網速全球排名上升至第19，但固網排名僅24名 | iThome
# 285   演繹數智加速度，洞見2021中國企業服務年會盛大召開 | 機器之心
# 286   10萬字節跳動員工都在用的辦公協同軟件，如何配得上這個時代？ | 機器之心
# 287   張亞勤：深度學習更近一步，如何突破香農、馮諾依曼和摩爾瓶頸？ | 機器之心
# 288   騰訊造「國產」機器狗，花式走梅花樁 | 機器之心
# 289   51WORLD地球克隆計劃4啓動：次時代數字孿生平臺發佈，成熟生態賦能行業 | 機器之心
# 290   CoRL 2020獎項公佈，斯坦福獲最佳論文獎，華爲等摘得最佳系統論文獎 | 機器之心
# 291   COLING 2020 | CharBERT：字符敏感的預訓練語言模型 | 機器之心
# 292   正式商用一週年，5G給我們生活帶來了什麼變化？ | 機器之心
# 293   Google Cloud Armor服務以機器學習防禦第7層DDoS攻擊 | iThome
# 294   在推薦系統中，我還有隱私嗎？聯邦學習：你可以有 | 機器之心
# 295   UC伯克利摘最佳論文、Hugging Face獲最佳demo，EMNLP 2020獎項公佈 | 機器之心
# 296   NeurIPS 2020 | AI編程：如何從復制粘貼走向推理合成 | 機器之心
# 297   秒變機器人！中國科學家發明磁性噴霧劑，簡單噴一噴即可快速“製造”機器人，已在生物醫學領域初步應用 | 機器之心
# 298   歷經三次IT大改造優化工地管理，瑞助下一步是挑戰智慧營造 | iThome
# 299   大人，時代變了：敏捷DevOps、低代碼、微服務的正確打開姿勢都在這兒了 | 機器之心
# 300   聯邦學習 OR 遷移學習？No，我們需要聯邦遷移學習 | 機器之心
# 301   人像摳圖已經滿足不了研究者了，這個研究專門給動物摳圖，毛髮根根分明 | 機器之心
# 302   NeurIPS 2020全程線上，但北京有一場官方線下MeetUp邀你參與 | 機器之心
# 303   機器學習平臺MLflow 1.12開始整合PyTorch | iThome
# 304   受益政策紅利！國產AI芯加速崛起 | 機器之心
# 305   Findings | 中文預訓練語言模型回顧 | 機器之心
# 306   人工智能先鋒人物傑夫·辛頓說：“深度學習將無所不能” | 機器之心
# 307   帶你讀論文 | 端到端語音識別模型 | 機器之心
# 308   關於中文預訓練模型泛化能力挑戰賽的調研 | 機器之心
# 309   國產品牌商用計算機新勢力，紫光計算機推Unis新品助力中國企業數字轉型 | 機器之心
# 310   阿里雲天池人工智能大賽：PAI-DSW中使用EasyTransfer快速搭建比賽Baseline | 機器之心
# 311   AMD發表目前最快HPC GPU，FP64運算效能突破10 TFLOPS | iThome
# 312   政府全資接盤武漢弘芯項目，繼續盤活難度大 | 機器之心
# 313   論壇全程回顧5：TCL實業副總裁何軍分享《新基建時代的製造業大數據價值變現》 | 機器之心
# 314   26億參數，智源、清華開源中文大規模預訓練模型 | 機器之心
# 315   深度學習搞起來！對標英偉達Tensor Core，AMD推出Matrix Core | 機器之心
# 316   沈向洋博士：三十年科研路，我踩過的那些坑 | 機器之心
# 317   奪魁NeurIPS 2020電網調度大賽，百度PARL實現NeurIPS強化學習競賽三連冠 | 機器之心
# 318   論壇全程回顧4：郭毅可院士作主題演講《不求讓機器做的多，但求要機器做的對》 | 機器之心
# 319   關係重疊？實體嵌套？曝光偏差？這個模型統統都搞得定！ | 機器之心
# 320   清華大學施路平：雙腦驅動的人工通用智能 | 機器之心
# 321   那個屠榜的T5模型，現在可以在中文上玩玩了 | 機器之心
# 322   改善僞影，這種插幀新方法讓視頻更絲滑，網友：我的PS 2能玩4K遊戲了嗎？ | 機器之心
# 323   雙十一剛過，你的手還好嗎？這些Colab技巧幫你愉快地薅谷歌羊毛 | 機器之心
# 324   SpaceX首次正式載人航天任務發射成功，助力美國重回太空 | 機器之心
# 325   Python正在慢慢褪色 | 機器之心
# 326   機器人是怎麼知道如何抓握杯子的？ | 機器之心
# 327   EMNLP 2020 | 微軟亞洲研究院精選論文解讀 | 機器之心
# 328   無需用戶輸入，Adobe提出自動生成高質量合成圖像新方法 | 機器之心
# 329   手殘黨福音：不會摘隱形眼鏡？這個機器人可以幫你 | 機器之心
# 330   英偉達RTX 3080值不值得搶？有人用它在TensorFlow上訓練了卷積網絡 | 機器之心
# 331   PyTorch現可在Android裝置利用硬體加速機器學習運算 | iThome
# 332   從末端配送到全場景賦能，坎德拉科技舉辦2020新品發佈 | 機器之心
# 333   高通獲許可供貨華爲，但僅限部分4G芯片 | 機器之心
# 334   CCKS 2020「基於標題的大規模商品實體檢索」競賽冠軍，DeepBlueAI團隊技術分享 | 機器之心
# 335   每人300萬激勵科學探索，北大謝濤、清華朱軍等50人獲獎，騰訊這個大獎公佈 | 機器之心
# 336   新任Google臺灣董事總經理馬大康：現階段全球AI發展仍處於石器時代，未來AI技術將有7大挑戰與新機會 | iThome
# 337   中國人工智能學會2020年度優秀科技成果出爐，百度文心ERNIE入選 | 機器之心
# 338   讓AI像Excel一樣普及：這週末，我們聊了聊AI的無障礙打開方式 | 機器之心
# 339   Dell、Fedex打造全美邊緣運算基礎架構 | iThome
# 340   基於課程學習（Curriculum Learning）的自然語言理解 | 機器之心
# 341   英特爾進擊新能源發電，看AI如何用氣象預報預測功率？ | 機器之心
# 342   剛剛，Python之父Guido Van Rossum宣佈加入微軟 | 機器之心
# 343   需要知識的後深度學習時代，如何高效自動構建知識圖譜？ | 機器之心
# 344   本科三篇頂會一作、超算競賽冠軍，2020清華本科特獎結果出爐 | 機器之心
# 345   LinkedIn釋出Java機器學習函式庫Dagli | iThome
# 346   「上頭」的南寧，除了老友粉，還有這場DevRun開發者沙龍 | 機器之心
# 347   美國大選之後的思考：AI能準確預測選民的行爲嗎？ | 機器之心
# 348   OSDI 2020 | RAMMER如何進一步“壓榨”加速器性能 | 機器之心
# 349   ModelArts加持，華爲雲進入領導者象限：Forrester最新報告出爐 | 機器之心
# 350   機器人是如何規劃路徑的？動畫演示一下吧 | 機器之心
# 351   不可區分混淆被實現，計算機科學家摘得這顆密碼學「皇冠上的明珠」 | 機器之心
# 352   超越谷歌BERT！依圖推出預訓練語言理解模型ConvBERT，入選NeurIPS 2020 | 機器之心
# 353   這場大會，讓兩千萬人擡頭看見了月亮 | 機器之心
# 354   EMNLP 2020 | 開放域對話系統的屬性一致性識別 | 機器之心
# 355   層級聚類和Python實現的初學者指南（附鏈接） | 機器之心
# 356   你的房東可能正用AI篩查你的犯罪記錄，決定要不要租房給你 | 機器之心
# 357   日交易3千億的票券市場全新監理架構大公開，明年Q2上線要靠大數據更即時管理市場 | iThome
# 358   小鵬汽車牽手千尋位置：P7擁有時空智能，定位精度可達釐米級 | 機器之心
# 359   124頁，UC伯克利大學胡戎航博士論文公佈：視覺與語言推理的結構化模型 | 機器之心
# 360   利用人類和機器智能創建ML模型，人機迴圈竟在這些領域大展手腳 | 機器之心
# 361   天貓雙11訂單峯值58.3萬筆/秒，消費狂歡背後隱藏了哪些技術？ | 機器之心
# 362   復旦大學黃萱菁：自然語言處理中的可理解分析 | 機器之心
# 363   哥本哈根兩學生開發新模型，預測深度學習算法碳排放量 | 機器之心
# 364   EMNLP 2020 | 忒修斯之船啓發下的知識蒸餾新思路 | 機器之心
# 365   500萬AI人才缺口「高校造」，科技公司培養AI應用人才的新模式 | 機器之心
# 366   AI輔助檢測腦動脈瘤，靈敏度達97.5%，華爲雲聯合成果登上國際頂級期刊 | 機器之心
# 367   微積分、線性代數、概率論，這裏有份超詳細的ML數學路線圖 | 機器之心
# 368   ICLR 2021投稿中值得一讀的NLP相關論文 | 機器之心
# 369   首屆AAAI/ACM SIGAI博士論文獎公佈，姚班學霸吳佳俊獲獎 | 機器之心
# 370   融合外部知識的常識問答 | 機器之心
# 371   論壇全程回顧3：騰訊公司副總裁鄭浩劍作主題演講《共建超級數據鏈，促進產業數字升級》 | 機器之心
# 372   消費行業的顆粒度革命，AI+BI如何打敗Excel報表？ | 機器之心
# 373   飛槳推出異構參數服務器架構，異構硬件高效組合，訓練速度提升65%以上 | 機器之心
# 374   重估「AI國家隊」雲從：步入寒冬還是萬物生長 | 機器之心
# 375   十一年磨一劍：中科大數學教授成功證明微分幾何學兩大猜想 | 機器之心
# 376   圖像也能做情感遷移？羅切斯特大學團隊提出計算機視覺新任務 | 機器之心
# 377   全球頂尖藥械齊聚、跨領域合作雲集，2020年的進博會都有哪些看點？ | 機器之心
# 378   硬核奶爸！用樹莓派做個「智能嬰兒監視器」：啼哭自動通知，還能分析哭聲含義 | 機器之心
# 379   如何打破AI偏見？Google是這麼做的 | 機器之心
# 380   AI 算法解決二進制安全問題，騰訊安全NeurIPS 2020論文有新方法 | 機器之心
# 381   百度CTO王海峯的履歷上，又多了個「第一」 | 機器之心
# 382   歐盟下月公佈革命性新規，科技巨頭商業模式面臨巨大挑戰 | 機器之心
# 383   「人工智能第一股」依圖科技衝刺科創板，按下國產芯片加速鍵 | 機器之心
# 384   AMD Zen3首發評測：頻率超5GHz，IPC提升不止19%，這次真的Yes了 | 機器之心
# 385   陳丹琦新作：關係抽取新SOTA，用pipeline方式挫敗joint模型 | 機器之心
# 386   AI趨勢周報第148期：國泰醫院靠健保署大數據提高5大慢性病罹患預測率 | iThome
# 387   竹間智能完成2億元人民幣C輪融資，獲兩大國有銀行共同投資 | 機器之心
# 388   爲幫患阿茲海默症的外婆找記憶，15歲初中生開發智能「識人」頸環，還能帶老人回家 | 機器之心
# 389   第一屆「多模態自然語言處理研討會」精彩回顧（免費獲取 PPT） | 機器之心
# 390   深度解讀展會場景智能推薦搭建之路 | 會展雲技術解讀 | 機器之心
# 391   三年半虧損7.9億元，虧損持續擴大，AI獨角獸雲知聲如何撐起12億美元估值 | 機器之心
# 392   王建宇院士作主題演講《激光通信一一空間大數據的高速公路》 | 機器之心
# 393   中國提出的AI方法影響越來越大，天大等從大量文獻中挖掘AI發展規律 | 機器之心
# 394   10分鐘標註數據勝過一年前的960h，FAIR新研究實現語音識別大進展（模型已開源） | 機器之心
# 395   ​傷不起的「小強」，竟被用來賣苦力，還要做臉部裝飾 | 機器之心
# 396   Colab不好用，有人花兩年開發了一個新notebook，支持實時協作還更快 | 機器之心
# 397   咳兩聲就能鎖定新冠！MIT收集20萬咳嗽樣本，用AI辨別無症狀感染者，準確率100% | 機器之心
# 398   聚焦工業互聯與製造生態，探尋智能製造發展新路徑 | 機器之心
# 399   國家電投能源科技工程有限公司數字化轉型諮詢服務項目啓動 | 機器之心
# 400   隧道、高架、電離層干擾衛星定位結果？千尋位置展開高精度定位路測 | 機器之心
# 401   僅次於癌症將成人類第二大殺手，面對抑鬱症AI能做些什麼？ | 機器之心
# 402   論壇全程回顧1：2020上海靜安國際大數據論壇首次發佈《長三角政府數據開放一體化報告》 | 機器之心
# 403   Facebook：易於解釋的神經元可能會阻礙深度神經網絡的學習 | 機器之心
# 404   吳恩達演講直指AI落地三大挑戰，並提出解決方案 | 機器之心
# 405   螞蟻暫緩上市影響前所未有，超20萬億打新資金面臨解凍 | 機器之心
# 406   谷歌發佈Amber項目，用AI分析腦電波診斷治療抑鬱症 | 機器之心
# 407   不要上手就學深度學習！超詳細的人工智能專家路線圖，GitHub數天獲2.1k星 | 機器之心
# 408   知識圖譜構建的研究已走入下半場，但大規模落地應用仍需時間 | 機器之心
# 409   ​KDD 2020 開源論文 | 圖神經網絡多變量時序預測 | 機器之心
# 410   EMNLP 2020 | 基於反事實推理的開放域生成式對話 | 機器之心
# 411   OSDI 2020 | 微軟亞洲研究院論文一覽 | 機器之心
# 412   行業首發AI實時隱身技術，來快手擁有隱身超能力 | 機器之心
# 413   2020世界計算機大會在湖南長沙開幕，來看倪光南院士怎麼說 | 機器之心
# 414   湘約未來 共話計算產業新動能  2020世界計算機大會在湖南長沙開幕 | 機器之心
# 415   爆肝100天，B站UP主開發會寫高考作文的AI，內含17億參數、2億數據、1萬行代碼 | 機器之心
# 416   AlphaGo原來是這樣運行的，一文詳解多智能體強化學習的基礎和應用 | 機器之心
# 417   字節跳動破局聯邦學習：開源Fedlearner框架，廣告投放增效209% | 機器之心
# 418   訓練時間和參數量百倍降低，直接使用標籤進行預測，康奈爾大學新方法性能竟超GNN | 機器之心
# 419   文獻進，產物出！"AI化學家"顛覆傳統化學研究過程，有望在製藥行業激發變革性突破 | 機器之心
# 420   基於數據預測的解釋真的能增加用戶對人工智能的信任嗎？（附鏈接） | 機器之心
# 421   XYZ“三原色”，助力AI決策類人化 | 機器之心
# 422   思必馳xiaochi獲2020 AESR“口音種類識別“冠軍和“口音英語語音識別”亞軍 | 機器之心
# 423   包含近 20 萬本圖書，OpenAI 級別的訓練數據集上線 | 機器之心
# 424   CMU出品，計算機圖形學秋季課程已上線，B站同步字幕視頻 | 機器之心
# 425   上海交大：我們做了一個醫療版MNIST數據集，發現常見AutoML算法沒那麼好用 | 機器之心
# 426   邊緣AI新方法TinyML，超低功耗，存儲佔用KB計，在邊緣設備上進行機器學習 | 機器之心
# 427   機器學習論文復現，這五大問題你需要注意 | 機器之心
# 428   亮劍INTERSPEECH 2020，思必馳10篇論文被收錄 | 機器之心
# 429   華爲、千尋位置、高德聯手，全球首發亞米級車道導航 | 機器之心
# 430   AI技術新玩法：看透前後100年，連接過去與未來 | 機器之心
# 431   打工人的疲勞和壓力，別人不懂 AI 懂 | 機器之心
# 432   十四五規劃發佈，科技自給自足第一次被擺在首位 | 機器之心
# 433   更快、更強的Python實現：Pyston v2.0發佈 | 機器之心
# 434   標星7.2萬熱門開源項目youtube-dl遭下架，開發者的權益誰來保護？ | 機器之心
# 435   騰訊QQ看點團隊：用遷移學習架構解決短視頻冷啓推薦問題 | 機器之心
# 436   什麼是優秀的圖表示？斯坦福提出首個信息論原則——圖信息瓶頸 | 機器之心
# 437   深入瞭解華爲麒麟9000：GPU性能翻身，AI算力頂尖的5G旗艦芯片 | 機器之心
# 438   百度獲INTERSPEECH2020競賽第一AI診斷早期阿爾茨海默症價值巨大 | 機器之心
# 439   倒計時5天|2020世界計算機大會舉辦在即17名院士精彩亮相 | 機器之心
# 440   把紙質家譜做成數據中臺，原來是這樣的體驗 | 機器之心
# 441   特朗普政府宣佈H-1B簽證重大改革計劃：放棄抽籤，按薪資高低發放 | 機器之心
# 442   如本科技推出僅9998元的高精度工業3D相機，降低3D智能視覺應用門檻 | 機器之心
# 443   全球對話技術頂賽DSTC9落幕，百度NLP開源PLATO-2斬獲四項冠軍 | 機器之心
# 444   AI和大數據下，前端技術將如何發展？ | 機器之心
# 445   基於飛槳復現 SRGAN 模型，對圖像進行超分辨率重構 | 機器之心
# 446   深度學習 V.S. 謎題遊戲 | 機器之心
# 447   基於飛槳復現語義分割網絡HRNet，實現瓷磚缺陷檢測 | 機器之心
# 448   即將引爆的新一輪技術熱點——TinyML 亞洲峯會 | 機器之心
# 449   首汽約車聯合亞馬遜雲服務發佈出行行業首個定製智能語音解決方案 | 機器之心
# 450   今天，我們來教AI下國際象棋 | 機器之心
# 451   PyTorch 1.7發佈，支持CUDA 11、Windows分佈式訓練 | 機器之心
# 452   雪豹也上雲，這是騰訊雲小微AI知識圖譜平臺的小場景大應用 | 機器之心
# 453   量子科技發展進入突破期，百度段潤堯：當下是播種“量子樹”最好時機 | 機器之心
# 454   讓機器學習不再依賴數據？Gary Marcus和「Roomba之父」的初創公司獲1500萬美元融資 | 機器之心
# 455   一鍵即運行！清華團隊推出圖深度學習工具包CogDL v0.1 | 機器之心
# 456   從ULMFiT、Transformer、BERT等經典模型看NLP發展趨勢 | 機器之心
# 457   六角靠IT整合加速全球展店，借鏡超商發展門店管理行動化 | iThome
# 458   助力「新四跨」九成車隊，千尋位置高精度定位成汽車新標配 | 機器之心
# 459   Photoshop打包實現AI圖像論文，英偉達在實時視頻上PS之路上越走越遠 | 機器之心
# 460   自己挖坑自己填，谷歌大改Transformer注意力，速度、內存利用率都提上去了 | 機器之心
# 461   十年磨礪，四代大數據平臺演進，騰訊雲爲什麼能夠踩對歷史的進程？ | 機器之心
# 462   如何用序列分類方式進行法律要素與當事人關聯性分析 | 機器之心
# 463   YouTube深度學習推薦系統的十大工程問題 | 機器之心
# 464   大規模圖訓練調優指南 | 機器之心
# 465   強強聯手！AMD官宣350億美元收購賽靈思 | 機器之心
# 466   思謀科技A輪融資超1億美元，成爲最年輕「準獨角獸」AI企業 | 機器之心
# 467   央視再曝AI黑產！2塊能買上千人臉照，輕鬆「換臉」仙人跳 | 機器之心
# 468   如何用好雲原生數據湖？ | 機器之心
# 469   11位科幻作家參與，首次AI人機共創寫作實驗啓動 | 機器之心
# 470   哪種編程語言又快又省電？有人對比了27種語言 | 機器之心
# 471   萬餘首鋼琴作品、一千多個小時，字節跳動發佈全球最大鋼琴MIDI數據集 | 機器之心
# 472   爲非專業人員量身打造，斯坦福教授Christopher Manning一頁紙定義AI核心概念 | 機器之心
# 473   亞馬遜：我們提取了BERT的一個最優子架構，只有Bert-large的16%，CPU推理速度提升7倍 | 機器之心
# 474   微軟預覽桌機版機器學習訓練工具Lobe | iThome
# 475   騰訊雲小微&騰訊雲智能鈦聯合團隊獲Interspeech 2020口音英語語音識別技術挑戰賽冠軍 | 機器之心
# 476   文本摘要論文列表 | 機器之心
# 477   微軟與Honeywell合作推建築營運解決方案 | iThome
# 478   場景AI時代來臨 思圖場景再摘EmotiW桂冠 | 機器之心
# 479   科大訊飛再添A.I.學習新品：訊飛掃描詞典筆正式發佈 | 機器之心
# 480   揭祕30億美元富士康「騙局」，特朗普夢碎再工業化 | 機器之心
# 481   萬聖節定製「喪屍生成器」，編輯部親測，效果鬼畜 | 機器之心
# 482   180G！中文ELECTRA預訓練模型再升級 | 機器之心
# 483   229頁，CMU博士張昊畢業論文公佈，探索機器學習並行化的奧祕 | 機器之心
# 484   2017-2020 JS最受歡迎、全球活躍開發者1240萬，SlashData發佈最新開發者報告 | 機器之心
# 485   YOLOv5的妙用：學習手語，幫助聽力障礙羣體 | 機器之心
# 486   300學者雲遊戲中開AI大會，網易伏羲全球首創沉浸式會議 | 機器之心
# 487   中小企業數智化方案如何採購？數據解讀我國中小企業數智化解決方案供應市場 | 機器之心
# 488   阿里安全「啓發式領域適應」成果入選NIPS2020，新一代算法「鑑黃師」誕生 | 機器之心
# 489   27場機器學習面試後，來劃個概念重點吧 | 機器之心
# 490   建造自己的「天空之城」，密歇根大學博士後的這項研究可以虛空造物、偷天換日 | 機器之心
# 491   這個程序員節，我們不寫代碼 | 機器之心
# 492   2020上海靜安國際大數據論壇數據治理與實踐分論壇今日舉辦 | 機器之心
# 493   不用攝像頭和激光雷達，四足機器人「憑感覺」越野：ANYmal登上Science子刊封面 | 機器之心
# 494   速度超快！字節跳動開源序列推理引擎LightSeq | 機器之心
# 495   十年之後，科大訊飛終於「獨木成林」 | 機器之心
# 496   人臉識別戰役尾聲，騰訊優圖謀新 | 機器之心
# 497   微軟攜手MITRE釋出捍衛機器學習系統的Adversarial ML Threat Matrix開放框架 | iThome
# 498   Photoshop把AI論文demo打包實現了：照片上色、改年齡、換表情只需要點點鼠標 | 機器之心
# 499   無懼分辨率變化，頑強求解PDE家族：加州理工學院等提出傅里葉神經算子方法 | 機器之心
# 500   引入魯棒性作爲連續參數，這種新的損失函數實現了自適應、隨時變換 | 機器之心

# %%
# 轉成 dataframe 並存檔

df = pd.DataFrame(articles_info)
df.head(10)

df.to_csv('news_info.csv', index=False)

# %%
# 讀取 csv
news_info = pd.read_csv('news_info.csv')
news_info.head(10)
# Out:
#                                                title  \
# 0             顛覆知產保護傳統模式，阿里AI模特首度現身國內頂尖AI安全會議 | 機器之心
# 1        阿里AI“一對多”挑戰人類律師，不到10秒審近百行合同文書，準確率96% | 機器之心
# 2               快手聯手英特爾提升 KGNN 平臺大規模實時動態圖訓練效率 | 機器之心
# 3            因應後疫新常態數位爆量新挑戰，Line發布2021技術新戰略 | iThome
# 4                                   LG 計劃外包更多低階和中階手機
# 5                Apple 的 2021 年 Mac 晶片中可能包含 32 核心的產品
# 6         apple one營收比重估達85%！分析師：可能推出軟硬體結合的訂閱服務｜數位時代
# 7           Google Authenticator 新增匯出帳戶功能，可將資料移轉到新手機
# 8  您與孩子使用的Apps正被祕密監控中！國際版「360兒童手錶」後門偷窺事件 - The Ne...
# 9           Bose 新型真無線運動耳機通過 FCC 認證，無耳塞式外觀構造曝光 | T客邦
#
#                                                  url  \
# 0   https://www.jiqizhixin.com/articles/2020-12-08-3
# 1   https://www.jiqizhixin.com/articles/2020-12-08-2
# 2     https://www.jiqizhixin.com/articles/2020-12-08
# 3              https://www.ithome.com.tw/news/141465
# 4  https://chinese.engadget.com/lg-smartphone-out...
# 5  https://chinese.engadget.com/apple-silicon-mac...
# 6  https://www.bnext.com.tw/article/60416/all-in-...
# 7  https://free.com.tw/google-authenticator-expor...
# 8         https://www.thenewslens.com/article/144319
# 9  https://www.techbang.com/posts/82981-boses-new...
#
#                          origin
# 0    https://www.jiqizhixin.com
# 1    https://www.jiqizhixin.com
# 2    https://www.jiqizhixin.com
# 3     https://www.ithome.com.tw
# 4  https://chinese.engadget.com
# 5  https://chinese.engadget.com
# 6      https://www.bnext.com.tw
# 7           https://free.com.tw
# 8   https://www.thenewslens.com
# 9      https://www.techbang.com

# %%
# 以多執行緒爬取每篇新聞內容，比原來以單一執行緒跑完 500 篇節省許多時間

import threading
import requests
import re
from tqdm import tqdm_notebook, tnrange 
#import random

n_thread = 10           # 執行緒數量
news_url = list(news_info['url'].values)
contents = []           # 每個執行緒爬取完結果的串列，長度是執行緒數量
headers = {'user-agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.66 Safari/537.36'}

# 原本要使用一些代理 ip 避免用原 ip 大量爬取網頁的問題，但這些代理 ip 卻有時候會抓不到正確的新聞內容
# 後來只好還是使用原 ip 只是得在每一筆爬取資料後多加些等待時間
# proxy = ['113.53.83.212:44664', '14.143.168.230:8080', '186.159.3.193:56861',       
#          '163.172.229.166:3838', '65.51.251.218:3128', '51.15.157.208:3838', 
#          '163.172.226.90:3838', '103.103.175.253:3128', '212.83.178.76:3838', 
#          '150.107.31.176:8080', '68.168.123.98:80', '54.151.3.183:8080']
# proxies={'http': ip, 'https:': ip},

def job(url_list, num, contents):                   # 每個執行緒要做的工作: 爬取 (N/n_thread) 筆數新聞內容
    print('Start parsing job ', num)
    print()
    multi_content = []                              # 每個執行緒做完，所得新聞內文的集合串列，長度為 (N/n_thread)
    
    start = int(N/n_thread)*num                     # 設定此項 job 所負責的起始和終點序號              
    end = int(N/n_thread)*(num+1)
    if end > N:
        end = N
    
    for i in tnrange(len(url_list[start:end])):     # 引入 tqdm 的進度條，可以清楚看到執行進度
        single_content = ''                         # 每篇新聞爬取出來的內文
        
        while True:
            try:
                #ip = random.choice(proxy)
                response = requests.get(url_list[int(N/n_thread)*num+i], headers=headers)  # 加入 headers 以防有些網頁無法進入
                response.encoding='utf-8'
                soup = BeautifulSoup(response.text, 'html.parser')
        
                paragraphs = []
                if soup.find('p'):                                         # 新聞內文有些在 section 標籤
                    paragraphs.append(soup.find_all('p'))                  # 有些在 p 標籤
                                                                           # paragraphs 是 <p>集合 和 <section>集合的串列      
                if soup.find('section'):
                    paragraphs.append(soup.find_all('section'))

                for pars in paragraphs:                                    # pars 是 <p>集合 和 <section>集合
                    for par in pars:
                        text = re.sub('[\W]+', ' ', par.text)                   # 找出特殊字元 (\n,\t,...等) 替換成空白      
                        single_content += text
                
                if single_content != '' and type(single_content) == str:        # 確認抓取到的內容是否為空，否則再重新抓一次
                    break                                                       # 用代理 ip 有時候會抓不到內文變成 nan
                else:
                    #print(ip)                                             # 若有抓不到內文的情況就回報 url 再確認
                    print(url_list[int(N/n_thread)*num+i])                 # 取消用代理伺服器就不需要
                    print(soup.find_all('p')[:5])
            except:                                                        # 若有 proxy error 的情況，也是再重新 request
                continue
        
        multi_content.append(single_content)                               
        time.sleep(10)

    contents.insert(num, multi_content)                                    # 按照 job 的順序放入 contents 為 n_thread job
    print('Done parsing job ', num)                                        # 結果的集合

    
# 進行多執行緒爬取 N 篇新聞內容

threads = []
for i in range(n_thread):
    t = threading.Thread(target=job,args=(news_url, i, contents))          
    t.start()
    threads.append(t)
    
for thread in threads:
    thread.join()    
    
news = []
for item in contents:                                       # 打破 n_thread job 的串列，重組成 N 篇新聞內文的串列
    for a in item:
        news.append(a)

news_info['content'] = news                                 # 把新聞內容加進 dataframe
news_info.head(10)

news_info.to_csv('news.csv', index=False)                   # 重新存檔
# Out:
# Start parsing job  Start parsing job Start parsing job Start parsing job  0 Start parsing job Start parsing job  Start parsing job Start parsing job 1
# Start parsing job 2 Start parsing job 3   4
#
#
#
# 657
# 8
#
#
#
#
# 9
# HBox(children=(IntProgress(value=0, max=50), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=50), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=50), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=50), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=50), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=50), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=50), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=50), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=50), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=50), HTML(value='')))
# Done parsing job  2
#
# Done parsing job  0
#
# Done parsing job  1
#
# Done parsing job  3
#
# Done parsing job  9
#
# Done parsing job  4
#
# Done parsing job  8
#
# Done parsing job  5
#
# Done parsing job  7
#
# Done parsing job  6

# %%
# 載入有新聞內容的 csv 檔案
final_news = pd.read_csv('news.csv')

origin_state = pd.DataFrame(final_news['origin'].value_counts()).reset_index()       # 另創 dataframe 統計新聞來源網站
origin_state.columns=['origin', 'count']
origin_state
# Out:
#                                origin  count
# 0          https://www.jiqizhixin.com    313
# 1           https://www.ithome.com.tw     47
# 2          https://www.blocktempo.com     14
# 3            https://www.techbang.com     12
# 4            https://www.kocpc.com.tw     11
# 5              https://www.cool3c.com     11
# 6                https://blockcast.it     10
# 7         https://www.thenewslens.com      9
# 8            https://www.bnext.com.tw      8
# 9                https://www.storm.mg      8
# 10                  https://unwire.hk      7
# 11            https://applealmond.com      6
# 12       https://chinese.engadget.com      6
# 13                  https://qooah.com      4
# 14             https://www.cup.com.hk      3
# 15                 https://briian.com      3
# 16                    https://ez3c.tw      3
# 17                https://free.com.tw      3
# 18                 https://ahui3c.com      2
# 19  http://3smarket-info.blogspot.com      2
# 20         https://www.cmmedia.com.tw      2
# 21            https://www.saydigi.com      2
# 22             https://softnshare.com      2
# 23              https://money.udn.com      1
# 24              https://autos.udn.com      1
# 25                 https://medium.com      1
# 26             https://www.upmedia.mg      1
# 27       https://www.foxsports.com.tw      1
# 28                 https://unwire.pro      1
# 29        https://www.azofreeware.com      1
# 30          https://www.peoplenews.tw      1
# 31             https://ga.awoo.com.tw      1
# 32           https://www.niusnews.com      1
# 33        https://www.gamebase.com.tw      1
# 34            https://tw.my-hiend.com      1

# %%
def mapping_new_origin(origin, count):                              # 把太少的部分歸納成 Others
    if count >= 5:
        return origin
    else:
        return 'Others'

new_origin = []

for i in range(len(origin_state)):
    new_origin.append(mapping_new_origin(origin_state.iloc[i, 0], origin_state.iloc[i, 1]))

origin_state['new_origin'] = new_origin
origin_state
# Out:
#                                origin  count                    new_origin
# 0          https://www.jiqizhixin.com    313    https://www.jiqizhixin.com
# 1           https://www.ithome.com.tw     47     https://www.ithome.com.tw
# 2          https://www.blocktempo.com     14    https://www.blocktempo.com
# 3            https://www.techbang.com     12      https://www.techbang.com
# 4            https://www.kocpc.com.tw     11      https://www.kocpc.com.tw
# 5              https://www.cool3c.com     11        https://www.cool3c.com
# 6                https://blockcast.it     10          https://blockcast.it
# 7         https://www.thenewslens.com      9   https://www.thenewslens.com
# 8            https://www.bnext.com.tw      8      https://www.bnext.com.tw
# 9                https://www.storm.mg      8          https://www.storm.mg
# 10                  https://unwire.hk      7             https://unwire.hk
# 11            https://applealmond.com      6       https://applealmond.com
# 12       https://chinese.engadget.com      6  https://chinese.engadget.com
# 13                  https://qooah.com      4                        Others
# 14             https://www.cup.com.hk      3                        Others
# 15                 https://briian.com      3                        Others
# 16                    https://ez3c.tw      3                        Others
# 17                https://free.com.tw      3                        Others
# 18                 https://ahui3c.com      2                        Others
# 19  http://3smarket-info.blogspot.com      2                        Others
# 20         https://www.cmmedia.com.tw      2                        Others
# 21            https://www.saydigi.com      2                        Others
# 22             https://softnshare.com      2                        Others
# 23              https://money.udn.com      1                        Others
# 24              https://autos.udn.com      1                        Others
# 25                 https://medium.com      1                        Others
# 26             https://www.upmedia.mg      1                        Others
# 27       https://www.foxsports.com.tw      1                        Others
# 28                 https://unwire.pro      1                        Others
# 29        https://www.azofreeware.com      1                        Others
# 30          https://www.peoplenews.tw      1                        Others
# 31             https://ga.awoo.com.tw      1                        Others
# 32           https://www.niusnews.com      1                        Others
# 33        https://www.gamebase.com.tw      1                        Others
# 34            https://tw.my-hiend.com      1                        Others

# %%
# 重新統整出新聞來源

new_origin_state = origin_state.groupby(by='new_origin').sum().reset_index().sort_values(by='count', ascending=False).reset_index(drop=True)
new_origin_state
# Out:
#                       new_origin  count
# 0     https://www.jiqizhixin.com    313
# 1      https://www.ithome.com.tw     47
# 2                         Others     38
# 3     https://www.blocktempo.com     14
# 4       https://www.techbang.com     12
# 5         https://www.cool3c.com     11
# 6       https://www.kocpc.com.tw     11
# 7           https://blockcast.it     10
# 8    https://www.thenewslens.com      9
# 9       https://www.bnext.com.tw      8
# 10          https://www.storm.mg      8
# 11             https://unwire.hk      7
# 12       https://applealmond.com      6
# 13  https://chinese.engadget.com      6

# %%
# 新聞來源畫成圓餅圖

import matplotlib.pyplot as plt
# %matplotlib inline

# plt.rcParams['font.sans-serif']=['Microsoft JhengHei']
# plt.rcParams['axes.unicode_minus'] = False
plt.figure(figsize=(20, 10))
plt.pie(new_origin_state['count'], labels=new_origin_state['new_origin'], autopct='%0.1f%%')
plt.legend(loc='best')
plt.title('新聞來源網站分布', fontproperties="Microsoft JhengHei")
plt.show()

# %%
# 把新聞內容轉成獨立串列做進一步處理

news = list(final_news['content'].values)                                 
print(len(news), type(news))
# Out:
# 500 <class 'list'>

# %%
import jieba
import jieba.analyse

# 移除停用詞
stopwords=[]

with open('new_stopwords.txt', 'r', encoding='utf-8') as f:             # 使用從網路上抓來的停用詞表
    for data in f.readlines():
        data = data.strip()
        stopwords.append(data)

# jieba 分詞
remained_news = []

for n in news:
    seg = jieba.cut(n, cut_all=False)               # 分詞後去除停用詞, 然後再重組回文章
    try:
        remained_news.append(''.join(list(filter(lambda a: a not in stopwords and a != '\n', seg))))
    except Exception as e:                         
        print(e)                                    # 若有 'nan' 的項目會引發錯誤  
        print(news.index(n))                        # 取得序號再次確認新聞內容是否有問題

# 關鍵字 tfidf
keywords = []

for n in remained_news:
    keywords.append(jieba.analyse.extract_tags(n, topK=20, withWeight=False))

for j in keywords:
    print(j)
    print()
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache C:\Users\brian\AppData\Local\Temp\jieba.cache
# Loading model cost 1.375 seconds.
# Prefix dict has been built successfully.
# ['AI', '阿里', '电商', '算法', '郑俊芳', '模特', '人工智能', '鲁棒性', '清华大学', '多媒体', '模型', '数字', '合作', '驾驶', '张钹', '模态', '基建', '领域', '商家', '识别']
#
# ['AI', '达摩院', '律师', '合同', '审核', '人类', 'ALICE', '法务', '交卷', '人机', '语言', '智能', '比赛', '机器', '50', '准确率', '分钟', '风险', '人工智能', '浙江大学']
#
# ['内存', '傲腾', '英特尔', 'KGNN', '持久', '快手', 'DRAM', '采样', '存储', '场景', '平台', '算法', '训练', '动态图', 'GNN', '推荐', '提供', '性能', '分片', '级别']
#
# ['Line', '服務', '資料', 'AI', '團隊', 'social', 'btn', 'set', '疫情', 'left', '區塊', 'Yahoo', '12', 'block', 'margin', '專案', '2020', 'width', '一個', '線上']
#
# ['LG', '手機', '部門', '重組', 'Reuters', '確認', '低階中', '階手', '機設', '計生', '產數量', '就會', '專注', '高階產品', '因應', '架構', '改變', '調任', '減生產', '研發']
#
# ['Apple', 'CPU', '核心', 'Pro', 'iMac', '晶片', '2021', '32', '高階桌', 'Mac', 'MacBook', '16', '顯示', '新款', '效能', '大計來', 'M1', '一個', '開端', '發展']
#
# ['蘋果', '服務', 'Apple', '使用者', '訂閱', '新機', '硬體', '金額', '產品', '三星', '市場', '內容', '舊機', '透過', 'Google', '舊機換', '00', '方案', '持續', 'Loup']
#
# ['免費', 'Google', '下載', '教學', 'WordPress', '匯出', 'Authenticator', '網站', '帳戶', '應用', '服務', '主機', '手機', '證碼', '設定', '電子', '程式', '網路', '郵件', '推薦']
#
# ['蹲點', '360', '台灣', '社區', '640', '兒童', '300', '資安', '2020', '透過', 'Apps', '網路', '活動', '480', '監控', 'type', '250', 'screen', 'list', '影展']
#
# ['ONEAD', 'window', '耳機', 'parent', 'var', 'Earbuds', 'function', 'Sport', 'inread', 'Open', 'div', 'divcontent', 'js', '發表', 'document', '留言', 'Bose', '一個', 'FCC', '運動']
#
# ['ONEAD', 'window', 'parent', 'Galaxy', 'S21', 'var', '螢幕', 'function', 'inread', 'div', 'divcontent', 'js', '發表', 'document', '留言', '鏡頭', 'HD', 'slot', 'push', '手機']
#
# ['12', '2020', '08', '市場', '10', '阿里', 'Aliexpress', '11', '美國', '新聞', '俄羅斯', '台灣', '速賣通', '階段', '00', '電子', '13', '華爾街', '天貓', '發展']
#
# ['2020', '12', '08', '11', 'iPhone', '財經', '10', '新聞', '問題', '20', '06', '華爾街', '蘋果', '螢幕', '07', '觀點', '日報', '50', '無法', '回應觸']
#
# ['ONEAD', 'window', 'parent', 'var', '透過', 'function', '系統', 'inread', '下水道', '遠傳', '雲端物', '聯網', '監測', 'div', 'divcontent', 'js', 'document', '留言', '大數據', '桃園']
#
# ['2020', '12', '08', '代工', '調漲', '晶圓', '價格', '10', '財經', '客戶', '新聞', '產能', '記憶體', '20', '06', '華爾街', '漲價', 'IC', '市場', '中國']
#
# ['晶片', '手機', '高通', '蘋果', '技術', '華為', 'AI', '性能', '驍龍', '888', '三星', 'A14', '5nm', 'GPU', '現在', '廠商', '體驗', '原神', '遊戲', 'iPhone']
#
# ['網頁', '雷射', 'adsbygoogle', '點擊', '煩悶', 'Laser', 'Cat', '貓咪', '兩個', '出現', '選單', '電子', 'window', 'push', '10', '分就會', '集滿', '1000', 'Chrome', '擴充']
#
# ['區塊', '計畫', '新加坡', '鏈技術', '創新', '發展', '王瑞傑', '啟動', '這項', '資訊', '推進', '貿易', '供應', '這是', '對區', 'email', 'protected', '閱聽', '旨在', '研究']
#
# ['區塊', '數位', '貨幣', '市場', 'Bill', 'Winters', '銀行', '發展', '廣泛', '創建', '未來', '關鍵', '趨勢', '發行', 'email', 'protected', '閱聽', '渣打', '致力', '全球']
#
# ['12', 'GU', '網路', '單品', '哈利波', '推出', 'PlayStation', '商店', '11', '1212', '終狂', '歡節', '活動', '212', '優惠', '期間', '必備', '000', '聯名', '居家']
#
# ['AirPods', '蘋果', 'fbq', '發表', '2021', '2020', 'Pro', '耳機', 'js', 'Twitter', '改變', '12', 'Studio', '應該', 'function', '爆料', '將於', '外觀', '將有', 'push']
#
# ['XRP', '瑞波', 'Jed', '卡列', '億枚', '萬枚', '出售', '數據', '29', '影響', '美元', 'Ripple', '創辦', '市場', '957', '區塊', '貨幣', '990', 'million', '價格']
#
# ['Google', 'Apple', 'Music', '音樂', '支援', '服務', '智慧', '語音', 'Home', '選擇', '助理', 'Nest', '音響', '使用者', '播放', '台灣', '訂閱', '這項', 'Audio', '串流']
#
# ['產業', '蘋果', '應用', '個小時', '消息', '理器', '推出', '晶片', '台積', 'Apple', '自動', '開箱', '未來', 'iPhone', 'Mash', 'Yang', '科技', '市值', '美元', '研發']
#
# ['蘋果', '產品', 'Google', '訂閱', '服務', '新機', '應用', '使用者', 'iPhone', 'Apple', '方案', '推出', '理器', '三星', '舊機', '換購', '硬體', '透過', '機種', '持續']
#
# ['Uber', '自動', '駕駛技術', '發展', '產業', '天前', 'Innovation', 'Aurora', 'Apple', '應用', '消息', '業務', '開箱', '魔物', '科科', 'M1', '美元', '科技', '10', '投資']
#
# ['蘋果', '設計', 'CPU', '產業', '效能', '晶圓', '核心', 'Pro', 'GPU', '個小時', 'iPhone', '2021', 'Mac', '產品', '應用', 'Arm', '理器', '消息', 'Apple', '32']
#
# ['Bobii', 'Box', '語音', '搜尋', '影音', '影片', '控器', 'YouTube', '頻道', '應用', 'OTT', '查詢', '透過', '使用者', '娛樂', '內容', '用戶', 'KTV', '功能', '相當']
#
# ['應用', 'LG', '天前', '科技', 'Google', '產品', '機產品', '設計', '手機', '市場', 'AI', '品牌', '持續', '高階手', '相關', '透過', '未來', 'Pixel', '魔物', '科科']
#
# ['Google', '理器', '應用', '產品', 'Pixel', '科技', '發展', '個小時', '開箱', 'Mash', 'Yang', '蘋果', '三星', '推出', '打造', '伺服器', 'Core', '未來', '服務', '評測']
#
# ['Pixel', 'Google', '手機', 'View', 'post', 'imgur', '功能', '機種', '自動', '更新', '12', '用戶', '這次', '開發', '通話', '編輯', 'adsbygoogle', '放到', '支援', '介面']
#
# ['比特', 'MicroStrategy', '優先', '購買', '轉換', '美元', '投資', '公司', '12', '15', '40', '投資人', '募資', '將會', '獲得', '債務', '動區', '趨勢', '出售', 'BTC']
#
# ['地址', '代幣', '價值', 'DeFi', '用戶', '以太', '市場', 'YFI', '美元', 'Etherscan', '機構', '投資', '萬枚', '筆者', 'Cream', '加密', '活動', '數據', 'a16z', 'Jump']
#
# ['App', '2020', 'Apple', '蘋果', 'fbq', '最佳', '年度', '實體', 'iPhone', '獎座', 'Mac', 'js', '12', 'Store', '整體', 'TV', '相當', 'function', 'push', 'facebook']
#
# ['Windows', 'M1', 'Mac', 'Pro', 'Surface', '執行', '系統', '晶片', 'fbq', '2020', 'https', 'js', '12', 'function', '蘋果', 'push', 'facebook', '奶昔', 'iOS', '測試']
#
# ['公室', '遙距辦', 'IBM', '實體', '企業', '工作', '當時', '曾經', '實驗', '2017', '遙距', '時間', 'Google', '環境', '2020', '發現', '視像', '會議', '政策', '新潮']
#
# ['蛋白', '結構', 'AlphaFold', '預測', 'DeepMind', '質結構', '實驗', '形狀', '能夠', '推測', '計算', 'GDT', '氨基酸', '序列', 'CASP', '比賽', '決定', '3D', '人員', '射線']
#
# ['貨幣', '加密', '科銀行', '投資', '德國顥', '基金', '科資本', '德國', '銀行', 'Hauck', 'Aufh', '資產', '客戶', 'HAIC', '組合', '獲得', '監管局', 'Kapilendo', '推出', '金融']
#
# ['Memoji', '選擇', '貼圖', '按鈕', '口罩', '相機', '開啟', '進行', '編輯', '頭飾', '分類', '聖誕帽', '顏色', '設定', '傳送', '聖誕節', '影響', '軟體', '聖誕裝扮', 'iPhone']
#
# ['駕駛', '百度', '測試', '自動', '實測', 'googletag', '車輛', '路段', '的士', '服務', '部無人', '進行', '集團', '監場', '司機', 'div', 'gpt', 'ad', '1529571774980', '1009429']
#
# ['Porter', 'Shock', 'DW5600', 'googletag', '經典', '注版', 'Tanker', '結合', 'div', 'gpt', 'ad', '1529571774980', '1009433', '慶祝', '85', '週年', '潮牌', 'Casio', '2020', '發表']
#
# ['順澤宮', 'var', 'left', 'top', '冠軍帽', '奧運', '艾登', '鐵人', '三項', '比賽', '媒體', 'pageURL', 'title', 'screen', 'width', 'height', '彰化', '參加', 'PTO', '留言']
#
# ['upmedia', 'mg', '新聞', '上報', '皮卡丘', '直播', '登場', '資訊', '寶可夢', '粉絲', '手機', '周邊', '三越', '開箱', '12', '採訪', '相關', 'Telegram', '協商', '美豬']
#
# ['電子', '郵件', 'Soft', 'Share', '服務', '位址', '訂閱', '網站', '文章', '選讀', 'Akismet', '留言', '接收', '通知', '告訴', '我會', '忘記', '教導', '記得', '學會']
#
# ['iPhone', '11', '序號', '查詢', '蘋果', '問題', '資格', '官網', '免費維修', 'adsbygoogle', '符合', '手機', 'Apple', '更換', 'window', 'push', '輸入', '維修', '身邊', '證實']
#
# ['皮卡丘', '30W', '充電器', '網站', '線材', '廖阿輝', '聯名', 'USB', '開箱', '12', '授權', '2020', '充電', 'Lightning', 'Akismet', '3C', 'Anker', '阿輝', 'iPhone', '規格']
#
# ['Ravn', '火箭', 'Aevum', '發射', '新創', '衛星', 'Virgin', 'Orbit', '軌道', '軍方', '客戶', '已經', '公尺', '送入', '公司', '重酬', '不用', '本週', '一個', '總部']
#
# ['Apple', '維修', 'iPhone', '11', '產品', '問題', '計劃', 'Follow', '屏幕', '影響', '更換', '半個', '不幸', '前往', '電子', '發生', '每個', '面售', '課題', '覺得']
#
# ['Nokia', 'C1', '12', 'Plus', '鏡頭', '工信部', 'TA', '手機', '2020', '像素', 'NokiaTA', '認證', '4G', '1335', '發布', 'RAM', 'Android', 'LTE', '800', 'Kin']
#
# ['Timnit', 'Gebru', 'Google', '語言', 'social', 'btn', 'set', 'left', 'margin', 'width', 'block', 'Jeff', '12', 'Dean', '模型', 'page', 'important', '論文', 'AI', '100']
#
# ['social', 'btn', 'set', 'left', 'block', 'margin', '軟體', '12', 'width', '勒索', '企業', '駭客', 'important', '15px', '100', 'float', 'fb', 'fan', 'page', 'top']
#
# ['social', 'btn', 'set', 'left', 'block', 'margin', '蘋果', '12', 'width', '裝置', 'AI', '使用者', 'important', '15px', '100', 'float', 'fb', '2020', 'Mac', '系統']
#
# ['数字化', '转型', '供应链', '调研', '参考性', '之能', '274', '1000', '家大', '实操', '企业', '群像', '各行各业', '洞察', '智能', '汇总', '调查结果', '囊括', '专业人士', '技术创新']
#
# ['PAI', '机器人', '技能', '学科', '人工智能', '社区', '研究', '机体', '机器人学', '跨学科', '领域', '层面', '机构', '实体', '材料', '培训', '智能', '方法', '大脑', '作者']
#
# ['英特尔', '量子', '机器', '编程', '计算', '神经网络', '学习', '拟态', '技术', '集成', '数据', '神经', '软件', '研究', 'Horse', 'Ridge', '计算机', '芯片', '功耗', '100']
#
# ['ISP', '安谋', '处理器', '玲珑', 'i3', 'i5', '场景', '摄像头', '客户', '中国', 'AI', '技术', '刘澍', 'IP', '研发', '产品', '图像处理', '安防', '视频', '业界']
#
# ['social', 'btn', 'set', 'left', 'block', 'margin', '12', 'width', 'App', 'important', '15px', '100', 'float', 'fb', '程式', '訂閱', 'iOS', '2020', 'fan', 'page']
#
# ['Google', 'social', 'btn', 'set', 'left', 'block', 'margin', '字型', '12', 'width', 'Chrome', '網站', 'important', '2020', '15px', '100', 'float', 'fb', '跨網', 'fan']
#
# ['App', 'social', 'btn', 'set', 'left', '函式', 'block', 'margin', 'Google', '12', 'width', '2020', 'Core', '檔案', '執行', '程式', 'Play', 'important', '漏洞', '15px']
#
# ['MARVEL', '上汽', '5G', 'SUV', '品牌', '续航', '700', '开卖', '车联', '华为', '智能', '百公里', '一台', '汽车', '搭载', '设计', '电动', '技术', '势力', '驾驶']
#
# ['SOLOv2', '分割', '实例', '算法', 'PaddleDetection', '卷积', 'mask', '语义', '检测', '训练', '提升', '预测', '精度', 'SOTA', '分支', '飞桨', 'Mask', '类别', '计算', '优化']
#
# ['十六进制', '编辑器', 'star', 'GitHub', '2500', 'ImHex', '最火', '24', '1600', '友好', '上线', 'bit', '视力', '字节', '收获', '文件', 'SHA', '项目', '字符串', '数据']
#
# ['Adam', '优化', '算法', '神经网络', '最佳', '假设', '架构', '学习', '2015', '波士顿大学', '深度', '人会', '助理', '社区', '王者', 'idea', '教授', '训练', '论文', '领域']
#
# ['郵件', 'social', 'btn', 'set', 'left', 'block', 'margin', '詐騙', '駭客', '12', 'width', 'BEC', '企業', '網頁', 'important', '規則', '15px', '100', 'float', 'fb']
#
# ['位幣', '000', '萬元', '現在', '將會', '12', '消費', '購物', '京東', '技術', '貨幣', '帶來', 'JD', 'China', 'currency', 'digital', '瑞拉', '平台', '市民', '兩個']
#
# ['Oppo', 'Vivo', '相機', '一項', '專利', '乾脆', '同工', '一套', '幾個', '曾公', '分離式', '手機', '設計', '將相機', '隱藏', '機身', '頂端', '時用戶', '根據個', '將其以']
#
# ['駕駛', 'AutoX', 'googletag', '全自動', '中國', '車隊', '的士', '初創', '已經', '自動', '情況', 'Level', '無人', 'div', 'gpt', 'ad', '1529571774980', '1009409', '路面', '牌照']
#
# ['數碼幣', '碼幣', '京東', '紅包', '購物', '中國', 'googletag', '州政府', '發放數', '出資', '消費', '貨幣', '深圳', '指定', '平台', '抽獎', '萬位', '參加', '相關', '推廣']
#
# ['輔助', 'NTD', '駕駛', '自動', '聯合', '新聞', 'udn', '特斯拉', '升級', 'Tesla', '全自動', 'EAP', '軟體', '服務', '選擇', '數位', '運動', '筆記', '文創', '功能']
#
# ['iPhone', 'iOS', '14', '12', '耗電', 'fbq', '電量', '問題', '2020', '手機', '電異常', 'js', '蘋果', '災情', '論壇', '50', '傳出', '狀況', '網友', 'function']
#
# ['比特', '區塊', '市場', '監管', '中國', '貨幣', '持續', '投資者', '趨勢', '減少', '狂人', '數位', '投資', '2017', '風險', '幣價', '調整', '聯動', '建議', '新高']
#
# ['社群', '廣告', '電商', '消費者', '平台', '協作', '數據', '品牌', 'Facebook', '數位', '購物', '成長', '商品', '投放', '興趣', '用戶', '網購', '服務', '台灣', '消費']
#
# ['Uber', '服務', 'Eats', '消費者', '台灣', '計程', '車隊', '優惠', '夥伴', '限次', '手續費', '成為', '陸續', '駕駛', '雙享', '外送', '00', '方案', '台北市', '介面']
#
# ['HoloLens2', '醫療', '應用', '天晟醫院', '翁國益', '醫生', '導入', '3D', '病患', '體系', '服務', '設備', '軟體', '領域', '場景', '進行', '討論', '透過', '鄭貴麟', '科技']
#
# ['浮動式', '風場', '開發', 'CIP', '離岸', '台灣', '風機', '階段', '區塊', '侯奕凱', '風電', '目標', '計畫', '超過', '國際', '00', '苗栗', '第三', '容量', '水深']
#
# ['LINE', 'MUSIC', '中華電信', '雙方', '服務', '用戶', '張景雯', '音樂', '合作', '答鈴', '台灣', '上線', '串流', '100', '活躍用', '市場', '鈴聲', '行動', 'KKBOX', '成為']
#
# ['發票', '免費', '電子', '教學', '下載', '服務', 'Steam', 'WordPress', '設定', '網站', '遊戲', '郵件', '載具', '主機', 'Google', '網路', '推薦', '平台', '台灣', '歸戶']
#
# ['蹲點', '640', '台灣', '職場', '學習', '社區', '300', '心態', '投資', '480', '薪水', '創業', '程天', '投機', 'type', '250', '360', 'screen', 'list', '工作']
#
# ['ONEAD', 'window', 'parent', 'var', 'function', 'inread', '服務', '網友', 'div', 'divcontent', 'js', 'document', '留言', '京尊達', '尊享', 'slot', 'push', 'true', 'mobile', 'frameElement']
#
# ['蹲點', '社區', '台灣', '640', '動物', '保育', '300', 'conservation', '活動', '480', 'endangered', 'type', '250', '360', 'screen', 'list', '影展', 'extinct', '中華電信', '絕種']
#
# ['住宅', '國民', '發展', '台灣', '640', '檔案', '區域', 'Taiwan', '灣亞洲', '論壇', '300', '國家', '社會', '創新', '藝文', 'epidemic', '480', '交流', '南向', '組織']
#
# ['ONEAD', '華強', 'window', '電子', '轉型', 'parent', '化妝品', 'var', '市場', '美妝', 'function', 'inread', '手機', '數位', '遠望', '中國', '明通', '商場', '廣告', '已經']
#
# ['ONEAD', 'window', 'parent', 'var', 'function', '耳機', 'inread', 'Hammerhead', 'True', 'Wireless', 'Pro', 'Razer', 'div', 'divcontent', 'js', 'document', '留言', '低延遲', 'slot', 'push']
#
# ['ONEAD', 'window', 'parent', '14', 'var', 'function', '問題', 'inread', 'iPhone', '手機', '蘋果', '電池', 'div', 'divcontent', 'js', 'document', '留言', '更新', 'iPadOS', 'iOS']
#
# ['英國', '歐盟', '空氣', '640', '空污', '協議', '脫歐', '減排', '300', '10', '減煤', '機組', '貿易', '影響', '電廠', '480', '台灣', '品質', 'type', '250']
#
# ['牙膏', '640', '北宜', '300', '林佳龍', '480', '台鐵', '環境', '口腔', '環保', 'type', '250', '360', 'screen', 'list', '添加物', '高鐵', '台灣', '成分', 'TNL']
#
# ['ONEAD', 'Windows', 'window', 'parent', 'var', 'function', 'inread', 'Feature', 'Experience', 'Pack', '系統', 'div', 'divcontent', 'js', '功能', '透過', 'document', '留言', '更新', '微軟']
#
# ['2020', '12', '08', '財經', '10', '20', '新聞', '06', '華爾街', '銀行', '天牧', '台灣', '07', '觀點', '11', '日報', '50', '股利', '英國', '國內']
#
# ['ONEAD', 'window', 'parent', '系統', 'var', 'function', '微軟', 'inread', '軟體', '會議', '一種', 'AI', 'div', 'divcontent', 'js', '工作', '數據', 'document', '留言', '時間']
#
# ['ONEAD', 'window', 'parent', 'MacBook', 'var', 'function', 'inread', 'Mini', 'LED', 'Apple', '蘋果', 'Pro', 'div', 'divcontent', 'js', 'document', '留言', '顯示器', 'slot', 'push']
#
# ['12', '2020', '08', '美國', '中國', '10', '日報', '11', '新聞', '監管', '台灣', '00', '電子', '13', '華爾街', '香港', '公司', '概股', '預計', '市場']
#
# ['2020', '12', '08', '10', '國產化', '新聞', '20', '11', '30', '階段', '遴選', '台灣', '潘維庭', '00', '13', '立邦', '離岸', '風電', '區塊', 'CIP']
#
# ['台灣', '640', '劉銘', '300', 'Taiwan', '傳台灣', '480', '數位化', '劉銘傳', '電視', 'Vietnam', 'epidemic', 'type', '250', '360', 'screen', 'list', '灣亞洲', '中共', '國家']
#
# ['social', 'btn', 'set', 'left', 'block', 'margin', '伺服器', 'Dell', '12', 'width', '資料', 'important', '15px', '100', 'float', 'fb', '防護', '硬碟', '產品', 'fan']
#
# ['social', 'btn', 'set', 'left', 'margin', 'width', 'block', 'Monitron', '12', 'page', 'important', '100', '15px', 'AWS', '學習', '閘道器', 'float', 'fb', '感測器', 'Amazon']
#
# ['人工智能', 'Synced', '机器', '全球', '学习', 'Medium', 'Reddit', '之心', '算法', '产业', '拥有', '平台', '媒体', '账号', '统计学', '用户', '理论', '高校', 'Twitter', 'Top']
#
# ['AI', '高通', '骁龙', '888', '张量', '引擎', 'Hexagon', '处理器', '神经网络', '游戏', '5G', '提升', '支持', '开发者', '体验', 'Direct', '性能', '全新', '加速器', '平台']
#
# ['CPU', 'GPU', 'BytePS', '带宽', 'PS', '机器', 'reduce', 'PCIe', '梯度', 'NVLink', '架构', '链路', '瓶颈', 'CPU0', '拓扑', '通信', '利用', '聚合', '内存', '优化']
#
# ['DETR', 'Transformer', '查询', '检测', '目标', 'patch', 'transformer', '研究者', 'CNN', '解码器', '注意力', '训练', '特征', 'Deformable', 'ACT', '编码器', '图像', 'Detection', '论文', '模块']
#
# ['MODNet', 'trimap', '方法', '子目标', '神经网络', '模型', 'free', '人像', '蒙版', '100', 'PPM', '数据', '图像', '提出', '绿幕', 'SOC', '监督', '语义', '基准', '前景']
#
# ['內容', 'social', 'btn', 'set', 'left', '銀行', '樂天', 'block', 'margin', '12', 'width', '資料', '2020', '攻擊', 'AI', '服務', 'important', '應用', '15px', '100']
#
# ['比特', '區塊', '貨幣', 'Didi', 'Taihuttu', '加密', '2017', '市場', '40', '個國家', '發揮', '盧布爾雅', '韋雷托', '國家', '傳統', '價值', '改變', '鏈技術', '經歷', '堅持']
#
# ['數位幣', '測試', '京東', '區塊', '蘇州', '位幣', '數位', '活動', '消費', '技術', '12', '進行', '支付', '中國', '場景', '紅包', '購物節', '銀行', '貨幣', '香港']
#
# ['UTXO', 'withdraw', 'layer', 'tree', '一個', '協議', '證明', 'zkopru', 'Rollup', 'hash', 'period', 'merkle', '使用者', '收款', 'circuit', 'Optimistic', 'proof', '零知識', 'EVM', 'outputs']
#
# ['穩定幣', '貨幣', 'Tether', '加密', 'USDT', '區塊', '美元', '掛鉤', 'USDC', '市場', '增長', 'DeFi', '資產', '開發', '中心化', '數位', 'TUSD', '金融', '項目', '獲得']
#
# ['比特', '資產', '區塊', '投資', '投資人', '市場', 'Niall', 'Ferguson', '價格', '認為', '這種', '幣做', '組合', '投入', '美元', '低點', '現在', '選擇', '幣的', '貨幣']
#
# ['Apple', '產品', '維修', '服務', '過時', 'iMac', '預約', 'fbq', '時間', '12', '解析度', '授權', '停產產品', '2020', 'js', 'Retina', '清單', 'function', '保固', 'iPhone']
#
# ['比特', '區塊', 'Willy', 'Woo', '增長', '認為', '廣泛', '市場', '未來', '機構', '數位', '美元', '全球', '分析', '幾年', '投資', '頂級', '幣的', '技術', '2021']
#
# ['課程', '電子', '開發', '郵件', '設計', 'HTML', 'CSS', '一個', '人員', 'Web', 'Brad', 'Traversy', '程式', '專案', 'JavaScript', '這是', '講師', '位址', '訂閱', '網站']
#
# ['感器', 'Samsung', '像素', '相機', '研發', 'Sony', '12', 'CMOS', '手機', '2020', '已經', '幻燈片', '模組', '這款', '應用', '鏡頭', 'Kin', '11', '在手', '率先']
#
# ['失智症', '失智', '國泰人壽', '40', '預防', '花漾', '網站', '資源', '提供', '推估', '大人', '部協理', '建勳', 'facebook', '協會', '65', '20', '瞭解', '建議', '大腦']
#
# ['Nokia', '設計', '12', 'FCC', '採用', '理器', '2020', '曝光', '屏幕', '認證', '這是', '機型', '電池', '4000mAh', '手機', '將會', '風格', '配備', '4GB', 'RAM']
#
# ['Fitbit', 'Sense', '發現', '問題', '影響', 'fitbit', 'Verge', '論壇', '戶回', '報稱', '主動', '聯絡', '擁有', '心電圖', '願意', '免費', '更換', '出貨', '總共幾百', '會出']
#
# ['手機', '小米', '市場', '印度', '出貨量', '銷量', '中國', '成長', '億部', 'Counterpoint', '資料', '萬部', '華為', '30', '市占率', '第三季', '品牌', '蘋果', '2021', '00']
# ['國安法', '露營', '親子', '保釋', '關鍵', '640', '得志', '戶外', 'Sammi', '香港', '控罪', '許多', '餐豐', '300', '活動', '案件', '法官', '露宿', '漫畫', '黎智英']
#
# ['照護', '640', '風險', '比特', '投資', 'P2P', '網路', '借貸', '300', '艾蜜莉', '榮家', '平台', '480', '貨幣', 'type', '250', '360', 'screen', 'list', '台北']
#
# ['2020', '12', '08', '10', '財經', '11', 'P1101', '20', '新聞', '醫藥', '營收', '市場', '06', '華爾街', '藥華', '歐洲', '07', '觀點', '日報', '50']
#
# ['ONEAD', 'window', 'parent', 'var', 'function', 'inread', '步驟', 'div', 'divcontent', 'js', '內容', 'document', '留言', '黏箋', '10', 'slot', 'push', '刪除', 'true', 'mobile']
#
# ['12', '2020', '08', '科技', '10', '創新', '銘傳大學', '新冠', '金融', '總經理', '新聞', '台灣', '20', '觀點', '06', '肺炎', '論壇', '學院', '李銓', '發展']
#
# ['免費', '下載', '網站', '教學', '紅酒', 'WordPress', '推薦', '服務', '主機', '應用', '小資', '筆記本', 'Google', '電子', '賣場', '郵件', '葡萄酒', '程式', '網路', '台灣']
#
# ['ONEAD', '投影', 'window', 'Epson', 'parent', 'var', '雷射', 'AR', '教學', 'function', '超短', 'inread', '眼鏡', 'EB', '教育', '智慧', '12', '軟體', 'div', 'divcontent']
#
# ['Galaxy', 'Flip', '5G', '新色', '手機', '萬畫素', 'https', '2020', '08', '編輯', '主題', 'Candice', '三星', '帶來', '白色', '設計', '總絕', '心動', '9to5google', '將為']
#
# ['WeMo', 'Scooter', '2020', '軌跡', '熱區', '活動', '年度', '回顧', '12', '獲得', '免費', '星座', '洞察', '大數據', '機車', '樣貌', '消費者', '統整', '還能', '兌換']
#
# ['駕駛', 'AutoX', 'googletag', '全自動', '中國', '車隊', '的士', '初創', '已經', '自動', '情況', 'Level', '無人', 'div', 'gpt', 'ad', '1529571774980', '1009409', '路面', '牌照']
#
# ['應用', 'AI', '影像', 'ADA', 'NVIDIA', '產生', 'Google', '訓練', '醫療', '開發', '計畫', '科技', '技術', '資料', '透過', '理器', '個小時', '藝術', 'GAN', '領域']
#
# ['adsbygoogle', '解壓', '檔案', 'window', 'push', '軟體', '問題', '轉貼', '本站', '縮密碼', 'azo', '阿榮', '福利', '常見', '連結', '載點', '歡迎', '隨意', '盜連', '無須']
#
# ['應用', '貨幣', '科技', '位幣', '發展', 'Google', '透過', '理器', '個小時', '加密', '未來', 'Mash', 'Yang', '推出', '中國', '推動', '數位幣', 'PaMu', '三星', '交易']
#
# ['貨幣', 'ETF', '加密', '投資', '監管', '奧利里', '比特', '機構', 'SEC', '考慮', '態度', '美國', '許可', '組合', 'Pompliano', '獲得', '願意', 'Kevin', 'Leary', '採訪']
#
# ['Google', 'Timnit', 'Gebru', '應用', '科技', '未來', '個小時', '人工智慧', '技術', '問題', '內容', '報告', 'Mash', 'Yang', '蘋果', '理器', '推出', '過去', '處理', '相關']
#
# ['中國', '郭文貴', '貨幣', '推特', '虛擬', '戰爭', '武漢', '所謂', '軍事', '西方', '美國', '市場', '發生', '無聲', '認為', '現在', '部隊', '3700', '發展', '島鏈']
#
# ['Instagram', 'Academy', '企業家', '課程', '透過', '培訓', '創業', '網上', '計劃', 'Facebook', '傳統', '傳承傳', '青年', '300', '35', '協會', '社會', '創新及', '階段', '大中華區']
#
# ['比特', '單位', 'bits', '100', '貝克', 'sat', '認為', 'Adam', 'Back', 'Satoshi', '區塊', 'BTC', '000', '最小', '雜湊', '推特', 'bit', '幣的', '美元', '明人']
#
# ['Google', '應用', '程式', 'Play', '開發者', '一個', '修補', '核心', '商店', '已經', '漏洞', '用戶', '來源', '瀏覽器', '還沒有', 'Check', 'Point', 'adsbygoogle', '安全性', '伺服器']
#
# ['2020', '12', '07', '22', '08', '雷姆', '雷斯特', '18', '44', '20', '目標', '37', 'Chungwen19', '09', '45', '惡魔', '獵人', '14', '33', '期望']
#
# ['創意', 'QoA', '耳機', '個小時', 'iPhone', '推出', '採用', 'Adonis', '12', '評測', 'PaMu', '應用', '未來', 'Mash', 'Yang', '理器', '文化', '科技', '新品', 'May']
#
# ['iPhone', '12', '充電器', '18W', '12W', 'Pro', 'PD', 'mini', '電池', 'Max', 'USB', '滿足', '充電', '實測', '充電頭網', '5W', '20W', 'adsbygoogle', '容量', '系列']
#
# ['項目', 'BAC', '代幣', '美元', '協議', '11', 'DeFi', '市場', 'Aave', '中心化', 'Compound', '挖礦', '一個', '上線', '價格', 'DAI', '獲得', '流動性', 'Basis', '穩定幣']
#
# ['中國', '支付', '香港', '跨境', '進行', '數位幣', '國際', '投資', '金管局', '金融', 'DCEP', '余偉文', '銀行', '發展', '文章', '試點', '報告', '位幣', '貨幣', '技術']
#
# ['螢幕', '中國', '米家', '小米', '掛燈', '來源', '圖片', '台灣', '採用', '產品', 'NCC', '選擇', '調整', '市場', '顯示器', '開賣', '這款', '認證', '設計', '螢幕掛']
#
# ['Pixel', 'Google', 'XE', '這支', '4a', '手機', '5G', '理器', 'Snapdragon', 'Redmi', 'Note', '手機間', '諜照', '螢幕', '開發', 'Pro', 'adsbygoogle', '系列', '以來', 'Android']
#
# ['Mola', '音響', '擴大機', '音樂', '歐姆', '博韻', 'DAC', 'Ted', 'Chen', '2020', 'MOLA', '發燒友', '透過', '一個', '內容', '前級', '網路', '輸入', 'Roon', 'https']
#
# ['Tesla', 'FSD', 'EAP', '自動', '輔助', '駕駛', '來源', '超充', '特斯拉', '用戶', '現在', '已經', 'Autopilot', '圖片', '台灣', 'Beta', '1500', '持續', '不斷', '價值']
#
# ['DCEP', '紅包', '銀行', '中國', '消費', '10', '000', '蘇州', '試點', '萬幣', '這次', '總額', '位幣', '抽獎', '活動', '12', '微信', '200', '京東', '效期']
#
# ['比特', '2021', 'Willy', '幣的', 'Woo', '美元', '減少', '2020', '2017', '持有者', '增加', '20', '估計', '導致', '獲利', '幣數量', '拋售', '壓力', '購入', '市場']
#
# ['以太', '比特', '加密', '貨幣', 'ETH', '投資人', 'Grayscale', 'ETHE', '越來', '歷史', '數據', '幣價格', 'Eth2', '美元', 'Michael', 'BTC', '認識', '網路', '升級', '計畫']
#
# ['符號', '記錄', '心情', '表情', 'adsbygoogle', '文字', '寫日記', '下來', '日記', '15', '種情緒', '名稱', '點擊', '電子', '完整版', '寫些', 'window', 'push', '情緒', '當天']
#
# ['比特', '經濟', '數據', '美元', '拜登', '貶值', '美國', '000', 'ECB', '歷史', '非農就業', '就業', '規模', '指數', '顯示', '成長', '080', '印鈔', '債務', '困案']
#
# ['事項', '獲得', 'adsbygoogle', '辦清單', '設定', '清單', '出現', '電子', '新任', '滿足感', 'window', 'push', 'Least', 'Dangerous', 'Do', 'List', '打開', '標記', '辦事項', '右側']
#
# ['應用', 'Google', '科技', '克里', '薩德', '理器', '個小時', '伊朗', '透過', '推出', '人工智慧', '機關', '法達威', 'AI', '報導', '發展', 'iPhone', 'Mash', 'Yang', 'Pixel']
#
# ['iPhone', '電量', '6s', 'iOS', 'Apple', '14', '升級', '論壇', '用戶', '反應', 'iPad', 'mini', 'Plus', '一個', '時間', '30', '分鐘', '誇張', '這位', '發生']
#
# ['DeFi', 'AC', '項目', '一個', 'YFI', '托拉斯', '當前', '區塊', 'Yearn', '社群', '這種', 'Layer', '閱讀', '借貸', '市場', '商業', 'Sushiswap', '世界', '中心化', '出現']
#
# ['比特', '市場', 'USDT', '機構', '加密', '投資者', 'Tether', '區塊', '貨幣', '投資', '一個', 'Coinbase', '美元', '000', '20', '投資人', '服務', '指數', '價格', '聖誕節']
#
# ['iPhone', '12', 'Pro', 'fbq', '14', '15', '20', '平均', 'js', '薪資', '2020', '工作', '一個', '國家', 'Index', '21', '128GB', '17', '18', 'function']
#
# ['加密', '貨幣', 'Coinbase', '市場', 'BitGo', 'Genesis', 'CEO', '服務', '機構', '銀行', '全倉', '大宗', '圖薩爾', '莫羅', 'MicroStrategy', '已經', '保證', 'Block', '領域', '卡邁']
#
# ['台南', '發展', '鐵路', '地下', '台積', '投資', '台南市', '未來', '綠能', '產業', '台積電', '南科', '預計', '蘇煥智', '周邊', '系統', '一個', '平交道', '智慧', '都市']
#
# ['計畫', '李奧納', '美國', '中國', '試圖', '機密', '成為', '英國', '防部', '一前', '將與', '法國', '進行', '聯合海', '陸軍事', '演習', '以面', '威脅', '國務院', '終止']
#
# ['省心', 'googletag', '淘寶', '網購', '特別長', '設計', '能夠', 'div', 'gpt', 'ad', '1529571774980', '1009156', '版面', '疫症', '爆發', '次數', '大減', '網絡', '購物次', '數則']
#
# ['Galaxy', 'Buds', 'Pro', 'googletag', '發表', '設計', 'Samsung', 'Evan', 'Blass', 'div', 'gpt', 'ad', '1529571774980', '1009160', '上代', '紫色', '版本', '色感', '系列', '亦不例外']
#
# ['企業', '軟體', '資料', '程式', 'Auto', 'Office', 'adsbygoogle', 'L1', 'App', 'Windows', '安裝', '選擇', '設定', '功能', '下載', '執行', '系統', 'APP', 'window', 'push']
#
# ['成長', '行銷', '消費者', 'awoo', '數據', 'www', '2020', '技術', 'https', '駭客', '講者', 'facebook', '能夠', 'groups', 'shumai', 'permalink', '持續', '相關', '創辦', '品牌']
#
# ['Ctrl', 'Chrome', '開啟', '擴充', 'Shift', '設定', '瀏覽器', '實用', '快捷', '功能', '快速', 'Alt', '一個', 'adsbygoogle', '分頁', '指令', '許多', '切換', '顯示', '新分頁']
#
# ['Chrome', '網站', '自動', '創建群', '組標', '分頁', '功能', '顏色', '瀏覽器', 'adsbygoogle', '開啟', '瀏覽', 'Google', '87', '免安裝版', '群組', '並用', '將網', '找到', '滑鼠']
#
# ['5G', '解決', '網路', '服務', '技術', '遠端', '設備', '應用', '數據', 'COVID', '19', '方案', '透過', 'MEC', '問題', '連接', '醫療', 'AR', '挑戰', 'IoT']
#
# ['攻擊', '設備', '雲端', '物聯網', '終端', '聯網', '網路', '無線', '進行', '平台', '應用', 'LoRa', '通信', '3S', 'Market', '領域', '企業', '數據', '應該', '駭客']
#
# ['區塊', '市場', '投資者', '回調', '走勢', '狂人', '比特', '出現', '持續', '新高', '數據', '情況', '震盪', '繼續', '這種', '機構', '建議', '高位', '拋壓', '出貨']
#
# ['程式', '英國', '下載', '國家', '各國', '成效', '透明度', '疫情', '20', 'Gardner', '民眾', '反應', '人下載', '當地', '法國', '15', '12', '數字', '解決', '資料']
#
# ['razr', '5G', 'Moto', '測試', '手機', '阿輝', '螢幕', '拍攝', '設計', '參考', '像素', '技術', '折疊', '採用', '相機', '電力', '夜景', '部份', '問題', '理器']
#
# ['开发人员', '代码', '应用程序', '时间', '有助于', '编写', '开发者', '高级', '评审', '编码方式', '19', '嵌套', '可读性', '编码', '命名', '程序', '语句', '解决', 'CRUD', '语法']
#
# ['开源', '飞桨', 'AI', '启智', '开发者', '社区', '人工智能', '深度', '开放', '百度', '学习', 'OpenI', '硬件', '框架', '技术', '适配', '芯片', '产业', '研发', '计算']
#
# ['Line', '5G', 'social', 'btn', 'set', 'left', 'block', 'margin', '中華電信', '12', 'width', '服務', 'Music', '內容', '100', 'important', '2020', '15px', '鈴聲', '答鈴']
#
# ['实体', '查询', '图谱', '知识', '路径', '自然语言', '问答', 'select', '识别', '关系', '模型', '方法', '答案', '链接', '莫妮卡', '语义', '分类', '人工智能', '贝鲁奇', '语句']
#
# ['軟體', '資料', 'social', 'btn', 'set', '勒索', 'left', '攻擊', 'block', 'margin', '12', 'width', '攻擊者', 'important', '15px', '駭客', '100', 'float', 'fb', '贖金']
#
# ['social', 'btn', 'set', 'left', '12', 'block', 'margin', 'width', '駭客', '攻擊', 'important', '15px', '100', 'float', 'fb', '疫苗', '冷鏈', 'fan', 'page', 'top']
#
# ['量子', '潘建伟', '计算', '计算机', '九章', '优越性', '玻色', '原型机', '采样', '光子', 'Sycamore', '团队', '物理学', '研究', '2020', '10', '朝阳', '超级计算机', '中科院', '100']
#
# ['伟达', '注册', '参会', '显卡', 'A100', 'GTC', 'RTX', 'NVIDIA', 'GPU', '19', '12', '电商', '参会者', '15', '拉杆箱', 'Jetson', 'Nano', 'GeForce', '3070', '二维码']
#
# ['巡检', '输电线', '无人机', '控制站', 'substation', '地面', '停车', '路径', '时间', '站点', '飞行', '传输', 'PP', '方法', '下图', '信号', '顺序', '电力', '动力系统', '2020']
#
# ['算法', 'model', 'M2AC', '环境', '交互', '噪音', 'RL', 'MBRL', '模型', 'based', '策略', '样本', 'MBPO', '学习', '性能', '试错', '强化', '误差', 'Model', 'free']
#
# ['AACL', '自然语言', '百度', 'NLP', '论文', 'ACL', '主席', '千言', '会议', '2020', '亚太', '技术', '收录', '分会', '海峰', '中文', '领域', '知识', '投稿', '图谱']
#
# ['该市', 'COUNTY', 'NO', '数据', '网络安全', '系统', '部门', '2019', '服务', '公民', '提供', '应用程序', '技术', '2020', '10', '信息', '远程', '网站', '城市', '网络']
#
# ['samples', '置信度', '聚类', '样本', '方差', 'feature', '标签', 'sampling', 'dataset', 'labeled', 'label', 'sample', 'confidence', 'number', 'distance', 'unlabeled', 'labels', 'space', 'variance', '采样']
#
# ['5G', 'V2X', '公交', '轻舟', '无人', '场景', '车路', '智行', '协同', '无人驾驶', '智能', '智航', '华砺', 'Waymo', '智航华砺', '10', '合作', '安全性', '车辆', '运动']
#
# ['区块', '节点', '联邦', '学习', '比特', '参与方', '梯度', '数据', '模型', '以太', '加密', '中心化', '隐私', '索信', '信息', '中心', '生态', '训练', '点对点', '机制']
#
# ['ID', 'pseudo', 'loss', 'shot', 'labelled', 'training', 'Re', 'sample', 'label', 'method', 'HSoften', 'Triplet', 'Loss', 'mAP', 'learning', 'triplet', 'positive', 'person', 'images', 'samples']
#
# ['social', 'btn', 'set', 'left', 'Google', 'block', 'margin', '12', 'width', 'VR', 'important', '15px', 'AR', '100', 'float', 'fb', '2020', 'fan', 'page', 'top']
#
# ['social', 'btn', 'set', 'left', 'block', 'margin', '12', 'width', 'important', '資訊', '15px', '100', 'float', 'fb', '美國', '2020', 'fan', 'page', 'top', 'ACLU']
#
# ['攻擊', 'social', 'btn', 'set', 'left', 'block', 'margin', '12', 'width', 'macOS', '駭客', '程式', '趨勢', '軟體', 'important', '15px', '100', 'float', 'fb', '檔案']
#
# ['NeurIPS', '2020', 'MeetUp', '参会', 'AI', '接收', '论文', '学术会议', '人数', '人工智能', '顶级', '之心', '邀请', '机器', '12', '林宙辰', '俞扬', 'Lab', '13', 'http']
#
# ['AWS', '机器', '学习', 'Trainium', '实例', '芯片', 'Inferentia', '训练', '2020', 'Invent', 'Jassy', 'Amazon', '计算', '发布', '亿美元', '数据', '服务', '客户', 'EC2', 'GPU']
#
# ['social', 'btn', 'set', 'left', 'block', 'margin', '12', 'width', 'Crutch', 'important', '15px', '程式', '100', 'float', 'fb', 'ESET', 'fan', 'page', 'top', '2020']
#
# ['social', 'btn', 'set', 'left', 'block', 'margin', '12', 'width', '2020', '攻擊', '漏洞', 'important', '15px', 'WebLogic', '100', 'float', 'fb', '發現', 'DarkIRC', 'fan']
#
# ['銀行', 'social', 'btn', 'set', 'left', 'block', 'margin', '12', '服務', '用戶', 'width', '手機', 'ATM', 'NFC', '感應', 'API', '樂天', '中信', '台壽', '2020']
#
# ['行人', '识别', '30k', '图像', 'SYSU', '识别方法', '监督', '类别', '数据', '模型', '标签', '标注', '研究者', '训练', '神经网络', '函数', '学习', '方法', '身份', '本文']
#
# ['开源', '项目', '经受考验', '捆住', '下班', '维护', 'Thornton', '精力', '开发者', '小时', 'Bootstrap', '工人', '几个', '代码', '时间', 'Otto', '贡献者', '源代码', 'Jacob', 'Mark']
#
# ['GitHub', '2020', 'Octoverse', '开发者', '开源', '报告', '往年', '稍微', '来得', '贡献者', '用户', '数量', '规划', '社区', '2025', 'JavaScript', 'Python', 'TypeScript', '10', '工作']
#
# ['Transformer', '视觉', '模型', 'IPT', '底层', '训练', '自然语言', '分辨率', '维度', '领域', '华为', '鹏程', '悉大', 'Image', 'Processing', '输入输出', '研究者', 'OpenAI', 'iGPT', 'Facebook']
#
# ['social', 'btn', 'set', 'left', 'block', 'margin', 'Visa', '12', 'width', 'Circle', '貨幣', 'important', '15px', 'USDC', '100', 'float', 'fb', '2020', '加密', 'fan']
#
# ['盘古', '作业', '百度', '工程机械', '无人化', '规划', '宝马', 'AI', '算法', '无人', '运动', '智能', '路径', '挖掘机', '智能化', '技术', '感知', '机械行业', '赋能', '徐工']
#
# ['注意力', '解释性', '显著性', '机制', '方法', '输入', '分析', '定义', '研究', '本文', '解释', '用于', '对模型', '论文', '人工智能', '工作', '发挥作用', 'NLP', '作者', '观点']
#
# ['样本', '物体', '检测', '类别', 'RepPoints', '微软', '验证', '检测器', '目标', '学习', 'CNN', 'BVR', '候选框', '特征', '模块', '2020', 'RepMet', '方法', '机器翻译', '图像']
#
# ['存取', '儲存', '加密', '服務', '檔案', 'social', 'btn', 'set', '用戶', 'left', 'block', 'margin', '儲存區', '資料', '12', 'width', '網路', '傳輸', 'Storage', '設定']
#
# ['儲存', '服務', '公有', '檔案', '雲檔案', '應用', 'social', 'btn', 'set', 'left', 'block', '協定', 'margin', '12', 'width', '類型', 'Storage', 'NAS', 'NFS', 'NFSSMB']
#
# ['social', 'btn', 'set', 'left', 'margin', 'width', 'block', '裝置', '12', '無人機', '攝影', 'page', '跌倒', 'important', '無人', '2020', '100', '15px', '親人', 'float']
#
# ['social', 'btn', 'set', 'left', '攻擊', 'block', 'margin', '資料', '12', '系統', 'width', '資安', '勒索', '軟體', '用戶', '駭客', '100', '2020', 'important', '程式']
#
# ['social', 'btn', 'set', 'left', 'block', 'margin', '12', 'width', '漏洞', '100', 'iOS', '2020', '蘋果', '攻擊', 'important', 'Beer', '15px', 'float', 'fb', '裝置']
#
# ['Libra', '貨幣', 'social', 'btn', 'set', 'left', 'block', 'margin', '12', 'width', 'Diem', '協會', '臉書', '加密', 'important', '2020', '15px', '100', 'float', 'fb']
#
# ['废钢', '定级', 'AI', '阿里巴巴', '准确率', '学习', '达摩院', '深度', '识别', '扣重', '料型', '2018', '算法', '神经网络', '晋南', '钢铁集团', '例数', '分类', '网络', '质检员']
#
# ['3D', '视频', '图像', '关键点', '方法', '伟达', '头部', '视频会议', '模型', '合成', '人脸', '人物', '驱动', '2D', '动作', '带宽', '研究', '研究者', '说话', '提出']
#
# ['API', '飞桨', '模型', '高层', '框架', '组网', '数据', '自定义', '学习', '深度', '训练', '加载', 'paddle', '代码', '披萨', 'Sequential', 'SubClass', '预处理', 'Model', 'aistudio']
#
# ['骁龙', '888', '高通', '5G', '芯片', 'AI', '5nm', '三星', '制程', 'www', '采用', '小米', '基带', '雷军', '处理器', '2020', 'SoC', 'X60', '35', '11']
#
# ['social', 'btn', 'set', 'left', 'Google', 'block', 'margin', '12', 'width', 'Maps', 'important', '15px', '100', 'float', 'fb', '2020', 'fan', 'page', 'top', 'display']
#
# ['social', 'btn', 'set', 'left', 'block', 'margin', '12', 'width', '軟體', 'important', '15px', '100', 'float', 'fb', 'BCPS', 'fan', 'page', 'top', '2020', '勒索']
#
# ['查询', '代理', '视频', '结构化', '方法', '分数', 'DNN', '提取', '算法', '模型', 'oracle', '记录', '数据', '神经网络', 'Oracle', '信息', '学习', '多地', '近似', '训练']
#
# ['因果关系', 'al', 'Proceedings', 'Workshop', '2016', '因果', 'ACL', 'Causal', '学习', '神经网络', '2008', 'Extraction', '事件', '关系', 'Computational', 'task', 'Event', '语义', 'Association', 'Linguistics']
#
# ['誠品', 'social', 'btn', 'set', 'left', 'block', '網站', 'margin', '12', 'width', '電商', '通路', '吳旻潔', '社區', 'important', '15px', '物流', '新電商', '顧客', '100']
#
# ['social', 'btn', 'set', 'left', 'block', 'margin', '比特', '12', 'width', 'important', '2020', '15px', '100', 'float', 'fb', '市場', 'fan', 'page', 'top', 'display']
#
# ['数字化', '企业', 'AI', '转型', '业务', '客户', '能力', '架构', '5G', '数据', '敏捷', '成熟度', '方式', '传统', '服务', '组织', '机制', '2020', '运营', '分析']
#
# ['AI', '开发者', '华为', 'DevOps', '开发', 'ModelArts', '12', '技术', '原生', '沙龙', '研发', '面对面', '现场', 'DevRun', '进阶', '算力', '运维', 'DevCloud', '数据', '高效']
#
# ['语言', '模型', '学习', '解释', '训练', 'SAIL', '神经网络', '自然语言', '机器', 'BERT', '论文', '表征', '领域', '识别', '视觉', '语义', '深度', '特征', '输入', '研究者']
#
# ['paper', '学习', '顶会', '讲故事', '工业界', 'talk', '领域', '工作', '方法', '机器', '一篇', '灌水', '理论', '解决', '越来越', '角度', '贡献', '例子', '经典', '算法']
#
# ['学习', '论文', 'ICLR', '模型', '深度', '卷积', '神经网络', '机器', '2021', '算法', '数据', '自然语言', '表征', '得分', '网路', '梯度', '特征', '关键词', '生成', '领域']
#
# ['蛋白质', 'AlphaFold', 'DeepMind', '结构', 'CASP', '预测', '折叠', '序列', '氨基酸', 'GDT', '实验', '领域', '神经网络', '方法', '残基', '研究', 'AI', 'CASP14', '准确率', '学习']
#
# ['AI', '芯片', 'BP', '技术', '黑磷', '功能', '层状', '图像', '成像', '集成', '系统', '人脑', 'RMIT', '由光', 'Ahmed', '纳米级', '视觉', '内存', '论文', '学习']
#
# ['9000X', '2021', '拯救', '全新', '粉丝', '轻薄', '性能', '显卡', '搭载', '处理器', '联想', '体验', 'Y9000X', 'R9000X', '标压', 'RTX', '2060', 'Max', '144Hz', '100']
#
# ['人工智能', '百度', '专利申请', '自然语言', '领域', '智能', '图谱', '深度', '学习', '技术', '授权量', '知识', '专利', '2020', '我国', '语音', '搜索引擎', '数量', 'AI', '发展']
#
# ['BLENDer', '模型', '微视', 'VCR', '腾讯', 'person', '视频', '刷新', '成绩', '技术', '模态', '最佳', '史上', '内容', '一举', '团队', 'AI', '人工智能', '理解', 'MLM']
#
# ['时空', '操作系统', '千寻', '昆仑镜', '北斗', '智能', '调度', '位置', '能力', '高精度', '定位', '终端', '城市', '基准', '精准', '地图', '统一', '时间', '空间信息', '计算能力']
#
# ['人工智能', 'MBZUAI', '邢波', 'AI', '教授', '大学', '扎耶德', '阿联酋', '第一所', '默德', '默罕', '一职', '校长', '领域', '全球', '任命', '担任', '学者', '著名', 'Al']
# ['Rust', 'AWS', 'Klock', 'Felix', '语言', '编译器', '聘用', '开源', '团队', 'loves', 'Why', 'Amazon', '文章', '数种', '上周二', '篇文章', '列举', 'Mozilla', '工程师', '一篇']
#
# ['翻译', '情感', '知识', '模型', '方法', '语义', 'SQL', '文档', '分类器', '文本', '神经网络', '训练', '领域', '数据', '单元', '机器翻译', '语音', '信息', '提出', '2020']
#
# ['人工智能', '智能', '测试', '算法', '认知', '算力', '脑科学', '图灵', '计算', '神经元', '光电', '神经网络', '新一代', '发展', '包括', '提出', '通用', '提升', '科学家', '类脑']
#
# ['app', 'Windows', '安卓', '微软', '10', '操作系统', 'Latte', '将安卓', 'WSL', '设备', '项目', '开发', '英特尔', 'Microsoft', 'Linux', 'Play', 'Services', 'PC', 'M1', '引入']
#
# ['模型', 'Transformer', '基准', '序列', '注意力', 'LRA', 'DeepMind', '高效', '评估', '图像', 'xformer', '内存', '性能', '长度', '研究', '语境', '长程', '机制', 'Long', 'Linformer']
#
# ['AI', '游戏', '玩家', '学习', '英雄', '绝悟', '腾讯', '王者', '荣耀', '挑战', 'MOBA', '训练', '人工智能', 'AlphaGo', '神经网络', '强化', '围棋', '智能', '模型', '五一']
#
# ['快手', '模型', '王子', '机器', '神经网络', '之心', '图像', '收留', '学习', '算力', '生成', '童话', '特效', '风格', '一批', '训练', '映射', '用户', 'CPU', '分级']
#
# ['py', 'mlp', '分类', 'lightgbm', 'keras', 'pytorch', '数据挖掘', 'xgboost', '回归', 'binaryclass', 'multiclass', 'regression', '模型', '项目', 'mp', 'weixin', 'qq', '数据', '比赛', '类别']
#
# ['神经科学', 'AI', '大脑', '李飞飞', 'Newsome', '神经', '计算', '人工智能', '视觉', '领域', '智能', '神经元', '认知', '理解', '学习', '算法', '研究', '神经网络', '科学家', '意识']
#
# ['读博', '博士', '学习', '导师', '发帖人', '生涯', '机器', '项目', '算法', '方法', 'Nature', 'reddit', 'SOTA', '学生', '实验室', '机会', '想法', '博士生', '领域', 'idea']
#
# ['AI', '工业', '场景', '数据', '模型', '特征提取', '商业', '人才培养', '厘清', '采集', '迥然不同', '认知', '物理', '落地', '部署', '训练', '互联网', '对象', '系统', '困难']
#
# ['搜索', '三元组', '模型', '建模', '结点', 'Interstellar', '路径', '知识', '搜索算法', '图谱', '关系', '研究', 'shot', 'level', '方式', '算法', '递归', '2020', 'KG', 'P4']
#
# ['3D', '人脸', '图像', '三维', '融合', '特征', '视觉', '算法', '点云', '检测', '模态', '模型', '2D', 'https', '数据', '重建', '向量', '目标', 'RCNN', '人脸识别']
#
# ['流形', '学习', '图像', '数据', '空间', '像素', '假设', '正则', '监督', '算子', '拉普拉斯', '高维', '机器', '数学', '介绍', '论文', '领域', '嵌入', '维流形', 'https']
#
# ['学习', '机器', '算法', '算力', '下一代', '主义', '数据', '深度', '人工智能', '崔鹏', '教授', '观点', '奇迹', '神经元', 'AI', '领域', '徐君', '模型', '符号', '提出']
#
# ['山水画', 'AI', 'SAPGAN', '生成', 'Alice', '模型', '数据', '参与者', 'GAN', '创作', '学习', '人类', '55', 'AIice', '中国', '图像', '论文', '机器', '图灵', 'GitHub']
#
# ['CAMEO', '材料', '算法', '实验', 'AI', '学习', '神经元', 'GST467', '科学家', '研究', '机器', '人员', 'Nature', 'Communications', 'Kusne', '数据', '最佳', '射线', '10', '人工智能']
#
# ['张家港', '腾讯', '宏宝', '工业', '鹤鸣', '信息化', '管理', '实时', '园区', '互联网', '企业', '苏南', '保税区', '夏燕良', '生产', '平台', 'MES', '小微', '亚龙', '区块']
#
# ['评审', '双盲', '论文', '偏见', '接收', '学术界', '同行', '发表', '身份', '期刊', 'Lemire', '女性', '招聘', '开放', '严苛', '隐藏', '作者', '同质性', '会议', 'Daniel']
#
# ['点云', '图像', '3D', '视觉', '三维', 'RGB', '格式', '像素', 'https', '图源', '存储', '深度', '相机', 'www', '数据', '算法', '技术', '识别', '深度图', '文件格式']
#
# ['注释', '类型', '10', '版本', 'Python3', 'Python', 'int', 'alpha', '字典', '字符串', '视图', '前向', 'strict', '代码', '定义', 'zip', 'Union', 'float', 'MyType', 'True']
#
# ['学习', '神经网络', 'tinygrad', '霍兹', '乔治', '深度', '开源', '算法', '机器', '黑客', '框架', '代码', 'George', 'PyTorch', 'micrograd', 'GitHub', 'https', 'comma', 'ai', '驾驶']
#
# ['social', 'btn', 'set', '生產', 'left', 'margin', 'width', 'block', '100', '12', 'AI', '溫度', 'page', '新產品', 'important', '15px', '預測', 'float', 'fb', '應用']
#
# ['路径', '神经网络', '学习', '网络', '训练', '优先', '蒸馏', '算法', '搜索', '模型', '网络结构', '超网', '微软', '2020', 'NNI', '方法', '机器', '深度', '设计', '特征']
#
# ['模型', '嵌入', '语言', '图像', 'AI', '视觉', '自然语言', '数据', '单词', 'voken', '训练', 'GPT', '文本', '上下文', 'transformer', '技术', '学习', 'NLP', 'vokenization', 'MS']
#
# ['Nature', '期刊', 'OA', '费用', '作者', '论文', '评审', 'Springer', '9500', '支付', '欧元', '开放', 'Physics', '每篇', '获取', 'Communications', 'Plan', '文章', '发表', '学习']
#
# ['智能', '转型', '工厂', '报告', '制造', '2020', '数字化', '埃森哲', '智能化', '白皮书', '数字', '企业', 'https', '互联', '技术', '驱动', '行业', '高质', '机器', '制造商']
#
# ['3D', '视图', '物体', '机器', '作者', '三维', '论文', 'Bo', 'Yang', '形状', '图像', '分割', '方法', '重建', '感知', '场景', '识别', '人工智能', '研究者', '真实世界']
#
# ['模型', '学习', '微分方程', '机器', '建模', '方程', '数据', 'logistic', '算法', '驱动', '系统', '假设', '预测', '爱因斯坦', 'SIR', 'dP', 'dt', '方法', '机制', '随机']
#
# ['学习', '强化', '李宏毅', '2020', '老师', '深度', '习题', '课程', '视频', '算法', '笔记', '内容', '教程', '项目', 'Datawhale', '学习者', '复现', '开源', '资料', '关键字']
#
# ['文本', '模型', '生成', '规划', '内容', '数据', '数值', '信息', 'NCP', '模块', '三元组', '建模', '神经网络', '抽取', '数值数据', '基线', '上下文', '球员', '结构化', '2019']
#
# ['人工智能', '张亚勤', 'AI', '数字化', '产业', '智能', '百度', '互联网', '技术', '演讲', '研究院', '科技', '智能化', '机器', '世界', '工业革命', '聚焦', '第四次', '清华大学', '24']
#
# ['Mythic', '芯片', '闪存', '神经元', '权值', 'AI', '模型', 'tiles', '映射', 'M1108', '模拟', 'IPU', '智能', '嵌入式', '封装', '内存', '处理器', 'Mike', 'SRAM', 'AMP']
#
# ['模型', '数据', '训练', '拟合', '图像', '增强', '学习', '泛化', '参数', '基线', 'Kaggle', '函数', '正则', '容量', '技术', '架构', '机器', '性能', '项目', '50']
#
# ['Robotaxi', '文远', '知行', '无人驾驶', '乘客', '运营', '驾驶', '自动', '出行', '落地', '乘坐', '一周年', '2020', '报告', '服务', '黄埔区', '调研', '技术', '开放', '对外开放']
#
# ['百度', 'AI', '人工智能', '语音', '知识', '技术', '识别', '深度', '智能', '学习', '大脑', '图谱', '海峰', '平台', '信息', '视觉', '麦克风', '产业', '2020', '核心技术']
#
# ['小冰', '人工智能', '微软', '自然语言', '领域', '图谱', '解决方案', '智能', '技术', '知识', '设计', '李笛', 'AI', '用户', '生成', '交互', '金融', '内容', '26', '沈向洋']
#
# ['华为', '阿利', '5G', '香农', '极化', '拉格尔', '信息', 'LDPC', '技术', '理论', '研究', '任正非', '北电', '标准', '20', '童文', '达尔', '公司', '极限', '噪音']
#
# ['js', 'TensorFlow', '模型', '浏览器', 'DL', '框架', 'GPU', 'Keras', '训练', 'CPU', '支持', 'ConvNetJS', '推理', '性能', '加载', 'WebDNN', '深度', 'synaptic', '时间', '作者']
#
# ['快手', '视频', '用户', '算法', '学习', '技术', 'KTP', '深度', '内容', '神经网络', '网络', '模型', '语音', '音视频', '传输', '排序', '直播', 'AI', '团队', 'LAS']
#
# ['BERT', '搜索引擎', '搜索', '谷歌', '自然语言', '查询', '模型', '段落', '指代', '10', 'bert', '文本', '理解', '网页', '语句', '同形异义', '单词', '领域', '拼写错误', '多义']
#
# ['检测', '模型', '卷积', 'NanoDet', 'YOLO', '目标', 'FCOS', 'PAN', '轻量化', '项目', 'free', '轻量级', 'Anchor', 'tiny', '学习', '作者', '深度', 'https', 'demo', '权重']
#
# ['模型', '增强', '搜索', '数据', '策略', '训练', '学习', '算法', '共享', '神经网络', '权重', '参数', '自动', '验证', '分类器', '后期', '深度', '图像', '方法', '搜索算法']
#
# ['模型', '对称', '线性', '单元', '矩阵', '数据', '神经网络', 'LR', '假设', '回归', '高斯', '无处不在', '训练', '协方差', '机器', '10', 'GPR', '学习', '原子', '对称性']
#
# ['字符', '模型', '鲁棒性', 'CharBERT', '训练', '噪音', 'BERT', '序列', '子词', '融合', '集合', '提升', '分类', '信息', 'Character', 'CoNLL', '2003', 'NLM', '节点', '粒度']
#
# ['生态系统', '智能', '制造', '企业', '打法', '数字化', '调研', 'MAPI', '外部', '供应商', '德勤', '网络', '工厂', '问卷', '高管', '用例', '各方', '带来', '合作伙伴', '疫情']
#
# ['Net', '研究者', 'RSU', '网络', '肖像画', '卷积', '检测', '深度', '论文', '架构', '阿尔伯', '生成', 'SOTA', 'BASNet', '2020', '目标', 'CVPR', '2019', 'ICPR', '提出']
#
# ['mRASP', '语言', '训练', '机器翻译', '翻译', '模型', '平行', '2020', '学习', 'BLEU', '范式', '微调', '拉近', 'al', '句子', '语料', 'EMNLP', 'BERT', 'Exotic', 'RAS']
#
# ['词汇', '句法', '句子', '层次', '单词', 'embedding', 'GCN', 'LSTM', '模型', 'BiGCN', 'Bi', '局部', '语料库', '节点', '聚合', '关系', '嵌入', '信息', '类型', '共现']
#
# ['分词', 'MiNLP', '开源', '小米', '自然语言', '词典', '切分', '中文', '轻量级', '粒度', '效果', '功能', '平台', '调用', '便捷', '定制', 'NLP', '具备', 'txt', '近日']
#
# ['机器人', '客户', '酒店', '科技', '半导体', '落地', '企业', '赵云', '软件', '系统', 'VR', '比亚迪', '行业', '齐笑', '尹川', '支涛', 'XR', '5G', '智能', '医院']
#
# ['人工智能', '论文', '学习', '研究', '大学', '深度', '数据', '排名', '学术界', '图像', '精英', '机器', 'AI', '领域', '算法', '资源', 'QS', '500', '5G', '计算机']
#
# ['影谱', 'AI', '影像', '人工智能', '智能', '科技', '产业', '技术', '规划', '数字化', '生成', '领域', '推动', '数字', '集群', '独角兽', '引擎', '中国', '视觉', '赋能']
#
# ['Code', 'VS', '扩展', '文档', '字符串', 'Python', 'graykode', 'docstring', '代码', 'ai', 'docker', '5000', 'CodeBERT', 'https', '编辑器', '模型', '生成', '推断', '自然语言', '服务器']
#
# ['Transformer', '图像', '模型', '特征', '上下文', '纹理', '注意力', '输入', '嵌入', 'lambda', '序列', '训练', 'https', '编码器', '论文', '检测', 'DETR', 'transformer', 'iGPT', 'ImageNet']
#
# ['华为', 'API', '开发者', 'CloudIDE', 'Explorer', '沙龙', '开发', 'IDE', '能力', '代码', '技术', '场景', '快速', '分享', '干货', '交付', '鲲鹏', '生态', '提供', '研发']
#
# ['資料', '服務', '雲端', '存取', 'AWS', 'Google', 'social', 'btn', 'set', '11', 'left', 'block', 'margin', '伺服器', '技術', '12', 'width', '企業', '網路', '封存']
#
# ['企业', '数字化', '服务', '互联网', '2021', '软件', '平台', '赋能', '领域', '代码', '智能', '5G', '区块', '生态', '转型', '数字', '中国软件行业协会', '软件网', '海比', '中国']
#
# ['字节', '跳动', '企业', '员工', '文档', '协作', '日历', '视频会议', '微信', '工具', '产品', '沟通', '谢欣', '办公', '功能', '发布会', '用户', '会议', '飞书', '妙记']
#
# ['数字化', '算法', '研究院', '架构', '智能', '深度', '数据', '人工智能', '微软', '张亚勤', '算力', '互联网', '产业', '世界', '物理', '芯片', '冯诺', 'AI', '香农', '计算']
#
# ['机器人', 'Jamoca', '梅花桩', '腾讯', 'Robotics', 'AI', '实验室', '移动机器人', '平衡', '实时', '运动', '感知', '控制器', '轮式', '规划', '行进', '控制', '四足', '人工智能', '通用']
#
# ['孪生', '数字', 'AES', '2021', '51WORLD', '李熠', '平台', '场景', '开发者', '京东', '行业', '智慧', '调度', 'EC4', '5G', '动态', '搭建', '产品', '克隆', '论坛']
#
# ['论文', 'pdf', 'https', 'CoRL', '智能', '最佳', '学习', '2020', 'Learning', 'arxiv', 'org', '链接', 'SMARTS', '技能', '研究者', '先验', '南加州', 'Presentation', 'Multi', 'Agent']
#
# ['模型', 'BPE', '字符', '输入', '映射', 'CharBERT', 'CNN', '自然语言', '训练', '方法', '级别', 'Character', 'RNN', 'embedding', 'MLM', '作者', '更好', '实验', '编码', '链接']
#
# ['5G', '2020', '远程', '医疗', '联网', '基站', '工业', '商用', '技术', '数据', '互联网', '通信', '网络', '2025', '基建', '场景', '汽车', '4G', '驾驶', '信息']
#
# ['social', 'btn', 'set', 'left', 'block', 'margin', 'width', '12', 'Google', 'important', '防火', '15px', '攻擊', '100', 'float', 'fb', '2020', '防護', '偵測', '學習']
#
# ['用户', 'item', '模型', '推荐', 'FL', '学习', 'DSSM', 'MV', '视图', '联邦', '新闻', '数据', '训练', '梯度', '系统', 'FCF', '隐私', 'NewsRec', '算法', '客户端']
#
# ['论文', '最佳', '2020', '奖由', 'EMNLP', '奖项', '微软', '提名奖', 'Hugging', 'Face', '加州大学', 'Yanpeng', 'Zhao', '伯克利分校', '大会', '自然语言', '一作', '获此', 'Demo', '爱丁堡大学']
#
# ['AI', '泛化', '学习', '神经网络', '深度', '抽象化', '组合', 'LANE', '模型', '自然语言', '映射', '表达式', '能力', '编程', '程序', '解析', '抽象', '训练', '人类', '数据']
#
# ['spray', '机器人', '涂层', '物体', '研究', '微型', '人员', '崩解', '毫米', '磁性', '运动', '表面', '生物医学', '编程', '导管', '香港城市大学', '磁场', '实验', '微粒', '论文']
#
# ['資訊', '系統', '工地', '瑞助', '營造', 'social', 'btn', 'set', 'left', '部門', 'block', 'margin', '現場', 'width', '12', '丁宏祈', '進出', '發展', '轉型', '辨識']
#
# ['华为', 'DevOps', '服务', '开发者', '平台', '开发', '企业', '软件开发', 'DevCloud', '架构', 'DevRun', '业务', '南宁', '代码', '交付', 'AppCube', '云微', '沙龙', '上云', '工具']
#
# ['FTL', '学习', '数据', '训练', '模型', '梯度', '算法', '迁移', '参与方', '联邦', '机器', '加密', '标注', '隐私', 'FL', '客户机', '特征', '作者', '方法', '目标']
#
# ['图像', '动物', '毛茸茸', '分割', '长相', '习以为常', '几部', 'GFM', '各异', '电视剧', '媒介', '视频', '难度', '拍摄', '浑身', '合成', '看过', '更大', '前景', '主流']
#
# ['NeurIPS', '00', '2020', '人工智能', '论文', 'MeetUp', '报名', '30', '12', 'AI', '机器', '参会', '范式', '之心', '分享', '智能', '学术会议', '现场', '华为', '北京']
#
# ['social', 'btn', 'set', 'left', '12', 'block', 'margin', 'MLflow', 'PyTorch', 'width', '模型', '機器', '學習', 'important', '15px', 'Databricks', '100', 'float', 'fb', '2020']
#
# ['AI', '芯片', '国产', '人工智能', '芯迎', '就位', '寒武纪', '依图', '智能', '加码', '最佳时机', '科技', '产业', '催生', '企业', '科创板', '机遇', '突围', '华为', '集成电路']
#
# ['掩码', '模型', '训练', 'BERT', '中文', '替换', 'MacBERT', '语言', 'MLM', '10', 'Liu', 'MASK', 'arXiv', '精调', '实验', 'Chen', '性能', '文本', '2018', 'gram']
#
# ['神经网络', '自然语言', '学习', '深度', '人工智能', '辛顿', '20', '大脑', '图像', '数据', '符号', '领域', 'learning', '观点', '识别', '算法', '模型', '向量', '理解', 'GPT']
#
# ['语音', '模型', '端到', '识别', 'CTC', 'Transducer', '建模', '机器翻译', '神经网络', 'Seq2Seq', 'RNN', '论文', '输入', '文本', '方法', 'Speech', 'Transformer', '微软', '训练', '映射']
#
# ['loss', '多任务', '模型', '学习', '共享', '训练', '权重', '泛化', '中文', '模式', 'CLUE', 'MTL', '所示', '函数', '参数', '如上图', '示例', 'learning', 'sklearn', '参考']
#
# ['紫光', '计算机', '数字化', '企业', '基建', '商用', 'Unis', '转型', '台式机', '服务', '客户', '发布会', '中国', '事业部', '科技', '总裁', '逸群', '数字', '有限公司', '全新']
#
# ['模型', '训练', '中文', '泛化', '自然语言', '算法', '多任务', '评测', '通用', '选手', '配置文件', '能力', 'PAI', 'CLUE', '乐言', '赛题', 'OCNLI', 'tfrecord', '挑战赛', '提交']
#
# ['social', 'btn', 'set', 'left', 'margin', '運算', 'width', 'block', 'GPU', '12', 'MI100', '架構', 'page', '效能', 'important', '100', '15px', 'AMD', 'CDNA', 'float']
#
# ['弘芯', '项目', '武汉', '光量', '停摆', '半导体', '蓝图', '东西湖区', '政府', '产业', '10', '集成电路', '地方', '孟玮', '尚义', '人才', '北京', '烂尾', '有限公司', '控股']
#
# ['数据', 'TCL', '制造业', '工业', '工厂', '传统', '互联网', '基建', '数字化', '算法', '企业', '环节', '抓取', '分析', '融合', '因子分析', 'APaaS', '供应链', '变现', '平台']
#
# ['CPM', '模型', '训练', '中文', '清源', '设定', '对话', '自然语言', '生成', '样本', '语言', '分类', 'GPT', '监督', '给定', '文本', '数据', '段落', '人工智能', '效果']
#
# ['AMD', 'MI100', 'GPU', 'Instinct', 'HPC', '性能', 'Matrix', 'Core', 'AI', '学习', '加速器', '提供', 'FP64', 'ROCm', '带宽', '峰值', 'TFLOPS', 'FP32', 'amd', '收敛']
#
# ['微软', '研究院', '事情', 'lesson', 'start', '了不起', '职业生涯', 'Eric', '工作', '部门', '产品', 'Bing', '演讲', 'Harry', 'Jim', 'projects', '哪几个', '教授', '中庸之道', '分享']
#
# ['电网', 'PARL', '学习', '调度', '赛道', '动作', '强化', '神经网络', '算法', '百度', '进化', '系统', '竞赛', '专家系统', 'NeurIPS', '专家', '场景', '框架', '方案', '运行']
#
# ['机器', '人工智能', '效用函数', '学习', '伦理', '目的', '计算机', '这时候', '表达', '理解', '模型', '机器人', '图灵', '优化', '主观', '目标', '最大化', '算法', '测试', '客观']
#
# ['周星驰', '大话西游', '喜剧之王', '关系', '嵌套', '实体', '主演', '功夫', '演员', '导演', '重叠', '文本', '上映', 'token', '标注', '抽取', '通州', '参考文献', '北京市政府', '哈尔滨工业大学']
#
# ['类脑', '计算', '研究', '清华大学', '神经元', '计算机', '架构', '芯片', '施路平', '融合', '发展', '异构', '神经网络', '智能', '人工智能', '数据', '系统', '通用', '知识', '做类']
#
# ['T5', 'mT5', '模型', '输入', '输出', '特朗普', 'M0', 'M1', 'M2', 'M3', 'M4', '中文', '训练', 'https', 'model', '参考文献', 't5', '参数', 'Embedding', 'text']
#
# ['视频', '插值', '伪影', '研究者', '算法', 'IFNet', 'RIFE', '速度', '方法', '估计', '旷视', 'warp', '实时', '本文', 'Vimeo90K', '高效', '数十倍', 'leakage', 'distillation', 'FusionNet']
#
# ['Colab', 'Google', 'GPU', 'TPU', 'Drive', 'Python', 'Kaggle', 'https', '加速器', '代码', 'notebook', '硬件', '免费资源', '上传', 'GitHub', 'Jupyter', '篇文章', '设置', 'API', 'google']
#
# ['SpaceX', 'NASA', '宇航员', '飞船', '载人', '空间站', '发射', '航天飞机', '马斯克', '火箭', '航天器', '飞行', '航天', '美国', '国际', '公司', 'Crew', '11', '商业', '七名']
#
# ['Python', 'Julia', '语言', '学习', '机器', '内存', '数据', '编程语言', '算法', '封装', '开发人员', '密集型', 'PythonGIL', '计算', '科学', '领域', '知识', '理论', '识别', '牵强']
#
# ['神经网络', '卷积', '学习', '知识', '深度', '映射', '图谱', '机器', '网路', '图像', '逻辑', '图像处理', '领域', '特征', '神经', '识别', '网络', '算法', '信息', '一种']
#
# ['问句', '生成', '模型', '句子', '新闻标题', '知识', '文本', '短语', '增广', '数据', '知识库', '图谱', '方法', '语义', 'CRQDA', 'RUN', '常识', '关键', '映射', '编辑']
#
# ['图像', '合成', '分割', '步骤', '前景', '肖像', '方法', '高质量', '用例', '图像编辑', '蒙版', '网络', '去污', '背景', '耗时', '手动', 'MLF', '区域', '数据', '生成']
#
# ['隐形眼镜', 'Hershoff', 'Craig', '机器人', 'Cliara', '佩戴', '公司', 'CLIARA', 'LLC', 'FDA', 'https', 'contact', 'lens', 'robot', '2020', '一款', '软管', '摘掉', '数据', '设备']
#
# ['RTX', '3090', '伟达', 'GPU', '3080', '30', '架构', '显卡', '测试', '学习', 'TensorFlow', '卷积', '系列', '机器', 'AI', '容器', '下单', '安培', '代工', '爬坡']
#
# ['social', 'btn', 'set', 'left', 'margin', 'width', 'block', 'PyTorch', 'NNAPI', '應用', '12', '模型', 'page', 'Android', '學習', 'important', '100', '15px', 'float', 'fb']
#
# ['坎德拉', '机器人', '科技', '场景', '烛光', '消毒', '医院', '配送', '天安', '现场', '产品', '智慧', '智能', '测温', '医院院长', '抗疫', '耗材', '末端', '垃圾', '自主']
#
# ['华为', '高通', '芯片', '5G', '4G', '许可', '许可证', '高通公司', '美国', '手机', '专利', '美国政府', '供货', '纳米', '供应链', '手机芯片', '产品', '专利费', '制裁', '业务']
#
# ['实体', '文本', '模型', '标题', '样本', '排序', 'BERT', '召回', '训练', '采用', '知识库', 'top10', '图谱', 'top100', '商品', '描述', 'bert', '输入', '知识', '向量']
#
# ['教授', '北京大学', '清华大学', '探索', 'IEEE', '个人主页', '腾讯', '芊芊', '青年', '人工智能', '谢涛', '2017', '领域', '获奖', '2018', '朱军', '科学家', '软件工程', '研究', 'CCF']
#
# ['AI', 'Google', '學習', 'social', 'btn', 'set', 'left', 'margin', 'width', 'block', '資料', '12', 'page', '挑戰', '未來', 'important', '分散式', '大康', '技術', '架構']
#
# ['ERNIE', '自然语言', '2020', 'AI', '百度', '文心', '学习', '人工智能', '海峰', '院士', '智能', '科技', '语义', '深度', '生成', '技术', '疫情', '理解', '机器', '知识']
#
# ['AI', 'IoT', '开发者', 'ModelArts', '华为', 'AIoT', '使能', '数据', '行业', '5G', '算法', '开发', '模型', '解锁', '场景', '智能', '无障碍', '绕不开', '手时', '稍显']
#
# ...
#
# ['手语', 'David', '数据', '图像', 'Lee', 'https', '模型', '美式', '听力', '群体', '视觉', '障碍', '计算机', '学习', '项目', '预测', '训练', 'github', '给出', '科学家']
#
# ['网易', '伏羲', '沉浸', '游戏', '会议', 'AI', '逆水', '墙展', '场景', '人工智能', '用户', '系统', '学者', '虚拟', '智能', '2020', '技术', '学习', '环节', '体验']
#
# ['数智化', '中小企业', '之心', '机器', '报告', '企业', '2020', '数智', '转型', '二维码', '决策', '解决方案', '识别', '调研', '数据包', '供应', '近千家', '多维度', '理解', '智化']
#
# ['学习', '场景', '启发式', '识别', '领域', '迁移', '模型', '深度', '算法', '阿里', '技术', '训练', '特征', '迭代', '环境', '内容', '收敛', 'AI', '人工智能', '机器']
#
# ['学习', '模型', '神经网络', '算法', '机器', '监督', '回归', '线性', '向量', '实例', 'AI', '聚类', '决策树', '前馈', '贝叶斯', '介绍', '分析', '训练', '近邻', '人工智能']
#
# ['天空', '方法', '场景', '研究', '视频', '视觉', '图像', 'https', 'skybox', '实时处理', '网络', '运动', '学习', '识别', '这项', 'Zhengxia', 'Zou', 'CycleGAN', '卷积', '深度']
#
# ['华为', '开发者', 'AI', 'ModelArts', 'IoT', '模型', '标注', '星星之火', '数据', '算法', '汇聚', '设备', 'AIoT', '学习', '智能', '图像', '服务', '仓储', '平台', '一位']
#
# ['数据', '治理', '上海', '交易中心', '上海市', '演讲', '主题', '实践', '静安', '产业', '发表', '软件产业', '论坛', '创始人', 'ISACA', '胡伟健', '吴志刚', '鸿翼', 'CTO', '罗永秀']
#
# ['机器人', '控制器', 'ANYmal', '腿式', '卷积', '地形', 'ANYbotics', '学习', '环境', '运动', '方法', '训练', '四足', '建模', '研究', '雪地', 'TCN', '苏黎世', '强化', '传感器']
#
# ['LightSeq', '模型', '显存', '解码', 'Transformer', '推理', 'top', '计算', 'beam', '序列', '生成', 'logit', '延迟', '场景', '矩阵', 'GPT', 'search', 'Tensorflow', 'https', '运算']
#
# ['科大', '语音', 'AI', '开发者', '开放平台', '人工智能', '识别', '赋能', '场景', '1024', '合成', '技术', '多语种', '音频', '2020', '麦克风', '建模', '自然语言', '语种', '刘庆峰']
#
# ['优图', '腾讯', 'AI', '实验室', '视觉', '解决方案', '内容', '未成年人', '场景', '审核', '能力', '技术', '人脸识别', '郭晓威', '落地', '行业', '识别', '原子', '方向', '定制']
#
# ['social', 'btn', 'set', 'left', 'block', 'margin', 'ML', 'width', '12', 'important', '系統', '學習', 'AI', '15px', '100', 'float', 'fb', 'fan', 'page', 'top']
#
# ['Filters', 'Neural', 'filters', 'Adobe', '神经网络', '像素', '图像', '生成', '云端', 'Photoshop', 'Layer', '新层', 'filter', '效果', '功能', 'Filter', 'demo', 'Sensei', 'GPU', '学习']
#
# ['算子', '神经', '神经网络', '傅里叶', '方法', 'FNO', '卷积', 'PDE', '学习', '函数', '空间', '求解', '方程', '深度', '网路', '分辨率', 'FEM', 'dv', '映射', '加州理工学院']
#
# ['损失', '函数', '导数', 'torch', '拟合', '梯度', '鲁棒性', '鲁棒', '优化', 'MSE', 'np', 'regression', 'optimizer', 'loss', '异常', '误差', 'yi', '参数', '所示', '训练']
#
# ['iO', '映射', '混淆', '加密', '多项式', '线性', '多重', 'Sahai', '构建', '程序', '假设', 'Jain', 'Lin', '研究者', '隐藏', 'locker', '研究', '二阶', 'Amit', 'Aayush']
#
# ['卷积', '模型', '依图', 'ConvBERT', 'BERT', '注意力', '训练', 'attention', 'map', '自然语言', '跨度', '动态', '模块', '语言', '人工智能', '理解', 'GPT', '冗余', 'base', '学习']
#
# ['量子', '腾讯', '马斯克', '脑机', 'Miguel', 'Nicolelis', '大会', '潘建伟', '接口', '科学', '向善', '2020', '领域', '北展', '说法', '马化腾', '10', '重大突破', '未来', '技术']
#
# ['一致性', '对话', '模型', 'KvPI', '回复', '信息', '标注', '识别', '属性', '角色', 'BERT', '数据', '键值', '生成', '人工', '实验', '理解', '含义', '论文', 'ACL']
#
# ['聚类', '层级', '学习', '数据', '分类', '距离', '监督', '树状', '邻接矩阵', '算法', '样本', '融合', '北京大学', '目标', '数量', '变量', '机器', '顾客', '陈超', '步骤']
#
# ['犯罪', 'CoreLogic', '数据库', 'Mikhail', '记录', '房东', '数据', '工具', '公司', '威尔逊', '有审判权', '犯过', '背景', '专属', '这项', '调查', '筛选', '指控', '标记', '租客']
#
# ['監理', '資料', '票券', 'social', 'btn', 'set', '申報', 'left', 'block', 'margin', '12', 'width', '機制', '單位', '市場', '數位', '集保', '機關', 'important', '科技']
#
# ['千寻', '小鹏', '高精度', '智能', '汽车', '时空', '定位', '位置', '驾驶', '量产', 'P7', '提供', 'OTA', '感知', '服务', '地基', '智能网', '能力', '场景', '2020']
#
# ['视觉', '模型', '推理', '指令', '语言', '模块', '文本', '论文', '网络', '2020', '导航', '图像', '定位', '提出', '结构化', '问答', 'UC', '胡戎航', '显式', 'VQA']
#
# ['图像', '受试者', '模型', '学习', '回圈', '设计', '实验', '反馈', '人机', '本文', '代谢', '生成', 'RBI', '人类', '方法', '机器人', '优化', '对话', '训练', 'EEG']
#
# ['阿里', '双十', '直播', '主播', '技术', '11', '智能', '计算', '阿里巴巴', '数据中心', '实时', '消费者', 'IOE', 'AI', '商家', '平台', '数据', '供应链', '操作系统', '服务器']
#
# ['模型', '自然语言', '神经元', '学习', '微软', '神经网络', '黄萱菁', '语言', '理解', '机器', '周明', '样本', '鲁棒性', '分析', '大学', '人工智能', '算法', '2020', '计划', '智能']
#
# ['深度', '学习', '训练', '能源消耗', '126', '模型', '算法', 'Lasse', 'Wolff', '丹麦', '改进', '年度', 'Kanding', 'Anthony', 'GPT', '家庭', '排放量', '二氧化碳', '数据', '人工智能']
#
# ['模型', '自然语言', '神经网络', '压缩', '训练', '蒸馏', '学习', '模块', '深度', '知识', '微软', '领域', 'Theseus', '函数', '教师', 'NLG', 'BERT', '理解', '机器', '人工智能']
#
# ['机器人', '必选', '高校', '人工智能', 'AI', '人才', '人才培养', '科技', '科研', '教育', '实训', '平台', '教学', '服务', '产业', '算法', '智能', '人才需求', '竞赛', '培养']
#
# ['动脉瘤', '算法', 'AI', '诊断', '影像', '医生', '医学影像', 'CTA', '华为', '人工智能', '华中科技大学', '放射科', '检测', '医疗', '领域', '研究', '验证', '深度', 'Radiology', '学习']
#
# ['函数', '向量', '矩阵', '神经网络', '梯度', '线性代数', '学习', '导数', '算法', '变量', '分解', '范数', '空间', '模型', '微积分', '训练', '机器', '数学', '优化', 'https']
#
# ['论文', 'https', 'openreview', 'net', 'forum', 'id', '摘要', '链接', '模型', '标题', '训练', '学习', '方法', '嵌入', 'Transformer', '提出', '一种', '文本', '自然语言', '语言']
#
# ['自然语言', '论文', '模型', '学习', '神经网络', '人工智能', '吴佳俊', 'ACM', 'https', '微软', '机器', '研究', 'AAAI', 'AI', '图像', '深度', '映射', '计算机', '数据', '引擎']
#
# ['知识', '模型', '常识', '知识库', '神经网络', '2019', '示例', '训练', '问答', '关系', '数据', '推理', '学习', 'ConceptNet', 'knowledge', 'Conference', 'Language', '融合', '路径', '节点']
#
# ['区块', '数据', '整合', '节点', '思考', '效率', '腾讯', '用户', '数字化', '带来', 'SaaS', '发票', '构建', '见证', '例子', '部署', '迁移', '云端', '有个', '算法']
#
# ['观远', '数据', 'BI', '企业', 'AI', '数据分析', '零售', '商业智能', '决策', '消费', '运营', '春园', '门店', '智能', '行业', '数字化', '业务', '店长', '补货', '分析']
#
# ['Trainer', '服务器', 'CPU', 'GPU', '参数', '异构', '架构', '飞桨', '训练', 'Heter', '机器', '模型', '硬件', 'IO', '训练任务', '稀疏', 'Server', '算力', 'Collective', 'PS']
#
# ['AI', '人机', '周曦', '人工智能', '协同', '技术', '科技', '独角兽', '浪潮', '内忧', '外患', '对话', '狂热', '操作系统', '务实', '时代', '融入', '境地', '广州', '这场']
#
# ['11', '王兵', '陈秀雄', '微分', '论文', '里奇', '几何', '几何学', '猜想', '偏零阶', '哈密尔顿', '20', '重大突破', '数学界', '教授', '悬而未决', '领域', '中科大', '历时', '研究']
#
# ['迁移', '图像', '情感', '物体', '模型', '输入', 'SentiGAN', '风格', '参考', '掩码', '所示', '内容', '研究', '语音', '框架', '执行', '粗粒度', '消极', '示例', 'Sentiment']
#
# ['医疗', '合作', '患者', '博会', '企业', '治疗', '系统', '疾病', '放疗', '手术', '磁共振', '阿斯利康', '达芬奇', '药械', '银屑病', '测序', '3D', '健康', '平台', '2020']
#
# ['音频', '样本', '婴儿', '模型', 'Platypush', '检测', '频率', '示例', '声音', '摄像头', '哭声', '数据', '脚本', '扬声器', '监视器', 'micmon', 'positive', '利用', '训练', '标注']
#
# ['AI', 'Google', '团队', '原则', 'Frey', '学习', 'Cloud', 'Doshi', '性别', '偏见', '算法', '机器', '产品', '模型', '技术', '领域', '理论', '识别', '研究', '分享']
#
# ['源代码', '二进制', '代码', '模型', '采样', '腾讯', '2020', '算法', '研究', '字符串', '特征', '语义', '向量', 'NeurIPS', 'weighted', '领域', '输入', '训练', 'AI', 'loss']
#
# ['海峰', 'AI', 'ACL', '百度', '机器翻译', '科技奖', 'NLP', '工程', '光华', '神经网络', '领域', '中国', '人工智能', '奖项', '科技', '产业界', '自然语言', '李生', '研究', '搜索引擎']
#
# ['巨头', '欧盟', '数字', '平台', '二十年', 'DSA', '科技', 'Facebook', '出台', '12', '对谷歌', '内容', '谷歌', '革命性', '法案', '游说', '商业模式', '竞争对手', '规则', '在短期内']
#
# ['依图', '人工智能', '芯片', '智能', '算力', '公司', '解决方案', '研发', '科技', '技术', '图谱', '亿元', '寒武纪', '自然语言', '视觉', '2020', 'AI', '招股书', '计算', '求索']
#
# ['AMD', 'Ryzen', '测试', '游戏', '系列', 'CPU', 'Low', '基准', '设置', 'Zen', '处理器', '5000', '提升', 'IPC', '5950X', '英特尔', '评测', 'Core', '频率', 'anandtech']
#
# ['模型', '实体', '关系', '方法', '抽取', '编码器', '研究', 'span', 'token', 'pipeline', '实体模型', '性能', '语境', '识别', '训练', '近似', 'joint', '文本', '学习', '标记']
#
# ['資料', 'AI', 'social', 'btn', 'set', 'left', '訓練', 'margin', '模型', 'width', 'block', '學習', '醫院', 'Excel', '微軟', '12', '機器', 'BERT', 'page', '國泰']
#
# ['智能', '竹间', '自然语言', 'AI', '人工智能', 'NLP', '场景', '机器人', '企业', '平台', '学习', '客户', '语音', '理解', 'AICC', '技术', '提供', '知识', '用户', '业务']
#
# ['陆原', 'App', '人脸识别', '外婆', '编程', '查房', '识别器', '识别', '紫外线', '爸爸', 'AI', 'Yang', '记忆', '患者', '开发', '界面', '程序员', '智能', '四年级', '技术']
#
# ['模态', 'AI', '自然语言', '京东', '语言', '摘要', '介绍', '视觉', '技术', '训练', '分享', '方法', '博士', '开发者', '领域', '研究', '模型', '智联', '对话', '指代']
#
# ['用户', '推荐', '服贸会', '缓存', '数据', '云上', '场景', '信息', '画像', '智能', '兴趣', '向量', '维度', '访问', 'Redis', 'Cache', '候选', '参展商', 'Caffeine', 'TinyLFU']
#
# ['云知声', 'AI', '语音', '研发', '招股书', '人工智能', '2020', '智能', '2019', '芯片', '独角兽', '投入', '解决方案', '营收', '亏损', '亿元', '物联', '场景', '交互', '面向']
#
# ['通信', '激光', '卫星', '光通信', '探测', '10', '空间', '光子', '水下', '深空', '微波', '中科院', '商业化', '150', '蓝绿', '探测器', '速率', '月球', '信息量', '口径']
#
# ['AI', '方法', '文献', '场景', '标记', '数据', '研究', '10', '提出', '章节', '聚类', '2019', '单词', '归一化', '示踪', '数量', 'CCF', '信息', 'corpus', 'https']
#
# ['标注', '训练', '语音', '数据', '互补性', '模型', '识别', 'FAIR', '方法', 'wav2vec', '研究者', 'Librispeech', '监督', '不错', '两种', '执行', '自然语言', 'clean', '集上', '词错']
#
# ['蟑螂', '日本筑波大学', '画画', '地想', 'Qi', 'Guai', '令人厌恶', '别出心裁', '物体', '研究', '真是太', '脸部', '神奇', '装饰', '团队', '实验', '研究者', '一支', '对象', '一系列']
#
# ['Deepnote', '开发者', 'notebook', '任性', '工具', '变量', 'Julia', '用户', '开发', '函数', '不好', '协作', '数据', 'Jakub', '定义', '代码', '共享', 'Jupyter', '实时', '文档']
#
# ['咳嗽', '19', 'Covid', '模型', '神经网络', 'AI', '无症状', '检测', '感染者', '新冠', '算法', '样本', 'Subirana', '阿尔茨海默氏症', '学习', '研究', '数据', '训练', '20', '症状']
#
# ['工业', '互联网', '产业', 'AI', '融合', '智能', '副总裁', '数字化', '转型', '金蝶', '企业', '有限公司', '赛迪', '制造业', '制造', '发展', '5G', '战斗力', '场景', '生态']
#
# ['数字化', '电投', '转型', '能源', '工程建设', '上海交通大学', '科技', '学院', '国家', '李仁涵', '人工智能', '研究院', '风电', '发展', '业务', '国有企业', '有限公司', '管理', '产业链', '旭东']
#
# ['高精度', '千寻', '定位', '路测', '位置', '驾驶', '智能', '时空', '2020', '量产', '提供', '智能网', '大规模', '汽车', '卫星', '11', '场景', '服务', '感知', '算法']
#
# ['抑郁症', '数据', '学习', '机器', 'AI', '患者', '卷积', '诊断', '模型', '算法', '人工智能', '研究', '聚类', '预测', '神经网络', '心理', '识别', '技术', '治疗', '自然语言']
#
# ['数据', '开放', '长三角', '地方', '一体化', '开放平台', '浙江', '协同', '公共数据', '报告', '利用', '上海', '政府', '平台', '数木', '可视化', '2020', '数根', '地区', '上线']
#
# ['DNN', '神经元', '选择性', '研究者', '神经网络', '图像', '分类', 'Facebook', 'pdf', '模型', 'AI', '理解', '训练', '网络', 'https', '学习', '方法', '性能', '研究', '准确率']
#
# ['吴恩达', 'AI', '算法', '人工智能', '学习', '机器', '挑战', 'HAI', '数据', '研讨会', '斯坦福大学', '泛化', '百度', '部署', '领域', '面临', '统计学', '理论', '研究', '解决方案']
#
# ['蚂蚁', '集团', '暂缓', '11', '金服', '监管', '上市', '金融', '阿里巴巴', '马云', '科技', '上交所', '普惠', '金融服务', '小微', '相关', '信用', '金融风险', '2014', '2018']
#
# ['学习', '脑电图', 'Amber', '抑郁症', '机器', 'IBM', '算法', 'DeepMind', '编码器', '噪音', '研究', '自动', '实验室', '团队', '用于', '深度', '大脑', '分类', '数据', '耳机']
#
# ['学习', '路线图', '数据', 'AI', '神经网络', '机器', '算法', '梯度', '深度', '工程师', '方法', '线性代数', '置信区间', '信息', '模型', '编码器', '50', '领域', '学习者', '人工智能']
#
# ['图谱', '知识', '构建', '实体', '推理', '学习', '认知', '算法', 'AI', '智谱', '数据', '关系', '神经网络', '模型', '系统', '方法', '人工智能', '自然语言', '文本', '语义']
#
# ['时序', '卷积', '学习', '神经网络', '变量', '模块', '预测', '节点', 'MTGNN', 'Graph', 'hop', '信息', '算法', '数据', '规范化', 'mix', '邻接矩阵', '优化', '结构', '实验']
# ['Conference', 'Proceedings', '朱庆福', '论文', 'Counterfactual', '2018', '2019', 'pages', 'generative', 'Language', 'Processing', '哈工大', '王威廉', 'Jean', 'policy', 'International', 'Learning', 'evaluation', 'models', 'end']
#
# ['GPU', '深度', 'Cell', '神经网络', '调度', 'HiveD', '学习', '集群', '微软', '共识', '论文', 'https', '租户', 'VC', 'Protean', '硬件', '框架', '拜占庭', 'Azure', 'Retiarii']
#
# ['快手', '隐身', '魔法', '特效', '用户', '万圣节', '超能力', 'AI', '好莱坞', '凭空出现', '系列', '实时', '视频', '热巴', '哈利波', '隐身衣', '科技', '拍摄', '体验', '魔幻']
#
# ['开源', '芯片', '软件', 'CPU', '架构', 'Risc', '基金会', '优势', '区块', '英特尔', '投入', '边缘', '硬件', '兼容', '中国', '管制', '好处', 'BSD', '5G', '操作系统']
#
# ['计算', '生态', '产业', '大会', '先进', '赋能', '2020', '发展', '计算机', '王志军', '杜家', '创新', '湖南省委', '院士', '集团', '书记', '开幕式', '芯片', '企业', '副总裁']
#
# ['神经网络', 'EssayKiller', 'UP', '卷积', '网络', 'AI', '作文', '高考作文', '网路', '学习', '深度', '训练', '数据', '写作', '神经', '人工智能', '小编', '前馈', '网格', '识别']
#
# ['智能', '学习', '动作', '策略', 'learning', '个体', '方法', '全局', '强化', '函数', '机器人', '图源', '最优', '纳什', '联合', '建模', '局部', '之间', '回报', '均衡']
#
# ['Fedlearner', '字节', '学习', '联邦', '模型', '训练', '数据', '用户', '跳动', '平台', '电商', '神经网络', 'ID', '加密', '求交', '场景', '客户', '正价', '广告主', '巨量']
#
# ['模型', 'GNN', '性能', '节点', '标签', '预测', '神经网络', '集上', 'SOTA', '方法', '后处理', '步骤', '训练', 'LP', 'Products', '研究者', '学习', '数据', '简单', '准确率']
#
# ['化学', 'Cronin', 'AutoSyn', '化学家', '分子', 'chemputer', '机器', '自动化', '史克', '葛兰素', '研究', 'Collins', '自然语言', '学习', '团队', '领域', '算法', '描述语言', '配方', '实验']
#
# ['人工智能', 'AI', '数据', '用户', '学习', '科学', 'Le', '机器', '解释', '清华大学', '算法', '物理', '直博生', '工程系', '清华', '研究', '别样', '浓厚兴趣', '在读', '机械工程']
#
# ['语言', '代码', 'AI', '学习', '自然语言', '文本', '机器翻译', '模型', '语音', '迁移', '理解', '神经网络', '人类', '识别', '训练', '微软', '视觉', 'XYZ', '机器', '自动']
#
# ['语音', '识别', '口音', '训练', '思必驰', '音频', '模型', '2020', 'Speech', 'Recognition', 'xiaochi', '数据', '队伍', '分类', '准确率', '参赛', '例数', '自动', '种类', 'Track1']
#
# ['数据', '训练', 'GPT', '文本', '自然语言', 'books1', '模型', '图书', '196640', 'https', '学习', '包含', '语言', 'Shawn', 'Presser', 'books3', '机器', '语料库', '统计学', '代码']
#
# ['课程', '图形学', '授课', '视频', '计算机', 'CMU', '这门', '主题', '多月', '放出', '更新', '同步', '为期', '动画', 'Keenan', 'Crane', '概论', '阶段', '几何', 'NSF']
#
# ['MedMNIST', '数据', 'AutoML', '图像', '医疗', '算法', 'https', '十项全能', '集上', '分类', '研究', '模态', '人员', '链接', '上海交大', '创建', '10', 'Data', '设计', '领域']
#
# ['设备', '机器', 'TinyML', '模型', '学习', '联网', '嵌入式', '算法', '人工智能', '精度', 'AI', '微型', '计算', '微控制器', 'Lite', '功耗', '训练', '神经网络', '量化', '满足要求']
#
# ['复现', '论文', '机器', '代码', '模型', '学习', 'https', '参数', '训练', 'SOTA', 'README', 'Derek', 'Chia', '数据', '任重而道远', '提交', '学术会议', 'notebook', '尝试', '工程师']
#
# ['语音', '模型', '识别', '上下文', '模态', '说话', '嵌入', '集上', '口语', '理解', '思必驰', 'Speech', 'BERT', '混响', '分离', '数据', '性能', '智能', '语义', '2020']
#
# ['千寻', '手机', '华为', '定位', '车道', '高精度', '导航', 'Mate', 'HUAWEI', '时空', '智能', '高德', '系列', '位置', '能力', '服务', '用户', '10', '30', '40']
#
# ['AI', '微软', '技术', '学习', '人工智能', '自然语言', '算法', '落地', '修复', '程序员', '周明', '智能', '大谷', '理解', '知识', '赋能', '数据', '领域', '研究院', '2020']
#
# ['疲劳', 'AI', '认知', '系统', '工人', '干预', '林肯', '实验室', '偏差', '上班族', '生物', '研究', '数据', '2020', '输入', '辛酸', '标志物', '模型', '超负荷', '压力']
#
# ['科技', 'E5', '发展', '自立自强', '中国', '创新', '王志刚', '10', '规划', '习近平', '技术', '领域', 'E8', '五年', '数字', '制裁', '经济', '国际', '五年计划', '2020']
#
# ['Pyston', 'Python', 'v2', '优化', '20', 'CPython', 'pyston', '基准', '梯度', 'JIT', 'LLVM', '算法', '测试', '团队', '负载', '开发', '模型', '性能', 'IR', '10']
#
# ['youtube', 'dl', 'GitHub', '下架', 'RIAA', 'DMCA', '视频', '开发者', '下载', '通知', 'YouTube', 'Friedman', 'https', '源代码', '项目', '版权保护', '维护者', '示例', '授权', '2020']
#
# ['用户', '视频', '模型', 'item', '采样', '训练', 'PeterRec', '序列', '学习', '业务', '推荐', 'source', '样本', 'target', '泛化', '函数', 'loss', '腾讯', 'top', '播放']
#
# ['GIB', '节点', '信息', 'IB', '模型', 'Cat', 'Bern', '结构', '特征', '研究者', 'GNN', '信息论', '学习', '原则', '数据', '预测', '稳健性', '分类', '马尔可夫', '准确率']
#
# ['华为', 'AI', '5G', '视频', '9000', '40', 'Mate', '麒麟', '手机', '手机芯片', '余承东', '学习', '隔空', '实时', '识别', '机器', '字幕', '人眼', '旗舰', '图像']
#
# ['百度', '阿尔茨海默', '停顿', '模型', 'ERNIE', '研究院', '识别', '人工智能', '编码', '语音', '转写', '准确率', '语言', '学习', 'NLP', '微调', '算法', '竞赛', '训练', '文心']
#
# ['院士', '中国工程院', '大会', '生态', '论坛', '17', '计算', '科学院', '专题', '主题', '教授', '计算机', '2020', '中南大学', '11', '计算机领域', '开幕式', '工程院', '中国科学院', '5G']
#
# ['数据', '权限', '管理', '用户', 'Huapu', 'CP', '难倒', '图谱', '知识', '定义', '架构', '家谱', '智能', '一大批', '陌生', '说起', '逻辑', 'HAO', '技术', 'HI']
#
# ['1B', '签证', '薪资', 'Level', '新规', '美国', '申请', 'IBM', '岗位', '劳动者', 'DHS', 'www', '级别', '工资', '认定', 'https', '2019', '雇主', '这项', '科技']
#
# ['3D', 'RVC', '视觉', '智能', '如本', '相机', 'mini', '科技', '点云', '工业', '手眼', '分拣', '高精度', '行业', '算法', '创新', '机器人', '场景', '高性价比', '自动化']
#
# ['对话', 'PLATO', '回复', '评估', '百度', '模型', '赛道', '系统', 'Track', '知识', '训练', '在子', '用户', '生成', '开放', '上文', 'DSTC9', 'Task', '人机交互', '结构化']
#
# ['数据', 'Web', '2010', '前端', '可视化', '技术', '阿里', '交互', '新的篇章', '人工智能', '提上', '展现', '导读', '软件', '多样化', '本文', '分享', '如果说', '实践', '随之']
#
# ['fluid', 'layers', 'input', 'None', 'conv2d', 'numfilters', 'filtersize', 'stride', 'padding', 'np', 'SAME', 'dataformat', 'NCHW', 'cv2', 'epoch', 'net', 'dtype', 'plt', 'batchnorm', 'momentum']
#
# ['算法', '游戏', 'Free', 'Flow', 'learning', '译者', '简介', '谜题', '学习', '解决', '蛮力', 'CNN', 'https', '数据', 'FlowFree', '喜欢', '颜色', 'AI', 'Data', 'Science']
#
# ['channels', 'PaddleSeg', 'st4', 'cfg', '残差', '特征', '卷积', '模型', 'shape', 'img', '分割', 'HRNet', 'plt', 'MODEL', 'HRNET', 'nummodules', 'input', 'fluid', 'layers', '图像']
#
# ['TinyML', '机器', 'tinyML', '学习', '峰会', '设备', '低功耗', '2020', '高管', '边缘', 'Foundation', '2019', 'ARM', '技术论坛', '11', '工程师', '领域', '数据中心', '微处理器', '活动']
#
# ['首汽', '约车', 'AWS', '语音', '解决方案', '智能', '机器', '出行', 'Amazon', '服务', '学习', '安全监控', '司乘', '行程', '录音', '行业', '技术', '网约车', '用户', '识别']
#
# ['棋盘', '国际象棋', '无聊', '电脑', 'AI', '棋子', '64', '游戏', '网格', '双人', '有人', '下棋', '格式', '玩家', '函数', '排列', '对弈', 'board', '算法', '战略']

# %%
# 把這 500 篇新聞內容做成文字雲

def plt_wordcloud(content, maskpath):                               # 把文章內容轉文字雲
    from wordcloud import WordCloud
    import jieba
    import matplotlib.pyplot as plt
    from PIL import Image 
    import numpy as np
    # %matplotlib inline
    
    words = jieba.cut(content, cut_all=False)
    
    all_words = ''
    for word in words:
        all_words += ' '+word
    
    mask = np.array(Image.open(maskpath))
    
    wcloud = WordCloud(width=500, height=500, background_color='white', mask=mask, 
                       min_font_size=8, font_path='simhei.ttf').generate(all_words)
    plt.figure(figsize=(20, 10), facecolor=None)
    plt.imshow(wcloud)
    plt.axis('off')
    plt.tight_layout(pad=0)
    
    plt.show()


allnews = ''

for n in remained_news:                                         # 這500篇新聞的總和
    allnews += n

plt_wordcloud(allnews, 'new_trex.jpg')
