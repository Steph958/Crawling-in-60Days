# %% [markdown]
# # 作業
#
# 以正確的副檔名下載網頁中的圖片
# 範例網頁:https://www.ptt.cc/bbs/Beauty/M.1556291059.A.75A.html
#
# Note：因為 PTT 會詢問「是否滿 18 歲」，這邊可以用 cookies 繞過
#
# `requests.get(URL, cookies={'over18': '1'}`

# %%
import requests
import os

from bs4 import BeautifulSoup
from PIL import Image

# %%
url = 'https://www.ptt.cc/bbs/Beauty/M.1556291059.A.75A.html'
resp = requests.get(url, cookies={'over18': '1'})
soup = BeautifulSoup(resp.text)

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <title>
#    [正妹] 新垣結衣幾張 發錢 - 看板 Beauty - 批踢踢實業坊
#   </title>
#   <meta content="all" name="robots"/>
#   <meta content="Ptt BBS 批踢踢" name="keywords"/>
#   <meta content="看了上面那篇又開始打開資料夾複習國民老婆的照片
# 又再次戀愛了 希望各位不要和我搶老婆&gt;///&lt;
# 結衣是我的
# https://imgur.com/Cgb5oo1
# https://imgur.com/MgjHY4f
# " name="description"/>
#   <meta content="Ptt 批踢踢實業坊" property="og:site_name"/>
#   <meta content="[正妹] 新垣結衣幾張 發錢" property="og:title"/>
#   <meta content="看了上面那篇又開始打開資料夾複習國民老婆的照片
# 又再次戀愛了 希望各位不要和我搶老婆&gt;///&lt;
# 結衣是我的
# https://imgur.com/Cgb5oo1
# https://imgur.com/MgjHY4f
# " property="og:description"/>
#   <link href="https://www.ptt.cc/bbs/Beauty/M.1556291059.A.75A.html" rel="canonical"/>
#   <link href="//images.ptt.cc/bbs/v2.27/bbs-common.css" rel="stylesheet" type="text/css"/>
#   <link href="//images.ptt.cc/bbs/v2.27/bbs-base.css" media="screen" rel="stylesheet" type="text/css"/>
#   <link href="//images.ptt.cc/bbs/v2.27/bbs-custom.css" rel="stylesheet" type="text/css"/>
#   <link href="//images.ptt.cc/bbs/v2.27/pushstream.css" media="screen" rel="stylesheet" type="text/css"/>
#   <link href="//images.ptt.cc/bbs/v2.27/bbs-print.css" media="print" rel="stylesheet" type="text/css"/>
#   <script async="" src="/cdn-cgi/bm/cv/1284585713/api.js">
#   </script>
#  </head>
#  <body>
#   <div id="topbar-container">
#    <div class="bbs-content" id="topbar">
#     <a href="/bbs/" id="logo">
#      批踢踢實業坊
#     </a>
#     <span>
#      ›
#     </span>
#     <a class="board" href="/bbs/Beauty/index.html">
#      <span class="board-label">
#       看板
#      </span>
#      Beauty
#     </a>
#     <a class="right small" href="/about.html">
#      關於我們
#     </a>
#     <a class="right small" href="/contact.html">
#      聯絡資訊
#     </a>
#    </div>
#   </div>
#   <div id="navigation-container">
#    <div class="bbs-content" id="navigation">
#     <a class="board" href="/bbs/Beauty/index.html">
#      返回看板
#     </a>
#     <div class="bar">
#     </div>
#    </div>
#   </div>
#   <div id="main-container">
#    <div class="bbs-screen bbs-content" id="main-content">
#     <div class="article-metaline">
#      <span class="article-meta-tag">
#       作者
#      </span>
#      <span class="article-meta-value">
#       clbkan (行動代號龍捲風)
#      </span>
#     </div>
#     <div class="article-metaline-right">
#      <span class="article-meta-tag">
#       看板
#      </span>
#      <span class="article-meta-value">
#       Beauty
#      </span>
#     </div>
#     <div class="article-metaline">
#      <span class="article-meta-tag">
#       標題
#      </span>
#      <span class="article-meta-value">
#       [正妹] 新垣結衣幾張 發錢
#      </span>
#     </div>
#     <div class="article-metaline">
#      <span class="article-meta-tag">
#       時間
#      </span>
#      <span class="article-meta-value">
#       Fri Apr 26 23:04:17 2019
#      </span>
#     </div>
#     看了上面那篇又開始打開資料夾複習國民老婆的照片
#
# 又再次戀愛了 希望各位不要和我搶老婆&gt;///&lt;
#
# 結衣是我的
#     <a href="https://imgur.com/Cgb5oo1" rel="nofollow" target="_blank">
#      https://imgur.com/Cgb5oo1
#     </a>
#     <div class="richcontent">
#      <blockquote class="imgur-embed-pub" data-id="Cgb5oo1" lang="en">
#       <a href="//imgur.com/Cgb5oo1">
#       </a>
#      </blockquote>
#      <script async="" charset="utf-8" src="//s.imgur.com/min/embed.js">
#      </script>
#     </div>
#     <a href="https://imgur.com/MgjHY4f" rel="nofollow" target="_blank">
#      https://imgur.com/MgjHY4f
#     </a>
#     <div class="richcontent">
#      <blockquote class="imgur-embed-pub" data-id="MgjHY4f" lang="en">
#       <a href="//imgur.com/MgjHY4f">
#       </a>
#      </blockquote>
#      <script async="" charset="utf-8" src="//s.imgur.com/min/embed.js">
#      </script>
#     </div>
#     <a href="https://imgur.com/yeoRtAs" rel="nofollow" target="_blank">
#      https://imgur.com/yeoRtAs
#     </a>
#     <div class="richcontent">
#      <blockquote class="imgur-embed-pub" data-id="yeoRtAs" lang="en">
#       <a href="//imgur.com/yeoRtAs">
#       </a>
#      </blockquote>
#      <script async="" charset="utf-8" src="//s.imgur.com/min/embed.js">
#      </script>
#     </div>
#     <a href="https://imgur.com/wsauNEW" rel="nofollow" target="_blank">
#      https://imgur.com/wsauNEW
#     </a>
#     <div class="richcontent">
#      <blockquote class="imgur-embed-pub" data-id="wsauNEW" lang="en">
#       <a href="//imgur.com/wsauNEW">
#       </a>
#      </blockquote>
#      <script async="" charset="utf-8" src="//s.imgur.com/min/embed.js">
#      </script>
#     </div>
#     <a href="https://imgur.com/IjiETcs" rel="nofollow" target="_blank">
#      https://imgur.com/IjiETcs
#     </a>
#     <div class="richcontent">
#      <blockquote class="imgur-embed-pub" data-id="IjiETcs" lang="en">
#       <a href="//imgur.com/IjiETcs">
#       </a>
#      </blockquote>
#      <script async="" charset="utf-8" src="//s.imgur.com/min/embed.js">
#      </script>
#     </div>
#     --
#     <span class="f2">
#      ※ 發信站: 批踢踢實業坊(ptt.cc), 來自: 111.242.90.183
#     </span>
#     <span class="f2">
#      ※ 文章網址:
#      <a href="https://www.ptt.cc/bbs/Beauty/M.1556291059.A.75A.html" rel="nofollow" target="_blank">
#       https://www.ptt.cc/bbs/Beauty/M.1556291059.A.75A.html
#      </a>
#     </span>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       KiniroMosaic
#      </span>
#      <span class="f3 push-content">
#       : 板皇下台
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:05
#      </span>
#     </div>
#     1
#     <div class="push">
#      <span class="f1 hl push-tag">
#       →
#      </span>
#      <span class="f3 hl push-userid">
#       KiniroMosaic
#      </span>
#      <span class="f3 push-content">
#       : 首推有嗎
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:05
#      </span>
#     </div>
#     好加碼給你 我統計完會給
#     <div class="push">
#      <span class="f1 hl push-tag">
#       →
#      </span>
#      <span class="f3 hl push-userid">
#       maxwells
#      </span>
#      <span class="f3 push-content">
#       : 版皇下台
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:05
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       KiniroMosaic
#      </span>
#      <span class="f3 push-content">
#       : 幫推~
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:07
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       lpoijk
#      </span>
#      <span class="f3 push-content">
#       : 我幾樓？
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:07
#      </span>
#     </div>
#     2
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       hdotistyle
#      </span>
#      <span class="f3 push-content">
#       : 我老婆好嗎 版皇下台
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:07
#      </span>
#     </div>
#     3
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       heycircle
#      </span>
#      <span class="f3 push-content">
#       : 推
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:08
#      </span>
#     </div>
#     <div class="push">
#      <span class="f1 hl push-tag">
#       →
#      </span>
#      <span class="f3 hl push-userid">
#       htc10
#      </span>
#      <span class="f3 push-content">
#       : 板皇下台
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:10
#      </span>
#     </div>
#     4
#     <span class="f2">
#      ※ 編輯: clbkan (111.242.90.183), 04/26/2019 23:11:12
#     </span>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       iLuciferous
#      </span>
#      <span class="f3 push-content">
#       : 推我老婆
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:11
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       lpoijk
#      </span>
#      <span class="f3 push-content">
#       : 板皇下台
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:11
#      </span>
#     </div>
#     5
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       Kaiserguy
#      </span>
#      <span class="f3 push-content">
#       : 板皇下台
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:12
#      </span>
#     </div>
#     6
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       maxwells
#      </span>
#      <span class="f3 push-content">
#       : 版皇下台
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:12
#      </span>
#     </div>
#     7
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       ececeec
#      </span>
#      <span class="f3 push-content">
#       : 板皇下台
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:12
#      </span>
#     </div>
#     8
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       windisbig
#      </span>
#      <span class="f3 push-content">
#       : 好喔 錢
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:13
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       x3011775
#      </span>
#      <span class="f3 push-content">
#       : 推
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:14
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       Steven6666
#      </span>
#      <span class="f3 push-content">
#       : 版皇下台
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:14
#      </span>
#     </div>
#     9
#     <div class="push">
#      <span class="f1 hl push-tag">
#       →
#      </span>
#      <span class="f3 hl push-userid">
#       willy911006
#      </span>
#      <span class="f3 push-content">
#       : 版皇下台
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:14
#      </span>
#     </div>
#     10
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       mlb99551155
#      </span>
#      <span class="f3 push-content">
#       : 版皇下台
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:14
#      </span>
#     </div>
#     11
#     <div class="push">
#      <span class="f1 hl push-tag">
#       →
#      </span>
#      <span class="f3 hl push-userid">
#       ToyotaPrius
#      </span>
#      <span class="f3 push-content">
#       : 版黃下台
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:14
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       henry60409
#      </span>
#      <span class="f3 push-content">
#       : 推拉版黃滾
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:14
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       darkhearo
#      </span>
#      <span class="f3 push-content">
#       : 板皇下台
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:15
#      </span>
#     </div>
#     12
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       CKKai
#      </span>
#      <span class="f3 push-content">
#       : 版皇下台
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:15
#      </span>
#     </div>
#     13
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       Reznov
#      </span>
#      <span class="f3 push-content">
#       : 板皇下台
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:16
#      </span>
#     </div>
#     14
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       jay0601zzz
#      </span>
#      <span class="f3 push-content">
#       : 版皇下台
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:17
#      </span>
#     </div>
#     15
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       Katsuyuki118
#      </span>
#      <span class="f3 push-content">
#       : 版皇下台
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:17
#      </span>
#     </div>
#     16
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       leoeeeaaa
#      </span>
#      <span class="f3 push-content">
#       : 版皇下台
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:17
#      </span>
#     </div>
#     17
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       MoDerF
#      </span>
#      <span class="f3 push-content">
#       : 板皇下台
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:18
#      </span>
#     </div>
#     18
#     <div class="push">
#      <span class="f1 hl push-tag">
#       →
#      </span>
#      <span class="f3 hl push-userid">
#       lynnc
#      </span>
#      <span class="f3 push-content">
#       : 版皇下台
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:18
#      </span>
#     </div>
#     19
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       ChrisJohnson
#      </span>
#      <span class="f3 push-content">
#       : 班鞥推
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:18
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       dwuacoa63
#      </span>
#      <span class="f3 push-content">
#       : 版皇下台
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:18
#      </span>
#     </div>
#     20
#     <div class="push">
#      <span class="f1 hl push-tag">
#       →
#      </span>
#      <span class="f3 hl push-userid">
#       jerrydbk
#      </span>
#      <span class="f3 push-content">
#       : 版皇下台
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:18
#      </span>
#     </div>
#     21
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       panex0845
#      </span>
#      <span class="f3 push-content">
#       : 板皇下台
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:18
#      </span>
#     </div>
#     22
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       x007
#      </span>
#      <span class="f3 push-content">
#       : 版皇下台
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:19
#      </span>
#     </div>
#     23
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       Slupi
#      </span>
#      <span class="f3 push-content">
#       : 板皇下台
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:20
#      </span>
#     </div>
#     24
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       davidtai12
#      </span>
#      <span class="f3 push-content">
#       : 版皇下台
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:20
#      </span>
#     </div>
#     25
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       nfrxzguosd
#      </span>
#      <span class="f3 push-content">
#       : 板皇下台
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:21
#      </span>
#     </div>
#     26
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       nillller
#      </span>
#      <span class="f3 push-content">
#       : 版皇下台
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:21
#      </span>
#     </div>
#     27
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       andylee84126
#      </span>
#      <span class="f3 push-content">
#       : 版皇下台
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:21
#      </span>
#     </div>
#     28
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       joe95175313
#      </span>
#      <span class="f3 push-content">
#       : 板皇下台
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:21
#      </span>
#     </div>
#     29
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       BKD858
#      </span>
#      <span class="f3 push-content">
#       : 版皇下台
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:22
#      </span>
#     </div>
#     30
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       fakejoker
#      </span>
#      <span class="f3 push-content">
#       : 板皇下台
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:22
#      </span>
#     </div>
#     31
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       makeamyth
#      </span>
#      <span class="f3 push-content">
#       : 板皇下台
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:23
#      </span>
#     </div>
#     32
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       sam1217222
#      </span>
#      <span class="f3 push-content">
#       : 版皇下台
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:23
#      </span>
#     </div>
#     33
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       nekoten
#      </span>
#      <span class="f3 push-content">
#       : 板皇下台
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:23
#      </span>
#     </div>
#     34
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       g987669
#      </span>
#      <span class="f3 push-content">
#       : 錢
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:24
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       sa80223
#      </span>
#      <span class="f3 push-content">
#       : 版皇下台
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:24
#      </span>
#     </div>
#     35
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       HandsomeN
#      </span>
#      <span class="f3 push-content">
#       : 板皇下台
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:24
#      </span>
#     </div>
#     36
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       mkncle7836
#      </span>
#      <span class="f3 push-content">
#       : 推
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:25
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       fakm
#      </span>
#      <span class="f3 push-content">
#       : 板皇下台
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:25
#      </span>
#     </div>
#     37
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       gusony
#      </span>
#      <span class="f3 push-content">
#       : 版皇下台
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:25
#      </span>
#     </div>
#     38
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       ghost900713
#      </span>
#      <span class="f3 push-content">
#       : 版皇下台
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:26
#      </span>
#     </div>
#     39
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       JAJ
#      </span>
#      <span class="f3 push-content">
#       : 板皇下台
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:26
#      </span>
#     </div>
#     40
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       brian112233
#      </span>
#      <span class="f3 push-content">
#       : 版黃下台
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:26
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       eric19990726
#      </span>
#      <span class="f3 push-content">
#       : 板皇下台
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:26
#      </span>
#     </div>
#     41
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       nzsrr
#      </span>
#      <span class="f3 push-content">
#       : 推
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:28
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       btim
#      </span>
#      <span class="f3 push-content">
#       : 推推
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:28
#      </span>
#     </div>
#     <div class="push">
#      <span class="f1 hl push-tag">
#       →
#      </span>
#      <span class="f3 hl push-userid">
#       Forthelife
#      </span>
#      <span class="f3 push-content">
#       : 中國人表示一堆推好正常好高興
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:28
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       sondbe
#      </span>
#      <span class="f3 push-content">
#       : 推 耶
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:28
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       btim
#      </span>
#      <span class="f3 push-content">
#       : 板皇下臺
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:29
#      </span>
#     </div>
#     42
#     <div class="push">
#      <span class="f1 hl push-tag">
#       →
#      </span>
#      <span class="f3 hl push-userid">
#       bomo
#      </span>
#      <span class="f3 push-content">
#       : 板皇下台
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:29
#      </span>
#     </div>
#     43
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       abcte
#      </span>
#      <span class="f3 push-content">
#       : ya
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:29
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       bonebonebone
#      </span>
#      <span class="f3 push-content">
#       : 班蝗下台
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:30
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       Coblinant
#      </span>
#      <span class="f3 push-content">
#       : 板皇下台
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:30
#      </span>
#     </div>
#     44
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       x8066397
#      </span>
#      <span class="f3 push-content">
#       :  版皇下台
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:30
#      </span>
#     </div>
#     45
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       jasonJASONle
#      </span>
#      <span class="f3 push-content">
#       : 版皇下台
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:31
#      </span>
#     </div>
#     46
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       joey881023iu
#      </span>
#      <span class="f3 push-content">
#       : 板皇下臺
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:31
#      </span>
#     </div>
#     47
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       zxc881230
#      </span>
#      <span class="f3 push-content">
#       : 板皇下台
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:32
#      </span>
#     </div>
#     48
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       fiegger
#      </span>
#      <span class="f3 push-content">
#       : 推
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:33
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       XXXXHAY
#      </span>
#      <span class="f3 push-content">
#       : 板皇下台
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:33
#      </span>
#     </div>
#     49
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       Nick87061319
#      </span>
#      <span class="f3 push-content">
#       : 我有嗎
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:33
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       pinion0796
#      </span>
#      <span class="f3 push-content">
#       : 板皇下台
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:34
#      </span>
#     </div>
#     50
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       yonggan
#      </span>
#      <span class="f3 push-content">
#       : 下台啦 不要再撐了
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:34
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       Skpiygs
#      </span>
#      <span class="f3 push-content">
#       : 板皇下台
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:34
#      </span>
#     </div>
#     51
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       Ken1843
#      </span>
#      <span class="f3 push-content">
#       : 版皇下台
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:34
#      </span>
#     </div>
#     52
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       ianchen1223
#      </span>
#      <span class="f3 push-content">
#       : 版皇下台
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:35
#      </span>
#     </div>
#     53
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       wwjd198323
#      </span>
#      <span class="f3 push-content">
#       : 推
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:35
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       nonis
#      </span>
#      <span class="f3 push-content">
#       : 下台
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:36
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       kingcatkuo
#      </span>
#      <span class="f3 push-content">
#       : 版皇下台
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:36
#      </span>
#     </div>
#     54
#     <div class="push">
#      <span class="f1 hl push-tag">
#       →
#      </span>
#      <span class="f3 hl push-userid">
#       smallming
#      </span>
#      <span class="f3 push-content">
#       : 版皇下台
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:36
#      </span>
#     </div>
#     55
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       brian36
#      </span>
#      <span class="f3 push-content">
#       : 板皇下台
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:36
#      </span>
#     </div>
#     56
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       karta1616029
#      </span>
#      <span class="f3 push-content">
#       : 版皇下台
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:37
#      </span>
#     </div>
#     57
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       hollytakuma
#      </span>
#      <span class="f3 push-content">
#       : 版皇下台
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:37
#      </span>
#     </div>
#     58
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       rachihwei
#      </span>
#      <span class="f3 push-content">
#       : 板皇下台
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:37
#      </span>
#     </div>
#     59
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       bomo
#      </span>
#      <span class="f3 push-content">
#       : 板皇下台
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:37
#      </span>
#     </div>
#     60
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       qazwsx0123q
#      </span>
#      <span class="f3 push-content">
#       : 版皇下台
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:38
#      </span>
#     </div>
#     61
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       ahfeng718
#      </span>
#      <span class="f3 push-content">
#       : 板皇下台
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:38
#      </span>
#     </div>
#     62
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       lejumple86
#      </span>
#      <span class="f3 push-content">
#       : 版皇下台
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:38
#      </span>
#     </div>
#     63
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       BruceChen227
#      </span>
#      <span class="f3 push-content">
#       : 老婆♥ 版皇下台 滾
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:39
#      </span>
#     </div>
#     64
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       bunnybubu
#      </span>
#      <span class="f3 push-content">
#       : 板皇下台
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:39
#      </span>
#     </div>
#     65
#     <div class="push">
#      <span class="f1 hl push-tag">
#       →
#      </span>
#      <span class="f3 hl push-userid">
#       tom50512
#      </span>
#      <span class="f3 push-content">
#       : 板皇下台
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:39
#      </span>
#     </div>
#     66
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       nonis
#      </span>
#      <span class="f3 push-content">
#       : 版皇下台
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:39
#      </span>
#     </div>
#     67
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       Kevin0821
#      </span>
#      <span class="f3 push-content">
#       : 板皇下台
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:39
#      </span>
#     </div>
#     68
#     <div class="push">
#      <span class="f1 hl push-tag">
#       →
#      </span>
#      <span class="f3 hl push-userid">
#       oramge
#      </span>
#      <span class="f3 push-content">
#       : 版皇下台
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:39
#      </span>
#     </div>
#     69
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       amos30627
#      </span>
#      <span class="f3 push-content">
#       : 版皇下台
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:39
#      </span>
#     </div>
#     70
#     <div class="push">
#      <span class="f1 hl push-tag">
#       →
#      </span>
#      <span class="f3 hl push-userid">
#       timmmit
#      </span>
#      <span class="f3 push-content">
#       : 版皇下台 表特發大財！
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:40
#      </span>
#     </div>
#     71
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       kevin11tw
#      </span>
#      <span class="f3 push-content">
#       : 版皇下台
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:40
#      </span>
#     </div>
#     72
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       qialian
#      </span>
#      <span class="f3 push-content">
#       : 版皇下台
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:41
#      </span>
#     </div>
#     73
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       taesoneyeon
#      </span>
#      <span class="f3 push-content">
#       : 推
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:41
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       a22224738
#      </span>
#      <span class="f3 push-content">
#       : 版皇下台  新垣我婆
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:41
#      </span>
#     </div>
#     74
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       Llind31100
#      </span>
#      <span class="f3 push-content">
#       : 推
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:41
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       eternal04
#      </span>
#      <span class="f3 push-content">
#       : 板皇下台
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:41
#      </span>
#     </div>
#     75
#     <div class="push">
#      <span class="f1 hl push-tag">
#       →
#      </span>
#      <span class="f3 hl push-userid">
#       QQKKQKQK
#      </span>
#      <span class="f3 push-content">
#       : 錢錢
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:42
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       GnilZL
#      </span>
#      <span class="f3 push-content">
#       : 板皇下台
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:42
#      </span>
#     </div>
#     76
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       an4001014
#      </span>
#      <span class="f3 push-content">
#       : 版皇下台
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:42
#      </span>
#     </div>
#     77
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       aoba
#      </span>
#      <span class="f3 push-content">
#       : 錢
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:42
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       ulayeee
#      </span>
#      <span class="f3 push-content">
#       : 版皇下台
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:42
#      </span>
#     </div>
#     78
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       j900802f
#      </span>
#      <span class="f3 push-content">
#       : 版皇下台
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:43
#      </span>
#     </div>
#     79
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       GMQQQ
#      </span>
#      <span class="f3 push-content">
#       : 板皇下台推推
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:43
#      </span>
#     </div>
#     80
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       ageless2233
#      </span>
#      <span class="f3 push-content">
#       : GM不下臺 表特不會好
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:44
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       divineyo
#      </span>
#      <span class="f3 push-content">
#       : 板皇下台
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:44
#      </span>
#     </div>
#     81
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       dodobado
#      </span>
#      <span class="f3 push-content">
#       : 板皇下台
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:44
#      </span>
#     </div>
#     82
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       don323
#      </span>
#      <span class="f3 push-content">
#       : 喔
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:44
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       awaydd0929
#      </span>
#      <span class="f3 push-content">
#       : 板皇下台
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:45
#      </span>
#     </div>
#     83
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       h2872k
#      </span>
#      <span class="f3 push-content">
#       : 板皇下台
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:45
#      </span>
#     </div>
#     84
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       clinder
#      </span>
#      <span class="f3 push-content">
#       : 版皇下台
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:45
#      </span>
#     </div>
#     85
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       fish30705
#      </span>
#      <span class="f3 push-content">
#       : 版皇下台
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:45
#      </span>
#     </div>
#     86
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       zxc89003
#      </span>
#      <span class="f3 push-content">
#       : 推
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:45
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       nagin910
#      </span>
#      <span class="f3 push-content">
#       : 版皇下台
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:45
#      </span>
#     </div>
#     87
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       slowdowner
#      </span>
#      <span class="f3 push-content">
#       : 錢
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:45
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       Bombax43
#      </span>
#      <span class="f3 push-content">
#       : 推
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:46
#      </span>
#     </div>
#     <div class="push">
#      <span class="f1 hl push-tag">
#       →
#      </span>
#      <span class="f3 hl push-userid">
#       jhkujhku
#      </span>
#      <span class="f3 push-content">
#       : 滾去日劇版
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:46
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       don323
#      </span>
#      <span class="f3 push-content">
#       : 板皇下台
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:46
#      </span>
#     </div>
#     88
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       edgerjian
#      </span>
#      <span class="f3 push-content">
#       : 推
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:46
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       twbill
#      </span>
#      <span class="f3 push-content">
#       : 版皇下台
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:48
#      </span>
#     </div>
#     89
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       jhkujhku
#      </span>
#      <span class="f3 push-content">
#       : 版皇下台
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:48
#      </span>
#     </div>
#     90
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       dakekumo7788
#      </span>
#      <span class="f3 push-content">
#       : 結衣推
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:49
#      </span>
#     </div>
#     <div class="push">
#      <span class="f1 hl push-tag">
#       →
#      </span>
#      <span class="f3 hl push-userid">
#       cxz123
#      </span>
#      <span class="f3 push-content">
#       : 版皇下臺
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:49
#      </span>
#     </div>
#     91
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       wenhuanorman
#      </span>
#      <span class="f3 push-content">
#       : 老婆我愛你
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:49
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       Tony818995
#      </span>
#      <span class="f3 push-content">
#       : 推
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:49
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       Leoyao
#      </span>
#      <span class="f3 push-content">
#       : 推
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:49
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       andy055097
#      </span>
#      <span class="f3 push-content">
#       : 板皇下台
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:50
#      </span>
#     </div>
#     92
# 還要上班 板版直接不管了== 各位塊上
#     <span class="f2">
#      ※ 編輯: clbkan (111.242.90.183), 04/27/2019 00:16:40
#     </span>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       qtp010105
#      </span>
#      <span class="f3 push-content">
#       : 推
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:51
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       lin1020
#      </span>
#      <span class="f3 push-content">
#       : 推
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:51
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       musttech
#      </span>
#      <span class="f3 push-content">
#       : 推
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:51
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       cxz123
#      </span>
#      <span class="f3 push-content">
#       : 版皇下臺，標題錯誤。。。
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:51
#      </span>
#     </div>
#     93
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       Asakura091
#      </span>
#      <span class="f3 push-content">
#       : 版皇下台
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:53
#      </span>
#     </div>
#     94
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       celtics1997
#      </span>
#      <span class="f3 push-content">
#       : 板皇下台
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:54
#      </span>
#     </div>
#     95
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       arashi81
#      </span>
#      <span class="f3 push-content">
#       : 有結衣我就推
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:54
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       o20385783
#      </span>
#      <span class="f3 push-content">
#       : 推
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:54
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       az7836507
#      </span>
#      <span class="f3 push-content">
#       : 板皇下台
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:54
#      </span>
#     </div>
#     96
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       ppdogliu
#      </span>
#      <span class="f3 push-content">
#       : 板皇下台
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:57
#      </span>
#     </div>
#     97
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       m0m0112202
#      </span>
#      <span class="f3 push-content">
#       : 版皇下台
#      </span>
#      <span class="push-ipdatetime">
#       04/26 23:58
#      </span>
#     </div>
#     98
#     <div class="push">
#      <span class="f1 hl push-tag">
#       →
#      </span>
#      <span class="f3 hl push-userid">
#       dindaofay
#      </span>
#      <span class="f3 push-content">
#       : 板皇下台
#      </span>
#      <span class="push-ipdatetime">
#       04/27 00:01
#      </span>
#     </div>
#     99
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       unrealman
#      </span>
#      <span class="f3 push-content">
#       : 板皇下台
#      </span>
#      <span class="push-ipdatetime">
#       04/27 00:03
#      </span>
#     </div>
#     100
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       hsu50302
#      </span>
#      <span class="f3 push-content">
#       : 板皇下台
#      </span>
#      <span class="push-ipdatetime">
#       04/27 00:03
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       avalon66
#      </span>
#      <span class="f3 push-content">
#       : 版皇下台
#      </span>
#      <span class="push-ipdatetime">
#       04/27 00:05
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       asdeax08
#      </span>
#      <span class="f3 push-content">
#       : 板皇下台
#      </span>
#      <span class="push-ipdatetime">
#       04/27 00:05
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       paulsama
#      </span>
#      <span class="f3 push-content">
#       : 版皇下台
#      </span>
#      <span class="push-ipdatetime">
#       04/27 00:06
#      </span>
#     </div>
#     <div class="push">
#      <span class="f1 hl push-tag">
#       →
#      </span>
#      <span class="f3 hl push-userid">
#       williamy
#      </span>
#      <span class="f3 push-content">
# ...
#      </span>
#      <span class="push-ipdatetime">
#       04/27 07:10
#      </span>
#     </div>
#     <div class="push">
#      <span class="f1 hl push-tag">
#       →
#      </span>
#      <span class="f3 hl push-userid">
#       zingy
#      </span>
#      <span class="f3 push-content">
#       : 有自省能力的人，早就下台了。
#      </span>
#      <span class="push-ipdatetime">
#       04/27 07:29
#      </span>
#     </div>
#     <div class="push">
#      <span class="f1 hl push-tag">
#       →
#      </span>
#      <span class="f3 hl push-userid">
#       zingy
#      </span>
#      <span class="f3 push-content">
#       : 厚臉皮的人，最難處理。
#      </span>
#      <span class="push-ipdatetime">
#       04/27 07:30
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       comein17
#      </span>
#      <span class="f3 push-content">
#       : 推
#      </span>
#      <span class="push-ipdatetime">
#       04/27 07:40
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       canore
#      </span>
#      <span class="f3 push-content">
#       : 推
#      </span>
#      <span class="push-ipdatetime">
#       04/27 07:48
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       youuuuuli
#      </span>
#      <span class="f3 push-content">
#       : 板皇下台
#      </span>
#      <span class="push-ipdatetime">
#       04/27 08:03
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       PCHiding360
#      </span>
#      <span class="f3 push-content">
#       : 板皇下台
#      </span>
#      <span class="push-ipdatetime">
#       04/27 08:26
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       robert31039
#      </span>
#      <span class="f3 push-content">
#       : 推
#      </span>
#      <span class="push-ipdatetime">
#       04/27 08:33
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       john950146
#      </span>
#      <span class="f3 push-content">
#       : 板皇下台
#      </span>
#      <span class="push-ipdatetime">
#       04/27 08:42
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       yccmygoddess
#      </span>
#      <span class="f3 push-content">
#       : 板皇下台
#      </span>
#      <span class="push-ipdatetime">
#       04/27 08:53
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       neru0616
#      </span>
#      <span class="f3 push-content">
#       : 板皇下台
#      </span>
#      <span class="push-ipdatetime">
#       04/27 08:54
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       murderer
#      </span>
#      <span class="f3 push-content">
#       : 版皇下台
#      </span>
#      <span class="push-ipdatetime">
#       04/27 09:03
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       danny0108
#      </span>
#      <span class="f3 push-content">
#       : 好正
#      </span>
#      <span class="push-ipdatetime">
#       04/27 09:07
#      </span>
#     </div>
#     <div class="push">
#      <span class="f1 hl push-tag">
#       →
#      </span>
#      <span class="f3 hl push-userid">
#       danny0108
#      </span>
#      <span class="f3 push-content">
#       : 老婆我愛你
#      </span>
#      <span class="push-ipdatetime">
#       04/27 09:07
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       papayasoup
#      </span>
#      <span class="f3 push-content">
#       : 板皇下台
#      </span>
#      <span class="push-ipdatetime">
#       04/27 09:12
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       a86710985
#      </span>
#      <span class="f3 push-content">
#       : 板皇下台
#      </span>
#      <span class="push-ipdatetime">
#       04/27 09:13
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       shawnguo
#      </span>
#      <span class="f3 push-content">
#       : 板皇下台
#      </span>
#      <span class="push-ipdatetime">
#       04/27 09:16
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       charlie0810
#      </span>
#      <span class="f3 push-content">
#       : 版皇下台
#      </span>
#      <span class="push-ipdatetime">
#       04/27 09:16
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       jhengsiaomin
#      </span>
#      <span class="f3 push-content">
#       : 版皇下台
#      </span>
#      <span class="push-ipdatetime">
#       04/27 09:17
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       tomedc14
#      </span>
#      <span class="f3 push-content">
#       : 推
#      </span>
#      <span class="push-ipdatetime">
#       04/27 09:25
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       barry86910
#      </span>
#      <span class="f3 push-content">
#       : 版皇下台
#      </span>
#      <span class="push-ipdatetime">
#       04/27 09:29
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       msgm0731
#      </span>
#      <span class="f3 push-content">
#       : 推
#      </span>
#      <span class="push-ipdatetime">
#       04/27 09:31
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       yo199218
#      </span>
#      <span class="f3 push-content">
#       : 推
#      </span>
#      <span class="push-ipdatetime">
#       04/27 09:32
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       liu8908167
#      </span>
#      <span class="f3 push-content">
#       : 錢
#      </span>
#      <span class="push-ipdatetime">
#       04/27 10:08
#      </span>
#     </div>
#     <div class="push">
#      <span class="f1 hl push-tag">
#       →
#      </span>
#      <span class="f3 hl push-userid">
#       yoyo83117
#      </span>
#      <span class="f3 push-content">
#       : 板皇下台
#      </span>
#      <span class="push-ipdatetime">
#       04/27 10:25
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       sky42919
#      </span>
#      <span class="f3 push-content">
#       : 板皇下台
#      </span>
#      <span class="push-ipdatetime">
#       04/27 10:35
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       RexSu
#      </span>
#      <span class="f3 push-content">
#       : 有結衣就是要推
#      </span>
#      <span class="push-ipdatetime">
#       04/27 10:39
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       DuncanChueh
#      </span>
#      <span class="f3 push-content">
#       : 板皇下台
#      </span>
#      <span class="push-ipdatetime">
#       04/27 10:50
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       stonediary30
#      </span>
#      <span class="f3 push-content">
#       : 推推推
#      </span>
#      <span class="push-ipdatetime">
#       04/27 10:52
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       voguish66
#      </span>
#      <span class="f3 push-content">
#       : 推了推了！
#      </span>
#      <span class="push-ipdatetime">
#       04/27 10:59
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       eqaknzy78653
#      </span>
#      <span class="f3 push-content">
#       : 版皇下台
#      </span>
#      <span class="push-ipdatetime">
#       04/27 11:06
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       allenend
#      </span>
#      <span class="f3 push-content">
#       : 板皇下台
#      </span>
#      <span class="push-ipdatetime">
#       04/27 11:18
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       mmmimi11tw
#      </span>
#      <span class="f3 push-content">
#       : 板皇下台
#      </span>
#      <span class="push-ipdatetime">
#       04/27 11:20
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       wei880222
#      </span>
#      <span class="f3 push-content">
#       : 推
#      </span>
#      <span class="push-ipdatetime">
#       04/27 11:43
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       joyboyalan
#      </span>
#      <span class="f3 push-content">
#       : 板皇下台啦
#      </span>
#      <span class="push-ipdatetime">
#       04/27 12:10
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       darin8709
#      </span>
#      <span class="f3 push-content">
#       : 推
#      </span>
#      <span class="push-ipdatetime">
#       04/27 13:00
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       ef1300161
#      </span>
#      <span class="f3 push-content">
#       : 板皇下台
#      </span>
#      <span class="push-ipdatetime">
#       04/27 13:12
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       Olympicss
#      </span>
#      <span class="f3 push-content">
#       : 推
#      </span>
#      <span class="push-ipdatetime">
#       04/27 13:36
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       sample
#      </span>
#      <span class="f3 push-content">
#       : 板皇下台 結衣一生推
#      </span>
#      <span class="push-ipdatetime">
#       04/27 13:43
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       jet0120
#      </span>
#      <span class="f3 push-content">
#       : 推
#      </span>
#      <span class="push-ipdatetime">
#       04/27 14:17
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       Bigwastrel
#      </span>
#      <span class="f3 push-content">
#       : 推
#      </span>
#      <span class="push-ipdatetime">
#       04/27 15:28
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       qq7769912
#      </span>
#      <span class="f3 push-content">
#       : 版皇下台
#      </span>
#      <span class="push-ipdatetime">
#       04/27 16:59
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       ken0103010
#      </span>
#      <span class="f3 push-content">
#       : 版皇下台
#      </span>
#      <span class="push-ipdatetime">
#       04/27 18:29
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       RichardTu
#      </span>
#      <span class="f3 push-content">
#       : 板皇下台
#      </span>
#      <span class="push-ipdatetime">
#       04/27 18:52
#      </span>
#     </div>
#     <div class="push">
#      <span class="f1 hl push-tag">
#       →
#      </span>
#      <span class="f3 hl push-userid">
#       laytomall
#      </span>
#      <span class="f3 push-content">
#       : 沒航航好看 下去
#      </span>
#      <span class="push-ipdatetime">
#       04/28 00:17
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       jack3254
#      </span>
#      <span class="f3 push-content">
#       : 推
#      </span>
#      <span class="push-ipdatetime">
#       04/28 02:07
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       Willy860524
#      </span>
#      <span class="f3 push-content">
#       : 推
#      </span>
#      <span class="push-ipdatetime">
#       04/28 03:13
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       hicochan
#      </span>
#      <span class="f3 push-content">
#       : 推老婆
#      </span>
#      <span class="push-ipdatetime">
#       04/28 10:39
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       michael5567
#      </span>
#      <span class="f3 push-content">
#       : 版皇下台
#      </span>
#      <span class="push-ipdatetime">
#       04/28 15:03
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       john60111
#      </span>
#      <span class="f3 push-content">
#       : 推個
#      </span>
#      <span class="push-ipdatetime">
#       223.136.174.185 04/29 10:17
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       halfgodhsiao
#      </span>
#      <span class="f3 push-content">
#       : 板皇下台
#      </span>
#      <span class="push-ipdatetime">
#       27.247.100.211 04/29 22:08
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       jason81305
#      </span>
#      <span class="f3 push-content">
#       : 推
#      </span>
#      <span class="push-ipdatetime">
#       101.15.172.81 05/01 14:26
#      </span>
#     </div>
#    </div>
#    <div data-longpollurl="/v1/longpoll?id=300da9ab8cd8284ed8ddc8e3db2735cedcfc27d7" data-offset="34228" data-pollurl="/poll/Beauty/M.1556291059.A.75A.html?cacheKey=2084-620769729&amp;offset=34228&amp;offset-sig=a25b73bb8b2a7f4fc09b072561f97b35cabaee9b" id="article-polling">
#    </div>
#    <div class="bbs-screen bbs-footer-message">
#     本網站已依台灣網站內容分級規定處理。此區域為限制級，未滿十八歲者不得瀏覽。
#    </div>
#   </div>
#   <script>
#    (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-32365737-1', {
#     cookieDomain: 'ptt.cc',
#     legacyCookieDomain: 'ptt.cc'
#   });
#   ga('send', 'pageview');
#   </script>
#   <script src="//ajax.googleapis.com/ajax/libs/jquery/2.1.1/jquery.min.js">
#   </script>
#   <script src="//images.ptt.cc/bbs/v2.27/bbs.js">
#   </script>
#   <script type="text/javascript">
#    (function(){window['__CF$cv$params']={r:'59cfdfe67fa7338f',m:'05ad0b01f8607c5d1663dc8bf54eb721ef1afcdc-1591087279-1800-AeQNO1N49zoBPNe5aEOucW1Kupohr625uDXR5T1i81giQNSEa1hRR5UXKx+ipjFEM/kHUr26+W0u4dcMuPyK1Eh8yRlmXg/iL38F1n7+zjqLYlTZmWDYH9b4pOToQESAS7XvEvvFjOol8baw9CymwmHPLpTsOdmXXgdwpIf5+iiu',s:[0x8d0da428c2,0xfeb667ccbb],}})();
#   </script>
#  </body>
# </html>

# %%
# 決定要儲存的資料夾
output_dir = 'downloads'

# 假如資料夾不存在就新增一個資料夾
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# 定位所有圖片的 tag，recursive=False 表示不會再往下找次節點，這個例子是還有下一層的 'a'，導致會多下載一次圖片
image_tags = soup.find('div', {'id':'main-content'}).find_all('a', recursive=False)

for img_tag in image_tags:
    #print(img_tag)
    # 取得所有圖片在第三方服務的 id
    if 'imgur' not in img_tag['href']:
        continue
    img_id = img_tag['href'].split('/')[-1]
    
    # 組合圖片而非網站的網址
    img_url = 'https://i.imgur.com/{}.jpg'.format(img_id)

    # 對圖片送出請求
    with requests.get(img_url, stream=True) as r:
        r.raise_for_status()
        img = Image.open(r.raw)
        img_savename = '{}/{}.{}'.format(output_dir, img_id, img.format.lower())
        img.save(img_savename)
        print('Save image {}'.format(img_savename))
# Out:
# Save image downloads/Cgb5oo1.jpeg
# Save image downloads/MgjHY4f.jpeg
# Save image downloads/yeoRtAs.jpeg
# Save image downloads/wsauNEW.jpeg
# Save image downloads/IjiETcs.jpeg
